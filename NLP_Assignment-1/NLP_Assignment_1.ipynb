# %%
from collections import Counter

# %% [markdown]
# ### 1. Write a function that calculates the unigram probability of a word appearing in some corpus.

# %%
def unigramProbability(word, count_table):
  count = count_table[word]
  N = len(count_table)
  return count / N

# %% [markdown]
# ### Importing all the required corpus

# %%
import nltk
nltk.download("brown")
nltk.download("webtext")
nltk.download("reuters")
nltk.download("punkt_tab")
from nltk.corpus import brown, webtext, reuters
brown_corpus = brown.sents()
brown_corpus = [" ".join(sentence) for sentence in brown_corpus]
brown_corpus = ["<s> " + sentence + " </s>" for sentence in brown_corpus][:5000]
webtext_corpus = webtext.sents()
webtext_corpus = [" ".join(sentence) for sentence in webtext_corpus]
webtext_corpus = ["<s> " + sentence + " </s>" for sentence in webtext_corpus][:5000]
reuters_corpus = reuters.sents()
reuters_corpus = [" ".join(sentence) for sentence in reuters_corpus]
reuters_corpus = ["<s> " + sentence + " </s>" for sentence in reuters_corpus][:5000]
# Out:
# [nltk_data] Downloading package brown to /root/nltk_data...
# [nltk_data]   Package brown is already up-to-date!
# [nltk_data] Downloading package webtext to /root/nltk_data...
# [nltk_data]   Package webtext is already up-to-date!
# [nltk_data] Downloading package reuters to /root/nltk_data...
# [nltk_data]   Package reuters is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!

# %% [markdown]
# ### Calculate V : unique words in vocabulary

# %%
def getUniqueWordsCountInVocab(corpus):
  tokens = set()

  for i in range(len(corpus)):
    temp = corpus[i].split()
    for t in temp:
      tokens.add(t)

  V = len(tokens)
  return(V)

# %%
V_brown = getUniqueWordsCountInVocab(brown_corpus)
print(V_brown)
V_webtext = getUniqueWordsCountInVocab(webtext_corpus)
print(V_webtext)
# Out:
# 15086
# 11379

# %% [markdown]
# ### Tokenize words of given corpus and store word count

# %%
def tokenizeCorpus(corpus):
  tokens = []
  for i in range(len(corpus)):
    temp = corpus[i].split()
    for t in temp:
      tokens.append(t)
  return tokens

# %%
brown_tokens = tokenizeCorpus(brown_corpus)
brown_wc = Counter(brown_tokens) # this the word count of brown corpus

print(brown_tokens)
print(brown_wc)

webtext_tokens = tokenizeCorpus(webtext_corpus)
webtext_wc = Counter(webtext_tokens) # this the word count of webtext corpus

print(webtext_tokens)
print(webtext_wc)
# Out:
# ['<s>', 'The', 'Fulton', 'County', 'Grand', 'Jury', 'said', 'Friday', 'an', 'investigation', 'of', "Atlanta's", 'recent', 'primary', 'election', 'produced', '``', 'no', 'evidence', "''", 'that', 'any', 'irregularities', 'took', 'place', '.', '</s>', '<s>', 'The', 'jury', 'further', 'said', 'in', 'term-end', 'presentments', 'that', 'the', 'City', 'Executive', 'Committee', ',', 'which', 'had', 'over-all', 'charge', 'of', 'the', 'election', ',', '``', 'deserves', 'the', 'praise', 'and', 'thanks', 'of', 'the', 'City', 'of', 'Atlanta', "''", 'for', 'the', 'manner', 'in', 'which', 'the', 'election', 'was', 'conducted', '.', '</s>', '<s>', 'The', 'September-October', 'term', 'jury', 'had', 'been', 'charged', 'by', 'Fulton', 'Superior', 'Court', 'Judge', 'Durwood', 'Pye', 'to', 'investigate', 'reports', 'of', 'possible', '``', 'irregularities', "''", 'in', 'the', 'hard-fought', 'primary', 'which', 'was', 'won', 'by', 'Mayor-nominate', 'Ivan', 'Allen', 'Jr.', '.', '</s>', '<s>', '``', 'Only', 'a', 'relative', 'handful', 'of', 'such', 'reports', 'was', 'received', "''", ',', 'the', 'jury', 'said', ',', '``', 'considering', 'the', 'widespread', 'interest', 'in', 'the', 'election', ',', 'the', 'number', 'of', 'voters', 'and', 'the', 'size', 'of', 'this', 'city', "''", '.', '</s>', '<s>', 'The', 'jury', 'said', 'it', 'did', 'find', 'that', 'many', 'of', "Georgia's", 'registration', 'and', 'election', 'laws', '``', 'are', 'outmoded', 'or', 'inadequate', 'and', 'often', 'ambiguous', "''", '.', '</s>', '<s>', 'It', 'recommended', 'that', 'Fulton', 'legislators', 'act', '``', 'to', 'have', 'these', 'laws', 'studied', 'and', 'revised', 'to', 'the', 'end', 'of', 'modernizing', 'and', 'improving', 'them', "''", '.', '</s>', '<s>', 'The', 'grand', 'jury', 'commented', 'on', 'a', 'number', 'of', 'other', 'topics', ',', 'among', 'them', 'the', 'Atlanta', 'and', 'Fulton', 'County', 'purchasing', 'departments', 'which', 'it', 'said', '``', 'are', 'well', 'operated', 'and', 'follow', 'generally', 'accepted', 'practices', 'which', 'inure', 'to', 'the', 'best', 'interest', 'of', 'both', 'governments', "''", '.', '</s>', '<s>', 'Merger', 'proposed', '</s>', '<s>', 'However', ',', 'the', 'jury', 'said', 'it', 'believes', '``', 'these', 'two', 'offices', 'should', 'be', 'combined', 'to', 'achieve', 'greater', 'efficiency', 'and', 'reduce', 'the', 'cost', 'of', 'administration', "''", '.', '</s>', '<s>', 'The', 'City', 'Purchasing', 'Department', ',', 'the', 'jury', 'said', ',', '``', 'is', 'lacking', 'in', 'experienced', 'clerical', 'personnel', 'as', 'a', 'result', 'of', 'city', 'personnel', 'policies', "''", '.', '</s>', '<s>', 'It', 'urged', 'that', 'the', 'city', '``', 'take', 'steps', 'to', 'remedy', "''", 'this', 'problem', '.', '</s>', '<s>', 'Implementation', 'of', "Georgia's", 'automobile', 'title', 'law', 'was', 'also', 'recommended', 'by', 'the', 'outgoing', 'jury', '.', '</s>', '<s>', 'It', 'urged', 'that', 'the', 'next', 'Legislature', '``', 'provide', 'enabling', 'funds', 'and', 're-set', 'the', 'effective', 'date', 'so', 'that', 'an', 'orderly', 'implementation', 'of', 'the', 'law', 'may', 'be', 'effected', "''", '.', '</s>', '<s>', 'The', 'grand', 'jury', 'took', 'a', 'swipe', 'at', 'the', 'State', 'Welfare', "Department's", 'handling', 'of', 'federal', 'funds', 'granted', 'for', 'child', 'welfare', 'services', 'in', 'foster', 'homes', '.', '</s>', '<s>', '``', 'This', 'is', 'one', 'of', 'the', 'major', 'items', 'in', 'the', 'Fulton', 'County', 'general', 'assistance', 'program', "''", ',', 'the', 'jury', 'said', ',', 'but', 'the', 'State', 'Welfare', 'Department', '``', 'has', 'seen', 'fit', 'to', 'distribute', 'these', 'funds', 'through', 'the', 'welfare', 'departments', 'of', 'all', 'the', 'counties', 'in', 'the', 'state', 'with', 'the', 'exception', 'of', 'Fulton', 'County', ',', 'which', 'receives', 'none', 'of', 'this', 'money', '.', '</s>', '<s>', 'The', 'jurors', 'said', 'they', 'realize', '``', 'a', 'proportionate', 'distribution',  ...
# Counter({'the': 6058, ',': 5506, '<s>': 5000, '</s>': 5000, '.': 4373, 'of': 3128, 'and': 2326, 'to': 2311, 'a': 2138, 'in': 2017, 'for': 1023, 'The': 888, 'that': 881, 'is': 825, 'was': 793, '``': 767, "''": 736, 'on': 704, 'at': 618, 'with': 607, 'be': 582, 'by': 536, 'as': 528, 'he': 490, 'his': 449, 'it': 425, 'will': 421, 'said': 408, 'from': 372, 'are': 354, 'has': 341, 'an': 329, ';': 318, '--': 313, 'had': 303, 'have': 302, 'not': 300, 'who': 292, 'this': 279, 'would': 272, 'which': 269, 'were': 260, 'Mrs.': 253, 'been': 241, 'their': 234, 'they': 223, 'He': 212, 'one': 202, 'its': 199, 'or': 197, 'but': 197, 'Mr.': 196, 'more': 189, 'I': 180, 'all': 176, ')': 175, 'up': 174, 'out': 173, '(': 172, 'last': 169, 'two': 167, 'other': 166, 'new': 158, 'than': 153, ':': 152, 'year': 150, 'A': 147, 'first': 146, 'about': 145, 'there': 138, 'when': 137, 'In': 135, 'after': 132, 'It': 131, 'into': 130, 'home': 129, 'But': 126, 'also': 123, 'over': 121, 'no': 120, 'made': 116, 'some': 115, 'only': 114, 'time': 109, 'years': 108, 'can': 108, 'him': 106, '?': 106, 'them': 105, 'state': 104, 'any': 103, 'her': 103, 'three': 99, 'New': 99, 'President': 94, 'before': 91, 'now': 91, 'could': 91, 'what': 90, 'week': 90, 'we': 89, 'under': 87, 'American': 86, 'against': 83, 'House': 82, 'such': 81, 'man': 81, 'most': 80, 'if': 79, 'off': 77, 'members': 77, 'so': 76, 'This': 76, 'four': 75, 'United': 74, 'do': 73, 'back': 73, 'per': 73, 'may': 72, 'here': 72, 'Kennedy': 72, 'program': 70, 'work': 70, 'get': 70, 'State': 69, 'good': 69, 'those': 69, 'should': 68, 'John': 68, 'did': 66, 'since': 66, 'school': 66, 'They': 65, 'day': 65, 'government': 65, 'many': 64, 'these': 64, 'night': 64, 'meeting': 64, 'each': 63, 'where': 63, 'There': 63, 'because': 63, 'public': 62, 'our': 61, 'both': 59, 'must': 59, 'U.S.': 59, 'even': 59, 'being': 58, 'then': 58, 'Washington': 58, 'you': 58, 'during': 58, 'through': 57, 'people': 57, 'much': 57, 'cent': 56, 'tax': 56, 'yesterday': 56, 'York': 56, 'today': 56, 'city': 55, 'administration': 55, 'down': 55, 'president': 55, 'Monday': 54, 'told': 53, 'high': 53, 'without': 53, 'men': 53, 'car': 53, 'sales': 52, 'between': 52, 'game': 52, 'Sunday': 51, 'set': 51, 'own': 51, 'take': 50, 'make': 50, 'like': 50, 'board': 50, 'way': 50, 'States': 50, 'took': 49, 'well': 49, 'system': 49, 'too': 49, 'Dallas': 49, '1': 48, 'Texas': 48, 'million': 48, 'City': 47, 'law': 47, 'might': 47, 'long': 47, 'bill': 47, 'Laos': 47, 'world': 47, 'Jr.': 46, 'plan': 46, 'go': 46, 'just': 46, "'": 46, 'National': 46, 'Miss': 46, 'Mantle': 46, 'got': 45, 'children': 45, 'months': 45, 'And': 45, 'jury': 44, 'next': 44, 'expected': 44, 'business': 44, 'St.': 44, 'Tuesday': 43, 'When': 43, '1961': 43, 'session': 43, 'left': 43, 'special': 43, 'Dr.': 43, 'University': 43, 'while': 43, 'area': 43, 'came': 43, 'company': 43, 'season': 43, 'committee': 42, 'J.': 42, 'group': 42, 'same': 42, 'she': 42, 'play': 42, 'Palmer': 42, 'Friday': 41, 'election': 41, 'held': 41, 'party': 41, 'schools': 41, 'five': 41, 'big': 41, 'family': 41, 'another': 41, 'record': 41, 'never': 41, 'problem': 40, 'given': 40, 'As': 40, 'local': 40, 'still': 40, 'White': 40, 'how': 40, 'At': 40, 'S.': 40, 'County': 39, 'past': 39, 'see': 39, 'days': 39, 'went': 39, 'little': 39, 'third': 39, 'case': 39, 'service': 39, 'W.': 38, 'however': 38, 'Democratic': 38, 'A.': 38, 'right': 38, 'early': 38, '!': 38, '1960': 38, 'began': 38, 'p.m.': 38, 'Committee': 37, 'federal': 37, 'William': 37, 'announced': 37, 'James': 37, 'Senate': 37, 'March': 37, 'West': 37, 'called': 37, '10': 37, 'use': 37, 'young': 37, 'ago': 37, 'military': 37, 'Congo': 37, 'run': 36, 'chairman': 36, 'vote': 36, 'several': 36, 'later': 36, 'firm': 36, 'second': 36, 'Maris': 36, 'received': 35, 'political': 35, '2': 35, 'wife': 35, 'asked': 35, 'issue': 35, 'very': 35, 'If': 35, '&': 35, 'along': 35, 'Soviet': 35, 'far': 35, 'member': 35, 'She': 35, 'money': 34, 'added': 34, 'On': 34, 'E.': 3 ...
# ['<s>', 'Cookie', 'Manager', ':', '"', 'Don', "'", 't', 'allow', 'sites', 'that', 'set', 'removed', 'cookies', 'to', 'set', 'future', 'cookies', '"', 'should', 'stay', 'checked', 'When', 'in', 'full', 'screen', 'mode', 'Pressing', 'Ctrl', '-', 'N', 'should', 'open', 'a', 'new', 'browser', 'when', 'only', 'download', 'dialog', 'is', 'left', 'open', 'add', 'icons', 'to', 'context', 'menu', 'So', 'called', '"', 'tab', 'bar', '"', 'should', 'be', 'made', 'a', 'proper', 'toolbar', 'or', 'given', 'the', 'ability', 'collapse', '/', 'expand', '.', '</s>', '<s>', '[', 'XUL', ']', 'Implement', 'Cocoa', '-', 'style', 'toolbar', 'customization', '.', '</s>', '<s>', '#', 'ifdefs', 'for', 'MOZ_PHOENIX', 'customize', 'dialog', "'", 's', 'toolbar', 'has', 'small', 'icons', 'when', 'small', 'icons', 'is', 'not', 'checked', 'nightly', 'builds', 'and', 'tinderboxen', 'for', 'Phoenix', 'finish', 'tearing', 'prefs', 'UI', 'to', 'pieces', 'and', 'then', 'make', 'it', 'not', 'suck', '"', 'mozbrowser', '"', 'script', 'doesn', "'", 't', 'start', 'correct', 'binary', 'Need', 'bookmark', 'groups', 'icon', 'Dropping', 'at', 'top', 'of', 'palette', 'box', 'horks', 'things', 'keyboard', 'shortcut', 'for', 'Increase', 'Text', 'Size', 'is', 'broken', 'default', 'phoenix', 'bookmarks', '[', 'cust', ']', 'need', 'a', 'toolbar', 'spacer', 'and', 'spring', 'spacer', 'for', 'customize', 'Can', "'", 't', 'launch', 'phoenix', 'while', 'Mozilla', 'is', 'running', '(', 'or', 'vice', 'versa', ')', 'separator', 'not', 'available', 'when', 'all', 'toolbar', 'items', 'are', 'in', 'toolbar', 'layout', 'history', 'menu', 'for', 'the', 'back', 'buttons', 'doesn', "'", 't', 'work', 'attempting', 'to', 'open', '"', 'back', 'button', 'history', 'menu', '"', 'in', 'the', 'second', 'window', 'generates', 'another', 'back', 'button', 'on', 'the', 'toolbar', 'Phoenix', 'and', 'Mozilla', 'cannot', 'comfortably', 'share', 'a', 'source', 'tree', 'Phoenix', 'forgets', 'all', 'cookies', 'even', 'though', '"', 'Enable', 'cookies', 'for', 'the', 'current', 'session', 'only', '"', 'is', 'NOT', 'chosen', 'Starting', 'Customizing', 'Toolbar', 'makes', 'the', 'current', 'page', 'go', 'blank', 'Check', 'in', 'Satchel', '(', 'the', 'successor', 'to', 'wallet', ')', 'Mousing', 'over', 'back', 'menu', 'in', 'second', 'window', 'horks', 'things', 'Personal', 'toolbar', 'needs', 'a', 'min', '-', 'height', 'to', 'avoid', '"', 'popping', 'in', '"', 'New', 'Folder', '...', 'in', 'ptoolbar', 'context', 'menu', 'is', 'broken', 'Implement', 'Mozilla', 'Firebird', 'Help', 'tabs', 'close', 'in', 'the', 'wrong', 'order', '(', 'right', 'to', 'left', ')', 'back', 'buttons', 'and', 'context', 'options', 'always', 'disabled', '.', '</s>', '<s>', 'Customising', 'toolbar', 'breaks', 'the', 'throbber', '!', '</s>', '<s>', 'manage', 'bookmarks', 'causes', 'hang', 'land', 'pch', "'", 's', 'bookmarks', 'patch', 'from', 'bug', '160019', 'Preferences', '>', 'Privacy', '>', 'Images', '==', 'Wonky', 'Extremely', 'high', 'memory', 'consumption', 'after', 'closing', 'all', 'windows', 'with', 'Quick', 'Launch', '(', 'Turbo', ')', 'enabled', 'Go', 'menu', 'needs', 'to', 'have', 'an', 'id', '=', 'implement', 'progress', 'meter', 'in', 'URLbar', 'view', 'source', 'tries', 'to', 'download', 'type', 'application', 'x', '-', 'view', '-', 'source', 'from', 'view', '-', 'source', ':<', 'url', '>', 'second', 'window', 'opens', 'mozilla', 'fix', 'branding', 'auto', 'close', 'for', 'download', 'manager', 'would', 'be', 'nice', 'Components', 'of', 'the', 'Navigation', 'Toolbar', 'do', 'not', 'appear', 'with', 'the', 'Modern', 'theme', '.', '</s>', '<s>', 'Pop', 'up', 'window', 'blocking', 'Uabar', 'doesn', "'", 't', 'work', 'Theme', 'changes', 'will', 'take', 'effect', 'when', 'you', 'restart', '_Mozilla_', '.', '</s>', '<s>', 'Need', 'large', 'icons', 'for', 'the', 'Options', 'menu', 'Enable', 'images', 'cannot', 'be', 'used', 'to', 'disable', 'the', 'display', 'of', 'images', '.', '</s>', '<s>', 'The', 'bookmark', 'tree', 'jumps', ' ...
# Counter({'<s>': 5000, '</s>': 5000, '.': 4432, ':': 2902, "'": 2795, 'to': 2630, 'the': 2456, 'in': 2424, '"': 2039, 'a': 1703, ',': 1672, 'not': 1611, '-': 1505, 'on': 1408, 'when': 1306, 't': 1297, 'is': 1284, 'I': 1271, 'and': 1221, 'of': 1176, '!': 1147, 'for': 832, 'with': 784, '(': 776, 'you': 739, 'page': 719, '?': 682, ')': 645, 'does': 615, 'window': 611, 's': 608, 'Firefox': 602, 'from': 562, 'it': 540, '#': 524, ']': 501, 'should': 490, 'open': 486, 'be': 483, '[': 475, 'doesn': 470, '1': 470, 'menu': 462, 'bar': 459, 'tab': 456, 'after': 453, 'if': 453, 'Firebird': 437, 'new': 436, 'that': 433, 'work': 430, 'browser': 392, 'are': 391, '0': 376, 'no': 372, 'as': 370, 'up': 366, 'toolbar': 364, 'button': 363, 'bookmarks': 352, 'dialog': 330, 'bookmark': 329, '...': 329, 'this': 319, 'or': 318, 'have': 315, 'file': 315, 'URL': 304, '2': 303, 'download': 297, 'all': 297, 'crashes': 291, 'can': 287, 'text': 279, 'crash': 262, 'my': 258, 'click': 253, 'tabs': 246, 'Bookmarks': 245, 'an': 244, 'link': 244, 'at': 243, 'No': 241, 'Guy': 241, 'don': 239, 'like': 239, '/': 237, 'firefox': 236, 'manager': 230, 'ARTHUR': 225, '+': 224, 'using': 224, 'do': 222, 'Mozilla': 220, 'default': 217, 'The': 214, 'error': 214, 'me': 210, 'You': 209, 'by': 205, 'right': 204, 'search': 198, 'clicking': 198, 'windows': 196, 'folder': 193, 'Phoenix': 186, 'Girl': 182, 'icon': 180, 'Manager': 179, '--': 178, 'one': 175, 'your': 174, 'about': 174, 'has': 173, 'but': 173, 'only': 172, 'site': 170, 'down': 169, 'use': 163, 'files': 163, 'Page': 163, 'fails': 162, 'was': 162, 'Oh': 162, 'causes': 161, 'close': 160, 'out': 160, 'm': 159, 'opening': 158, 'Toolbar': 154, 'will': 154, 'some': 154, 'Add': 153, 'back': 152, 'Bookmark': 152, 'just': 149, 'guy': 149, 'display': 148, 'When': 145, 'theme': 145, '9': 145, 'box': 144, 'Download': 144, 'pages': 142, 'get': 142, 'Can': 140, 'firebird': 140, 'while': 139, 'url': 136, 'into': 135, 'image': 134, 'links': 134, 'cannot': 133, 'location': 132, 're': 132, 'Crash': 130, 'option': 130, 'scroll': 129, 'load': 128, 'What': 128, 'start': 127, 'Options': 127, 'address': 127, '>': 126, 'know': 126, 'password': 124, 'show': 124, 'com': 124, '->': 122, 'extension': 122, 'install': 122, 'wrong': 121, 'history': 120, 'buttons': 120, 'too': 120, 'girl': 120, 'go': 119, 'loading': 119, 'form': 119, 'so': 119, 'instead': 119, 'any': 119, 'web': 118, 'time': 117, 'It': 117, 'build': 116, 'mouse': 115, 'sidebar': 114, 'focus': 113, 'they': 113, 'broken': 112, 'New': 112, 'http': 112, '://': 112, 'set': 111, 'other': 110, ';': 110, 'Windows': 109, 'popup': 109, 'change': 108, 'drop': 108, 'he': 108, 'icons': 106, 'opens': 106, '8': 106, 'we': 105, 'context': 104, 'what': 104, 'over': 103, 'missing': 103, 'autocomplete': 103, 'working': 103, 'there': 103, 'save': 103, 'screen': 102, 'preferences': 102, 'off': 102, 'name': 102, 'Open': 100, 'first': 99, 'trying': 98, 'field': 97, 'print': 97, 'Ctrl': 96, 'profile': 96, 'images': 95, 'options': 94, 'mozilla': 94, 'Yeah': 94, 'add': 93, 'Find': 93, 'Browser': 92, 'list': 92, 'startup': 92, 'A': 91, 'size': 91, 'javascript': 91, 'opened': 91, 'left': 90, 'going': 90, 'won': 89, 'type': 88, 'user': 88, 'even': 87, 'always': 87, 'i': 86, 'That': 86, 'then': 85, '<': 85, 'extensions': 85, 'We': 85, 'And': 85, 'shows': 84, 'displayed': 84, 'multiple': 83, 'Save': 83, 'make': 82, 'phoenix': 82, 'more': 82, 'selected': 82, 'Well': 82, 'Cannot': 81, 'properly': 81, 'her': 80, 'appears': 79, 'X': 79, 'view': 78, 'same': 78, 'Error': 78, 'than': 78, 'find': 77, 'correctly': 77, 'hangs': 76, 'Man': 76, 'LAUNCELOT': 76, 'Chick': 76, 'item': 75, 'appear': 74, 'home': 74, 'background': 74, '3': 73, 'menus': 73, 'got': 73, 'He': 73, 'UI': 72, 'without': 72, 'directory': 72, 'input': 72, 'application': 71, 'message': 71, 'middle': 70, 'themes': 70, 'version': 70, 'last': 70, 'line': 70, 'blank': 69, 'them': 69, 'see': 69, 'GALAHAD': 69, 'used': 68, 'non': 68, 'View': 68, 'Web': 68, 'www ...

# %% [markdown]
# ### Create Bigrams: Write a function that finds all bigrams in a sentence and returns them as a list of tuples.

# %%
def create_bigrams(corpus):
  bigrams = []
  corpus = list(corpus)
  for i in range(len(corpus)-1):
    bigrams.append((corpus[i], corpus[i+1])) # appends tuples to list

  # print(bigrams)
  return bigrams

# %% [markdown]
# ### Conditional Probability (BIGRAMS):

# %% [markdown]
# Write a function that calculates the conditional probability of a particular word given some previous word and a list of bigram tuples. This should be done using Laplace Smoothing
#
#
# I have maintained a map (cp) to store calculated values of conditional probabilities for later use

# %%
def conditional_probability(word1, word2, bigrams_wc, corpus_wc, V):
  count_w1w2 = bigrams_wc[(word1, word2)]
  count_w1 = corpus_wc[word1]
  return (count_w1w2+1) / (count_w1 + V) #Laplace smoothing

# %%
#For brown corpus
bgrams_brown = create_bigrams(brown_tokens)
bgrams_brown_wc = Counter(bgrams_brown)

# %%
cp_brown = {} # cp_brown -> map of conditional probabilities of bigrams

for i in bgrams_brown:
  cp_brown[i] = conditional_probability(i[0], i[1], bgrams_brown_wc, brown_wc, V_brown)

# %%
cp_brown
# Out:
# {('<s>', 'The'): 0.04027680971821169,
#  ('The', 'Fulton'): 0.000125203455615375,
#  ('Fulton', 'County'): 0.00046357615894039735,
#  ('County', 'Grand'): 0.0001322314049586777,
#  ('Grand', 'Jury'): 0.00019878081102570898,
#  ('Jury', 'said'): 0.0001325556733828208,
#  ('said', 'Friday'): 0.00032270556344391377,
#  ('Friday', 'an'): 0.00013221392212599986,
#  ('an', 'investigation'): 0.0003243593902043464,
#  ('investigation', 'of'): 0.0003312355084465055,
#  ('of', "Atlanta's"): 0.00010980564401010212,
#  ("Atlanta's", 'recent'): 0.0001325381047051027,
#  ('recent', 'primary'): 0.00013236267372600927,
#  ('primary', 'election'): 0.00019863603257630935,
#  ('election', 'produced'): 0.00013221392212599986,
#  ('produced', '``'): 0.00013252054068380598,
#  ('``', 'no'): 0.00012615908660821296,
#  ('no', 'evidence'): 0.00019729054320662896,
#  ('evidence', "''"): 0.00019859658413875282,
#  ("''", 'that'): 0.0002528125395019593,
#  ('that', 'any'): 0.00031314586334314526,
#  ('any', 'irregularities'): 0.00013167423793534794,
#  ('irregularities', 'took'): 0.00013254688846179335,
#  ('took', 'place'): 0.0003303600925008259,
#  ('place', '.'): 0.000661769571835087,
#  ('.', '</s>'): 0.22478030731281154,
#  ('</s>', '<s>'): 0.24892960270835407,
#  ('The', 'jury'): 0.0006260172780768749,
#  ('jury', 'further'): 0.00013218770654329148,
#  ('further', 'said'): 0.0001986491855383393,
#  ('said', 'in'): 0.00045178778882147926,
#  ('in', 'term-end'): 0.00011693854879260948,
#  ('term-end', 'presentments'): 0.00013256445946841652,
#  ('presentments', 'that'): 0.00013256445946841652,
#  ('that', 'the'): 0.009644892590968873,
#  ('the', 'City'): 0.0002364737041241014,
#  ('City', 'Executive'): 0.00013216150135465538,
#  ('Executive', 'Committee'): 0.00019878081102570898,
#  ('Committee', ','): 0.000528995569662104,
#  (',', 'which'): 0.003690753690753691,
#  ('which', 'had'): 0.0005210029306414849,
#  ('had', 'over-all'): 0.00012996296055624147,
#  ('over-all', 'charge'): 0.0001325556733828208,
#  ('charge', 'of'): 0.0006621201085876978,
#  ('of', 'the'): 0.05023608213462172,
#  ('the', 'election'): 0.0005675368898978433,
#  ('election', ','): 0.0003966417663779996,
#  (',', '``'): 0.004856254856254856,
#  ('``', 'deserves'): 0.00012615908660821296,
#  ('deserves', 'the'): 0.00013254688846179335,
#  ('the', 'praise'): 9.458948164964057e-05,
#  ('praise', 'and'): 0.00013254688846179335,
#  ('and', 'thanks'): 0.00011486331265793706,
#  ('thanks', 'of'): 0.00013252054068380598,
#  ('City', 'of'): 0.00026432300270931076,
#  ('of', 'Atlanta'): 0.0003843197540353574,
#  ('Atlanta', "''"): 0.00013245033112582781,
#  ("''", 'for'): 0.0002528125395019593,
#  ('for', 'the'): 0.014774349742380037,
#  ('the', 'manner'): 0.00018917896329928113,
#  ('manner', 'in'): 0.00019875447197561946,
#  ('in', 'which'): 0.0013447933111150091,
#  ('which', 'the'): 0.0017583848909150115,
#  ('election', 'was'): 0.0001983208831889998,
#  ('was', 'conducted'): 0.00012595251590150514,
#  ('conducted', '.'): 0.00013250298131707962,
#  ('The', 'September-October'): 0.000125203455615375,
#  ('September-October', 'term'): 0.00013256445946841652,
#  ('term', 'jury'): 0.00013245033112582781,
#  ('jury', 'had'): 0.00013218770654329148,
#  ('had', 'been'): 0.003444018454740399,
#  ('been', 'charged'): 0.00013048868010700072,
#  ('charged', 'by'): 0.00013246787653993907,
#  ('by', 'Fulton'): 0.00012802458071949814,
#  ('Fulton', 'Superior'): 0.00019867549668874172,
#  ('Superior', 'Court'): 0.00039758796633755216,
#  ('Court', 'Judge'): 0.00013234515616728428,
#  ('Judge', 'Durwood'): 0.00013232764324467382,
#  ('Durwood', 'Pye'): 0.00013256445946841652,
#  ('Pye', 'to'): 0.00013256445946841652,
#  ('to', 'investigate'): 0.00022992469966086107,
#  ('investigate', 'reports'): 0.00013254688846179335,
#  ('reports', 'of'): 0.0003311696913498477,
#  ('of', 'possible'): 0.00010980564401010212,
#  ('possible', '``'): 0.00013231013495633765,
#  ('``', 'irregularities'): 0.00012615908660821296,
#  ('irregularities', "''"): 0.00013254688846179335,
#  ("''", 'in'): 0.0005056250790039186,
#  ('in', 'the'): 0.034555341168216104,
#  ('the', 'hard-fought'): 9.458948164964057e-05,
#  ('hard-fought', 'primary'): 0.00013256445946841652,
#  ('primary', 'which'): 0.00013242402171753957,
#  ('which', 'was'): 0.0006512536633018561,
#  ('was', 'won'): 0.0001889287738522577,
#  ('won', 'by'): 0.00026469031233456857,
#  ('by', 'Mayor-nominate'): 0.00012802458071949814,
#  ('Mayor-nominate', 'Ivan'): 0.00013256445946841652,
#  ('Ivan', 'Allen'): 0.00019883351007423118,
#  ('Allen', 'Jr.'): 0.00019876764062810574,
#  ('Jr.', '.'): 0.0002643404705260375,
#  ('<s>', '``'): 0.01403962959275117,
#  ('``', 'Only'): 0.00012615908660821296,
#  ('Only', 'a'): 0.00019874130506790329,
#  ('a', 'relative'): 0.00011611704598235021,
#  ('relative', 'handful'): 0.0001325381047051027,
#  ('handful', 'of'): 0.00013256445946841652,
#  ('of', 'such'): 0.0004392225760404085,
#  ('such', 'reports'): 0.0001318652337311268,
#  ('reports', 'was'): 0.00013246787653993907,
#  ('was', 'received'): 0.00012595251590150514,
#  ('received', "''"): 0.00013226638449837975,
#  ("''", ','): 0.012830236379724434,
#  (',', 'the'): 0.018890831390831392,
#  ('the', 'jury'): 0.0009931895573212259,
#  ('jury', 'said'): 0.0005287508261731659,
#  ('said', ','): 0.004711501226281141,
#  ('``', 'considering'): 0.00012615908660821296,
#  ('considering', 'the'): 0.00019882033269269004,
#  ('the', 'widespread'): 9.458948164964057e-05,
#  ('widespread', 'interest'): 0.0001325381047051027,
#  ('interest', 'in'): 0.000595277465440836,
#  ('the', 'number'): 0.00028376844494892167,
#  ('number', 'of'): 0.0018519743369270454,
#  ('of', 'voters'): 0.00010980564401010212,
#  ('voters', 'and'): 0.00013246787653993907,
#  ('and', 'the'): 0.008844475074661153,
#  ('the', 'size'): 0.00018917896329928113,
#  ('size', 'of'): 0.00026500596263415925,
#  ('of', 'this'): 0.0013176677281212254,
#  ('this', 'city'): 0.0003254149040026033,
#  ('city', "''"): 0.00013209167162010435,
#  ("''", '.'): 0.019466565541650865,
#  ('said', 'it'): 0.0007099522395766103,
#  ('it', 'did'): 0.00019341112758687384,
#  ('did', 'find'): 0.00013199577613516366,
#  ('find', 'that'): 0.00019863603257630935,
#  ('that', 'many'): 0.00043840420868040335,
#  ('many', 'of'): 0.0007920792079207921,
#  ('of', "Georgia's"): 0.0002745141100252553,
#  ("Georgia's", 'registration'): 0.0001324942033786022,
#  ('registration', 'and'): 0.0001325556733828208,
#  ('and', 'election'): 0.00011486331265793706,
#  ('election', 'laws'): 0.00013221392212599986,
#  ('laws', '``'): 0.00013228388120907467,
#  ('``', 'are'): 0.0003153977165205324,
#  ('are', 'outmoded'): 0.00012953367875647668,
#  ('outmoded', 'or'): 0.00013256445946841652,
#  ('or', 'inadequate'): 0.00013086435909180134,
#  ('inadequate', 'and'): 0.0001325293221125174,
#  ('and', 'often'): 0.00022972662531587412,
#  ('often', 'ambiguous'): 0.00013243279035889287,
#  ('ambiguous', "''"): 0.00013256445946841652,
#  ('<s>', 'It'): 0.005974310465000498,
#  ('It', 'recommended'): 0.00013143195110731419,
#  ('recommended', 'that'): 0.0003312355084465055,
#  ('that', 'Fulton'): 0.00012525834533725808,
#  ('Fulton', 'legislators'): 0.00019867549668874172,
#  ('legislators', 'act'): 0.0001324942033786022,
#  ('act', '``'): 0.00013238895876083935,
#  ('``', 'to'): 0.0005677158897369583,
#  ('to', 'have'): 0.0015519917227108122,
#  ('have', 'these'): 0.0001949571094359241,
#  ('these', 'laws'): 0.00019801980198019803,
#  ('laws', 'studied'): 0.00013228388120907467,
#  ('studied', 'and'): 0.00013250298131707962,
#  ('and', 'revised'): 0.00011486331265793706,
#  ('revised', 'to'): 0.0001325556733828208,
#  ('to', 'the'): 0.017129390124734148,
#  ('the', 'end'): 0.0005675368898978433,
#  ('end', 'of'): 0.0007275613466499108,
#  ('of', 'modernizing'): 0.00010980564401010212,
#  ('modernizing', 'and'): 0.00013256445946841652,
#  ('and', 'improving'): 0.00011486331265793706,
#  ('improving', 'them'): 0.00013252054068380598,
#  ('them', "''"): 0.0005266276084523731,
#  ('The', 'grand'): 0.00018780518342306247,
#  ('grand', 'jury'): 0.0004636068613815484,
#  ('jury', 'commented'): 0.00013218770654329148,
#  ('commented', 'on'): 0.00019876764062810574,
#  ('on', 'a'): 0.0034832172260924636,
#  ('a', 'number'): 0.001103111936832327,
#  ('of', 'other'): 0.0004392225760404085,
#  ('other', 'topics'): 0.00013113034356150013,
#  ('topics', ','): 0.0001325556733828208,
#  (',', 'among'): 0.00033993783993783994,
#  ('among', 'them'): 0.0001985308715505261,
#  ('them', 'the'): 0.00026331380422618656,
#  ('the', 'Atlanta'): 0.00028376844494892167,
#  ('Atlanta', 'and'): 0.00013245033112582781,
#  ('and', 'Fulton'): 0.00011486331265793706,
#  ('County', 'purchasing'): 0.0001322314049586777,
#  ('purchasing', 'departments'): 0.00013254688846179335,
#  ('departments', 'which'): 0.0001325556733828208,
#  ('which', 'it'): 0.0005210029306414849,
#  ('it', 'said'): 0.0002578815034491651,
#  ('said', '``'): 0.00032270556344391377,
#  ('are', 'well'): 0.00019430051813471502,
#  ('well', 'operated'): 0.00013214403700033037,
#  ('operated', 'and'): 0.0001325381047051027,
#  ('and', 'follow'): 0.00011486331265793706,
#  ('follow', 'generally'): 0.00013246787653993907,
#  ('generally', 'accepted'): 0.00013245033112582781,
#  ('accepted', 'practices'): 0.00013250298131707962,
#  ('practices', 'which'): 0.00013251176041873715,
#  ('which', 'inure'): 0.00013025073266037122,
#  ('inure', 'to'): 0.00013256445946841652,
#  ('the', 'best'): 0.0008986000756715854,
#  ('best', 'interest'): 0.00013228388120907467,
#  ('interest', 'of'): 0.00026456776241814934,
#  ('of', 'both'): 0.00021961128802020424,
#  ('both', 'governments'): 0.00013205678441729945,
#  ('governments', "''"): 0.00013252054068380598,
#  ('<s>', 'Merger'): 9.957184108334163e-05,
#  ('Merger', 'proposed'): 0.00013256445946841652,
#  ('proposed', '</s>'): 0.00013241525423728814,
#  ('<s>', 'However'): 0.0005974310465000497,
#  ('However', ','): 0.0008610411975096039,
#  ('it', 'believes'): 0.00012894075172458256,
#  ('believes', '``'): 0.00013250298131707962,
#  ('``', 'these'): 0.00018923862991231943,
#  ('these', 'two'): 0.000264026402640264,
#  ('two', 'offices'): 0.00013112174654166393,
#  ('offices', 'should'): 0.0001325293221125174,
#  ('should', 'be'): 0.0023096212221195723,
#  ('be', 'combined'): 0.00012764871074802145,
#  ('combined', 'to'): 0.0002649884067572044,
#  ('to', 'achieve'): 0.00045984939932172214,
#  ('achieve', 'greater'): 0.00013251176041873715,
#  ('greater', 'efficiency'): 0.00013247665099026297,
#  ('efficiency', 'and'): 0.0001325556733828208,
#  ('and', 'reduce'): 0.00011486331265793706,
#  ('reduce', 'the'): 0.0003312355084465055,
#  ('the', 'cost'): 0.00018917896329928113,
#  ('cost', 'of'): 0.0005296960868701583,
#  ('of', 'administration'): 0.00016470846601515318,
#  ('administration', "''"): 0.00013209167162010435,
#  ('The', 'City'): 0.00025040691123075,
#  ('City', 'Purchasing'): 0.00013216150135465538,
#  ('Purchasing', 'Department'): 0.00013256445946841652,
#  ('Department', ','): 0.000198583438141259,
#  ('``', 'is'): 0.0005046363464328518,
#  ('is', 'lacking'): 0.0001256992018100685,
#  ('lacking', 'in'): 0.00019880715705765408,
#  ('in', 'experienced'): 0.00011693854879260948,
#  ('experienced', 'clerical'): 0.0001325381047051027,
#  ('clerical', 'personnel'): 0.0001325381047051027,
#  ('personnel', 'as'): 0.00013246787653993907,
#  ('as', 'a'): 0.005571922633534008,
#  ('a', 'result'): 0.0011611704598235022,
#  ('result', 'of'): 0.0011906336817039292,
#  ('of', 'city'): 0.00016470846601515318,
#  ('city', 'personnel'): 0.00013209167162010435,
#  ('personnel', 'policies'): 0.00019870181480990858,
#  ('policies', "''"): 0.00013248542660307367,
#  ('It', 'urged'): 0.0001971479266609713,
#  ('urged', 'that'): 0.0003311696913498477,
#  ('the', 'city'): 0.0011350737797956867,
#  ('city', '``'): 0.00013209167162010435,
#  ('``', 'take'): 0.00012615908660821296,
#  ('take', 'steps'): 0.0001982029598308668,
#  ('steps', 'to'): 0.00033125745329269906,
#  ('to', 'remedy'): 0.00011496234983043054,
#  ('remedy', "''"): 0.00013256445946841652,
#  ("''", 'this'): 0.00012640626975097966,
#  ('this', 'problem'): 0.00026033192320208264,
#  ('problem', '.'): 0.0003966679888932963,
#  ('<s>', 'Implementation'): 9.957184108334163e-05,
#  ('Implementation', 'of'): 0.00013256445946841652,
#  ("Georgia's", 'automobile'): 0.0001324942033786022,
#  ('automobile', 'title'): 0.0001325381047051027,
#  ('title', 'law'): 0.00019880715705765408,
#  ('law', 'was'): 0.0001982422520319831,
#  ('was', 'also'): 0.0005038100636060206,
#  ('also', 'recommended'): 0.00019725162732592543,
#  ('recommended', 'by'): 0.0001324942033786022,
#  ('by', 'the'): 0.007873511714249135,
#  ('the', 'outgoing'): 9.458948164964057e-05,
#  ('outgoing', 'jury'): 0.00013254688846179335,
#  ('jury', '.'): 0.0003965631196298744,
#  ('the', 'next'): 0.0008986000756715854,
#  ('next', 'Legislature'): 0.00013218770654329148,
#  ('Legislature', '``'): 0.000132406487917908,
#  ('``', 'provide'): 0.00012615908660821296,
#  ('provide', 'enabling'): 0.00013234515616728428,
#  ('enabling', 'funds'): 0.0001325293221125174,
#  ('funds', 'and'): 0.00026458526260087314,
#  ('and', 're-set'): 0.00011486331265793706,
#  ('re-set', 'the'): 0.00013256445946841652,
#  ('the', 'effective'): 0.00014188422247446084,
#  ('effective', 'date'): 0.0001324415601615787,
#  ('date', 'so'): 0.00013243279035889287,
#  ('so', 'that'): 0.0007254979554148529,
#  ('that', 'an'): 0.0003757750360117743,
#  ('an', 'orderly'): 0.00019461563412260784,
#  ('orderly', 'implementation'): 0.00013254688846179335,
#  ('implementation', 'of'): 0.00013256445946841652,
#  ('the', 'law'): 0.00037835792659856227,
#  ('law', 'may'): 0.00013216150135465538,
#  ('may', 'be'): 0.0017152658662092624,
#  ('be', 'effected'): 0.00012764871074802145,
#  ('effected', "''"): 0.00013256445946841652,
#  ('jury', 'took'): 0.00013218770654329148,
#  ('took', 'a'): 0.00039643211100099106,
#  ('a', 'swipe'): 0.00011611704598235021,
#  ('swipe', 'at'): 0.00013256445946841652,
#  ('at', 'the'): 0.011971472236372899,
#  ('the', 'State'): 0.000851305334846765,
#  ('State', 'Welfare'): 0.00019795447047179148,
#  ('Welfare', "Department's"): 0.00013254688846179335,
#  ("Department's", 'handling'): 0.0001325556733828208,
#  ('handling', 'of'): 0.00013254688846179335,
#  ('of', 'federal'): 0.00021961128802020424,
#  ('federal', 'funds'): 0.000264497784831052,
#  ('funds', 'granted'): 0.00013229263130043657,
#  ('granted', 'for'): 0.00013252054068380598,
#  ('for', 'child'): 0.00012415419951579862,
#  ('child', 'welfare'): 0.0001324942033786022,
#  ('welfare', 'services'): 0.0001324415601615787,
#  ('services', 'in'): 0.000132406487917908,
#  ('in', 'foster'): 0.00011693854879260948,
#  ('foster', 'homes'): 0.00013256445946841652,
#  ('homes', '.'): 0.00019874130506790329,
#  ('``', 'This'): 0.0008831136062574906,
#  ('This', 'is'): 0.0019786307874950534,
#  ('is', 'one'): 0.0009427440135755138,
#  ('one', 'of'): 0.003924646781789639,
#  ('the', 'major'): 0.00028376844494892167,
#  ('major', 'items'): 0.00013231888852133642,
#  ('items', 'in'): 0.0001325381047051027,
#  ('the', 'Fulton'): 0.00028376844494892167,
#  ('County', 'general'): 0.0001322314049586777,
#  ('general', 'assistance'): 0.00019847833278200462,
#  ('assistance', 'program'): 0.00013250298131707962,
#  ('program', "''"): 0.0001319609395618897,
#  (',', 'but'): 0.004953379953379953,
#  ('but', 'the'): 0.0013086435909180135,
#  ('Welfare', 'Department'): 0.00013254688846179335,
#  ('Department', '``'): 0.00013238895876083935,
#  ('``', 'has'): 0.0002523181732164259,
#  ('has', 'seen'): 0.00025928566798470216,
#  ('seen', 'fit'): 0.0001324942033786022,
#  ('fit', 'to'): 0.0001325381047051027,
#  ('to', 'distribute'): 0.00011496234983043054,
#  ('distribute', 'these'): 0.0001325556733828208,
#  ('these', 'funds'): 0.000264026402640264,
#  ('funds', 'through'): 0.00013229263130043657,
#  ('through', 'the'): 0.0015848907085782209,
#  ('the', 'welfare'): 0.00018917896329928113,
#  ('welfare', 'departments'): 0.0001324415601615787,
#  ('departments', 'of'): 0.0001325556733828208,
#  ('of', 'all'): 0.000988250796090919,
#  ('all', 'the'): 0.0016380553007469532,
#  ('the', 'counties'): 9.458948164964057e-05,
#  ('counties', 'in'): 0.00019866234024236806,
#  ('the', 'state'): 0.0024593265228906543,
#  ('state', 'with'): 0.00019749835418038183,
#  ('with', 'the'): 0.009303511119607468,
#  ('the', 'exception'): 0.00014188422247446084,
#  ('exception', 'of'): 0.0002650762094102054,
#  ('of', 'Fulton'): 0.00010980564401010212,
#  ('County', ','): 0.0004628099173553719,
#  ('which', 'receives'): 0.00013025073266037122,
#  ('receives', 'none'): 0.00013256445946841652,
#  ('none', 'of'): 0.0002650235208374743,
#  ('this', 'money'): 0.00013016596160104132,
#  ('money', '.'): 0.0003968253968253968,
#  ('The', 'jurors'): 0.000125203455615375,
#  ('jurors', 'said'): 0.00019880715705765408,
#  ('said', 'they'): 0.0005808700141990448,
#  ('they', 'realize'): 0.00013064210595074792,
#  ('realize', '``'): 0.0001325381047051027,
#  ('``', 'a'): 0.0006307954330410648,
#  ('a', 'proportionate'): 0.00011611704598235021,
#  ('proportionate', 'distribution'): 0.00013256445946841652,
#  ('distribution', 'of'): 0.0002650235208374743,
#  ('of', 'these'): 0.0011529592621060721,
#  ('funds', 'might'): 0.00013229263130043657,
#  ('might', 'disable'): 0.00013216150135465538,
#  ('disable', 'this'): 0.00013256445946841652,
#  ('this', 'program'): 0.000195248942401562,
#  ('program', 'in'): 0.000395882818685669,
#  ('in', 'our'): 0.0004092849207741332,
#  ('our', 'less'): 0.00013203934772562222,
#  ('less', 'populous'): 0.0001986491855383393,
#  ('populous', 'counties'): 0.00013254688846179335,
#  ('counties', "''"): 0.0001324415601615787,
#  ('<s>', 'Nevertheless'): 9.957184108334163e-05,
#  ('Nevertheless', ','): 0.00013256445946841652,
#  ('``', 'we'): 0.0003153977165205324,
#  ('we', 'feel'): 0.00013179571663920922,
#  ('feel', 'that'): 0.00039719316827750565,
#  ('that', 'in'): 0.0005010333813490323,
#  ('the', 'future'): 0.0005202421490730231,
#  ('future', 'Fulton'): 0.00013232764324467382,
#  ('County', 'should'): 0.0001322314049586777,
#  ('should', 'receive'): 0.00013197835554968986,
#  ('receive', 'some'): 0.0001324415601615787,
#  ('some', 'portion'): 0.0001315702914281955,
#  ('portion', 'of'): 0.00019883351007423118,
#  ('these', 'available'): 0.000132013201320132,
#  ('available', 'funds'): 0.00013247665099026297,
#  ('funds', "''"): 0.00019843894695065485,
#  ('the', 'jurors'): 0.00018917896329928113,
#  ('said', '.'): 0.005034206789725055,
#  ('``', 'Failure'): 0.00012615908660821296,
#  ('Failure', 'to'): 0.00019883351007423118,
#  ('to', 'do'): 0.001264585848134736,
#  ('do', 'this'): 0.00019790223629527012,
#  ('this', 'will'): 0.000195248942401562,
#  ('will', 'continue'): 0.0003224350293415877,
#  ('continue', 'to'): 0.0005961054444297258,
#  ('to', 'place'): 0.00028740587457607634,
#  ('place', 'a'): 0.00013235391436701742,
#  ('a', 'disproportionate'): 0.00011611704598235021,
#  ('disproportionate', 'burden'): 0.00013256445946841652,
#  ('burden', "''"): 0.0001325556733828208,
#  ("''", 'on'): 0.0007584376185058779,
#  ('on', 'Fulton'): 0.0001266624445851805,
#  ('Fulton', 'taxpayers'): 0.00013245033112582781,
#  ('taxpayers', '.'): 0.0001325293221125174,
#  ('jury', 'also'): 0.00013218770654329148,
#  ('also', 'commented'): 0.0001315010848839503,
#  ('on', 'the'): 0.016529449018366053,
#  ('Fulton', "ordinary's"): 0.00013245033112582781,
#  ("ordinary's", 'court'): 0.00013256445946841652,
#  ('court', 'which'): 0.00013231888852133642,
#  ('which', 'has'): 0.0005861282969716704,
#  ('has', 'been'): 0.006482141699617553,
#  ('been', 'under'): 0.00026097736021400144,
#  ('under', 'fire'): 0.00019771963355961247,
#  ('fire', 'for'): 0.00013238019592268997,
#  ('for', 'its'): 0.0005586938978210938,
#  ('its', 'practices'): 0.00013084723585214263,
#  ('practices', 'in'): 0.00013251176041873715,
#  ('the', 'appointment'): 0.00018917896329928113,
#  ('appointment', 'of'): 0.00046376043460977874,
#  ('of', 'appraisers'): 0.00010980564401010212,
#  ('appraisers', ','): 0.00013256445946841652,
#  (',', 'guardians'): 9.712509712509713e-05,
#  ('guardians', 'and'): 0.0001325556733828208,
#  ('and', 'administrators'): 0.00011486331265793706,
#  ('administrators', 'and'): 0.00013256445946841652,
#  ('the', 'awarding'): 9.458948164964057e-05,
#  ('awarding', 'of'): 0.00013256445946841652,
#  ('of', 'fees'): 0.00010980564401010212,
#  ('fees', 'and'): 0.00013245910325187097,
#  ('and', 'compensation'): 0.00011486331265793706,
#  ('compensation', '.'): 0.0001325381047051027,
#  ('<s>', 'Wards'): 9.957184108334163e-05,
#  ('Wards', 'protected'): 0.00013256445946841652,
#  ('protected', '</s>'): 0.0001325556733828208,
#  ('it', 'found'): 0.00012894075172458256,
#  ('found', 'the'): 0.00033070970302268666,
#  ('the', 'court'): 0.00033106318577374197,
#  ('court', '``'): 0.00013231888852133642,
#  ('has', 'incorporated'): 0.00012964283399235108,
#  ('incorporated', 'into'): 0.00013256445946841652,
#  ('into', 'its'): 0.00013144058885383806,
#  ('its', 'operating'): 0.00013084723585214263,
#  ('operating', 'procedures'): 0.0001325293221125174,
#  ('procedures', 'the'): 0.00013252054068380598,
#  ('the', 'recommendations'): 9.458948164964057e-05,
#  ('recommendations', "''"): 0.00013252054068380598,
#  ("''", 'of'): 0.0006952344836303881,
#  ('of', 'two'): 0.0004392225760404085,
#  ('two', 'previous'): 0.0001966826198124959,
#  ('previous', 'grand'): 0.00013247665099026297,
#  ('grand', 'juries'): 0.00013245910325187097,
#  ('juries', ','): 0.00013256445946841652,
#  ('Atlanta', 'Bar'): 0.00013245033112582781,
#  ('Bar', 'Association'): 0.00013254688846179335,
#  ('Association', 'and'): 0.00013239772275916854,
#  ('and', 'an'): 0.0005743165632896852,
#  ('an', 'interim'): 0.00012974375608173857,
#  ('interim', 'citizens'): 0.00013254688846179335,
#  ('citizens', 'committee'): 0.00019875447197561946,
#  ('committee', '.'): 0.0003966155473294553,
#  ('``', 'These'): 0.00018923862991231943,
#  ('These', 'actions'): 0.00013245033112582781,
#  ('actions', 'should'): 0.00013252054068380598,
#  ('should', 'serve'): 0.00013197835554968986,
#  ('serve', 'to'): 0.00013250298131707962,
#  ('to', 'protect'): 0.0001724435247456458,
#  ('protect', 'in'): 0.0001325556733828208,
#  ('in', 'fact'): 0.0004092849207741332,
#  ('fact', 'and'): 0.00019843894695065485,
#  ('and', 'in'): 0.000976338157592465,
#  ('in', 'effect'): 0.00023387709758521897,
#  ('effect', 'the'): 0.00019862288135593222,
#  ('the', "court's"): 9.458948164964057e-05,
#  ("court's", 'wards'): 0.00013256445946841652,
#  ('wards', 'from'): 0.00013256445946841652,
#  ('from', 'undue'): 0.00012938284383490748,
#  ('undue', 'costs'): 0.0001325556733828208,
#  ('costs', 'and'): 0.000132406487917908,
#  ('and', 'its'): 0.0007466115322765909,
#  ('its', 'appointed'): 0.00013084723585214263,
#  ('appointed', 'and'): 0.00013252054068380598,
#  ('and', 'elected'): 0.00011486331265793706,
#  ('elected', 'servants'): 0.00013246787653993907,
#  ('servants', 'from'): 0.0001325293221125174,
#  ('from', 'unmeritorious'): 0.00012938284383490748,
#  ('unmeritorious', 'criticisms'): 0.00013256445946841652,
#  ('criticisms', "''"): 0.0001325556733828208,
#  ('<s>', 'Regarding'): 9.957184108334163e-05,
#  ('Regarding', "Atlanta's"): 0.00013256445946841652,
#  ("Atlanta's", 'new'): 0.0001325381047051027,
#  ('new', 'multi-million-dollar'): 0.0001311991603253739,
#  ('multi-million-dollar', 'airport'): 0.00013256445946841652,
#  ('airport', ','): 0.0001325381047051027,
#  ('jury', 'recommended'): 0.0001982815598149372,
#  ('recommended', '``'): 0.0001324942033786022,
#  ('``', 'that'): 0.00018923862991231943,
#  ('that', 'when'): 0.00025051669067451617,
#  ('when', 'the'): 0.0024305327465020034,
#  ('the', 'new'): 0.0015607264472190692,
#  ('new', 'management'): 0.0001311991603253739,
#  ('management', 'takes'): 0.00013251176041873715,
#  ('takes', 'charge'): 0.00013250298131707962,
#  ('charge', 'Jan.'): 0.00013242402171753957,
#  ('Jan.', '1'): 0.00033110390040394673,
#  ('1', 'the'): 0.0001321527686005022,
#  ('the', 'airport'): 0.00018917896329928113,
#  ('airport', 'be'): 0.0001325381047051027,
#  ('be', 'operated'): 0.00012764871074802145,
#  ('operated', 'in'): 0.0001325381047051027,
#  ('in', 'a'): 0.007133251476349178,
#  ('a', 'manner'): 0.00011611704598235021,
#  ('manner', 'that'): 0.00013250298131707962,
#  ('that', 'will'): 0.00043840420868040335,
#  ('will', 'eliminate'): 0.00012897401173663506,
#  ('eliminate', 'political'): 0.0001325293221125174,
#  ('political', 'influences'): 0.00013226638449837975,
#  ('influences', "''"): 0.00013256445946841652,
#  ('jury', 'did'): 0.00013218770654329148,
#  ('did', 'not'): 0.0015179514255543823,
#  ('not', 'elaborate'): 0.00012998830105290525,
#  ('elaborate', ','): 0.00019882033269269004,
#  ('but', 'it'): 0.0004580252568213047,
#  ('it', 'added'): 0.00012894075172458256,
#  ('added', 'that'): 0.0005952380952380953,
#  ('that', '``'): 0.0007515500720235486,
#  ('``', 'there'): 0.0003153977165205324,
#  ('there', 'should'): 0.00019705727798213348,
#  ('be', 'periodic'): 0.00012764871074802145,
#  ('periodic', 'surveillance'): 0.00013256445946841652,
#  ('surveillance', 'of'): 0.00013256445946841652,
#  ('the', 'pricing'): 9.458948164964057e-05,
#  ('pricing', 'practices'): 0.00013254688846179335,
#  ('practices', 'of'): 0.00013251176041873715,
#  ('the', 'concessionaires'): 9.458948164964057e-05,
#  ('concessionaires', 'for'): 0.00013256445946841652,
#  ('the', 'purpose'): 0.00014188422247446084,
#  ('purpose', 'of'): 0.0003974299529707889,
#  ('of', 'keeping'): 0.00010980564401010212,
#  ('keeping', 'the'): 0.0001325381047051027,
#  ('the', 'prices'): 0.00018917896329928113,
#  ('prices', 'reasonable'): 0.000132406487917908,
#  ('reasonable', "''"): 0.0001325556733828208,
#  ('<s>', 'Ask'): 9.957184108334163e-05,
#  ('Ask', 'jail'): 0.00013256445946841652,
#  ('jail', 'deputies'): 0.00013252054068380598,
#  ('deputies', '</s>'): 0.00013254688846179335,
#  ('<s>', 'On'): 0.001593149457333466,
#  ('On', 'other'): 0.00013227513227513228,
#  ('other', 'matters'): 0.00013113034356150013,
#  ('matters', ','): 0.00019882033269269004,
#  ('that', ':'): 0.00012525834533725808,
#  (':', '('): 0.000131250820317627,
#  ('(', '1'): 0.00019661816751867872,
#  ('1', ')'): 0.00033038192150125544,
#  (')', '</s>'): 0.0022934276915012124,
#  ('<s>', 'Four'): 0.0003485014437916957,
#  ('Four', 'additional'): 0.0001324942033786022,
#  ('additional', 'deputies'): 0.00013243279035889287,
#  ('deputies', 'be'): 0.00013254688846179335,
#  ('be', 'employed'): 0.00019147306612203217,
#  ('employed', 'at'): 0.0001325293221125174,
#  ('County', 'Jail'): 0.00019834710743801652,
#  ('Jail', 'and'): 0.0001325556733828208,
#  ('and', '``'): 0.0008040431886055594,
#  ('a', 'doctor'): 0.00011611704598235021,
#  ('doctor', ','): 0.00013254688846179335,
#  (',', 'medical'): 9.712509712509713e-05,
#  ('medical', 'intern'): 0.00013241525423728814,
#  ('intern', 'or'): 0.00013256445946841652,
#  ('or', 'extern'): 0.00013086435909180134,
#  ('extern', 'be'): 0.00013256445946841652,
#  ('employed', 'for'): 0.0001325293221125174,
#  ('for', 'night'): 0.00012415419951579862,
#  ('night', 'and'): 0.000132013201320132,
#  ('and', 'weekend'): 0.00011486331265793706,
#  ('weekend', 'duty'): 0.00013245910325187097,
#  ('duty', 'at'): 0.0001325381047051027,
#  ('the', 'jail'): 9.458948164964057e-05,
#  ('jail', "''"): 0.00013252054068380598,
#  ('<s>', '('): 0.0012446480135417705,
#  ('(', '2'): 0.00019661816751867872,
#  ('2', ')'): 0.0004629323457443291,
#  ('<s>', 'Fulton'): 9.957184108334163e-05,
#  ('legislators', '``'): 0.0001324942033786022,
#  ('``', 'work'): 0.00012615908660821296,
#  ('work', 'with'): 0.000395882818685669,
#  ('with', 'city'): 0.00012744535780284203,
#  ('city', 'officials'): 0.00013209167162010435,
#  ('officials', 'to'): 0.0002648831203231574,
#  ('to', 'pass'): 0.0005748117491521527,
#  ('pass', 'enabling'): 0.00013243279035889287,
#  ('enabling', 'legislation'): 0.00019879398316877608,
#  ('legislation', 'that'): 0.00013243279035889287,
#  ('will', 'permit'): 0.00012897401173663506,
#  ('permit', 'the'): 0.00019878081102570898,
#  ('the', 'establishment'): 0.0002364737041241014,
#  ('establishment', 'of'): 0.0004637911614655801,
#  ('of', 'a'): 0.0066981442846162295,
#  ('a', 'fair'): 0.00023223409196470042,
#  ('fair', 'and'): 0.00019871497648539445,
#  ('and', 'equitable'): 0.00017229496898690558,
#  ('equitable', "''"): 0.0001325556733828208,
#  ("''", 'pension'): 0.00012640626975097966,
#  ('pension', 'plan'): 0.0002650586442250348,
#  ('plan', 'for'): 0.0003965107057890563,
#  ('for', 'city'): 0.00012415419951579862,
#  ('city', 'employes'): 0.00019813750743015652,
#  ('employes', '.'): 0.0001987281399046105,
#  ('jury', 'praised'): 0.00013218770654329148,
#  ('praised', 'the'): 0.00013254688846179335,
#  ('the', 'administration'): 0.0008040105940219448,
#  ('administration', 'and'): 0.0002641833432402087,
#  ('and', 'operation'): 0.00017229496898690558,
#  ('operation', 'of'): 0.0004634840760113885,
#  ('Atlanta', 'Police'): 0.00013245033112582781,
#  ('Police', 'Department'): 0.0001324942033786022,
#  ('Fulton', 'Tax'): 0.00013245033112582781,
#  ('Tax', "Commissioner's"): 0.0001325293221125174,
#  ("Commissioner's", 'Office'): 0.00013256445946841652,
#  ('Office', ','): 0.0001325381047051027,
#  ('the', 'Bellwood'): 9.458948164964057e-05,
#  ('Bellwood', 'and'): 0.00013256445946841652,
#  ('and', 'Alpharetta'): 0.00011486331265793706,
#  ('Alpharetta', 'prison'): 0.00013256445946841652,
#  ('prison', 'farms'): 0.00013251176041873715,
#  ('farms', ','): 0.00013254688846179335,
#  (',', 'Grady'): 9.712509712509713e-05,
#  ('Grady', 'Hospital'): 0.0002650586442250348,
#  ('Hospital', 'and'): 0.00013238019592268997,
#  ('Fulton', 'Health'): 0.00013245033112582781,
#  ('Health', 'Department'): 0.0001325293221125174,
#  ('Department', '.'): 0.00013238895876083935,
#  ('<s>', 'Mayor'): 0.0002489296027083541,
#  ('Mayor', 'William'): 0.00013235391436701742,
#  ('William', 'B.'): 0.000132248892415526,
#  ('B.', 'Hartsfield'): 0.00013229263130043657,
#  ('Hartsfield', 'filed'): 0.0001325293221125174,
#  ('filed', 'suit'): 0.00013250298131707962,
#  ('suit', 'for'): 0.00013252054068380598,
#  ('for', 'divorce'): 0.00012415419951579862,
#  ('divorce', 'from'): 0.00013254688846179335,
#  ('from', 'his'): 0.00045283995342217624,
#  ('his', 'wife'): 0.0010299324106855488,
#  ('wife', ','): 0.0011242642682362278,
#  (',', 'Pearl'): 9.712509712509713e-05,
#  ('Pearl', 'Williams'): 0.00013256445946841652,
#  ('Williams', 'Hartsfield'): 0.0001324415601615787,
#  ('Hartsfield', ','): 0.0001325293221125174,
#  (',', 'in'): 0.004079254079254079,
#  ('in', 'Fulton'): 0.00011693854879260948,
#  ('Court', 'Friday'): 0.00019851773425092641,
#  ('Friday', '.'): 0.0005949626495669995,
#  ('<s>', 'His'): 0.0014437916957084536,
#  ('His', 'petition'): 0.00013228388120907467,
#  ('petition', 'charged'): 0.00013252054068380598,
#  ('charged', 'mental'): 0.00013246787653993907,
#  ('mental', 'cruelty'): 0.00013254688846179335,
#  ('cruelty', '.'): 0.00013256445946841652,
#  ('The', 'couple'): 0.00018780518342306247,
#  ('couple', 'was'): 0.00013245910325187097,
#  ('was', 'married'): 0.0002519050318030103,
#  ('married', 'Aug.'): 0.00013250298131707962,
#  ('Aug.', '2'): 0.00013250298131707962,
#  ('2', ','): 0.0007274651147410885,
#  (',', '1913'): 9.712509712509713e-05,
#  ('1913', '.'): 0.0001325556733828208,
#  ('<s>', 'They'): 0.0031365129941252614,
#  ('They', 'have'): 0.00033001122038149296,
#  ('have', 'a'): 0.0013646997660514686,
#  ('a', 'son'): 0.00029029261495587555,
#  ('son', ','): 0.0005957108816521049,
#  (',', 'William'): 0.0003885003885003885,
#  ('William', 'Berry'): 0.000132248892415526,
#  ('Berry', 'Jr.'): 0.0001325293221125174,
#  ('Jr.', ','): 0.001916468411313772,
#  (',', 'and'): 0.019425019425019424,
#  ('and', 'a'): 0.003560762692396049,
#  ('a', 'daughter'): 0.00040640966093822574,
#  ('daughter', ','): 0.0011911064055055585,
#  (',', 'Mrs.'): 0.0035936285936285935,
#  ('Mrs.', 'J.'): 0.0003259664906447617,
#  ('J.', 'M.'): 0.00013220518244315177,
#  ('M.', 'Cheshire'): 0.00013238019592268997,
#  ('Cheshire', 'of'): 0.00013256445946841652,
#  ('of', 'Griffin'): 0.00010980564401010212,
#  ('Griffin', '.'): 0.00019883351007423118,
#  ('<s>', 'Attorneys'): 0.00014935776162501243,
#  ('Attorneys', 'for'): 0.00019883351007423118,
#  ('the', 'mayor'): 9.458948164964057e-05,
#  ('mayor', 'said'): 0.0001325556733828208,
#  ('said', 'that'): 0.0021298567187298307,
#  ('an', 'amicable'): 0.00012974375608173857,
#  ('amicable', 'property'): 0.00013256445946841652,
#  ('property', 'settlement'): 0.00013243279035889287,
#  ('settlement', 'has'): 0.00013254688846179335,
#  ('been', 'agreed'): 0.00013048868010700072,
#  ('agreed', 'upon'): 0.0001986491855383393,
#  ('upon', '.'): 0.00019850459868986966,
#  ('The', 'petition'): 0.00018780518342306247,
#  ('petition', 'listed'): 0.00013252054068380598,
#  ('listed', 'the'): 0.0001987281399046105,
#  ('the', "mayor's"): 0.00018917896329928113,
#  ("mayor's", 'occupation'): 0.0001325381047051027,
#  ('occupation', 'as'): 0.00013252054068380598,
#  ('as', '``'): 0.0005764057896759318,
#  ('``', 'attorney'): 0.00012615908660821296,
#  ('attorney', "''"): 0.00013242402171753957,
#  ("''", 'and'): 0.001074453292883327,
#  ('and', 'his'): 0.0021249712841718356,
#  ('his', 'age'): 0.0001287415513356936,
#  ('age', 'as'): 0.00019870181480990858,
#  ('as', '71'): 0.0001280901754835404,
#  ('71', '.'): 0.00019880715705765408,
#  ('It', 'listed'): 0.00013143195110731419,
#  ('listed', 'his'): 0.00013248542660307367,
#  ('his', "wife's"): 0.0001287415513356936,
#  ("wife's", 'age'): 0.00013256445946841652,
#  ('as', '74'): 0.0001280901754835404,
#  ('74', 'and'): 0.00019882033269269004,
#  ('and', 'place'): 0.00011486331265793706,
#  ('place', 'of'): 0.0001985308715505261,
#  ('of', 'birth'): 0.00010980564401010212,
#  ('birth', 'as'): 0.00013252054068380598,
#  ('as', 'Opelika'): 0.0001280901754835404,
#  ('Opelika', ','): 0.00013256445946841652,
#  (',', 'Ala.'): 0.0003885003885003885,
#  ('Ala.', '.'): 0.0003312794010468429,
#  ('petition', 'said'): 0.00013252054068380598,
#  ('the', 'couple'): 0.00018917896329928113,
#  ('couple', 'has'): 0.00013245910325187097,
#  ('has', 'not'): 0.0009074998379464575,
#  ('not', 'lived'): 0.00012998830105290525,
#  ('lived', 'together'): 0.00013254688846179335,
#  ('together', 'as'): 0.00013231888852133642,
#  ('as', 'man'): 0.0001280901754835404,
#  ('man', 'and'): 0.000329663084327817,
#  ('and', 'wife'): 0.0002871582816448426,
#  ('wife', 'for'): 0.0002645327689967595,
#  ('for', 'more'): 0.0005586938978210938,
#  ('more', 'than'): 0.003600654664484452,
#  ('than', 'a'): 0.0009186954524575103,
#  ('a', 'year'): 0.001741755689735253,
#  ('year', '.'): 0.002559726962457338,
#  ('The', 'Hartsfield'): 0.000125203455615375,
#  ('Hartsfield', 'home'): 0.0001325293221125174,
#  ('home', 'is'): 0.00013144922773578705,
#  ('is', 'at'): 0.00018854880271510275,
#  ('at', '637'): 0.00012735608762098828,
#  ('637', 'E.'): 0.00013256445946841652,
#  ('E.', 'Pelham'): 0.00013227513227513228,
#  ('Pelham', 'Rd.'): 0.0001325293221125174,
#  ('Rd.', 'Aj'): 0.00013254688846179335,
#  ('Aj', '.'): 0.0009271523178807947,
#  ('<s>', 'Henry'): 0.00014935776162501243,
#  ('Henry', 'L.'): 0.00019862288135593222,
#  ('L.', 'Bowden'): 0.0001985308715505261,
#  ('Bowden', 'was'): 0.0001325556733828208,
#  ('was', 'listed'): 0.00012595251590150514,
#  ('listed', 'on'): 0.0001987281399046105,
#  ('the', 'petition'): 9.458948164964057e-05,
#  ('petition', 'as'): 0.00013252054068380598,
#  ('as', 'the'): 0.004034840527731523,
#  ("mayor's", 'attorney'): 0.0001325381047051027,
#  ('attorney', '.'): 0.00019863603257630935,
#  ('<s>', 'Hartsfield'): 9.957184108334163e-05,
#  ('Hartsfield', 'has'): 0.0001325293221125174,
#  ('been', 'mayor'): 0.00013048868010700072,
#  ('mayor', 'of'): 0.0001325556733828208,
#  ('Atlanta', ','): 0.00033112582781456954,
#  (',', 'with'): 0.0030594405594405595,
#  ('with', 'exception'): 0.00012744535780284203,
#  ('of', 'one'): 0.0005490282200505106,
#  ('one', 'brief'): 0.00013082155939298797,
#  ('brief', 'interlude'): 0.00013254688846179335,
#  ('interlude', ','): 0.00013256445946841652,
#  (',', 'since'): 0.0004856254856254856,
#  ('since', '1937'): 0.00013199577613516366,
#  ('1937', '.'): 0.00019883351007423118,
#  ('His', 'political'): 0.00013228388120907467,
#  ('political', 'career'): 0.0001983995767475696,
#  ('career', 'goes'): 0.00013247665099026297,
#  ('goes', 'back'): 0.0001325293221125174,
#  ('back', 'to'): 0.0007916089451810805,
#  ('to', 'his'): 0.0008047364488130138,
#  ('his', 'election'): 0.0001287415513356936,
#  ('election', 'to'): 0.0002644278442519997,
#  ('to', 'city'): 0.00011496234983043054,
#  ('city', 'council'): 0.00033022917905026086,
#  ('council', 'in'): 0.00013239772275916854,
#  ('in', '1923'): 0.00011693854879260948,
#  ('1923', '.'): 0.0001325556733828208,
#  ('The', "mayor's"): 0.000125203455615375,
#  ("mayor's", 'present'): 0.0001325381047051027,
#  ('present', 'term'): 0.00013228388120907467,
#  ('term', 'of'): 0.00013245033112582781,
#  ('of', 'office'): 0.00010980564401010212,
#  ('office', 'expires'): 0.00013234515616728428,
#  ('expires', 'Jan.'): 0.00013256445946841652,
#  ('1', '.'): 0.0005946874587022598,
#  ('<s>', 'He'): 0.010206113711042518,
#  ('He', 'will'): 0.0005229441757092431,
#  ('will', 'be'): 0.010640355968272393,
#  ('be', 'succeeded'): 0.00019147306612203217,
#  ('succeeded', 'by'): 0.00019880715705765408,
#  ('by', 'Ivan'): 0.00012802458071949814,
#  (',', 'who'): 0.00641025641025641,
#  ('who', 'became'): 0.00019508388607101054,
#  ('became', 'a'): 0.0002647954455183371,
#  ('a', 'candidate'): 0.00046446818392940084,
#  ('candidate', 'in'): 0.00026483050847457627,
#  ('the', 'Sept.'): 0.00014188422247446084,
#  ('Sept.', '13'): 0.00013252054068380598,
#  ('13', 'primary'): 0.00013242402171753957,
#  ('primary', 'after'): 0.00013242402171753957,
#  ('after', 'Mayor'): 0.0001314233144959916,
#  ('Mayor', 'Hartsfield'): 0.00013235391436701742,
#  ('Hartsfield', 'announced'): 0.0001325293221125174,
#  ('announced', 'that'): 0.0009257422469086821,
#  ('that', 'he'): 0.0031940878061000816,
#  ('he', 'would'): 0.0012198253723677453,
#  ('would', 'not'): 0.0013673655423883319,
#  ('not', 'run'): 0.00012998830105290525,
#  ('run', 'for'): 0.00013225763787858748,
#  ('for', 'reelection'): 0.00012415419951579862,
#  ('reelection', '.'): 0.0001325556733828208,
#  ('<s>', 'Georgia'): 0.00014935776162501243,
#  ('Georgia', 'Republicans'): 0.00013234515616728428,
#  ('Republicans', 'are'): 0.00013243279035889287,
#  ('are', 'getting'): 0.00025906735751295336,
#  ('getting', 'strong'): 0.000132406487917908,
#  ('strong', 'encouragement'): 0.00013245910325187097,
#  ('encouragement', 'to'): 0.00019879398316877608,
#  ('to', 'enter'): 0.00028740587457607634,
#  ('enter', 'a'): 0.00019878081102570898,
#  ('the', '1962'): 0.00014188422247446084,
#  ('1962', "governor's"): 0.0001325293221125174,
#  ("governor's", 'race'): 0.0001325381047051027,
#  ('race', ','): 0.0005295558350433574,
#  (',', 'a'): 0.006216006216006216,
#  ('a', 'top'): 0.00029029261495587555,
#  ('top', 'official'): 0.00013227513227513228,
#  ('official', 'said'): 0.00019863603257630935,
#  ('said', 'Wednesday'): 0.0001290822253775655,
#  ('Wednesday', '.'): 0.0003971405877680699,
#  ('<s>', 'Robert'): 0.00014935776162501243,
#  ('Robert', 'Snodgrass'): 0.00013231888852133642,
#  ('Snodgrass', ','): 0.00013256445946841652,
#  (',', 'state'): 0.00033993783993783994,
#  ('state', 'GOP'): 0.00013166556945358788,
#  ('GOP', 'chairman'): 0.0001325293221125174,
#  ('chairman', ','): 0.0004629017325750562,
#  (',', 'said'): 0.0026223776223776225,
#  ('said', 'a'): 0.00032270556344391377,
#  ('a', 'meeting'): 0.0008128193218764515,
#  ('meeting', 'held'): 0.000132013201320132,
#  ('held', 'Tuesday'): 0.00013221392212599986,
#  ('Tuesday', 'night'): 0.000396589331746976,
#  ('night', 'in'): 0.00033003300330033004,
#  ('in', 'Blue'): 0.00011693854879260948,
#  ('Blue', 'Ridge'): 0.00019871497648539445,
#  ('Ridge', 'brought'): 0.00013254688846179335,
#  ('brought', 'enthusiastic'): 0.00013238019592268997,
#  ('enthusiastic', 'responses'): 0.00013254688846179335,
#  ('responses', 'from'): 0.00013256445946841652,
#  ('from', 'the'): 0.00724543925475482,
#  ('the', 'audience'): 0.0002364737041241014,
#  ('audience', '.'): 0.00039740362961981717,
#  ('<s>', 'State'): 0.0003485014437916957,
#  ('State', 'Party'): 0.00013196964698119432,
#  ('Party', 'Chairman'): 0.00013248542660307367,
#  ('Chairman', 'James'): 0.0001324942033786022,
#  ('James', 'W.'): 0.00019837333862328903,
#  ('W.', 'Dorsey'): 0.0001322401481089659,
#  ('Dorsey', 'added'): 0.00013256445946841652,
#  ('that', 'enthusiasm'): 0.00012525834533725808,
#  ('enthusiasm', 'was'): 0.00013254688846179335,
#  ('was', 'picking'): 0.00012595251590150514,
#  ('picking', 'up'): 0.00013256445946841652,
#  ('up', 'for'): 0.0007208387942332896,
#  ('for', 'a'): 0.006393941275063629,
#  ('a', 'state'): 0.00029029261495587555,
#  ('state', 'rally'): 0.00013166556945358788,
#  ('rally', 'to'): 0.00013254688846179335,
#  ('to', 'be'): 0.007070184514571478,
#  ('be', 'held'): 0.0008297166198621394,
#  ('held', 'Sept.'): 0.00013221392212599986,
#  ('Sept.', '8'): 0.00013252054068380598,
#  ('8', 'in'): 0.00013238019592268997,
#  ('in', 'Savannah'): 0.00011693854879260948,
#  ('Savannah', 'at'): 0.00013256445946841652,
#  ('at', 'which'): 0.0006367804381049414,
#  ('which', 'newly'): 0.00013025073266037122,
#  ('newly', 'elected'): 0.00013251176041873715,
#  ('elected', 'Texas'): 0.00013246787653993907,
#  ('Texas', 'Sen.'): 0.0001321527686005022,
#  ('Sen.', 'John'): 0.00019862288135593222,
#  ('John', 'Tower'): 0.00013197835554968986,
#  ('Tower', 'will'): 0.00013256445946841652,
#  ('be', 'the'): 0.0016594332397242787,
#  ('the', 'featured'): 0.00014188422247446084,
#  ('featured', 'speaker'): 0.00013254688846179335,
#  ('speaker', '.'): 0.0001325381047051027,
#  ('<s>', 'In'): 0.006223240067708852,
#  ('In', 'the'): 0.0025622495236843836,
#  ('the', 'Blue'): 0.00018917896329928113,
#  ('Ridge', 'meeting'): 0.00013254688846179335,
#  ('meeting', ','): 0.00046204620462046204,
#  ('audience', 'was'): 0.00019870181480990858,
#  ('was', 'warned'): 0.00012595251590150514,
#  ('warned', 'that'): 0.0001325556733828208,
#  ('that', 'entering'): 0.00012525834533725808,
#  ('entering', 'a'): 0.00019878081102570898,
#  ('candidate', 'for'): 0.00039724576271186443,
#  ('for', 'governor'): 0.00031038549878949657,
#  ('governor', 'would'): 0.00013245033112582781,
#  ('would', 'force'): 0.0002604505795025394,
#  ('force', 'it'): 0.00013250298131707962,
#  ('it', 'to'): 0.0005802333827606215,
#  ('to', 'take'): 0.0013220670230499512,
#  ('take', 'petitions'): 0.0001321353065539112,
#  ('petitions', 'out'): 0.00013252054068380598,
#  ('out', 'into'): 0.0001310701880857199,
#  ('into', 'voting'): 0.00013144058885383806,
#  ('voting', 'precincts'): 0.0001324942033786022,
#  ('precincts', 'to'): 0.0001325381047051027,
#  ('to', 'obtain'): 0.00045984939932172214,
#  ('obtain', 'the'): 0.00019875447197561946,
#  ('the', 'signatures'): 0.00018917896329928113,
#  ('signatures', 'of'): 0.00019879398316877608,
#  ('of', 'registered'): 0.00010980564401010212,
#  ('registered', 'voters'): 0.0001325556733828208,
#  ('voters', '.'): 0.00019870181480990858,
#  ('<s>', 'Despite'): 0.00029871552325002487,
#  ('Despite', 'the'): 0.0002650586442250348,
#  ('the', 'warning'): 9.458948164964057e-05,
#  ('warning', ','): 0.0001325381047051027,
#  (',', 'there'): 0.0012626262626262627,
#  ('there', 'was'): 0.001182343667892801,
#  ('was', 'a'): 0.003337741671389886,
#  ('a', 'unanimous'): 0.00017417556897352532,
#  ('unanimous', 'vote'): 0.0001325556733828208,
#  ('vote', 'to'): 0.00026451527575717496,
#  ('candidate', ','): 0.00026483050847457627,
#  (',', 'according'): 0.001116938616938617,
#  ('according', 'to'): 0.0015884572109338805,
#  ('to', 'Republicans'): 0.00011496234983043054,
#  ('Republicans', 'who'): 0.00013243279035889287,
#  ('who', 'attended'): 0.00019508388607101054,
#  ('attended', '.'): 0.00013248542660307367,
#  ('<s>', 'When'): 0.0017922931395001494,
#  ('When', 'the'): 0.0007270804415361227,
#  ('the', 'crowd'): 0.00014188422247446084,
#  ('crowd', 'was'): 0.00013250298131707962,
#  ('was', 'asked'): 0.0003778575477045154,
#  ('asked', 'whether'): 0.0001983995767475696,
#  ('whether', 'it'): 0.00019857029388403494,
#  ('it', 'wanted'): 0.00012894075172458256,
#  ('wanted', 'to'): 0.0005957897524162584,
#  ('to', 'wait'): 0.0001724435247456458,
#  ('wait', 'one'): 0.0001325381047051027,
#  ('one', 'more'): 0.00019623233908948196,
#  ('more', 'term'): 0.0001309328968903437,
#  ('term', 'to'): 0.00019867549668874172,
#  ('to', 'make'): 0.0016094728976260276,
#  ('make', 'the'): 0.000660676532769556,
#  ('the', 'race'): 0.00018917896329928113,
#  (',', 'it'): 0.0031565656565656565,
#  ('it', 'voted'): 0.00012894075172458256,
#  ('voted', 'no'): 0.00013247665099026297,
#  ('no', '--'): 0.00013152702880441932,
#  ('--', 'and'): 0.0016884213260601338,
#  ('and', 'there'): 0.0005168849069607167,
#  ('there', 'were'): 0.001182343667892801,
#  ('were', 'no'): 0.00019549068161084322,
#  ('no', 'dissents'): 0.00013152702880441932,
#  ('dissents', '.'): 0.00013256445946841652,
#  ('The', 'largest'): 0.000125203455615375,
#  ('largest', 'hurdle'): 0.00013248542660307367,
#  ('hurdle', 'the'): 0.00013256445946841652,
#  ('the', 'Republicans'): 0.00028376844494892167,
#  ('Republicans', 'would'): 0.00013243279035889287,
#  ('would', 'have'): 0.001302252897512697,
#  ('have', 'to'): 0.0012997140629061607,
#  ...}

# %%
#For webtext corpus
bgrams_webtext = create_bigrams(webtext_tokens)
bgrams_webtext_wc = Counter(bgrams_webtext)

# %%
cp_webtext = {} # cp_webtext -> conditional probabilities of bigrams

for i in bgrams_webtext:
  cp_webtext[i] = conditional_probability(i[0], i[1], bgrams_webtext_wc, webtext_wc, V_webtext)

# %%
cp_webtext
# Out:
# {('<s>', 'Cookie'): 0.00018316136516270836,
#  ('Cookie', 'Manager'): 0.0008771160424524164,
#  ('Manager', ':'): 0.00025956047759127874,
#  (':', '"'): 0.0022407394440165256,
#  ('"', 'Don'): 0.0003726337755254136,
#  ('Don', "'"): 0.0035905070496540853,
#  ("'", 't'): 0.09080005644137153,
#  ('t', 'allow'): 0.000552224676554118,
#  ('allow', 'sites'): 0.0002624212736179146,
#  ('sites', 'that'): 0.00043698654081454294,
#  ('that', 'set'): 0.00025397900440230273,
#  ('set', 'removed'): 0.0002610966057441253,
#  ('removed', 'cookies'): 0.00026313481273572496,
#  ('cookies', 'to'): 0.00026232948583420777,
#  ('to', 'set'): 0.0013562709686630024,
#  ('set', 'future'): 0.0002610966057441253,
#  ('future', 'cookies'): 0.00026352775825720307,
#  ('cookies', '"'): 0.0004372158097236796,
#  ('"', 'should'): 0.0014160083469965717,
#  ('should', 'stay'): 0.00033701238520515627,
#  ('stay', 'checked'): 0.0005259006047856955,
#  ('checked', 'When'): 0.00017540782318891423,
#  ('When', 'in'): 0.0003471017007983339,
#  ('in', 'full'): 0.0005071361298268492,
#  ('full', 'screen'): 0.0017514668534897976,
#  ('screen', 'mode'): 0.0013936068286734605,
#  ('mode', 'Pressing'): 0.00017497812773403323,
#  ('Pressing', 'Ctrl'): 0.00035124692658939234,
#  ('Ctrl', '-'): 0.002178649237472767,
#  ('-', 'N'): 0.0001552312946289972,
#  ('N', 'should'): 0.00017571604287471446,
#  ('should', 'open'): 0.0017693150223270706,
#  ('open', 'a'): 0.0037926675094816687,
#  ('a', 'new'): 0.00825561840697141,
#  ('new', 'browser'): 0.0006771053745239103,
#  ('browser', 'when'): 0.0005097272958966952,
#  ('when', 'only'): 0.00086716594402838,
#  ('only', 'download'): 0.0001731451822353043,
#  ('download', 'dialog'): 0.0006851661527920521,
#  ('dialog', 'is'): 0.0011102570672132548,
#  ('is', 'left'): 0.00039485114111979786,
#  ('left', 'open'): 0.0002615746795710175,
#  ('open', 'add'): 0.0001685630004214075,
#  ('add', 'icons'): 0.00017433751743375174,
#  ('icons', 'to'): 0.000522420548541576,
#  ('to', 'context'): 0.0002855307302448426,
#  ('context', 'menu'): 0.007315161543150745,
#  ('menu', 'So'): 0.00016890465332319906,
#  ('So', 'called'): 0.00017476406850751484,
#  ('called', '"'): 0.00035081564637782847,
#  ('"', 'tab'): 0.0003726337755254136,
#  ('tab', 'bar'): 0.0019433882551753274,
#  ('bar', '"'): 0.00042236864335191754,
#  ('should', 'be'): 0.013059229926699806,
#  ('be', 'made'): 0.0005901197099983139,
#  ('made', 'a'): 0.00026308866087871614,
#  ('a', 'proper'): 0.00030576364470264486,
#  ('proper', 'toolbar'): 0.0001756388864494599,
#  ('toolbar', 'or'): 0.00042578557438473983,
#  ('or', 'given'): 0.000170984012994785,
#  ('given', 'the'): 0.00026325026325026325,
#  ('the', 'ability'): 0.00028912179255511386,
#  ('ability', 'collapse'): 0.00017537706068046299,
#  ('collapse', '/'): 0.000175530981218185,
#  ('/', 'expand'): 0.0001721763085399449,
#  ('expand', '.'): 0.0001753155680224404,
#  ('.', '</s>'): 0.18714818797040036,
#  ('</s>', '<s>'): 0.30526894193784726,
#  ('<s>', '['): 0.008547530374259723,
#  ('[', 'XUL'): 0.00016871941960519654,
#  ('XUL', ']'): 0.00017556179775280898,
#  (']', 'Implement'): 0.00016835016835016836,
#  ('Implement', 'Cocoa'): 0.00017537706068046299,
#  ('Cocoa', '-'): 0.0001757469244288225,
#  ('-', 'style'): 0.0009313877677739833,
#  ('style', 'toolbar'): 0.00017511601435951318,
#  ('toolbar', 'customization'): 0.0009367282636464277,
#  ('customization', '.'): 0.00026327336551118914,
#  ('<s>', '#'): 0.00018316136516270836,
#  ('#', 'ifdefs'): 0.0002520373015206251,
#  ('ifdefs', 'for'): 0.00017571604287471446,
#  ('for', 'MOZ_PHOENIX'): 0.00016378674965195316,
#  ('MOZ_PHOENIX', 'customize'): 0.00017570060616709128,
#  ('customize', 'dialog'): 0.00043790506218251883,
#  ('dialog', "'"): 0.00025621316935690495,
#  ("'", 's'): 0.040778890927049526,
#  ('s', 'toolbar'): 0.00025027112705430885,
#  ('toolbar', 'has'): 0.0003406284595077919,
#  ('has', 'small'): 0.00017313019390581717,
#  ('small', 'icons'): 0.0009626323619497681,
#  ('icons', 'when'): 0.000261210274270788,
#  ('when', 'small'): 0.00015766653527788727,
#  ('icons', 'is'): 0.000174140182847192,
#  ('is', 'not'): 0.013109057885177288,
#  ('not', 'checked'): 0.00030792917628945344,
#  ('checked', 'nightly'): 0.00017540782318891423,
#  ('nightly', 'builds'): 0.0008766546857192952,
#  ('builds', 'and'): 0.00017507002801120448,
#  ('and', 'tinderboxen'): 0.00015873015873015873,
#  ('tinderboxen', 'for'): 0.0001757469244288225,
#  ('for', 'Phoenix'): 0.0004094668741298829,
#  ('Phoenix', 'finish'): 0.0001729355814958928,
#  ('finish', 'tearing'): 0.0001756543123133673,
#  ('tearing', 'prefs'): 0.0001757469244288225,
#  ('prefs', 'UI'): 0.0001752541184717841,
#  ('UI', 'to'): 0.0005239717055279015,
#  ('to', 'pieces'): 0.0001427653651224213,
#  ('pieces', 'and'): 0.0001757469244288225,
#  ('and', 'then'): 0.0025396825396825397,
#  ('then', 'make'): 0.00017445917655268666,
#  ('make', 'it'): 0.0007852717912922083,
#  ('it', 'not'): 0.00041949828005705174,
#  ('not', 'suck'): 0.00030792917628945344,
#  ('suck', '"'): 0.00017570060616709128,
#  ('"', 'mozbrowser'): 0.00014905351021016544,
#  ('mozbrowser', '"'): 0.00017573148229505317,
#  ('"', 'script'): 0.00014905351021016544,
#  ('script', 'doesn'): 0.00017543859649122806,
#  ('doesn', "'"): 0.03958139927420035,
#  ('t', 'start'): 0.0019722309876932785,
#  ('start', 'correct'): 0.00017382235355466714,
#  ('correct', 'binary'): 0.0001755001755001755,
#  ('binary', 'Need'): 0.0001756388864494599,
#  ('Need', 'bookmark'): 0.00017503938386136881,
#  ('bookmark', 'groups'): 0.00034164673727365904,
#  ('groups', 'icon'): 0.0001755926251097454,
#  ('icon', 'Dropping'): 0.00017302534821351327,
#  ('Dropping', 'at'): 0.00017573148229505317,
#  ('at', 'top'): 0.00043021855102392013,
#  ('top', 'of'): 0.0014869238170209043,
#  ('of', 'palette'): 0.00015929908403026683,
#  ('palette', 'box'): 0.00017570060616709128,
#  ('box', 'horks'): 0.00017356591165495098,
#  ('horks', 'things'): 0.0002635740643120717,
#  ('things', 'keyboard'): 0.000175530981218185,
#  ('keyboard', 'shortcut'): 0.001660258650821391,
#  ('shortcut', 'for'): 0.0012238832065740012,
#  ('for', 'Increase'): 0.00016378674965195316,
#  ('Increase', 'Text'): 0.0001757469244288225,
#  ('Text', 'Size'): 0.0005250721974271463,
#  ('Size', 'is'): 0.0002634120642725437,
#  ('is', 'broken'): 0.0022901366184948273,
#  ('broken', 'default'): 0.00017404925593943085,
#  ('default', 'phoenix'): 0.00025870989996550536,
#  ('phoenix', 'bookmarks'): 0.00026175726376406945,
#  ('bookmarks', '['): 0.00017048844940755265,
#  ('[', 'cust'): 0.002108992745064957,
#  ('cust', ']'): 0.0021924055073226346,
#  (']', 'need'): 0.0002525252525252525,
#  ('need', 'a'): 0.0008745845723281442,
#  ('a', 'toolbar'): 0.0008408500229322734,
#  ('toolbar', 'spacer'): 0.00017031422975389594,
#  ('spacer', 'and'): 0.00017573148229505317,
#  ('and', 'spring'): 0.00015873015873015873,
#  ('spring', 'spacer'): 0.0001757469244288225,
#  ('spacer', 'for'): 0.00017573148229505317,
#  ('for', 'customize'): 0.0002456801244779297,
#  ('customize', 'Can'): 0.00017516202487300754,
#  ('Can', "'"): 0.009202187689903638,
#  ('t', 'launch'): 0.0007100031555695803,
#  ('launch', 'phoenix'): 0.0002625131256562828,
#  ('phoenix', 'while'): 0.00017450484250937964,
#  ('while', 'Mozilla'): 0.00017364125716270185,
#  ('Mozilla', 'is'): 0.0003448573152858005,
#  ('is', 'running'): 0.0012635236515833531,
#  ('running', '('): 0.00017485574401119076,
#  ('(', 'or'): 0.0016454134101192926,
#  ('or', 'vice'): 0.00025647601949217746,
#  ('vice', 'versa'): 0.00017571604287471446,
#  ('versa', ')'): 0.00017573148229505317,
#  (')', 'separator'): 0.00016633399866932801,
#  ('separator', 'not'): 0.00017554638813306416,
#  ('not', 'available'): 0.0007698229407236335,
#  ('available', 'when'): 0.000350385423966363,
#  ('when', 'all'): 0.0004729996058336618,
#  ('all', 'toolbar'): 0.00025693730729701953,
#  ('toolbar', 'items'): 0.00042578557438473983,
#  ('items', 'are'): 0.00034965034965034965,
#  ('are', 'in'): 0.0005947323704333051,
#  ('in', 'toolbar'): 0.0007969282040136203,
#  ('toolbar', 'layout'): 0.00017031422975389594,
#  ('layout', 'history'): 0.0001755926251097454,
#  ('history', 'menu'): 0.00026089225150013044,
#  ('menu', 'for'): 0.0010134279199391944,
#  ('for', 'the'): 0.005077389239210548,
#  ('the', 'back'): 0.0010119262739428985,
#  ('back', 'buttons'): 0.000867227473766369,
#  ('buttons', 'doesn'): 0.00017392816766675364,
#  ('t', 'work'): 0.0156989586620385,
#  ('work', 'attempting'): 0.0001693623507494284,
#  ('attempting', 'to'): 0.0018421052631578947,
#  ('to', 'open'): 0.00770932971661075,
#  ('open', '"'): 0.0008428150021070375,
#  ('"', 'back'): 0.0005962140408406618,
#  ('back', 'button'): 0.001734454947532738,
#  ('button', 'history'): 0.00034065746891500596,
#  ('menu', '"'): 0.0005911662866311967,
#  ('"', 'in'): 0.004322551796094798,
#  ('in', 'the'): 0.023907846120408607,
#  ('the', 'second'): 0.0005059631369714493,
#  ('second', 'window'): 0.000525164113785558,
#  ('window', 'generates'): 0.00016680567139282736,
#  ('generates', 'another'): 0.0001756543123133673,
#  ('another', 'back'): 0.0001749475157452764,
#  ('button', 'on'): 0.0018736160790325327,
#  ('on', 'the'): 0.009697348869946039,
#  ('the', 'toolbar'): 0.0010842067220816769,
#  ('toolbar', 'Phoenix'): 0.0002554713446308439,
#  ('Phoenix', 'and'): 0.0001729355814958928,
#  ('and', 'Mozilla'): 0.0004761904761904762,
#  ('Mozilla', 'cannot'): 0.00017242865764290026,
#  ('cannot', 'comfortably'): 0.00017373175816539263,
#  ('comfortably', 'share'): 0.0001757469244288225,
#  ('share', 'a'): 0.0001756697408871322,
#  ('a', 'source'): 0.00015288182235132243,
#  ('source', 'tree'): 0.00017485574401119076,
#  ('tree', 'Phoenix'): 0.00017536168347216134,
#  ('Phoenix', 'forgets'): 0.0001729355814958928,
#  ('forgets', 'all'): 0.00017557721007813187,
#  ('all', 'cookies'): 0.0005138746145940391,
#  ('cookies', 'even'): 0.00026232948583420777,
#  ('even', 'though'): 0.0011337868480725624,
#  ('though', '"'): 0.00035096955339124333,
#  ('"', 'Enable'): 0.00022358026531524818,
#  ('Enable', 'cookies'): 0.00026325026325026325,
#  ('cookies', 'for'): 0.00026232948583420777,
#  ('the', 'current'): 0.0011564871702204554,
#  ('current', 'session'): 0.00043717758153361897,
#  ('session', 'only'): 0.00043828892005610097,
#  ('only', '"'): 0.0009522985022941737,
#  ('"', 'is'): 0.0031301237144134744,
#  ('is', 'NOT'): 0.00015794045644791914,
#  ('NOT', 'chosen'): 0.0001756388864494599,
#  ('chosen', 'Starting'): 0.00017562346329469617,
#  ('Starting', 'Customizing'): 0.0001756697408871322,
#  ('Customizing', 'Toolbar'): 0.00026345832967418985,
#  ('Toolbar', 'makes'): 0.00017341541663053845,
#  ('makes', 'the'): 0.0007007094683366909,
#  ('current', 'page'): 0.0006120486141470666,
#  ('page', 'go'): 0.00016531658125309968,
#  ('go', 'blank'): 0.00026091494172899633,
#  ('blank', 'Check'): 0.00017470300489168413,
#  ('Check', 'in'): 0.00026352775825720307,
#  ('in', 'Satchel'): 0.0001448960370933855,
#  ('Satchel', '('): 0.00017570060616709128,
#  ('(', 'the'): 0.00032908268202385847,
#  ('the', 'successor'): 0.00014456089627755693,
#  ('successor', 'to'): 0.0001757469244288225,
#  ('to', 'wallet'): 0.0001427653651224213,
#  ('wallet', ')'): 0.00017568517217146873,
#  (')', 'Mousing'): 0.00016633399866932801,
#  ('Mousing', 'over'): 0.00017573148229505317,
#  ('over', 'back'): 0.00017418568193694478,
#  ('back', 'menu'): 0.00026016824212991065,
#  ('menu', 'in'): 0.001097880246600794,
#  ('in', 'second'): 0.0001448960370933855,
#  ('window', 'horks'): 0.00016680567139282736,
#  ('things', 'Personal'): 0.000175530981218185,
#  ('Personal', 'toolbar'): 0.0002631809807877884,
#  ('toolbar', 'needs'): 0.00017031422975389594,
#  ('needs', 'a'): 0.0004374453193350831,
#  ('a', 'min'): 0.00015288182235132243,
#  ('min', '-'): 0.00017571604287471446,
#  ('-', 'height'): 0.00023284694194349582,
#  ('height', 'to'): 0.0002633889376646181,
#  ('to', 'avoid'): 0.0003569134128060533,
#  ('avoid', '"'): 0.00017570060616709128,
#  ('"', 'popping'): 0.00014905351021016544,
#  ('popping', 'in'): 0.0001757469244288225,
#  ('in', '"'): 0.002825472723321017,
#  ('"', 'New'): 0.0008943210612609927,
#  ('New', 'Folder'): 0.0010442955356365852,
#  ('Folder', '...'): 0.00026246719160104987,
#  ('...', 'in'): 0.00017082336863682952,
#  ('in', 'ptoolbar'): 0.0001448960370933855,
#  ('ptoolbar', 'context'): 0.0001757469244288225,
#  ('menu', 'is'): 0.0009289755932775948,
#  ('broken', 'Implement'): 0.00017404925593943085,
#  ('Implement', 'Mozilla'): 0.00017537706068046299,
#  ('Mozilla', 'Firebird'): 0.00689714630571601,
#  ('Firebird', 'Help'): 0.0005077860528097495,
#  ('Help', 'tabs'): 0.00017500875043752187,
#  ('tabs', 'close'): 0.00017204301075268816,
#  ('close', 'in'): 0.00025998786723286244,
#  ('the', 'wrong'): 0.0010119262739428985,
#  ('wrong', 'order'): 0.00034782608695652176,
#  ('order', '('): 0.0002629733520336606,
#  ('(', 'right'): 0.00032908268202385847,
#  ('right', 'to'): 0.000518000518000518,
#  ('to', 'left'): 0.0004282960953672639,
#  ('left', ')'): 0.0002615746795710175,
#  (')', 'back'): 0.00016633399866932801,
#  ('buttons', 'and'): 0.0004348204191668841,
#  ('and', 'context'): 0.0002380952380952381,
#  ('context', 'options'): 0.00017417051293216058,
#  ('options', 'always'): 0.0001743223219733287,
#  ('always', 'disabled'): 0.00017442874585731728,
#  ('disabled', '.'): 0.00026237537169844326,
#  ('<s>', 'Customising'): 0.0001221075767751389,
#  ('Customising', 'toolbar'): 0.0001757469244288225,
#  ('toolbar', 'breaks'): 0.0002554713446308439,
#  ('breaks', 'the'): 0.0004377517072316582,
#  ('the', 'throbber'): 0.00014456089627755693,
#  ('throbber', '!'): 0.00017551557700745942,
#  ('!', '</s>'): 0.09148970142104423,
#  ('<s>', 'manage'): 0.0001221075767751389,
#  ('manage', 'bookmarks'): 0.00070212392487274,
#  ('bookmarks', 'causes'): 0.0004262211235188816,
#  ('causes', 'hang'): 0.00025996533795493934,
#  ('hang', 'land'): 0.0001752694768206117,
#  ('land', 'pch'): 0.00017554638813306416,
#  ('pch', "'"): 0.0001757469244288225,
#  ('s', 'bookmarks'): 0.00025027112705430885,
#  ('bookmarks', 'patch'): 0.00017048844940755265,
#  ('patch', 'from'): 0.00017556179775280898,
#  ('from', 'bug'): 0.0003349803199062055,
#  ('bug', '160019'): 0.00017500875043752187,
#  ('160019', 'Preferences'): 0.0001757469244288225,
#  ('Preferences', '>'): 0.0005243380232456523,
#  ('>', 'Privacy'): 0.0001738374619730552,
#  ('Privacy', '>'): 0.0002631578947368421,
#  ('>', 'Images'): 0.0001738374619730552,
#  ('Images', '=='): 0.0001753155680224404,
#  ('==', 'Wonky'): 0.00017570060616709128,
#  ('Wonky', 'Extremely'): 0.0001757469244288225,
#  ('Extremely', 'high'): 0.0001757469244288225,
#  ('high', 'memory'): 0.00017546938059308652,
#  ('memory', 'consumption'): 0.00017542320849048328,
#  ('consumption', 'after'): 0.00017573148229505317,
#  ('after', 'closing'): 0.0011832319134550372,
#  ('closing', 'all'): 0.0004371393600279769,
#  ('all', 'windows'): 0.0012846865364850976,
#  ('windows', 'with'): 0.0002591792656587473,
#  ('with', 'Quick'): 0.0001644331168297295,
#  ('Quick', 'Launch'): 0.0006141967184346758,
#  ('Launch', '('): 0.0001755926251097454,
#  ('(', 'Turbo'): 0.00016454134101192923,
#  ('Turbo', ')'): 0.00017573148229505317,
#  (')', 'enabled'): 0.00016633399866932801,
#  ('enabled', 'Go'): 0.000175054704595186,
#  ('Go', 'menu'): 0.0009635599159074983,
#  ('menu', 'needs'): 0.00016890465332319906,
#  ('needs', 'to'): 0.0016622922134733157,
#  ('to', 'have'): 0.0017131843814690555,
#  ('have', 'an'): 0.000513083632632119,
#  ('an', 'id'): 0.00025810892196506923,
#  ('id', '='): 0.0002633889376646181,
#  ('=', 'implement'): 0.00017508535411012868,
#  ('implement', 'progress'): 0.00017554638813306416,
#  ('progress', 'meter'): 0.00017554638813306416,
#  ('meter', 'in'): 0.00017573148229505317,
#  ('in', 'URLbar'): 0.0001448960370933855,
#  ('URLbar', 'view'): 0.00017573148229505317,
#  ('view', 'source'): 0.001396526141223706,
#  ('source', 'tries'): 0.00017485574401119076,
#  ('tries', 'to'): 0.001491620601912784,
#  ('to', 'download'): 0.0023556285245199516,
#  ('download', 'type'): 0.00017129153819801302,
#  ('type', 'application'): 0.00017441353449027645,
#  ('application', 'x'): 0.00017467248908296942,
#  ('x', '-'): 0.0004385964912280702,
#  ('-', 'view'): 0.0001552312946289972,
#  ('view', '-'): 0.0005236973029588898,
#  ('-', 'source'): 0.0006209251785159888,
#  ('source', 'from'): 0.0003497114880223815,
#  ('from', 'view'): 0.00025123523992965415,
#  ('source', ':<'): 0.00017485574401119076,
#  (':<', 'url'): 0.0001757469244288225,
#  ('url', '>'): 0.00026052974381241857,
#  ('>', 'second'): 0.0001738374619730552,
#  ('window', 'opens'): 0.0004170141784820684,
#  ('opens', 'mozilla'): 0.000174140182847192,
#  ('mozilla', 'fix'): 0.0001743223219733287,
#  ('fix', 'branding'): 0.0001755001755001755,
#  ('branding', 'auto'): 0.00017573148229505317,
#  ('auto', 'close'): 0.00026272002802346965,
#  ('close', 'for'): 0.00017332524482190832,
#  ('for', 'download'): 0.0004913602489558594,
#  ('download', 'manager'): 0.006080849606029462,
#  ('manager', 'would'): 0.00017228012748729435,
#  ('would', 'be'): 0.0012249540642225918,
#  ('be', 'nice'): 0.0006744225257123588,
#  ('nice', 'Components'): 0.00017533093714385903,
#  ('Components', 'of'): 0.00017571604287471446,
#  ('of', 'the'): 0.014496216646754281,
#  ('the', 'Navigation'): 0.00014456089627755693,
#  ('Navigation', 'Toolbar'): 0.000614304519526108,
#  ('Toolbar', 'do'): 0.00017341541663053845,
#  ('do', 'not'): 0.008706146021894665,
#  ('not', 'appear'): 0.0020015396458814474,
#  ('appear', 'with'): 0.00026194010302977384,
#  ('with', 'the'): 0.0036175285702540493,
#  ('the', 'Modern'): 0.00021684134441633538,
#  ('Modern', 'theme'): 0.0004391743522178305,
#  ('theme', '.'): 0.0007809788267962514,
#  ('<s>', 'Pop'): 0.00018316136516270836,
#  ('Pop', 'up'): 0.00017562346329469617,
#  ('up', 'window'): 0.0009365687526607067,
#  ('window', 'blocking'): 0.0003336113427856547,
#  ('blocking', 'Uabar'): 0.0001752694768206117,
#  ('Uabar', 'doesn'): 0.0001757469244288225,
#  ('work', 'Theme'): 0.0002540435261241426,
#  ('Theme', 'changes'): 0.00017523876281433454,
#  ('changes', 'will'): 0.00017511601435951318,
#  ('will', 'take'): 0.0002601231249458077,
#  ('take', 'effect'): 0.0005249803132382536,
#  ('effect', 'when'): 0.00026313481273572496,
#  ('when', 'you'): 0.003232163973196689,
#  ('you', 'restart'): 0.0002475656048852946,
#  ('restart', '_Mozilla_'): 0.0001751927119831815,
#  ('_Mozilla_', '.'): 0.0001757469244288225,
#  ('<s>', 'Need'): 0.0002442151535502778,
#  ('Need', 'large'): 0.00017503938386136881,
#  ('large', 'icons'): 0.00026269702276707533,
#  ('icons', 'for'): 0.0008707009142359599,
#  ('the', 'Options'): 0.0006505240332490062,
#  ('Options', 'menu'): 0.00017382235355466714,
#  ('menu', 'Enable'): 0.00016890465332319906,
#  ('Enable', 'images'): 0.00026325026325026325,
#  ('images', 'cannot'): 0.0001743071291615827,
#  ('cannot', 'be'): 0.004169562195969423,
#  ('be', 'used'): 0.0005901197099983139,
#  ('used', 'to'): 0.0021839783349349175,
#  ('to', 'disable'): 0.001427653651224213,
#  ('disable', 'the'): 0.0005250721974271463,
#  ('the', 'display'): 0.00028912179255511386,
#  ('display', 'of'): 0.0010410340938665742,
#  ('of', 'images'): 0.00031859816806053366,
#  ('images', '.'): 0.0003486142583231654,
#  ('<s>', 'The'): 0.0031137432077660418,
#  ('The', 'bookmark'): 0.00025877684809799017,
#  ('bookmark', 'tree'): 0.00017082336863682952,
#  ('tree', 'jumps'): 0.00017536168347216134,
#  ('jumps', 'unexpectedly'): 0.00017570060616709128,
#  ('unexpectedly', 'to'): 0.00017570060616709128,
#  ('to', 'the'): 0.010064958241130701,
#  ('the', 'bottom'): 0.0008673653776653415,
#  ('bottom', 'of'): 0.0007894044382071748,
#  ('of', 'its'): 0.00015929908403026683,
#  ('its', 'view'): 0.00017500875043752187,
#  ('view', 'when'): 0.0002618486514794449,
#  ('when', 'the'): 0.0030744974379188017,
#  ('the', 'the'): 0.00021684134441633538,
#  ('the', 'first'): 0.0026020961329960247,
#  ('first', 'visible'): 0.00017424638438752395,
#  ('visible', 'row'): 0.0002628811777076761,
#  ('row', 'is'): 0.00017560804284836245,
#  ('not', 'the'): 0.0009237875288683603,
#  ('first', 'one'): 0.00026136957658128593,
#  ('one', 'Move'): 0.00017310022503029253,
#  ('Move', 'bookmarks'): 0.000175530981218185,
#  ('bookmarks', 'transactions'): 0.00017048844940755265,
#  ('transactions', 'into'): 0.0001757469244288225,
#  ('into', 'a'): 0.0016501650165016502,
#  ('a', 'JS'): 0.00030576364470264486,
#  ('JS', 'service'): 0.00017556179775280898,
#  ('service', '('): 0.00017568517217146873,
#  ('(', 'adding'): 0.00016454134101192923,
#  ('adding', 'a'): 0.0006138735420503376,
#  ('a', 'bookmark'): 0.003974927381134383,
#  ('bookmark', 'leaks'): 0.00017082336863682952,
#  ('leaks', 'the'): 0.00017570060616709128,
#  ('the', 'Add'): 0.00014456089627755693,
#  ('Add', 'Bookmark'): 0.002688172043010753,
#  ('Bookmark', 'dialog'): 0.0012141184632729165,
#  ('dialog', ')'): 0.00025621316935690495,
#  (')', 'Shortcut'): 0.00016633399866932801,
#  ('Shortcut', 'Ctrl'): 0.00017562346329469617,
#  ('-', 'Y'): 0.0001552312946289972,
#  ('Y', '('): 0.00017568517217146873,
#  ('(', 'redo'): 0.00016454134101192923,
#  ('redo', ')'): 0.0001757469244288225,
#  (')', 'does'): 0.000914836992681304,
#  ('does', 'not'): 0.045356011339002834,
#  ('not', 'work'): 0.01170130869899923,
#  ('work', 'in'): 0.0036412905411127108,
#  ('in', 'Bookmarks'): 0.0016663044265739333,
#  ('Bookmarks', 'Manager'): 0.00258086717136958,
#  ('Manager', 'Eradicate'): 0.00017304031839418584,
#  ('Eradicate', 'AddBookmarkImmediately'): 0.0001757469244288225,
#  ('AddBookmarkImmediately', 'Deleting'): 0.0001757469244288225,
#  ('Deleting', 'a'): 0.00026350461133069827,
#  ('a', 'selection'): 0.00022932273352698363,
#  ('selection', 'should'): 0.00017513134851138354,
#  ('should', 'select'): 0.00016850619260257814,
#  ('select', 'the'): 0.00026221484136002097,
#  ('the', 'next'): 0.00093964582580412,
#  ('next', 'item'): 0.00017514668534897976,
#  ('item', 'transaction'): 0.00017461148943600488,
#  ('transaction', 'manager'): 0.00017571604287471446,
#  ('manager', 'does'): 0.0009475407011801188,
#  ('not', 'handle'): 0.00030792917628945344,
#  ('handle', 'import'): 0.00017551557700745942,
#  ('import', 'customize'): 0.00017514668534897976,
#  ('customize', 'toolbar'): 0.0012261341741110527,
#  ('toolbar', 'clears'): 0.00017031422975389594,
#  ('clears', 'URL'): 0.00017568517217146873,
#  ('URL', '3'): 0.00017118890695882907,
#  ('3', '.'): 0.001309814879497031,
#  ('.', '2'): 0.0020239074062361646,
#  ('2', '%'): 0.0001712035610340695,
#  ('%', 'increase'): 0.00017503938386136881,
#  ('increase', 'in'): 0.00026343519494204424,
#  ('in', 'Phoenix'): 0.0009418242411070057,
#  ('Phoenix', 'Ts'): 0.0001729355814958928,
#  ('Ts', 'after'): 0.00017571604287471446,
#  ('after', 'bookmark'): 0.0002535496957403651,
#  ('bookmark', 'landing'): 0.00017082336863682952,
#  ('landing', 'cannot'): 0.00017573148229505317,
#  ('cannot', 'close'): 0.00026059763724808893,
#  ('close', 'folder'): 0.00017332524482190832,
#  ('folder', 'with'): 0.00025924645696508814,
#  ('with', 'single'): 0.0002466496752445943,
#  ('single', 'click'): 0.0002630655910206945,
#  ('click', 'on'): 0.0055880330123796425,
#  ('on', 'twistie'): 0.00015640885274106515,
#  ('twistie', 'Pref'): 0.0001757469244288225,
#  ('Pref', 'UI'): 0.0001756697408871322,
#  ('to', 'specify'): 0.0004996787779284746,
#  ('specify', 'a'): 0.00026343519494204424,
#  ('a', 'proxy'): 0.0003822045558783061,
#  ('proxy', 'server'): 0.0008738967054094206,
#  ('server', 'for'): 0.00017513134851138354,
#  ('for', 'web'): 0.00032757349930390633,
#  ('web', 'navigation'): 0.00017395842393667913,
#  ('navigation', 'Implement'): 0.00017530020159523183,
#  ('Implement', 'improved'): 0.00017537706068046299,
#  ('improved', 'Implement'): 0.00017571604287471446,
#  ('Implement', 'global'): 0.00017537706068046299,
#  ('global', 'Go'): 0.00017562346329469617,
#  ('menu', 'Readd'): 0.00016890465332319906,
#  ('Readd', 'Open'): 0.0001757469244288225,
#  ('Open', 'Location'): 0.0005226936144263438,
#  ('Location', 'Need'): 0.0001751006828926633,
#  ('Need', 'tab'): 0.00017503938386136881,
#  ('tab', 'loading'): 0.00033798056611744826,
#  ('loading', 'icon'): 0.00026091494172899633,
#  ('icon', 'first'): 0.00017302534821351327,
#  ('first', 'Mozilla'): 0.00017424638438752395,
#  ('Mozilla', 'Firefox'): 0.0018105009052504525,
#  ('Firefox', 'window'): 0.0005007929221267006,
#  ('window', 'ignored'): 0.000250208507089241,
#  ('ignored', 'by'): 0.00035075412136092597,
#  ('by', 'nsIWindowMediator'): 0.0002589779005524862,
#  ('nsIWindowMediator', 'first'): 0.00017573148229505317,
#  ('first', 'Phoenix'): 0.00017424638438752395,
#  ('Phoenix', 'window'): 0.00025940337224383917,
#  ('nsIWindowMediator', 'preferences'): 0.00017573148229505317,
#  ('preferences', 'no'): 0.0002613012803762738,
#  ('no', 'longer'): 0.004680452727427453,
#  ('longer', 'works'): 0.0010492261956806855,
#  ('works', 'Open'): 0.0001748710326134476,
#  ('Open', 'Personal'): 0.00017423120480878124,
#  ('Personal', 'Toolbar'): 0.0012281779103430126,
#  ('Toolbar', 'folder'): 0.0003468308332610769,
#  ('folder', 'in'): 0.001814725198755617,
#  ('toolbar', 'web'): 0.00017031422975389594,
#  ('web', 'search'): 0.00034791684787335825,
#  ('search', 'for'): 0.001209294290403386,
#  ('for', '""'): 0.00016378674965195316,
#  ('""', 'in'): 0.00017571604287471446,
#  ('in', 'context'): 0.00036224009273346376,
#  ('menu', 'don'): 0.0002533569799847986,
#  ('don', "'"): 0.020571526940953693,
#  ('work', 'Fix'): 0.0001693623507494284,
#  ('Fix', 'full'): 0.0001756543123133673,
#  ('screen', 'to'): 0.0002613012803762738,
#  ('have', 'smaller'): 0.0001710278775440397,
#  ('smaller', 'icons'): 0.0001756697408871322,
#  ('icons', 'Port'): 0.000174140182847192,
#  ('Port', 'patch'): 0.00017571604287471446,
#  ('patch', 'to'): 0.0002633426966292135,
#  ('to', 'bug'): 0.0003569134128060533,
#  ('bug', '164006'): 0.0002625131256562828,
#  ('164006', '('): 0.00017573148229505317,
#  ('(', 'wyciwyg'): 0.00016454134101192923,
#  ('wyciwyg', ':'): 0.00017570060616709128,
#  (':', 'in'): 0.00014004621525103285,
#  ('in', 'tab'): 0.0010142722596536984,
#  ('tab', 'titles'): 0.00016899028305872413,
#  ('titles', ')'): 0.0001756543123133673,
#  (')', '['): 0.0006653359946773121,
#  (']', 'Add'): 0.0003367003367003367,
#  ('Add', 'more'): 0.00026014568158168577,
#  ('more', 'off'): 0.00017450484250937964,
#  ('off', '-'): 0.0005226025607525476,
#  ('-', 'by'): 0.00023284694194349582,
#  ('by', '-'): 0.0002589779005524862,
#  ('-', 'default'): 0.00023284694194349582,
#  ('default', 'toolbar'): 0.00025870989996550536,
#  ('toolbar', 'buttons'): 0.0010218853785233756,
#  ('buttons', 'textmode'): 0.00017392816766675364,
#  ('textmode', 'buttons'): 0.0001757469244288225,
#  ('buttons', 'need'): 0.00017392816766675364,
#  ('need', 'hover'): 0.00017491691446562882,
#  ('hover', 'state'): 0.00043890449438202246,
#  ('state', 'enable'): 0.00017543859649122806,
#  ('enable', 'nsITheme'): 0.00017540782318891423,
#  ('nsITheme', 'form'): 0.0001757469244288225,
#  ('form', 'control'): 0.00017394329448599757,
#  ('control', 'goodness'): 0.00017543859649122806,
#  ('goodness', 'for'): 0.0001757469244288225,
#  ('Phoenix', 'rename'): 0.0001729355814958928,
#  ('rename', 'executable'): 0.0001755926251097454,
#  ('executable', 'and'): 0.0002634814684700509,
#  ('and', 'profile'): 0.0002380952380952381,
#  ('profile', 'dir'): 0.00026143790849673205,
#  ('dir', 'Need'): 0.0002633658151171978,
#  ('Need', 'to'): 0.0007001575354454753,
#  ('to', 'enable'): 0.0002855307302448426,
#  ('enable', 'wallet'): 0.00017540782318891423,
#  ('wallet', '('): 0.00017568517217146873,
#  ('(', 'password'): 0.00016454134101192923,
#  ('password', 'manager'): 0.0022602799269755714,
#  ('manager', 'manager'): 0.0002584201912309415,
#  ('manager', ')'): 0.0002584201912309415,
#  (')', 'New'): 0.00041583499667332,
#  ('New', 'Extension'): 0.00017404925593943085,
#  ('Extension', 'Manager'): 0.0012251684606633412,
#  ('Manager', 'the'): 0.00017304031839418584,
#  ('the', 'changes'): 0.00014456089627755693,
#  ('changes', 'to'): 0.0008755800717975659,
#  ('to', 'mozbrowser'): 0.0001427653651224213,
#  ('mozbrowser', 'too'): 0.00017573148229505317,
#  ('too', 'confusing'): 0.00017392816766675364,
#  ('confusing', 'and'): 0.00017571604287471446,
#  ('and', 'too'): 0.00015873015873015873,
#  ('too', 'much'): 0.0005217845030002609,
#  ('much', 'Missing'): 0.00017523876281433454,
#  ('Missing', 'proxy'): 0.000175530981218185,
#  ('proxy', 'image'): 0.00017477934108188413,
#  ('image', 'Cannot'): 0.00017371666811430558,
#  ('Cannot', 'File'): 0.00017452006980802793,
#  ('File', '>'): 0.0004368338284116722,
#  ('>', 'New'): 0.0001738374619730552,
#  ('New', 'Bookmark'): 0.000609172395788008,
#  ('Bookmark', 'while'): 0.0001734454947532738,
#  ('while', 'managing'): 0.00017364125716270185,
#  ('managing', 'a'): 0.00017570060616709128,
#  ('new', 'folder'): 0.0008463817181548879,
#  ('folder', 'Bookmarks'): 0.00025924645696508814,
#  ('Bookmarks', 'are'): 0.0006022023399862354,
#  ('are', 'not'): 0.0065420560747663555,
#  ('not', 'loaded'): 0.00046189376443418013,
#  ('loaded', 'if'): 0.00017511601435951318,
#  ('if', 'the'): 0.0021974306964164976,
#  ('the', 'Personal'): 0.00021684134441633538,
#  ('Toolbar', 'is'): 0.0006069539582068846,
#  ('is', 'switched'): 0.00015794045644791914,
#  ('switched', 'off'): 0.00017570060616709128,
#  ('off', 'Pretty'): 0.00017420085358418256,
#  ('Pretty', 'up'): 0.0001757469244288225,
#  ('up', 'dns'): 0.00017028522775649213,
#  ('dns', 'error'): 0.0002635509092506369,
#  ('error', 'page'): 0.0005175536961959803,
#  ('page', 'a'): 0.00033063316250619935,
#  ('a', 'bit'): 0.0006879682005809509,
#  ('bit', 'middle'): 0.00017546938059308652,
#  ('middle', 'click'): 0.0013975019652371387,
#  ('click', '('): 0.00042984869325997247,
#  ('(', 'pt'): 0.00016454134101192923,
#  ('pt', '+'): 0.00017571604287471446,
#  ('+', 'bookmark'): 0.00017236921485822633,
#  ('bookmark', 'menu'): 0.001110351896139392,
#  ('menu', ')'): 0.0006756186132927962,
#  (')', 'loads'): 0.00033266799733865603,
#  ('loads', 'in'): 0.0005253940455341507,
#  ('current', 'tab'): 0.0009617906793739617,
#  ('tab', '+'): 0.00016899028305872413,
#  ('+', 'new'): 0.00017236921485822633,
#  ('new', 'tab'): 0.011002962336013541,
#  ('tab', 'Nightly'): 0.00016899028305872413,
#  ('Nightly', 'for'): 0.00017571604287471446,
#  ('for', '22'): 0.00016378674965195316,
#  ('22', 'Sept'): 0.00017571604287471446,
#  ('Sept', 'displays'): 0.0001757469244288225,
#  ('displays', 'page'): 0.00017493221376716522,
#  ('page', 'details'): 0.00016531658125309968,
#  ('details', 'above'): 0.0001756543123133673,
#  ('above', 'window'): 0.00017540782318891423,
#  ('window', 'Ctrl'): 0.0003336113427856547,
#  ('-', 'W'): 0.0003104625892579944,
#  ('W', 'does'): 0.0002633889376646181,
#  ('not', 'close'): 0.001770592763664357,
#  ('close', 'the'): 0.0012132767137533582,
#  ('tab', 'listboxes'): 0.00016899028305872413,
#  ('listboxes', 'and'): 0.00017571604287471446,
#  ('and', 'tree'): 0.00015873015873015873,
#  ('tree', 'views'): 0.00017536168347216134,
#  ('views', 'don'): 0.0001757469244288225,
#  ('t', 'support'): 0.0004733354370463869,
#  ('support', 'themes'): 0.00017490161783996502,
#  ('themes', 'on'): 0.00017468774565464234,
#  ('on', 'winxp'): 0.00015640885274106515,
#  ('winxp', 'Ctrl'): 0.00017573148229505317,
#  ('Ctrl', '+'): 0.005751633986928104,
#  ('+', 'Mousewheel'): 0.00025855382228733947,
#  ('Mousewheel', 'should'): 0.00026352775825720307,
#  ('should', 'resize'): 0.00016850619260257814,
#  ('resize', 'text'): 0.00017542320849048328,
#  ('text', 'bookmarks'): 0.00017155601303825698,
#  ('bookmarks', 'should'): 0.0003409768988151053,
#  ('should', 'import'): 0.00016850619260257814,
#  ('import', 'Mozilla'): 0.0003502933706979595,
#  ('Mozilla', "'"): 0.0005172859729287007,
#  ('bookmarks', 'Please'): 0.00017048844940755265,
#  ('Please', 'tell'): 0.00017528483786152498,
#  ('tell', 'people'): 0.00017503938386136881,
#  ('people', 'to'): 0.00017484045808200017,
#  ('to', 'use'): 0.0027125419373260047,
#  ('use', 'a'): 0.0005198405822214521,
#  ('new', 'profile'): 0.0012695725772323319,
#  ('profile', '.'): 0.00026143790849673205,
#  ('<s>', 'combine'): 0.0001221075767751389,
#  ('combine', 'links'): 0.00017573148229505317,
#  ('links', '+'): 0.00017371666811430558,
#  ('+', 'toolbar'): 0.00017236921485822633,
#  ('toolbar', 'File'): 0.00017031422975389594,
#  ('File', '|'): 0.0004368338284116722,
#  ('|', 'Import'): 0.00026232948583420777,
#  ('Import', '...'): 0.0002632964718272775,
#  ('...', 'does'): 0.00034164673727365904,
#  ('work', 'cannot'): 0.0001693623507494284,
#  ('cannot', 'import'): 0.00026059763724808893,
#  ('import', '4'): 0.00017514668534897976,
#  ('4', '.'): 0.0014883558045876379,
#  ('.', 'x'): 0.000442729745114161,
#  ('x', 'About'): 0.00017543859649122806,
#  ('About', 'dialog'): 0.0005250262513125656,
#  ('dialog', 'weirdness'): 0.00025621316935690495,
#  ('weirdness', 'Context'): 0.00017570060616709128,
#  ('Context', 'menu'): 0.0012274241627213747,
#  ('menu', 'doesn'): 0.0010134279199391944,
#  ('t', 'appear'): 0.001183338592615967,
#  ('appear', 'when'): 0.0004365668383829564,
#  ('when', 'right'): 0.0007883326763894363,
#  ('right', 'clicking'): 0.000690667357334024,
#  ('clicking', 'on'): 0.00604647145201693,
#  ('on', 'disabled'): 0.0002346132791115977,
#  ('disabled', 'forward'): 0.00017491691446562882,
#  ('forward', 'or'): 0.0001753155680224404,
#  ('or', 'back'): 0.000170984012994785,
#  ('back', 'can'): 0.0001734454947532738,
#  ('can', "'"): 0.011914966569518258,
#  ('t', 'specify'): 0.00023666771852319345,
#  ('specify', 'cookie'): 0.00017562346329469617,
#  ('cookie', 'details'): 0.0001751927119831815,
#  ('details', 'Proxy'): 0.0001756543123133673,
#  ('Proxy', 'settings'): 0.00017562346329469617,
#  ('settings', 'in'): 0.00026255907579205323,
#  ('in', 'prefs'): 0.000289792074186771,
#  ('prefs', '.'): 0.0001752541184717841,
#  ('.', 'js'): 0.002150401619125925,
#  ('js', 'seem'): 0.00017502406580904875,
#  ('seem', 'to'): 0.001141051522864917,
#  ('to', 'be'): 0.006495824113070169,
#  ('be', 'ignored'): 0.0004215140785702242,
#  ('ignored', '...'): 0.00017537706068046299,
#  ('...', '</s>'): 0.0023915271609156134,
#  ('<s>', 'Incorrectly'): 0.0001221075767751389,
#  ('Incorrectly', 'renders'): 0.00017573148229505317,
#  ('renders', 'various'): 0.0001755001755001755,
#  ('various', 'web'): 0.0002634814684700509,
#  ('web', 'pages'): 0.001217708967556754,
#  ('pages', 'Window'): 0.00017359604201024216,
#  ('Window', 'won'): 0.00017514668534897976,
#  ('won', "'"): 0.0076735263341471925,
#  ('t', 'show'): 0.0022877879457242033,
#  ('show', 'completely'): 0.00017386768669042858,
#  ('completely', 'Can'): 0.00017528483786152498,
#  ('t', 'change'): 0.001183338592615967,
#  ('change', 'privacy'): 0.0001741098633237573,
#  ('privacy', 'settings'): 0.00017562346329469617,
#  ('settings', '['): 0.00017503938386136881,
#  ('[', 'Moz'): 0.0005061582588155897,
#  ('Moz', ']'): 0.0005268703898840885,
#  (']', 'Cannot'): 0.0002525252525252525,
#  ('Cannot', 'set'): 0.0002617801047120419,
#  ('set', '"'): 0.0002610966057441253,
#  ('"', 'Imported'): 0.00022358026531524818,
#  ('Imported', 'IE'): 0.00035140121233418256,
#  ('IE', 'Favorites'): 0.00026219192448872575,
#  ('Favorites', '"'): 0.00017571604287471446,
#  ('"', 'to'): 0.0022358026531524816,
#  ('to', 'default'): 0.0008565921907345278,
#  ('default', 'personal'): 0.00017247326664367022,
#  ('personal', 'toolbar'): 0.002279102384291725,
#  ('toolbar', 'folder'): 0.0017882994124159073,
#  ('folder', 'pheonix'): 0.00017283097131005876,
#  ('pheonix', 'Need'): 0.00017570060616709128,
#  ('Need', 'smaller'): 0.00017503938386136881,
#  ('smaller', 'throbber'): 0.0001756697408871322,
#  ('throbber', 'to'): 0.00017551557700745942,
#  ('use', 'with'): 0.00017328019407381737,
#  ('with', 'small'): 0.0001644331168297295,
#  ('icons', 'Blank'): 0.000174140182847192,
#  ('Blank', 'URL'): 0.0001756543123133673,
#  ('URL', 'bar'): 0.002739022511341265,
#  ('bar', 'after'): 0.0005913161006926846,
#  ('after', 'using'): 0.0012677484787018255,
#  ('using', 'Customize'): 0.00017236921485822633,
#  ('Customize', 'Toolbar'): 0.0007885053443140004,
#  ('Toolbar', 'Mousewheel'): 0.00017341541663053845,
#  ('Mousewheel', 'does'): 0.00017568517217146873,
#  ('not', 'scroll'): 0.0011547344110854503,
#  ('scroll', 'web'): 0.0001737921445950643,
#  ('web', 'page'): 0.0035661476907019223,
#  ('page', 'ctrl'): 0.00016531658125309968,
#  ('ctrl', '+'): 0.0019250962548127406,
#  ('+', 'tab'): 0.00025855382228733947,
#  ('tab', 'should'): 0.0005914659907055344,
#  ('should', 'switch'): 0.0004212654815064454,
#  ('switch', 'tabs'): 0.0006134969325153375,
#  ('tabs', 'in'): 0.0005161290322580645,
#  ('in', 'browser'): 0.0015938564080272405,
#  ('browser', 'favicon'): 0.00016990909863223177,
#  ('favicon', '.'): 0.0009639821225133643,
#  ('.', 'ico'): 0.0007589652773385617,
#  ('ico', 'colors'): 0.00017557721007813187,
#  ('colors', 'render'): 0.00017556179775280898,
#  ('render', 'improperly'): 0.00017533093714385903,
#  ('improperly', 'in'): 0.00017570060616709128,
#  ('in', 'tabs'): 0.0029703687604144026,
#  ('tabs', 'and'): 0.0008602150537634409,
#  ('and', 'URL'): 0.0002380952380952381,
#  ('bar', '-'): 0.00033789491468153406,
#  ('-', 'remote'): 0.0017851598882334678,
#  ('remote', 'openurl'): 0.00026308866087871614,
#  ('openurl', '()'): 0.00017573148229505317,
#  ('()', 'opens'): 0.0001751006828926633,
#  ('opens', 'Mozilla'): 0.000261210274270788,
#  ('Mozilla', 'window'): 0.00017242865764290026,
#  ('window', 'if'): 0.0003336113427856547,
#  ('if', 'Mozilla'): 0.0003380662609871535,
#  ('running', 'make'): 0.00017485574401119076,
#  ('make', 'preferences'): 0.00017450484250937964,
#  ('preferences', 'resizable'): 0.00017420085358418256,
#  ('resizable', 'Scroll'): 0.00017557721007813187,
#  ('Scroll', 'bar'): 0.0006140889551715063,
#  ('bar', 'becomes'): 0.00025342118601115053,
#  ('becomes', 'blank'): 0.0002632964718272775,
#  ('blank', 'fix'): 0.00017470300489168413,
#  ('fix', 'addressbar'): 0.0001755001755001755,
#  ('addressbar', 'dropdown'): 0.0001756543123133673,
#  ('dropdown', 'icon'): 0.00017491691446562882,
#  ('icon', 'for'): 0.0015572281339216196,
#  ('for', 'linux'): 0.0004094668741298829,
#  ('linux', '.'): 0.00017533093714385903,
#  ('<s>', '"'): 0.0014042371329140973,
#  ('"', 'Find'): 0.0014160083469965717,
#  ('Find', 'Next'): 0.0002615062761506276,
#  ('Next', '"'): 0.0002632964718272775,
#  ('"', 'button'): 0.003577284245043971,
#  ('button', 'doesn'): 0.00170328734457503,
#  ('t', 'always'): 0.0006311139160618492,
#  ('always', 'respond'): 0.00017442874585731728,
#  ('respond', 'to'): 0.0010526315789473684,
#  ('to', 'Enter'): 0.0001427653651224213,
#  ('Enter', 'Ctrl'): 0.00017536168347216134,
#  ('should', 'cycle'): 0.00016850619260257814,
#  ('cycle', 'tabs'): 0.00017570060616709128,
#  ('tabs', 'A'): 0.00017204301075268816,
#  ('A', 'new'): 0.00026155187445510024,
#  ('new', 'icon'): 0.00016927634363097757,
#  ('for', 'Firebird'): 0.0007370403734337892,
#  ('Firebird', '2nd'): 0.00016926201760324982,
#  ('2nd', 'Copy'): 0.00017571604287471446,
#  ('Copy', 'won'): 0.00017557721007813187,
#  ('t', 'load'): 0.0014988955506468917,
#  ('load', 'with'): 0.00026071087164334755,
#  ('with', 'same'): 0.0005755159089040532,
#  ('same', 'profile'): 0.00017456576765296326,
#  ('profile', 'width'): 0.00017429193899782134,
#  ('width', 'of'): 0.00026320407088962973,
#  ('of', 'table'): 0.00015929908403026683,
#  ('table', 'containing'): 0.000263042525208242,
#  ('containing', 'text'): 0.00017545398719185894,
#  ('text', 'being'): 0.00017155601303825698,
#  ('being', 'handled'): 0.0001748710326134476,
#  ('handled', 'incorrectly'): 0.00017560804284836245,
#  ('incorrectly', '('): 0.00017514668534897976,
#  ('(', 'multiple'): 0.00016454134101192923,
#  ('multiple', 'screenwidths'): 0.00017448961786773688,
#  ('screenwidths', 'wide'): 0.0001757469244288225,
#  ('wide', ')'): 0.0001756388864494599,
#  (')', 'accessing'): 0.00016633399866932801,
#  ('accessing', '"'): 0.00017539244058581075,
#  ('"', 'navigator'): 0.0002981070204203309,
#  ('navigator', '.'): 0.0007023705004389816,
#  ('.', 'cookieEnabled'): 0.00018974131933464043,
#  ('cookieEnabled', '"'): 0.0002635972234425797,
#  ('"', 'produces'): 0.00014905351021016544,
#  ('produces', '"'): 0.00017560804284836245,
#  ('"', 'uncaught'): 0.00022358026531524818,
#  ('uncaught', 'exception'): 0.0003514320857494289,
#  ('exception', '"'): 0.0002631578947368421,
#  ('"', 'Need'): 0.0003726337755254136,
#  ('Need', 'Mozilla'): 0.00017503938386136881,
#  ('Firebird', 'newsgroup'): 0.00016926201760324982,
#  ('newsgroup', 'Revive'): 0.00017573148229505317,
#  ('Revive', 'XUL'): 0.0001757469244288225,
#  ('XUL', 'preprocessor'): 0.0002633426966292135,
#  ('preprocessor', 'Phoenix'): 0.0001756388864494599,
#  ('Phoenix', 'needs'): 0.0003458711629917856,
#  ('needs', 'talkback'): 0.00017497812773403323,
#  ('talkback', 'Navigation'): 0.00017573148229505317,
#  ('Navigation', 'toolbar'): 0.00035103115401491884,
#  ('toolbar', 'is'): 0.0012773567231542196,
#  ('is', 'completely'): 0.00047382136934375743,
#  ('completely', 'blank'): 0.00026292725679228745,
#  ('blank', 'Phoenix'): 0.0002620545073375262,
#  ('Phoenix', 'refuses'): 0.0001729355814958928,
#  ('refuses', 'to'): 0.0013165979109979811,
#  ('to', 'start'): 0.0019273324291526875,
#  ('start', 'due'): 0.00043455588388666784,
#  ('due', 'missing'): 0.00043851955797228557,
#  ('missing', 'libstdc'): 0.0002612785229054172,
#  ('libstdc', '++-'): 0.00017570060616709128,
#  ('++-', 'libc6'): 0.0001757469244288225,
#  ('libc6', '.'): 0.0001757469244288225,
#  ('2', '-'): 0.00042800890258517377,
#  ('-', '2'): 0.0003104625892579944,
#  ('2', '.'): 0.0017976373908577298,
#  ('.', 'so'): 0.0008222123837834419,
#  ('so', '.'): 0.0008697164724299878,
#  ('.', '3'): 0.0016444247675668838,
#  ('3', 'restore'): 0.00017464198393293747,
#  ('restore', 'image'): 0.00017551557700745942,
#  ('image', 'blocking'): 0.0004342916702857639,
#  ('blocking', 'in'): 0.0001752694768206117,
#  ('Phoenix', 'error'): 0.0001729355814958928,
#  ('error', 'when'): 0.002760286379711895,
#  ('when', 'dragging'): 0.00039416633819471815,
#  ('dragging', 'from'): 0.00017537706068046299,
#  ('from', 'empty'): 0.00016749015995310275,
#  ('empty', 'area'): 0.0001748710326134476,
#  ('area', 'on'): 0.00017537706068046299,
#  ('on', 'personal'): 0.0004692265582231954,
#  ('toolbar', 'to'): 0.0005960998041386358,
#  ('to', 'window'): 0.0002855307302448426,
#  ('window', 'no'): 0.000250208507089241,
#  ('no', 'url'): 0.0002552974214960429,
#  ('url', 'bar'): 0.0017368649587494573,
#  ('bar', 'back'): 0.00025342118601115053,
#  ('back', 'or'): 0.0004336137368831845,
#  ('or', 'forward'): 0.00034196802598957,
#  ('forward', 'buttons'): 0.0006136044880785414,
#  ('buttons', 'fullscreen'): 0.00017392816766675364,
#  ('fullscreen', 'minimize'): 0.00017543859649122806,
#  ('minimize', 'scroll'): 0.00017562346329469617,
#  ('scroll', 'bar'): 0.0013903371567605145,
#  ('bar', 'button'): 0.00016894745734076703,
#  ('button', 'arrows'): 0.00017032873445750298,
#  ('arrows', 'magically'): 0.00017551557700745942,
#  ('magically', 'move'): 0.0001757469244288225,
#  ('move', 'implement'): 0.0001751927119831815,
#  ('implement', 'middle'): 0.00017554638813306416,
#  ('click', 'paste'): 0.00025790921595598347,
#  ('paste', 'to'): 0.00017546938059308652,
#  ('to', 'load'): 0.0033549860803769004,
#  ('load', 'URL'): 0.00043451811940557923,
#  ('URL', 'for'): 0.00034237781391765814,
#  ('for', 'Windows'): 0.00016378674965195316,
#  ('Windows', 'auto'): 0.00017409470752089137,
#  ('auto', '-'): 0.002101760224187757,
#  ('-', 'imported'): 0.0001552312946289972,
#  ('imported', 'ie'): 0.00017542320849048328,
#  ('ie', 'favorites'): 0.00017570060616709128,
#  ('favorites', '('): 0.0002633889376646181,
#  ('(', 'on'): 0.0007404360345536817,
#  ('on', 'every'): 0.0003910221318526629,
#  ('every', 'restart'): 0.00017514668534897976,
#  ('restart', ')'): 0.0002627890679747723,
#  (')', 'do'): 0.00033266799733865603,
#  ('not', 'resolve'): 0.00030792917628945344,
#  ('resolve', '.'): 0.00017568517217146873,
#  ('<s>', 'URL'): 0.0004884303071005556,
#  ('URL', 'toolbar'): 0.00017118890695882907,
#  ('toolbar', 'missing'): 0.00017031422975389594,
#  ('missing', 'off'): 0.00017418568193694478,
#  ('off', 'Phoenix'): 0.00017420085358418256,
#  ('Phoenix', 'nightly'): 0.0001729355814958928,
#  ('nightly', 'for'): 0.00017533093714385903,
#  ('for', '25'): 0.00016378674965195316,
#  ('25', 'September'): 0.00017571604287471446,
#  ('September', 'Cache'): 0.0001757469244288225,
#  ('Cache', 'appears'): 0.0001756388864494599,
#  ('appears', 'twice'): 0.00034910106475824753,
#  ('twice', 'in'): 0.00035075412136092597,
#  ('in', 'preferences'): 0.0015214083894805478,
#  ('preferences', 'Open'): 0.00017420085358418256,
#  ('Open', 'new'): 0.0003484624096175625,
#  ('new', 'window'): 0.006855691917054592,
#  ('window', '('): 0.001000834028356964,
#  ('(', 'script'): 0.00016454134101192923,
#  ('script', ')'): 0.0002631578947368421,
#  (')', 'on'): 0.000499001996007984,
#  ('on', 'onload'): 0.00015640885274106515,
#  ('onload', 'doesn'): 0.00017570060616709128,
#  ('work', 'Ability'): 0.0001693623507494284,
#  ...}

# %% [markdown]
# ### Predict next word (BIGRAMS):

# %% [markdown]
# Write a function that predicts the next word in a sequence (i.e., find the bigram which yields the highest
# conditional probability given a set initial word).

# %%
def predict_next_word(word, bigrams, cp):
  max_prob = 0
  next_word = ""

  for i in bigrams:
    if i[0] == word:
      if cp[i] > max_prob:
        max_prob = cp[i]
        next_word = i[1]

  return next_word

# %%
predict_next_word("took", bgrams_brown, cp_brown)
# Out:
# 'over'

# %%
predict_next_word("took", bgrams_webtext, cp_webtext)
# Out:
# 'to'

# %% [markdown]
# ### Predict sentence (BIGRAMS):

# %% [markdown]
# Write a function that predicts an entire sentence by continuously finding the most probable next word given a list of bigrams and some initial sequence. Only do this up to some specified limit in length (assume the initial sequence len ≥ 1, and use a limit of 5-10 for testing).

# %%
def predict_sentence(initial_sentence, bgrams, limit, cp):
  sentence = initial_sentence.split()
  while len(sentence) < limit:
    next_word = predict_next_word(sentence[-1], bgrams, cp)
    sentence.append(next_word)

  return " ".join(sentence)

# %%
sent_b_brown = predict_sentence("<s> Fools are ", bgrams_brown, 9, cp_brown)
print(sent_b_brown)
# Out:
# <s> Fools are not be a year . </s>

# %%
sent_b_webtext = predict_sentence("<s> Fools are ", bgrams_webtext, 9, cp_webtext)
print(sent_b_webtext)
# Out:
# <s> Fools are not work in the page is

# %% [markdown]
# ### Create Trigrams: Write a function that finds all trigrams in a sentence and returns them as a list of tuples.

# %%
def create_trigrams(corpus):
  trigrams = []
  corpus = list(corpus)
  for i in range(len(corpus)-2):
    trigrams.append((corpus[i], corpus[i+1], corpus[i+2]))

  # print(trigrams)
  return trigrams

# %% [markdown]
# ### Calculate conditional probabilities (TRIGRAMS):

# %%
def conditional_probability_trigrams(word1, word2, word3, trigrams_wc, bigrams_wc, V):
  count_w1w2w3 = trigrams_wc[(word1, word2, word3)]
  count_w1w2 = bigrams_wc[(word1, word2)]
  return (count_w1w2w3+1) / (count_w1w2 + V)

# %%
#For brown corpus
trigrams_brown = create_trigrams(brown_tokens)
trigrams_brown_wc = Counter(trigrams_brown)

# %%
cp_t_brown = {} # cp_t -> conditional probabilities of trigrams

for i in trigrams_brown:
  cp_t_brown[i] = conditional_probability_trigrams(i[0], i[1],i[2], trigrams_brown_wc, bgrams_brown_wc, V_brown)

# %%
cp_t_brown
# Out:
# {('<s>', 'The', 'Fulton'): 0.00012583364791745311,
#  ('The', 'Fulton', 'County'): 0.00013256445946841652,
#  ('Fulton', 'County', 'Grand'): 0.00013252054068380598,
#  ('County', 'Grand', 'Jury'): 0.00013256445946841652,
#  ('Grand', 'Jury', 'said'): 0.0001325556733828208,
#  ('Jury', 'said', 'Friday'): 0.00013256445946841652,
#  ('said', 'Friday', 'an'): 0.0001325381047051027,
#  ('Friday', 'an', 'investigation'): 0.00013256445946841652,
#  ('an', 'investigation', 'of'): 0.0002650762094102054,
#  ('investigation', 'of', "Atlanta's"): 0.0001325381047051027,
#  ('of', "Atlanta's", 'recent'): 0.00013256445946841652,
#  ("Atlanta's", 'recent', 'primary'): 0.00013256445946841652,
#  ('recent', 'primary', 'election'): 0.00013256445946841652,
#  ('primary', 'election', 'produced'): 0.0001325556733828208,
#  ('election', 'produced', '``'): 0.00013256445946841652,
#  ('produced', '``', 'no'): 0.00013256445946841652,
#  ('``', 'no', 'evidence'): 0.00013256445946841652,
#  ('no', 'evidence', "''"): 0.0001325556733828208,
#  ('evidence', "''", 'that'): 0.0001325556733828208,
#  ("''", 'that', 'any'): 0.00013254688846179335,
#  ('that', 'any', 'irregularities'): 0.0001325381047051027,
#  ('any', 'irregularities', 'took'): 0.00013256445946841652,
#  ('irregularities', 'took', 'place'): 0.00013256445946841652,
#  ('took', 'place', '.'): 0.0002650762094102054,
#  ('place', '.', '</s>'): 0.000662471016893011,
#  ('.', '</s>', '<s>'): 0.22478030731281154,
#  ('</s>', '<s>', 'The'): 0.040229026636793626,
#  ('<s>', 'The', 'jury'): 0.0006291682395872657,
#  ('The', 'jury', 'further'): 0.0001324942033786022,
#  ('jury', 'further', 'said'): 0.00013256445946841652,
#  ('further', 'said', 'in'): 0.0001325556733828208,
#  ('said', 'in', 'term-end'): 0.00013252054068380598,
#  ('in', 'term-end', 'presentments'): 0.00013256445946841652,
#  ('term-end', 'presentments', 'that'): 0.00013256445946841652,
#  ('presentments', 'that', 'the'): 0.00013256445946841652,
#  ('that', 'the', 'City'): 0.00013124220749393005,
#  ('the', 'City', 'Executive'): 0.0001325381047051027,
#  ('City', 'Executive', 'Committee'): 0.00013256445946841652,
#  ('Executive', 'Committee', ','): 0.0001325556733828208,
#  ('Committee', ',', 'which'): 0.00013251176041873715,
#  (',', 'which', 'had'): 0.0003297935492381769,
#  ('which', 'had', 'over-all'): 0.00013251176041873715,
#  ('had', 'over-all', 'charge'): 0.00013256445946841652,
#  ('over-all', 'charge', 'of'): 0.00013256445946841652,
#  ('charge', 'of', 'the'): 0.0003312355084465055,
#  ('of', 'the', 'election'): 0.0001875,
#  ('the', 'election', ','): 0.00019871497648539445,
#  ('election', ',', '``'): 0.0001325293221125174,
#  (',', '``', 'deserves'): 0.0001317089232795522,
#  ('``', 'deserves', 'the'): 0.00013256445946841652,
#  ('deserves', 'the', 'praise'): 0.00013256445946841652,
#  ('the', 'praise', 'and'): 0.00013256445946841652,
#  ('praise', 'and', 'thanks'): 0.00013256445946841652,
#  ('and', 'thanks', 'of'): 0.00013256445946841652,
#  ('thanks', 'of', 'the'): 0.00013256445946841652,
#  ('of', 'the', 'City'): 0.00025,
#  ('the', 'City', 'of'): 0.0001325381047051027,
#  ('City', 'of', 'Atlanta'): 0.00013254688846179335,
#  ('of', 'Atlanta', "''"): 0.00013252054068380598,
#  ('Atlanta', "''", 'for'): 0.00013256445946841652,
#  ("''", 'for', 'the'): 0.00013254688846179335,
#  ('for', 'the', 'manner'): 0.0001305227435880702,
#  ('the', 'manner', 'in'): 0.00013254688846179335,
#  ('manner', 'in', 'which'): 0.00019883351007423118,
#  ('in', 'which', 'the'): 0.0005957108816521049,
#  ('which', 'the', 'election'): 0.00013234515616728428,
#  ('the', 'election', 'was'): 0.00019871497648539445,
#  ('election', 'was', 'conducted'): 0.0001325556733828208,
#  ('was', 'conducted', '.'): 0.00013256445946841652,
#  ('conducted', '.', '</s>'): 0.00013256445946841652,
#  ('<s>', 'The', 'September-October'): 0.00012583364791745311,
#  ('The', 'September-October', 'term'): 0.00013256445946841652,
#  ('September-October', 'term', 'jury'): 0.00013256445946841652,
#  ('term', 'jury', 'had'): 0.00013256445946841652,
#  ('jury', 'had', 'been'): 0.00013256445946841652,
#  ('had', 'been', 'charged'): 0.0001321178491214163,
#  ('been', 'charged', 'by'): 0.00013256445946841652,
#  ('charged', 'by', 'Fulton'): 0.00013256445946841652,
#  ('by', 'Fulton', 'Superior'): 0.00013256445946841652,
#  ('Fulton', 'Superior', 'Court'): 0.00019883351007423118,
#  ('Superior', 'Court', 'Judge'): 0.0001325293221125174,
#  ('Court', 'Judge', 'Durwood'): 0.00013256445946841652,
#  ('Judge', 'Durwood', 'Pye'): 0.00013256445946841652,
#  ('Durwood', 'Pye', 'to'): 0.00013256445946841652,
#  ('Pye', 'to', 'investigate'): 0.00013256445946841652,
#  ('to', 'investigate', 'reports'): 0.00013254688846179335,
#  ('investigate', 'reports', 'of'): 0.00013256445946841652,
#  ('reports', 'of', 'possible'): 0.0001325381047051027,
#  ('of', 'possible', '``'): 0.00013256445946841652,
#  ('possible', '``', 'irregularities'): 0.00013256445946841652,
#  ('``', 'irregularities', "''"): 0.00013256445946841652,
#  ('irregularities', "''", 'in'): 0.00013256445946841652,
#  ("''", 'in', 'the'): 0.00019876764062810574,
#  ('in', 'the', 'hard-fought'): 0.00012758356723653993,
#  ('the', 'hard-fought', 'primary'): 0.00013256445946841652,
#  ('hard-fought', 'primary', 'which'): 0.00013256445946841652,
#  ('primary', 'which', 'was'): 0.00013256445946841652,
#  ('which', 'was', 'won'): 0.0001324942033786022,
#  ('was', 'won', 'by'): 0.0001325556733828208,
#  ('won', 'by', 'Mayor-nominate'): 0.00013254688846179335,
#  ('by', 'Mayor-nominate', 'Ivan'): 0.00013256445946841652,
#  ('Mayor-nominate', 'Ivan', 'Allen'): 0.00013256445946841652,
#  ('Ivan', 'Allen', 'Jr.'): 0.00019883351007423118,
#  ('Allen', 'Jr.', '.'): 0.0001325556733828208,
#  ('Jr.', '.', '</s>'): 0.0002650937769235867,
#  ('</s>', '<s>', '``'): 0.0140403286034354,
#  ('<s>', '``', 'Only'): 0.00013014902062861977,
#  ('``', 'Only', 'a'): 0.00013256445946841652,
#  ('Only', 'a', 'relative'): 0.0001325556733828208,
#  ('a', 'relative', 'handful'): 0.00013256445946841652,
#  ('relative', 'handful', 'of'): 0.00013256445946841652,
#  ('handful', 'of', 'such'): 0.00013256445946841652,
#  ('of', 'such', 'reports'): 0.00013251176041873715,
#  ('such', 'reports', 'was'): 0.00013256445946841652,
#  ('reports', 'was', 'received'): 0.00013256445946841652,
#  ('was', 'received', "''"): 0.00013256445946841652,
#  ('received', "''", ','): 0.00013256445946841652,
#  ("''", ',', 'the'): 0.0015044479330193615,
#  (',', 'the', 'jury'): 0.0005816207832493214,
#  ('the', 'jury', 'said'): 0.00039719316827750565,
#  ('jury', 'said', ','): 0.0002650235208374743,
#  ('said', ',', '``'): 0.0021770682148040637,
#  (',', '``', 'considering'): 0.0001317089232795522,
#  ('``', 'considering', 'the'): 0.00013256445946841652,
#  ('considering', 'the', 'widespread'): 0.0001325556733828208,
#  ('the', 'widespread', 'interest'): 0.00013256445946841652,
#  ('widespread', 'interest', 'in'): 0.00013256445946841652,
#  ('interest', 'in', 'the'): 0.00019875447197561946,
#  ('in', 'the', 'election'): 0.0001913753508548099,
#  ('election', ',', 'the'): 0.0001325293221125174,
#  (',', 'the', 'number'): 0.00012924906294429367,
#  ('the', 'number', 'of'): 0.0002650586442250348,
#  ('number', 'of', 'voters'): 0.00013233639912657976,
#  ('of', 'voters', 'and'): 0.00013256445946841652,
#  ('voters', 'and', 'the'): 0.00013256445946841652,
#  ('and', 'the', 'size'): 0.00019686331124089507,
#  ('the', 'size', 'of'): 0.0002650937769235867,
#  ('size', 'of', 'this'): 0.00013254688846179335,
#  ('of', 'this', 'city'): 0.00019855715136673507,
#  ('this', 'city', "''"): 0.0001325381047051027,
#  ('city', "''", '.'): 0.00013256445946841652,
#  ("''", '.', '</s>'): 0.020009095043201454,
#  ('The', 'jury', 'said'): 0.00019874130506790329,
#  ('jury', 'said', 'it'): 0.0002650235208374743,
#  ('said', 'it', 'did'): 0.00013248542660307367,
#  ('it', 'did', 'find'): 0.0001325556733828208,
#  ('did', 'find', 'that'): 0.00013256445946841652,
#  ('find', 'that', 'many'): 0.0001325556733828208,
#  ('that', 'many', 'of'): 0.00019878081102570898,
#  ('many', 'of', "Georgia's"): 0.00013247665099026297,
#  ('of', "Georgia's", 'registration'): 0.0001325381047051027,
#  ("Georgia's", 'registration', 'and'): 0.00013256445946841652,
#  ('registration', 'and', 'election'): 0.00013256445946841652,
#  ('and', 'election', 'laws'): 0.00013256445946841652,
#  ('election', 'laws', '``'): 0.00013256445946841652,
#  ('laws', '``', 'are'): 0.00013256445946841652,
#  ('``', 'are', 'outmoded'): 0.0001325381047051027,
#  ('are', 'outmoded', 'or'): 0.00013256445946841652,
#  ('outmoded', 'or', 'inadequate'): 0.00013256445946841652,
#  ('or', 'inadequate', 'and'): 0.00013256445946841652,
#  ('inadequate', 'and', 'often'): 0.00013256445946841652,
#  ('and', 'often', 'ambiguous'): 0.00013254688846179335,
#  ('often', 'ambiguous', "''"): 0.00013256445946841652,
#  ('ambiguous', "''", '.'): 0.00013256445946841652,
#  ('</s>', '<s>', 'It'): 0.00597460791635549,
#  ('<s>', 'It', 'recommended'): 0.00013153567905294311,
#  ('It', 'recommended', 'that'): 0.00013256445946841652,
#  ('recommended', 'that', 'Fulton'): 0.0001325381047051027,
#  ('that', 'Fulton', 'legislators'): 0.00013256445946841652,
#  ('Fulton', 'legislators', 'act'): 0.0001325556733828208,
#  ('legislators', 'act', '``'): 0.00013256445946841652,
#  ('act', '``', 'to'): 0.00013256445946841652,
#  ('``', 'to', 'have'): 0.00013250298131707962,
#  ('to', 'have', 'these'): 0.00019851773425092641,
#  ('have', 'these', 'laws'): 0.0001325556733828208,
#  ('these', 'laws', 'studied'): 0.0001325556733828208,
#  ('laws', 'studied', 'and'): 0.00013256445946841652,
#  ('studied', 'and', 'revised'): 0.00013256445946841652,
#  ('and', 'revised', 'to'): 0.00013256445946841652,
#  ('revised', 'to', 'the'): 0.00013256445946841652,
#  ('to', 'the', 'end'): 0.0001300136514334005,
#  ('the', 'end', 'of'): 0.0006623832549513148,
#  ('end', 'of', 'modernizing'): 0.00013248542660307367,
#  ('of', 'modernizing', 'and'): 0.00013256445946841652,
#  ('modernizing', 'and', 'improving'): 0.00013256445946841652,
#  ('and', 'improving', 'them'): 0.00013256445946841652,
#  ('improving', 'them', "''"): 0.00013256445946841652,
#  ('them', "''", '.'): 0.0003975352812562115,
#  ('<s>', 'The', 'grand'): 0.00018875047187617969,
#  ('The', 'grand', 'jury'): 0.00019883351007423118,
#  ('grand', 'jury', 'commented'): 0.00013252054068380598,
#  ('jury', 'commented', 'on'): 0.00013256445946841652,
#  ('commented', 'on', 'a'): 0.0001325556733828208,
#  ('on', 'a', 'number'): 0.0001321003963011889,
#  ('a', 'number', 'of'): 0.0012579449152542372,
#  ('number', 'of', 'other'): 0.0003308409978164494,
#  ('of', 'other', 'topics'): 0.00013251176041873715,
#  ('other', 'topics', ','): 0.00013256445946841652,
#  ('topics', ',', 'among'): 0.00013256445946841652,
#  (',', 'among', 'them'): 0.00013252054068380598,
#  ('among', 'them', 'the'): 0.0001325556733828208,
#  ('them', 'the', 'Atlanta'): 0.00013254688846179335,
#  ('the', 'Atlanta', 'and'): 0.0001325293221125174,
#  ('Atlanta', 'and', 'Fulton'): 0.00013256445946841652,
#  ('and', 'Fulton', 'County'): 0.00013256445946841652,
#  ('Fulton', 'County', 'purchasing'): 0.00013252054068380598,
#  ('County', 'purchasing', 'departments'): 0.00013256445946841652,
#  ('purchasing', 'departments', 'which'): 0.00013256445946841652,
#  ('departments', 'which', 'it'): 0.00013256445946841652,
#  ('which', 'it', 'said'): 0.00013251176041873715,
#  ('it', 'said', '``'): 0.00013254688846179335,
#  ('said', '``', 'are'): 0.0001325381047051027,
#  ('``', 'are', 'well'): 0.0001325381047051027,
#  ('are', 'well', 'operated'): 0.0001325556733828208,
#  ('well', 'operated', 'and'): 0.00013256445946841652,
#  ('operated', 'and', 'follow'): 0.00013256445946841652,
#  ('and', 'follow', 'generally'): 0.00013256445946841652,
#  ('follow', 'generally', 'accepted'): 0.00013256445946841652,
#  ('generally', 'accepted', 'practices'): 0.00013256445946841652,
#  ('accepted', 'practices', 'which'): 0.00013256445946841652,
#  ('practices', 'which', 'inure'): 0.00013256445946841652,
#  ('which', 'inure', 'to'): 0.00013256445946841652,
#  ('inure', 'to', 'the'): 0.00013256445946841652,
#  ('to', 'the', 'best'): 0.0001300136514334005,
#  ('the', 'best', 'interest'): 0.00013241525423728814,
#  ('best', 'interest', 'of'): 0.00013256445946841652,
#  ('interest', 'of', 'both'): 0.00013254688846179335,
#  ('of', 'both', 'governments'): 0.00013254688846179335,
#  ('both', 'governments', "''"): 0.00013256445946841652,
#  ('governments', "''", '.'): 0.00013256445946841652,
#  ('</s>', '<s>', 'Merger'): 9.957679860592482e-05,
#  ('<s>', 'Merger', 'proposed'): 0.00013256445946841652,
#  ('Merger', 'proposed', '</s>'): 0.00013256445946841652,
#  ('proposed', '</s>', '<s>'): 0.00013256445946841652,
#  ('</s>', '<s>', 'However'): 0.000597460791635549,
#  ('<s>', 'However', ','): 0.0007948599059415778,
#  ('However', ',', 'the'): 0.00026493575307987813,
#  ('said', 'it', 'believes'): 0.00013248542660307367,
#  ('it', 'believes', '``'): 0.00013256445946841652,
#  ('believes', '``', 'these'): 0.00013256445946841652,
#  ('``', 'these', 'two'): 0.0001325556733828208,
#  ('these', 'two', 'offices'): 0.00013254688846179335,
#  ('two', 'offices', 'should'): 0.00013256445946841652,
#  ('offices', 'should', 'be'): 0.00013256445946841652,
#  ('should', 'be', 'combined'): 0.00013227513227513228,
#  ('be', 'combined', 'to'): 0.00013256445946841652,
#  ('combined', 'to', 'achieve'): 0.00013254688846179335,
#  ('to', 'achieve', 'greater'): 0.00013251176041873715,
#  ('achieve', 'greater', 'efficiency'): 0.00013256445946841652,
#  ('greater', 'efficiency', 'and'): 0.00013256445946841652,
#  ('efficiency', 'and', 'reduce'): 0.00013256445946841652,
#  ('and', 'reduce', 'the'): 0.00013256445946841652,
#  ('reduce', 'the', 'cost'): 0.0001325381047051027,
#  ('the', 'cost', 'of'): 0.00019882033269269004,
#  ('cost', 'of', 'administration'): 0.00013251176041873715,
#  ('of', 'administration', "''"): 0.0001325556733828208,
#  ('administration', "''", '.'): 0.00013256445946841652,
#  ('<s>', 'The', 'City'): 0.00025166729583490623,
#  ('The', 'City', 'Purchasing'): 0.00013254688846179335,
#  ('City', 'Purchasing', 'Department'): 0.00013256445946841652,
#  ('Purchasing', 'Department', ','): 0.00013256445946841652,
#  ('Department', ',', 'the'): 0.00019883351007423118,
#  (',', '``', 'is'): 0.00032927230819888045,
#  ('``', 'is', 'lacking'): 0.00013251176041873715,
#  ('is', 'lacking', 'in'): 0.00013256445946841652,
#  ('lacking', 'in', 'experienced'): 0.0001325556733828208,
#  ('in', 'experienced', 'clerical'): 0.00013256445946841652,
#  ('experienced', 'clerical', 'personnel'): 0.00013256445946841652,
#  ('clerical', 'personnel', 'as'): 0.00013256445946841652,
#  ('personnel', 'as', 'a'): 0.00013256445946841652,
#  ('as', 'a', 'result'): 0.0009227524387028737,
#  ('a', 'result', 'of'): 0.0008606421714664018,
#  ('result', 'of', 'city'): 0.00013242402171753957,
#  ('of', 'city', 'personnel'): 0.0001325556733828208,
#  ('city', 'personnel', 'policies'): 0.00013256445946841652,
#  ('personnel', 'policies', "''"): 0.0001325556733828208,
#  ('policies', "''", '.'): 0.00013256445946841652,
#  ('<s>', 'It', 'urged'): 0.00019730351857941467,
#  ('It', 'urged', 'that'): 0.00019883351007423118,
#  ('urged', 'that', 'the'): 0.0002650762094102054,
#  ('that', 'the', 'city'): 0.0002624844149878601,
#  ('the', 'city', '``'): 0.00013237143424449003,
#  ('city', '``', 'take'): 0.00013256445946841652,
#  ('``', 'take', 'steps'): 0.00013256445946841652,
#  ('take', 'steps', 'to'): 0.00019883351007423118,
#  ('steps', 'to', 'remedy'): 0.0001325381047051027,
#  ('to', 'remedy', "''"): 0.00013256445946841652,
#  ('remedy', "''", 'this'): 0.00013256445946841652,
#  ("''", 'this', 'problem'): 0.00013256445946841652,
#  ('this', 'problem', '.'): 0.00013254688846179335,
#  ('problem', '.', '</s>'): 0.00039758796633755216,
#  ('</s>', '<s>', 'Implementation'): 9.957679860592482e-05,
#  ('<s>', 'Implementation', 'of'): 0.00013256445946841652,
#  ('Implementation', 'of', "Georgia's"): 0.00013256445946841652,
#  ('of', "Georgia's", 'automobile'): 0.0001325381047051027,
#  ("Georgia's", 'automobile', 'title'): 0.00013256445946841652,
#  ('automobile', 'title', 'law'): 0.00013256445946841652,
#  ('title', 'law', 'was'): 0.0001325556733828208,
#  ('law', 'was', 'also'): 0.0001325556733828208,
#  ('was', 'also', 'recommended'): 0.00013251176041873715,
#  ('also', 'recommended', 'by'): 0.0001325556733828208,
#  ('recommended', 'by', 'the'): 0.00013256445946841652,
#  ('by', 'the', 'outgoing'): 0.0001315097317201473,
#  ('the', 'outgoing', 'jury'): 0.00013256445946841652,
#  ('outgoing', 'jury', '.'): 0.00013256445946841652,
#  ('jury', '.', '</s>'): 0.00039758796633755216,
#  ('that', 'the', 'next'): 0.00019686331124089507,
#  ('the', 'next', 'Legislature'): 0.00013241525423728814,
#  ('next', 'Legislature', '``'): 0.00013256445946841652,
#  ('Legislature', '``', 'provide'): 0.00013256445946841652,
#  ('``', 'provide', 'enabling'): 0.00013256445946841652,
#  ('provide', 'enabling', 'funds'): 0.00013256445946841652,
#  ('enabling', 'funds', 'and'): 0.00013256445946841652,
#  ('funds', 'and', 're-set'): 0.00013254688846179335,
#  ('and', 're-set', 'the'): 0.00013256445946841652,
#  ('re-set', 'the', 'effective'): 0.00013256445946841652,
#  ('the', 'effective', 'date'): 0.0001325556733828208,
#  ('effective', 'date', 'so'): 0.00013256445946841652,
#  ('date', 'so', 'that'): 0.00013256445946841652,
#  ('so', 'that', 'an'): 0.00013248542660307367,
#  ('that', 'an', 'orderly'): 0.0001325293221125174,
#  ('an', 'orderly', 'implementation'): 0.0001325556733828208,
#  ('orderly', 'implementation', 'of'): 0.00013256445946841652,
#  ('implementation', 'of', 'the'): 0.00013256445946841652,
#  ('of', 'the', 'law'): 0.0001875,
#  ('the', 'law', 'may'): 0.00013251176041873715,
#  ('law', 'may', 'be'): 0.00013256445946841652,
#  ('may', 'be', 'effected'): 0.00013235391436701742,
#  ('be', 'effected', "''"): 0.00013256445946841652,
#  ('effected', "''", '.'): 0.00013256445946841652,
#  ('grand', 'jury', 'took'): 0.00013252054068380598,
#  ('jury', 'took', 'a'): 0.00013256445946841652,
#  ('took', 'a', 'swipe'): 0.0001325293221125174,
#  ('a', 'swipe', 'at'): 0.00013256445946841652,
#  ('swipe', 'at', 'the'): 0.00013256445946841652,
#  ('at', 'the', 'State'): 0.0002619000851175277,
#  ('the', 'State', 'Welfare'): 0.00019863603257630935,
#  ('State', 'Welfare', "Department's"): 0.0001325556733828208,
#  ('Welfare', "Department's", 'handling'): 0.00013256445946841652,
#  ("Department's", 'handling', 'of'): 0.00013256445946841652,
#  ('handling', 'of', 'federal'): 0.00013256445946841652,
#  ('of', 'federal', 'funds'): 0.00013254688846179335,
#  ('federal', 'funds', 'granted'): 0.00013254688846179335,
#  ('funds', 'granted', 'for'): 0.00013256445946841652,
#  ('granted', 'for', 'child'): 0.00013256445946841652,
#  ('for', 'child', 'welfare'): 0.00013256445946841652,
#  ('child', 'welfare', 'services'): 0.00013256445946841652,
#  ('welfare', 'services', 'in'): 0.00013256445946841652,
#  ('services', 'in', 'foster'): 0.00013256445946841652,
#  ('in', 'foster', 'homes'): 0.00013256445946841652,
#  ('foster', 'homes', '.'): 0.00013256445946841652,
#  ('homes', '.', '</s>'): 0.00019883351007423118,
#  ('<s>', '``', 'This'): 0.0008459686340860285,
#  ('``', 'This', 'is'): 0.000662295516259355,
#  ('This', 'is', 'one'): 0.00019847833278200462,
#  ('is', 'one', 'of'): 0.0006622516556291391,
#  ('one', 'of', 'the'): 0.002641135688345989,
#  ('of', 'the', 'major'): 0.000125,
#  ('the', 'major', 'items'): 0.0001325293221125174,
#  ('major', 'items', 'in'): 0.00013256445946841652,
#  ('items', 'in', 'the'): 0.00013256445946841652,
#  ('in', 'the', 'Fulton'): 0.00012758356723653993,
#  ('the', 'Fulton', 'County'): 0.00019879398316877608,
#  ('Fulton', 'County', 'general'): 0.00013252054068380598,
#  ('County', 'general', 'assistance'): 0.00013256445946841652,
#  ('general', 'assistance', 'program'): 0.0001325556733828208,
#  ('assistance', 'program', "''"): 0.00013256445946841652,
#  ('program', "''", ','): 0.00013256445946841652,
#  ('said', ',', 'but'): 0.00013194352816994325,
#  (',', 'but', 'the'): 0.0008559952591031803,
#  ('but', 'the', 'State'): 0.000132406487917908,
#  ('State', 'Welfare', 'Department'): 0.0001325556733828208,
#  ('Welfare', 'Department', '``'): 0.00013256445946841652,
#  ('Department', '``', 'has'): 0.00013256445946841652,
#  ('``', 'has', 'seen'): 0.00013254688846179335,
#  ('has', 'seen', 'fit'): 0.00013254688846179335,
#  ('seen', 'fit', 'to'): 0.00013256445946841652,
#  ('fit', 'to', 'distribute'): 0.00013256445946841652,
#  ('to', 'distribute', 'these'): 0.00013256445946841652,
#  ('distribute', 'these', 'funds'): 0.00013256445946841652,
#  ('these', 'funds', 'through'): 0.00013254688846179335,
#  ('funds', 'through', 'the'): 0.00013256445946841652,
#  ('through', 'the', 'welfare'): 0.00013237143424449003,
#  ('the', 'welfare', 'departments'): 0.00013254688846179335,
#  ('welfare', 'departments', 'of'): 0.00013256445946841652,
#  ('departments', 'of', 'all'): 0.00013256445946841652,
#  ('of', 'all', 'the'): 0.00013242402171753957,
#  ('all', 'the', 'counties'): 0.00013236267372600927,
#  ('the', 'counties', 'in'): 0.00013256445946841652,
#  ('counties', 'in', 'the'): 0.00019883351007423118,
#  ('in', 'the', 'state'): 0.0007017096198009697,
#  ('the', 'state', 'with'): 0.00019818986589152407,
#  ('state', 'with', 'the'): 0.0001325556733828208,
#  ('with', 'the', 'exception'): 0.00013131114175037753,
#  ('the', 'exception', 'of'): 0.00019883351007423118,
#  ('exception', 'of', 'Fulton'): 0.00013254688846179335,
#  ('of', 'Fulton', 'County'): 0.00013256445946841652,
#  ('Fulton', 'County', ','): 0.00013252054068380598,
#  ('County', ',', 'which'): 0.00013252054068380598,
#  (',', 'which', 'receives'): 0.00013191741969527076,
#  ('which', 'receives', 'none'): 0.00013256445946841652,
#  ('receives', 'none', 'of'): 0.00013256445946841652,
#  ('none', 'of', 'this'): 0.00013254688846179335,
#  ('of', 'this', 'money'): 0.00013237143424449003,
#  ('this', 'money', '.'): 0.00013256445946841652,
#  ('money', '.', '</s>'): 0.00039758796633755216,
#  ('<s>', 'The', 'jurors'): 0.00012583364791745311,
#  ('The', 'jurors', 'said'): 0.00013256445946841652,
#  ('jurors', 'said', 'they'): 0.0001325556733828208,
#  ('said', 'they', 'realize'): 0.00013250298131707962,
#  ('they', 'realize', '``'): 0.00013256445946841652,
#  ('realize', '``', 'a'): 0.00013256445946841652,
#  ('``', 'a', 'proportionate'): 0.0001324942033786022,
#  ('a', 'proportionate', 'distribution'): 0.00013256445946841652,
#  ('proportionate', 'distribution', 'of'): 0.00013256445946841652,
#  ('distribution', 'of', 'these'): 0.00013254688846179335,
#  ('of', 'these', 'funds'): 0.00019859658413875282,
#  ('these', 'funds', 'might'): 0.00013254688846179335,
#  ('funds', 'might', 'disable'): 0.00013256445946841652,
#  ('might', 'disable', 'this'): 0.00013256445946841652,
#  ('disable', 'this', 'program'): 0.00013256445946841652,
#  ('this', 'program', 'in'): 0.0001325556733828208,
#  ('program', 'in', 'our'): 0.0001325293221125174,
#  ('in', 'our', 'less'): 0.00013252054068380598,
#  ('our', 'less', 'populous'): 0.00013256445946841652,
#  ('less', 'populous', 'counties'): 0.0001325556733828208,
#  ('populous', 'counties', "''"): 0.00013256445946841652,
#  ('counties', "''", '.'): 0.00013256445946841652,
#  ('</s>', '<s>', 'Nevertheless'): 9.957679860592482e-05,
#  ('<s>', 'Nevertheless', ','): 0.00013256445946841652,
#  ('Nevertheless', ',', '``'): 0.00013256445946841652,
#  (',', '``', 'we'): 0.0002634178465591044,
#  ('``', 'we', 'feel'): 0.0001325381047051027,
#  ('we', 'feel', 'that'): 0.00013256445946841652,
#  ('feel', 'that', 'in'): 0.0001325293221125174,
#  ('that', 'in', 'the'): 0.0003312794010468429,
#  ('in', 'the', 'future'): 0.00031895891809134984,
#  ('the', 'future', 'Fulton'): 0.00013248542660307367,
#  ('future', 'Fulton', 'County'): 0.00013256445946841652,
#  ('Fulton', 'County', 'should'): 0.00013252054068380598,
#  ('County', 'should', 'receive'): 0.00013256445946841652,
#  ('should', 'receive', 'some'): 0.00013256445946841652,
#  ('receive', 'some', 'portion'): 0.00013256445946841652,
#  ('some', 'portion', 'of'): 0.00013256445946841652,
#  ('portion', 'of', 'these'): 0.0001325556733828208,
#  ('of', 'these', 'available'): 0.00013239772275916854,
#  ('these', 'available', 'funds'): 0.00013256445946841652,
#  ('available', 'funds', "''"): 0.00013256445946841652,
#  ('funds', "''", ','): 0.00019883351007423118,
#  (',', 'the', 'jurors'): 0.00012924906294429367,
#  ('the', 'jurors', 'said'): 0.00013254688846179335,
#  ('jurors', 'said', '.'): 0.0001325556733828208,
#  ('said', '.', '</s>'): 0.005144100771615116,
#  ('<s>', '``', 'Failure'): 0.00013014902062861977,
#  ('``', 'Failure', 'to'): 0.00013256445946841652,
#  ('Failure', 'to', 'do'): 0.0001325556733828208,
#  ('to', 'do', 'this'): 0.000198583438141259,
#  ('do', 'this', 'will'): 0.0001325556733828208,
#  ('this', 'will', 'continue'): 0.0001325556733828208,
#  ('will', 'continue', 'to'): 0.0002650762094102054,
#  ('continue', 'to', 'place'): 0.00013250298131707962,
#  ('to', 'place', 'a'): 0.0001325381047051027,
#  ('place', 'a', 'disproportionate'): 0.00013256445946841652,
#  ('a', 'disproportionate', 'burden'): 0.00013256445946841652,
#  ('disproportionate', 'burden', "''"): 0.00013256445946841652,
#  ('burden', "''", 'on'): 0.00013256445946841652,
#  ("''", 'on', 'Fulton'): 0.00013247665099026297,
#  ('on', 'Fulton', 'taxpayers'): 0.00013256445946841652,
#  ('Fulton', 'taxpayers', '.'): 0.00013256445946841652,
#  ('taxpayers', '.', '</s>'): 0.00013256445946841652,
#  ('The', 'jury', 'also'): 0.0001324942033786022,
#  ('jury', 'also', 'commented'): 0.00013256445946841652,
#  ('also', 'commented', 'on'): 0.00013256445946841652,
#  ('commented', 'on', 'the'): 0.0001325556733828208,
#  ('on', 'the', 'Fulton'): 0.00013032712107389547,
#  ('the', 'Fulton', "ordinary's"): 0.0001325293221125174,
#  ('Fulton', "ordinary's", 'court'): 0.00013256445946841652,
#  ("ordinary's", 'court', 'which'): 0.00013256445946841652,
#  ('court', 'which', 'has'): 0.00013256445946841652,
#  ('which', 'has', 'been'): 0.00033125745329269906,
#  ('has', 'been', 'under'): 0.0001317089232795522,
#  ('been', 'under', 'fire'): 0.00013254688846179335,
#  ('under', 'fire', 'for'): 0.0001325556733828208,
#  ('fire', 'for', 'its'): 0.00013256445946841652,
#  ('for', 'its', 'practices'): 0.00013250298131707962,
#  ('its', 'practices', 'in'): 0.00013256445946841652,
#  ('practices', 'in', 'the'): 0.00013256445946841652,
#  ('in', 'the', 'appointment'): 0.00012758356723653993,
#  ('the', 'appointment', 'of'): 0.0002650937769235867,
#  ('appointment', 'of', 'appraisers'): 0.00013252054068380598,
#  ('of', 'appraisers', ','): 0.00013256445946841652,
#  ('appraisers', ',', 'guardians'): 0.00013256445946841652,
#  (',', 'guardians', 'and'): 0.00013256445946841652,
#  ('guardians', 'and', 'administrators'): 0.00013256445946841652,
#  ('and', 'administrators', 'and'): 0.00013256445946841652,
#  ('administrators', 'and', 'the'): 0.00013256445946841652,
#  ('and', 'the', 'awarding'): 0.00013124220749393005,
#  ('the', 'awarding', 'of'): 0.00013256445946841652,
#  ('awarding', 'of', 'fees'): 0.00013256445946841652,
#  ('of', 'fees', 'and'): 0.00013256445946841652,
#  ('fees', 'and', 'compensation'): 0.00013256445946841652,
#  ('and', 'compensation', '.'): 0.00013256445946841652,
#  ('compensation', '.', '</s>'): 0.00013256445946841652,
#  ('</s>', '<s>', 'Wards'): 9.957679860592482e-05,
#  ('<s>', 'Wards', 'protected'): 0.00013256445946841652,
#  ('Wards', 'protected', '</s>'): 0.00013256445946841652,
#  ('protected', '</s>', '<s>'): 0.00013256445946841652,
#  ('said', 'it', 'found'): 0.00013248542660307367,
#  ('it', 'found', 'the'): 0.00013256445946841652,
#  ('found', 'the', 'court'): 0.0001325381047051027,
#  ('the', 'court', '``'): 0.00013252054068380598,
#  ('court', '``', 'has'): 0.00013256445946841652,
#  ('``', 'has', 'incorporated'): 0.00013254688846179335,
#  ('has', 'incorporated', 'into'): 0.00013256445946841652,
#  ('incorporated', 'into', 'its'): 0.00013256445946841652,
#  ('into', 'its', 'operating'): 0.00013256445946841652,
#  ('its', 'operating', 'procedures'): 0.00013256445946841652,
#  ('operating', 'procedures', 'the'): 0.00013256445946841652,
#  ('procedures', 'the', 'recommendations'): 0.00013256445946841652,
#  ('the', 'recommendations', "''"): 0.00013256445946841652,
#  ('recommendations', "''", 'of'): 0.00013256445946841652,
#  ("''", 'of', 'two'): 0.00013248542660307367,
#  ('of', 'two', 'previous'): 0.00013251176041873715,
#  ('two', 'previous', 'grand'): 0.0001325556733828208,
#  ('previous', 'grand', 'juries'): 0.00013256445946841652,
#  ('grand', 'juries', ','): 0.00013256445946841652,
#  ('juries', ',', 'the'): 0.00013256445946841652,
#  (',', 'the', 'Atlanta'): 0.00012924906294429367,
#  ('the', 'Atlanta', 'Bar'): 0.0001325293221125174,
#  ('Atlanta', 'Bar', 'Association'): 0.00013256445946841652,
#  ('Bar', 'Association', 'and'): 0.00013256445946841652,
#  ('Association', 'and', 'an'): 0.00013256445946841652,
#  ('and', 'an', 'interim'): 0.0001324942033786022,
#  ('an', 'interim', 'citizens'): 0.00013256445946841652,
#  ('interim', 'citizens', 'committee'): 0.00013256445946841652,
#  ('citizens', 'committee', '.'): 0.0001325556733828208,
#  ('committee', '.', '</s>'): 0.00039758796633755216,
#  ('<s>', '``', 'These'): 0.00019522353094292966,
#  ('``', 'These', 'actions'): 0.0001325556733828208,
#  ('These', 'actions', 'should'): 0.00013256445946841652,
#  ('actions', 'should', 'serve'): 0.00013256445946841652,
#  ('should', 'serve', 'to'): 0.00013256445946841652,
#  ('serve', 'to', 'protect'): 0.00013256445946841652,
#  ('to', 'protect', 'in'): 0.0001325556733828208,
#  ('protect', 'in', 'fact'): 0.00013256445946841652,
#  ('in', 'fact', 'and'): 0.00013252054068380598,
#  ('fact', 'and', 'in'): 0.00019883351007423118,
#  ('and', 'in', 'effect'): 0.00013243279035889287,
#  ('in', 'effect', 'the'): 0.00013254688846179335,
#  ('effect', 'the', "court's"): 0.0001325556733828208,
#  ('the', "court's", 'wards'): 0.00013256445946841652,
#  ("court's", 'wards', 'from'): 0.00013256445946841652,
#  ('wards', 'from', 'undue'): 0.00013256445946841652,
#  ('from', 'undue', 'costs'): 0.00013256445946841652,
#  ('undue', 'costs', 'and'): 0.00013256445946841652,
#  ('costs', 'and', 'its'): 0.00013256445946841652,
#  ('and', 'its', 'appointed'): 0.00013246787653993907,
#  ('its', 'appointed', 'and'): 0.00013256445946841652,
#  ('appointed', 'and', 'elected'): 0.00013256445946841652,
#  ('and', 'elected', 'servants'): 0.00013256445946841652,
#  ('elected', 'servants', 'from'): 0.00013256445946841652,
#  ('servants', 'from', 'unmeritorious'): 0.00013256445946841652,
#  ('from', 'unmeritorious', 'criticisms'): 0.00013256445946841652,
#  ('unmeritorious', 'criticisms', "''"): 0.00013256445946841652,
#  ('criticisms', "''", ','): 0.00013256445946841652,
#  ('jury', 'said', '.'): 0.00013251176041873715,
#  ('</s>', '<s>', 'Regarding'): 9.957679860592482e-05,
#  ('<s>', 'Regarding', "Atlanta's"): 0.00013256445946841652,
#  ('Regarding', "Atlanta's", 'new'): 0.00013256445946841652,
#  ("Atlanta's", 'new', 'multi-million-dollar'): 0.00013256445946841652,
#  ('new', 'multi-million-dollar', 'airport'): 0.00013256445946841652,
#  ('multi-million-dollar', 'airport', ','): 0.00013256445946841652,
#  ('airport', ',', 'the'): 0.00013256445946841652,
#  ('the', 'jury', 'recommended'): 0.00019859658413875282,
#  ('jury', 'recommended', '``'): 0.0001325556733828208,
#  ('recommended', '``', 'that'): 0.00013256445946841652,
#  ('``', 'that', 'when'): 0.0001325556733828208,
#  ('that', 'when', 'the'): 0.00013254688846179335,
#  ('when', 'the', 'new'): 0.00013225763787858748,
#  ('the', 'new', 'management'): 0.00013229263130043657,
#  ('new', 'management', 'takes'): 0.00013256445946841652,
#  ('management', 'takes', 'charge'): 0.00013256445946841652,
#  ('takes', 'charge', 'Jan.'): 0.00013256445946841652,
#  ('charge', 'Jan.', '1'): 0.00013256445946841652,
#  ('Jan.', '1', 'the'): 0.0001325381047051027,
#  ('1', 'the', 'airport'): 0.00013256445946841652,
#  ('the', 'airport', 'be'): 0.00013254688846179335,
#  ('airport', 'be', 'operated'): 0.00013256445946841652,
#  ('be', 'operated', 'in'): 0.00013256445946841652,
#  ('operated', 'in', 'a'): 0.00013256445946841652,
#  ('in', 'a', 'manner'): 0.00013151837969356216,
#  ('a', 'manner', 'that'): 0.00013256445946841652,
#  ('manner', 'that', 'will'): 0.00013256445946841652,
#  ('that', 'will', 'eliminate'): 0.00013252054068380598,
#  ('will', 'eliminate', 'political'): 0.00013256445946841652,
#  ('eliminate', 'political', 'influences'): 0.00013256445946841652,
#  ('political', 'influences', "''"): 0.00013256445946841652,
#  ('influences', "''", '.'): 0.00013256445946841652,
#  ('The', 'jury', 'did'): 0.0001324942033786022,
#  ('jury', 'did', 'not'): 0.00013256445946841652,
#  ('did', 'not', 'elaborate'): 0.00013238019592268997,
#  ('not', 'elaborate', ','): 0.00013256445946841652,
#  ('elaborate', ',', 'but'): 0.0001325556733828208,
#  (',', 'but', 'it'): 0.0003292289458089155,
#  ('but', 'it', 'added'): 0.00013252054068380598,
#  ('it', 'added', 'that'): 0.00013256445946841652,
#  ('added', 'that', '``'): 0.00013250298131707962,
#  ('that', '``', 'there'): 0.00013247665099026297,
#  ('``', 'there', 'should'): 0.0001325381047051027,
#  ('there', 'should', 'be'): 0.00019883351007423118,
#  ('should', 'be', 'periodic'): 0.00013227513227513228,
#  ('be', 'periodic', 'surveillance'): 0.00013256445946841652,
#  ('periodic', 'surveillance', 'of'): 0.00013256445946841652,
#  ('surveillance', 'of', 'the'): 0.00013256445946841652,
#  ('of', 'the', 'pricing'): 0.000125,
#  ('the', 'pricing', 'practices'): 0.00013256445946841652,
#  ('pricing', 'practices', 'of'): 0.00013256445946841652,
#  ('practices', 'of', 'the'): 0.00013256445946841652,
#  ('of', 'the', 'concessionaires'): 0.000125,
#  ('the', 'concessionaires', 'for'): 0.00013256445946841652,
#  ('concessionaires', 'for', 'the'): 0.00013256445946841652,
#  ('for', 'the', 'purpose'): 0.00019578411538210533,
#  ('the', 'purpose', 'of'): 0.00019883351007423118,
#  ('purpose', 'of', 'keeping'): 0.0001325293221125174,
#  ('of', 'keeping', 'the'): 0.00013256445946841652,
#  ('keeping', 'the', 'prices'): 0.00013256445946841652,
#  ('the', 'prices', 'reasonable'): 0.00013254688846179335,
#  ('prices', 'reasonable', "''"): 0.00013256445946841652,
#  ('reasonable', "''", '.'): 0.00013256445946841652,
#  ('</s>', '<s>', 'Ask'): 9.957679860592482e-05,
#  ('<s>', 'Ask', 'jail'): 0.00013256445946841652,
#  ('Ask', 'jail', 'deputies'): 0.00013256445946841652,
#  ('jail', 'deputies', '</s>'): 0.00013256445946841652,
#  ('deputies', '</s>', '<s>'): 0.00013256445946841652,
#  ('</s>', '<s>', 'On'): 0.0015932287776947972,
#  ('<s>', 'On', 'other'): 0.00013230138254944764,
#  ('On', 'other', 'matters'): 0.00013256445946841652,
#  ('other', 'matters', ','): 0.00013256445946841652,
#  ('matters', ',', 'the'): 0.0001325556733828208,
#  ('jury', 'recommended', 'that'): 0.0001325556733828208,
#  ('recommended', 'that', ':'): 0.0001325381047051027,
#  ('that', ':', '('): 0.00013256445946841652,
#  (':', '(', '1'): 0.00013256445946841652,
#  ('(', '1', ')'): 0.00019883351007423118,
#  ('1', ')', '</s>'): 0.0001325381047051027,
#  (')', '</s>', '<s>'): 0.0023148148148148147,
#  ('</s>', '<s>', 'Four'): 0.00034851879512073686,
#  ('<s>', 'Four', 'additional'): 0.00013252054068380598,
#  ('Four', 'additional', 'deputies'): 0.00013256445946841652,
#  ('additional', 'deputies', 'be'): 0.00013256445946841652,
#  ('deputies', 'be', 'employed'): 0.00013256445946841652,
#  ('be', 'employed', 'at'): 0.0001325556733828208,
#  ('employed', 'at', 'the'): 0.00013256445946841652,
#  ('at', 'the', 'Fulton'): 0.00013095004255876384,
#  ('Fulton', 'County', 'Jail'): 0.00013252054068380598,
#  ('County', 'Jail', 'and'): 0.0001325556733828208,
#  ('Jail', 'and', '``'): 0.00013256445946841652,
#  ('and', '``', 'a'): 0.00013245910325187097,
#  ('``', 'a', 'doctor'): 0.0001324942033786022,
#  ('a', 'doctor', ','): 0.00013256445946841652,
#  ('doctor', ',', 'medical'): 0.00013256445946841652,
#  (',', 'medical', 'intern'): 0.00013256445946841652,
#  ('medical', 'intern', 'or'): 0.00013256445946841652,
#  ('intern', 'or', 'extern'): 0.00013256445946841652,
#  ('or', 'extern', 'be'): 0.00013256445946841652,
#  ('extern', 'be', 'employed'): 0.00013256445946841652,
#  ('be', 'employed', 'for'): 0.0001325556733828208,
#  ('employed', 'for', 'night'): 0.00013256445946841652,
#  ('for', 'night', 'and'): 0.00013256445946841652,
#  ('night', 'and', 'weekend'): 0.00013256445946841652,
#  ('and', 'weekend', 'duty'): 0.00013256445946841652,
#  ('weekend', 'duty', 'at'): 0.00013256445946841652,
#  ('duty', 'at', 'the'): 0.00013256445946841652,
#  ('at', 'the', 'jail'): 0.00013095004255876384,
#  ('the', 'jail', "''"): 0.00013256445946841652,
#  ('jail', "''", '.'): 0.00013256445946841652,
#  ('</s>', '<s>', '('): 0.0012447099825740602,
#  ('<s>', '(', '2'): 0.0001985440105890139,
#  ('(', '2', ')'): 0.00019883351007423118,
#  ('2', ')', '</s>'): 0.00013252054068380598,
#  ('</s>', '<s>', 'Fulton'): 9.957679860592482e-05,
#  ('<s>', 'Fulton', 'legislators'): 0.00013256445946841652,
#  ('Fulton', 'legislators', '``'): 0.0001325556733828208,
#  ('legislators', '``', 'work'): 0.00013256445946841652,
#  ('``', 'work', 'with'): 0.00013256445946841652,
#  ('work', 'with', 'city'): 0.0001325293221125174,
#  ('with', 'city', 'officials'): 0.00013256445946841652,
#  ('city', 'officials', 'to'): 0.00013256445946841652,
#  ('officials', 'to', 'pass'): 0.00013254688846179335,
#  ('to', 'pass', 'enabling'): 0.0001324942033786022,
#  ('pass', 'enabling', 'legislation'): 0.00013256445946841652,
#  ('enabling', 'legislation', 'that'): 0.0001325556733828208,
#  ('legislation', 'that', 'will'): 0.00013256445946841652,
#  ('that', 'will', 'permit'): 0.00013252054068380598,
#  ('will', 'permit', 'the'): 0.00013256445946841652,
#  ('permit', 'the', 'establishment'): 0.0001325556733828208,
#  ('the', 'establishment', 'of'): 0.0003313452617627568,
#  ('establishment', 'of', 'a'): 0.00026504108136761196,
#  ('of', 'a', 'fair'): 0.00013151837969356216,
#  ('a', 'fair', 'and'): 0.00013254688846179335,
#  ('fair', 'and', 'equitable'): 0.0001325556733828208,
#  ('and', 'equitable', "''"): 0.0001325556733828208,
#  ('equitable', "''", 'pension'): 0.00013256445946841652,
#  ("''", 'pension', 'plan'): 0.00013256445946841652,
#  ('pension', 'plan', 'for'): 0.00013254688846179335,
#  ('plan', 'for', 'city'): 0.0001325293221125174,
#  ('for', 'city', 'employes'): 0.00013256445946841652,
#  ('city', 'employes', '.'): 0.0001325556733828208,
#  ('employes', '.', '</s>'): 0.00019883351007423118,
#  ('The', 'jury', 'praised'): 0.0001324942033786022,
#  ('jury', 'praised', 'the'): 0.00013256445946841652,
#  ('praised', 'the', 'administration'): 0.00013256445946841652,
#  ('the', 'administration', 'and'): 0.00013243279035889287,
#  ('administration', 'and', 'operation'): 0.00013254688846179335,
#  ('and', 'operation', 'of'): 0.00019883351007423118,
#  ('operation', 'of', 'the'): 0.00026504108136761196,
#  ('of', 'the', 'Atlanta'): 0.0001875,
#  ('the', 'Atlanta', 'Police'): 0.0001325293221125174,
#  ('Atlanta', 'Police', 'Department'): 0.00013256445946841652,
#  ('Police', 'Department', ','): 0.00013256445946841652,
#  (',', 'the', 'Fulton'): 0.00012924906294429367,
#  ('the', 'Fulton', 'Tax'): 0.0001325293221125174,
#  ('Fulton', 'Tax', "Commissioner's"): 0.00013256445946841652,
#  ('Tax', "Commissioner's", 'Office'): 0.00013256445946841652,
#  ("Commissioner's", 'Office', ','): 0.00013256445946841652,
#  ('Office', ',', 'the'): 0.00013256445946841652,
#  (',', 'the', 'Bellwood'): 0.00012924906294429367,
#  ('the', 'Bellwood', 'and'): 0.00013256445946841652,
#  ('Bellwood', 'and', 'Alpharetta'): 0.00013256445946841652,
#  ('and', 'Alpharetta', 'prison'): 0.00013256445946841652,
#  ('Alpharetta', 'prison', 'farms'): 0.00013256445946841652,
#  ('prison', 'farms', ','): 0.00013256445946841652,
#  ('farms', ',', 'Grady'): 0.00013256445946841652,
#  (',', 'Grady', 'Hospital'): 0.00013256445946841652,
#  ('Grady', 'Hospital', 'and'): 0.00013254688846179335,
#  ('Hospital', 'and', 'the'): 0.00013256445946841652,
#  ('and', 'the', 'Fulton'): 0.00013124220749393005,
#  ('the', 'Fulton', 'Health'): 0.0001325293221125174,
#  ('Fulton', 'Health', 'Department'): 0.00013256445946841652,
#  ('Health', 'Department', '.'): 0.00013256445946841652,
#  ('Department', '.', '</s>'): 0.00013256445946841652,
#  ('</s>', '<s>', 'Mayor'): 0.00024894199651481205,
#  ('<s>', 'Mayor', 'William'): 0.0001325381047051027,
#  ('Mayor', 'William', 'B.'): 0.00013256445946841652,
#  ('William', 'B.', 'Hartsfield'): 0.00013256445946841652,
#  ('B.', 'Hartsfield', 'filed'): 0.00013256445946841652,
#  ('Hartsfield', 'filed', 'suit'): 0.00013256445946841652,
#  ('filed', 'suit', 'for'): 0.00013256445946841652,
#  ('suit', 'for', 'divorce'): 0.00013256445946841652,
#  ('for', 'divorce', 'from'): 0.00013256445946841652,
#  ('divorce', 'from', 'his'): 0.00013256445946841652,
#  ('from', 'his', 'wife'): 0.00013252054068380598,
#  ('his', 'wife', ','): 0.0006622078008078935,
#  ('wife', ',', 'Pearl'): 0.00013243279035889287,
#  (',', 'Pearl', 'Williams'): 0.00013256445946841652,
#  ('Pearl', 'Williams', 'Hartsfield'): 0.00013256445946841652,
#  ('Williams', 'Hartsfield', ','): 0.00013256445946841652,
#  ('Hartsfield', ',', 'in'): 0.00013256445946841652,
#  (',', 'in', 'Fulton'): 0.00013184784758388818,
#  ('in', 'Fulton', 'Superior'): 0.00013256445946841652,
#  ('Superior', 'Court', 'Friday'): 0.0001325293221125174,
#  ('Court', 'Friday', '.'): 0.0001325556733828208,
#  ('Friday', '.', '</s>'): 0.0005962634159268584,
#  ('</s>', '<s>', 'His'): 0.00144386357978591,
#  ('<s>', 'His', 'petition'): 0.00013232764324467382,
#  ('His', 'petition', 'charged'): 0.00013256445946841652,
#  ('petition', 'charged', 'mental'): 0.00013256445946841652,
#  ('charged', 'mental', 'cruelty'): 0.00013256445946841652,
#  ('mental', 'cruelty', '.'): 0.00013256445946841652,
#  ('cruelty', '.', '</s>'): 0.00013256445946841652,
#  ('<s>', 'The', 'couple'): 0.00018875047187617969,
#  ('The', 'couple', 'was'): 0.0001325556733828208,
#  ('couple', 'was', 'married'): 0.00013256445946841652,
#  ('was', 'married', 'Aug.'): 0.00013254688846179335,
#  ('married', 'Aug.', '2'): 0.00013256445946841652,
#  ('Aug.', '2', ','): 0.00013256445946841652,
#  ('2', ',', '1913'): 0.00013248542660307367,
#  (',', '1913', '.'): 0.00013256445946841652,
#  ('1913', '.', '</s>'): 0.00013256445946841652,
#  ('</s>', '<s>', 'They'): 0.003136669156086632,
#  ('<s>', 'They', 'have'): 0.0003300765777660417,
#  ('They', 'have', 'a'): 0.0001325381047051027,
#  ('have', 'a', 'son'): 0.00013239772275916854,
#  ('a', 'son', ','): 0.0003313452617627568,
#  ('son', ',', 'William'): 0.00019875447197561946,
#  (',', 'William', 'Berry'): 0.00013251176041873715,
#  ('William', 'Berry', 'Jr.'): 0.00013256445946841652,
#  ('Berry', 'Jr.', ','): 0.00013256445946841652,
#  ('Jr.', ',', 'and'): 0.0001984914648670107,
#  (',', 'and', 'a'): 0.0006457862447529867,
#  ('and', 'a', 'daughter'): 0.00013203934772562222,
#  ('a', 'daughter', ','): 0.00046382189239332097,
#  ('daughter', ',', 'Mrs.'): 0.00019863603257630935,
#  (',', 'Mrs.', 'J.'): 0.00019790223629527012,
#  ('Mrs.', 'J.', 'M.'): 0.0001325381047051027,
#  ('J.', 'M.', 'Cheshire'): 0.00013256445946841652,
#  ('M.', 'Cheshire', 'of'): 0.00013256445946841652,
#  ('Cheshire', 'of', 'Griffin'): 0.00013256445946841652,
#  ('of', 'Griffin', '.'): 0.00013256445946841652,
#  ('Griffin', '.', '</s>'): 0.00019883351007423118,
#  ('</s>', '<s>', 'Attorneys'): 0.00014936519790888724,
#  ('<s>', 'Attorneys', 'for'): 0.00019883351007423118,
#  ('Attorneys', 'for', 'the'): 0.00019883351007423118,
#  ('for', 'the', 'mayor'): 0.0001305227435880702,
#  ('the', 'mayor', 'said'): 0.00013256445946841652,
#  ('mayor', 'said', 'that'): 0.00013256445946841652,
#  ('said', 'that', 'an'): 0.00013229263130043657,
#  ('that', 'an', 'amicable'): 0.0001325293221125174,
#  ('an', 'amicable', 'property'): 0.00013256445946841652,
#  ('amicable', 'property', 'settlement'): 0.00013256445946841652,
#  ('property', 'settlement', 'has'): 0.00013256445946841652,
#  ('settlement', 'has', 'been'): 0.00013256445946841652,
#  ('has', 'been', 'agreed'): 0.0001317089232795522,
#  ('been', 'agreed', 'upon'): 0.00013256445946841652,
#  ('agreed', 'upon', '.'): 0.0001325556733828208,
#  ('upon', '.', '</s>'): 0.00019883351007423118,
#  ('<s>', 'The', 'petition'): 0.00018875047187617969,
#  ('The', 'petition', 'listed'): 0.0001325556733828208,
#  ('petition', 'listed', 'the'): 0.00013256445946841652,
#  ('listed', 'the', "mayor's"): 0.0001325556733828208,
#  ('the', "mayor's", 'occupation'): 0.00013254688846179335,
#  ("mayor's", 'occupation', 'as'): 0.00013256445946841652,
#  ('occupation', 'as', '``'): 0.00013256445946841652,
#  ('as', '``', 'attorney'): 0.00013250298131707962,
#  ('``', 'attorney', "''"): 0.00013256445946841652,
#  ('attorney', "''", 'and'): 0.00013256445946841652,
#  ("''", 'and', 'his'): 0.00013243279035889287,
#  ('and', 'his', 'age'): 0.00013225763787858748,
#  ('his', 'age', 'as'): 0.00013256445946841652,
#  ('age', 'as', '71'): 0.0001325556733828208,
#  ('as', '71', '.'): 0.00013256445946841652,
#  ('71', '.', '</s>'): 0.00019883351007423118,
#  ('<s>', 'It', 'listed'): 0.00013153567905294311,
#  ('It', 'listed', 'his'): 0.00013256445946841652,
#  ('listed', 'his', "wife's"): 0.00013256445946841652,
#  ('his', "wife's", 'age'): 0.00013256445946841652,
#  ("wife's", 'age', 'as'): 0.00013256445946841652,
#  ('age', 'as', '74'): 0.0001325556733828208,
#  ('as', '74', 'and'): 0.00013256445946841652,
#  ('74', 'and', 'place'): 0.0001325556733828208,
#  ('and', 'place', 'of'): 0.00013256445946841652,
#  ('place', 'of', 'birth'): 0.0001325556733828208,
#  ('of', 'birth', 'as'): 0.00013256445946841652,
#  ('birth', 'as', 'Opelika'): 0.00013256445946841652,
#  ('as', 'Opelika', ','): 0.00013256445946841652,
#  ('Opelika', ',', 'Ala.'): 0.00013256445946841652,
#  (',', 'Ala.', '.'): 0.0003312794010468429,
#  ('Ala.', '.', '</s>'): 0.0003313452617627568,
#  ('The', 'petition', 'said'): 0.0001325556733828208,
#  ('petition', 'said', 'that'): 0.00013256445946841652,
#  ('said', 'that', 'the'): 0.0007276094721524011,
#  ('that', 'the', 'couple'): 0.00013124220749393005,
#  ('the', 'couple', 'has'): 0.00013254688846179335,
#  ('couple', 'has', 'not'): 0.00013256445946841652,
#  ('has', 'not', 'lived'): 0.00013245910325187097,
#  ('not', 'lived', 'together'): 0.00013256445946841652,
#  ('lived', 'together', 'as'): 0.00013256445946841652,
#  ('together', 'as', 'man'): 0.00013256445946841652,
#  ('as', 'man', 'and'): 0.00013256445946841652,
#  ('man', 'and', 'wife'): 0.0001325381047051027,
#  ('and', 'wife', 'for'): 0.0001325381047051027,
#  ('wife', 'for', 'more'): 0.00013254688846179335,
#  ('for', 'more', 'than'): 0.00033125745329269906,
#  ('more', 'than', 'a'): 0.0005944517833553501,
#  ('than', 'a', 'year'): 0.00026491820650374195,
#  ('a', 'year', '.'): 0.00039695666556400925,
#  ('year', '.', '</s>'): 0.0025786828881248346,
#  ('<s>', 'The', 'Hartsfield'): 0.00012583364791745311,
#  ('The', 'Hartsfield', 'home'): 0.00013256445946841652,
#  ('Hartsfield', 'home', 'is'): 0.00013256445946841652,
#  ('home', 'is', 'at'): 0.00013256445946841652,
#  ('is', 'at', '637'): 0.0001325556733828208,
#  ('at', '637', 'E.'): 0.00013256445946841652,
#  ('637', 'E.', 'Pelham'): 0.00013256445946841652,
#  ('E.', 'Pelham', 'Rd.'): 0.00013256445946841652,
#  ('Pelham', 'Rd.', 'Aj'): 0.00013256445946841652,
#  ('Rd.', 'Aj', '.'): 0.00013256445946841652,
#  ('Aj', '.', '</s>'): 0.0009272137227630969,
#  ('</s>', '<s>', 'Henry'): 0.00014936519790888724,
#  ('<s>', 'Henry', 'L.'): 0.0001325556733828208,
#  ('Henry', 'L.', 'Bowden'): 0.00019883351007423118,
#  ('L.', 'Bowden', 'was'): 0.0001325556733828208,
#  ('Bowden', 'was', 'listed'): 0.00013256445946841652,
#  ('was', 'listed', 'on'): 0.00013256445946841652,
#  ('listed', 'on', 'the'): 0.00019883351007423118,
#  ('on', 'the', 'petition'): 0.00013032712107389547,
#  ('the', 'petition', 'as'): 0.00013256445946841652,
#  ('petition', 'as', 'the'): 0.00013256445946841652,
#  ('as', 'the', "mayor's"): 0.0001320306311064167,
#  ('the', "mayor's", 'attorney'): 0.00013254688846179335,
#  ("mayor's", 'attorney', '.'): 0.00013256445946841652,
#  ('attorney', '.', '</s>'): 0.00019883351007423118,
#  ('</s>', '<s>', 'Hartsfield'): 9.957679860592482e-05,
#  ('<s>', 'Hartsfield', 'has'): 0.00013256445946841652,
#  ('Hartsfield', 'has', 'been'): 0.00013256445946841652,
#  ('has', 'been', 'mayor'): 0.0001317089232795522,
#  ('been', 'mayor', 'of'): 0.00013256445946841652,
#  ('mayor', 'of', 'Atlanta'): 0.00013256445946841652,
#  ('of', 'Atlanta', ','): 0.00026504108136761196,
#  ('Atlanta', ',', 'with'): 0.0001325381047051027,
#  (',', 'with', 'exception'): 0.0001320306311064167,
#  ('with', 'exception', 'of'): 0.00013256445946841652,
#  ('exception', 'of', 'one'): 0.00013254688846179335,
#  ('of', 'one', 'brief'): 0.0001324942033786022,
#  ('one', 'brief', 'interlude'): 0.00013256445946841652,
#  ('brief', 'interlude', ','): 0.00013256445946841652,
#  ('interlude', ',', 'since'): 0.00013256445946841652,
#  (',', 'since', '1937'): 0.0001324942033786022,
#  ('since', '1937', '.'): 0.00013256445946841652,
#  ('1937', '.', '</s>'): 0.00019883351007423118,
#  ('<s>', 'His', 'political'): 0.00013232764324467382,
#  ('His', 'political', 'career'): 0.00013256445946841652,
#  ('political', 'career', 'goes'): 0.0001325556733828208,
#  ('career', 'goes', 'back'): 0.00013256445946841652,
#  ('goes', 'back', 'to'): 0.00013256445946841652,
#  ('back', 'to', 'his'): 0.00013247665099026297,
#  ('to', 'his', 'election'): 0.00013245910325187097,
#  ('his', 'election', 'to'): 0.00013256445946841652,
#  ('election', 'to', 'city'): 0.00013254688846179335,
#  ('to', 'city', 'council'): 0.00013256445946841652,
#  ('city', 'council', 'in'): 0.0001325381047051027,
#  ('council', 'in', '1923'): 0.00013256445946841652,
#  ('in', '1923', '.'): 0.00013256445946841652,
#  ('1923', '.', '</s>'): 0.00013256445946841652,
#  ('<s>', 'The', "mayor's"): 0.00012583364791745311,
#  ('The', "mayor's", 'present'): 0.00013256445946841652,
#  ("mayor's", 'present', 'term'): 0.00013256445946841652,
#  ('present', 'term', 'of'): 0.00013256445946841652,
#  ('term', 'of', 'office'): 0.00013256445946841652,
#  ('of', 'office', 'expires'): 0.00013256445946841652,
#  ('office', 'expires', 'Jan.'): 0.00013256445946841652,
#  ('expires', 'Jan.', '1'): 0.00013256445946841652,
#  ('Jan.', '1', '.'): 0.00019880715705765408,
#  ('1', '.', '</s>'): 0.0005962634159268584,
#  ('</s>', '<s>', 'He'): 0.010206621857107294,
#  ('<s>', 'He', 'will'): 0.0005232177894048398,
#  ('He', 'will', 'be'): 0.0002650235208374743,
#  ('will', 'be', 'succeeded'): 0.00019672131147540983,
#  ('be', 'succeeded', 'by'): 0.00019883351007423118,
#  ('succeeded', 'by', 'Ivan'): 0.0001325556733828208,
#  ('by', 'Ivan', 'Allen'): 0.00013256445946841652,
#  ('Allen', 'Jr.', ','): 0.0001325556733828208,
#  ('Jr.', ',', 'who'): 0.0001984914648670107,
#  (',', 'who', 'became'): 0.00013143195110731419,
#  ('who', 'became', 'a'): 0.0001325556733828208,
#  ('became', 'a', 'candidate'): 0.00013254688846179335,
#  ('a', 'candidate', 'in'): 0.0002650235208374743,
#  ('candidate', 'in', 'the'): 0.00019882033269269004,
#  ('in', 'the', 'Sept.'): 0.0001913753508548099,
#  ('the', 'Sept.', '13'): 0.0001325556733828208,
#  ('Sept.', '13', 'primary'): 0.00013256445946841652,
#  ('13', 'primary', 'after'): 0.00013256445946841652,
#  ('primary', 'after', 'Mayor'): 0.00013256445946841652,
#  ('after', 'Mayor', 'Hartsfield'): 0.00013256445946841652,
#  ('Mayor', 'Hartsfield', 'announced'): 0.00013256445946841652,
#  ('Hartsfield', 'announced', 'that'): 0.00013256445946841652,
#  ('announced', 'that', 'he'): 0.00019868865487780648,
#  ('that', 'he', 'would'): 0.0003964059196617336,
#  ('he', 'would', 'not'): 0.0003310381355932203,
#  ('would', 'not', 'run'): 0.00013239772275916854,
#  ('not', 'run', 'for'): 0.00013256445946841652,
#  ('run', 'for', 'reelection'): 0.00013256445946841652,
#  ('for', 'reelection', '.'): 0.00013256445946841652,
#  ('reelection', '.', '</s>'): 0.00013256445946841652,
#  ('</s>', '<s>', 'Georgia'): 0.00014936519790888724,
#  ('<s>', 'Georgia', 'Republicans'): 0.0001325556733828208,
#  ('Georgia', 'Republicans', 'are'): 0.00013256445946841652,
#  ('Republicans', 'are', 'getting'): 0.00013256445946841652,
#  ('are', 'getting', 'strong'): 0.00013254688846179335,
#  ('getting', 'strong', 'encouragement'): 0.00013256445946841652,
#  ('strong', 'encouragement', 'to'): 0.00013256445946841652,
#  ('encouragement', 'to', 'enter'): 0.0001325556733828208,
#  ('to', 'enter', 'a'): 0.00019880715705765408,
#  ('enter', 'a', 'candidate'): 0.00019883351007423118,
#  ('in', 'the', '1962'): 0.00012758356723653993,
#  ('the', '1962', "governor's"): 0.0001325556733828208,
#  ('1962', "governor's", 'race'): 0.00013256445946841652,
#  ("governor's", 'race', ','): 0.00013256445946841652,
#  ('race', ',', 'a'): 0.00013251176041873715,
#  (',', 'a', 'top'): 0.00013146650890685598,
#  ('a', 'top', 'official'): 0.0001325381047051027,
#  ('top', 'official', 'said'): 0.00013256445946841652,
#  ('official', 'said', 'Wednesday'): 0.0001325556733828208,
#  ('said', 'Wednesday', '.'): 0.00013256445946841652,
#  ('Wednesday', '.', '</s>'): 0.00039758796633755216,
#  ('</s>', '<s>', 'Robert'): 0.00014936519790888724,
#  ('<s>', 'Robert', 'Snodgrass'): 0.0001325556733828208,
#  ('Robert', 'Snodgrass', ','): 0.00013256445946841652,
#  ('Snodgrass', ',', 'state'): 0.00013256445946841652,
#  (',', 'state', 'GOP'): 0.00013252054068380598,
#  ('state', 'GOP', 'chairman'): 0.00013256445946841652,
#  ('GOP', 'chairman', ','): 0.00013256445946841652,
#  ('chairman', ',', 'said'): 0.00019878081102570898,
#  (',', 'said', 'a'): 0.00026421824426976683,
#  ('said', 'a', 'meeting'): 0.0001325381047051027,
#  ('a', 'meeting', 'held'): 0.00013245910325187097,
#  ('meeting', 'held', 'Tuesday'): 0.00013256445946841652,
#  ('held', 'Tuesday', 'night'): 0.00013256445946841652,
#  ('Tuesday', 'night', 'in'): 0.0001325293221125174,
#  ('night', 'in', 'Blue'): 0.0001325381047051027,
#  ...}

# %%
#For webtext corpus
trigrams_webtext = create_trigrams(webtext_tokens)
trigrams_webtext_wc = Counter(trigrams_webtext)

# %%
cp_t_webtext = {} # cp_t -> conditional probabilities of trigrams

for i in trigrams_webtext:
  cp_t_webtext[i] = conditional_probability_trigrams(i[0], i[1],i[2], trigrams_webtext_wc, bgrams_webtext_wc, V_webtext)

# %%
cp_t_webtext
# Out:
# {('<s>', 'Cookie', 'Manager'): 0.00017573148229505317,
#  ('Cookie', 'Manager', ':'): 0.00017562346329469617,
#  ('Manager', ':', '"'): 0.00017573148229505317,
#  (':', '"', 'Don'): 0.00017528483786152498,
#  ('"', 'Don', "'"): 0.0004392515154177282,
#  ('Don', "'", 't'): 0.0035029337069795953,
#  ("'", 't', 'allow'): 0.0005527043031977891,
#  ('t', 'allow', 'sites'): 0.00026350461133069827,
#  ('allow', 'sites', 'that'): 0.0002635972234425797,
#  ('sites', 'that', 'set'): 0.0002635509092506369,
#  ('that', 'set', 'removed'): 0.0002635972234425797,
#  ('set', 'removed', 'cookies'): 0.0002635972234425797,
#  ('removed', 'cookies', 'to'): 0.0002635972234425797,
#  ('cookies', 'to', 'set'): 0.0002635972234425797,
#  ('to', 'set', 'future'): 0.00026322716504343247,
#  ('set', 'future', 'cookies'): 0.0002635972234425797,
#  ('future', 'cookies', '"'): 0.00017573148229505317,
#  ('cookies', '"', 'should'): 0.0002635509092506369,
#  ('"', 'should', 'stay'): 0.00035096955339124333,
#  ('should', 'stay', 'checked'): 0.0003514320857494289,
#  ('stay', 'checked', 'When'): 0.00017568517217146873,
#  ('checked', 'When', 'in'): 0.0001757469244288225,
#  ('When', 'in', 'full'): 0.00017571604287471446,
#  ('in', 'full', 'screen'): 0.0005270092226613965,
#  ('full', 'screen', 'mode'): 0.001052816283558519,
#  ('screen', 'mode', 'Pressing'): 0.000175530981218185,
#  ('mode', 'Pressing', 'Ctrl'): 0.0001757469244288225,
#  ('Pressing', 'Ctrl', '-'): 0.00017571604287471446,
#  ('Ctrl', '-', 'N'): 0.00017539244058581075,
#  ('-', 'N', 'should'): 0.0001757469244288225,
#  ('N', 'should', 'open'): 0.0001757469244288225,
#  ('should', 'open', 'a'): 0.0005263619615755768,
#  ('open', 'a', 'new'): 0.0018383962181563512,
#  ('a', 'new', 'browser'): 0.00034825004353125546,
#  ('new', 'browser', 'when'): 0.0001756543123133673,
#  ('browser', 'when', 'only'): 0.00017568517217146873,
#  ('when', 'only', 'download'): 0.00017560804284836245,
#  ('only', 'download', 'dialog'): 0.0001757469244288225,
#  ('download', 'dialog', 'is'): 0.0002634814684700509,
#  ('dialog', 'is', 'left'): 0.00017557721007813187,
#  ('is', 'left', 'open'): 0.0002635509092506369,
#  ('left', 'open', 'add'): 0.00017573148229505317,
#  ('open', 'add', 'icons'): 0.0001757469244288225,
#  ('add', 'icons', 'to'): 0.0001757469244288225,
#  ('icons', 'to', 'context'): 0.00017568517217146873,
#  ('to', 'context', 'menu'): 0.0003514320857494289,
#  ('context', 'menu', 'So'): 0.00017448961786773688,
#  ('menu', 'So', 'called'): 0.0001757469244288225,
#  ('So', 'called', '"'): 0.0001757469244288225,
#  ('called', '"', 'tab'): 0.00017571604287471446,
#  ('"', 'tab', 'bar'): 0.00017570060616709128,
#  ('tab', 'bar', '"'): 0.00017542320849048328,
#  ('bar', '"', 'should'): 0.00017570060616709128,
#  ('"', 'should', 'be'): 0.0005264543300868649,
#  ('should', 'be', 'made'): 0.0002601231249458077,
#  ('be', 'made', 'a'): 0.0001756697408871322,
#  ('made', 'a', 'proper'): 0.00017573148229505317,
#  ('a', 'proper', 'toolbar'): 0.00017571604287471446,
#  ('proper', 'toolbar', 'or'): 0.0001757469244288225,
#  ('toolbar', 'or', 'given'): 0.00017570060616709128,
#  ('or', 'given', 'the'): 0.0001757469244288225,
#  ('given', 'the', 'ability'): 0.00017573148229505317,
#  ('the', 'ability', 'collapse'): 0.00017571604287471446,
#  ('ability', 'collapse', '/'): 0.0001757469244288225,
#  ('collapse', '/', 'expand'): 0.0001757469244288225,
#  ('/', 'expand', '.'): 0.0001757469244288225,
#  ('expand', '.', '</s>'): 0.0001757469244288225,
#  ('.', '</s>', '<s>'): 0.20638906326288625,
#  ('</s>', '<s>', '['): 0.008548052265233851,
#  ('<s>', '[', 'XUL'): 0.00017364125716270185,
#  ('[', 'XUL', ']'): 0.0001757469244288225,
#  ('XUL', ']', 'Implement'): 0.0001757469244288225,
#  (']', 'Implement', 'Cocoa'): 0.0001757469244288225,
#  ('Implement', 'Cocoa', '-'): 0.0001757469244288225,
#  ('Cocoa', '-', 'style'): 0.0001757469244288225,
#  ('-', 'style', 'toolbar'): 0.0001755926251097454,
#  ('style', 'toolbar', 'customization'): 0.0001757469244288225,
#  ('toolbar', 'customization', '.'): 0.0002634120642725437,
#  ('customization', '.', '</s>'): 0.0002635972234425797,
#  ('</s>', '<s>', '#'): 0.00018317254854072538,
#  ('<s>', '#', 'ifdefs'): 0.00017573148229505317,
#  ('#', 'ifdefs', 'for'): 0.00017573148229505317,
#  ('ifdefs', 'for', 'MOZ_PHOENIX'): 0.0001757469244288225,
#  ('for', 'MOZ_PHOENIX', 'customize'): 0.0001757469244288225,
#  ('MOZ_PHOENIX', 'customize', 'dialog'): 0.0001757469244288225,
#  ('customize', 'dialog', "'"): 0.00017570060616709128,
#  ('dialog', "'", 's'): 0.0002635972234425797,
#  ("'", 's', 'toolbar'): 0.00025092004014720643,
#  ('s', 'toolbar', 'has'): 0.00017573148229505317,
#  ('toolbar', 'has', 'small'): 0.00017571604287471446,
#  ('has', 'small', 'icons'): 0.0001757469244288225,
#  ('small', 'icons', 'when'): 0.0002634120642725437,
#  ('icons', 'when', 'small'): 0.00017573148229505317,
#  ('when', 'small', 'icons'): 0.0001757469244288225,
#  ('small', 'icons', 'is'): 0.00017560804284836245,
#  ('icons', 'is', 'not'): 0.0001757469244288225,
#  ('is', 'not', 'checked'): 0.0003465003465003465,
#  ('not', 'checked', 'nightly'): 0.00017571604287471446,
#  ('checked', 'nightly', 'builds'): 0.0001757469244288225,
#  ('nightly', 'builds', 'and'): 0.00017562346329469617,
#  ('builds', 'and', 'tinderboxen'): 0.0001757469244288225,
#  ('and', 'tinderboxen', 'for'): 0.0001757469244288225,
#  ('tinderboxen', 'for', 'Phoenix'): 0.0001757469244288225,
#  ('for', 'Phoenix', 'finish'): 0.00017570060616709128,
#  ('Phoenix', 'finish', 'tearing'): 0.0001757469244288225,
#  ('finish', 'tearing', 'prefs'): 0.0001757469244288225,
#  ('tearing', 'prefs', 'UI'): 0.0001757469244288225,
#  ('prefs', 'UI', 'to'): 0.0001757469244288225,
#  ('UI', 'to', 'pieces'): 0.00017568517217146873,
#  ('to', 'pieces', 'and'): 0.0001757469244288225,
#  ('pieces', 'and', 'then'): 0.0001757469244288225,
#  ('and', 'then', 'make'): 0.00017528483786152498,
#  ('then', 'make', 'it'): 0.0001757469244288225,
#  ('make', 'it', 'not'): 0.0001756388864494599,
#  ('it', 'not', 'suck'): 0.00017570060616709128,
#  ('not', 'suck', '"'): 0.00017571604287471446,
#  ('suck', '"', 'mozbrowser'): 0.0001757469244288225,
#  ('"', 'mozbrowser', '"'): 0.0001757469244288225,
#  ('mozbrowser', '"', 'script'): 0.0001757469244288225,
#  ('"', 'script', 'doesn'): 0.0001757469244288225,
#  ('script', 'doesn', "'"): 0.0001757469244288225,
#  ('doesn', "'", 't'): 0.03950367181564953,
#  ("'", 't', 'start'): 0.0019739439399921043,
#  ('t', 'start', 'correct'): 0.00017539244058581075,
#  ('start', 'correct', 'binary'): 0.0001757469244288225,
#  ('correct', 'binary', 'Need'): 0.0001757469244288225,
#  ('binary', 'Need', 'bookmark'): 0.0001757469244288225,
#  ('Need', 'bookmark', 'groups'): 0.0001757469244288225,
#  ('bookmark', 'groups', 'icon'): 0.00017571604287471446,
#  ('groups', 'icon', 'Dropping'): 0.0001757469244288225,
#  ('icon', 'Dropping', 'at'): 0.0001757469244288225,
#  ('Dropping', 'at', 'top'): 0.0001757469244288225,
#  ('at', 'top', 'of'): 0.0002635509092506369,
#  ('top', 'of', 'palette'): 0.00017551557700745942,
#  ('of', 'palette', 'box'): 0.0001757469244288225,
#  ('palette', 'box', 'horks'): 0.0001757469244288225,
#  ('box', 'horks', 'things'): 0.0001757469244288225,
#  ('horks', 'things', 'keyboard'): 0.00017573148229505317,
#  ('things', 'keyboard', 'shortcut'): 0.0001757469244288225,
#  ('keyboard', 'shortcut', 'for'): 0.0007019391067824867,
#  ('shortcut', 'for', 'Increase'): 0.00017556179775280898,
#  ('for', 'Increase', 'Text'): 0.0001757469244288225,
#  ('Increase', 'Text', 'Size'): 0.0001757469244288225,
#  ('Text', 'Size', 'is'): 0.00017568517217146873,
#  ('Size', 'is', 'broken'): 0.00017573148229505317,
#  ('is', 'broken', 'default'): 0.00017533093714385903,
#  ('broken', 'default', 'phoenix'): 0.0001757469244288225,
#  ('default', 'phoenix', 'bookmarks'): 0.00017573148229505317,
#  ('phoenix', 'bookmarks', '['): 0.00017573148229505317,
#  ('bookmarks', '[', 'cust'): 0.0001757469244288225,
#  ('[', 'cust', ']'): 0.0021924055073226346,
#  ('cust', ']', 'need'): 0.00017539244058581075,
#  (']', 'need', 'a'): 0.00017573148229505317,
#  ('need', 'a', 'toolbar'): 0.00017562346329469617,
#  ('a', 'toolbar', 'spacer'): 0.00017560804284836245,
#  ('toolbar', 'spacer', 'and'): 0.0001757469244288225,
#  ('spacer', 'and', 'spring'): 0.0001757469244288225,
#  ('and', 'spring', 'spacer'): 0.0001757469244288225,
#  ('spring', 'spacer', 'for'): 0.0001757469244288225,
#  ('spacer', 'for', 'customize'): 0.0001757469244288225,
#  ('for', 'customize', 'Can'): 0.00017573148229505317,
#  ('customize', 'Can', "'"): 0.0001757469244288225,
#  ('Can', "'", 't'): 0.009230233368164403,
#  ("'", 't', 'launch'): 0.0007106198183971576,
#  ('t', 'launch', 'phoenix'): 0.0001756388864494599,
#  ('launch', 'phoenix', 'while'): 0.00017573148229505317,
#  ('phoenix', 'while', 'Mozilla'): 0.0001757469244288225,
#  ('while', 'Mozilla', 'is'): 0.0001757469244288225,
#  ('Mozilla', 'is', 'running'): 0.0002635740643120717,
#  ('is', 'running', '('): 0.000175530981218185,
#  ('running', '(', 'or'): 0.0001757469244288225,
#  ('(', 'or', 'vice'): 0.00026320407088962973,
#  ('or', 'vice', 'versa'): 0.00017573148229505317,
#  ('vice', 'versa', ')'): 0.0001757469244288225,
#  ('versa', ')', 'separator'): 0.0001757469244288225,
#  (')', 'separator', 'not'): 0.0001757469244288225,
#  ('separator', 'not', 'available'): 0.0001757469244288225,
#  ('not', 'available', 'when'): 0.00017562346329469617,
#  ('available', 'when', 'all'): 0.00017571604287471446,
#  ('when', 'all', 'toolbar'): 0.00026352775825720307,
#  ('all', 'toolbar', 'items'): 0.00017573148229505317,
#  ('toolbar', 'items', 'are'): 0.00017570060616709128,
#  ('items', 'are', 'in'): 0.00017571604287471446,
#  ('are', 'in', 'toolbar'): 0.0001756697408871322,
#  ('in', 'toolbar', 'layout'): 0.00017560804284836245,
#  ('toolbar', 'layout', 'history'): 0.0001757469244288225,
#  ('layout', 'history', 'menu'): 0.0001757469244288225,
#  ('history', 'menu', 'for'): 0.00017573148229505317,
#  ('menu', 'for', 'the'): 0.0002633889376646181,
#  ('for', 'the', 'back'): 0.00017482517482517483,
#  ('the', 'back', 'buttons'): 0.00017556179775280898,
#  ('back', 'buttons', 'doesn'): 0.00017562346329469617,
#  ('buttons', 'doesn', "'"): 0.0001757469244288225,
#  ("'", 't', 'work'): 0.015633636004737467,
#  ('t', 'work', 'attempting'): 0.0001727563272004837,
#  ('work', 'attempting', 'to'): 0.0001757469244288225,
#  ('attempting', 'to', 'open'): 0.0005263619615755768,
#  ('to', 'open', '"'): 0.00034825004353125546,
#  ('open', '"', 'back'): 0.00017562346329469617,
#  ('"', 'back', 'button'): 0.0001756543123133673,
#  ('back', 'button', 'history'): 0.00017546938059308652,
#  ('button', 'history', 'menu'): 0.00017571604287471446,
#  ('history', 'menu', '"'): 0.00017573148229505317,
#  ('menu', '"', 'in'): 0.0001756697408871322,
#  ('"', 'in', 'the'): 0.001136761105281567,
#  ('in', 'the', 'second'): 0.0002562350529552443,
#  ('the', 'second', 'window'): 0.0001756697408871322,
#  ('second', 'window', 'generates'): 0.00017568517217146873,
#  ('window', 'generates', 'another'): 0.0001757469244288225,
#  ('generates', 'another', 'back'): 0.0001757469244288225,
#  ('another', 'back', 'button'): 0.0001757469244288225,
#  ('back', 'button', 'on'): 0.00017546938059308652,
#  ('button', 'on', 'the'): 0.0005263157894736842,
#  ('on', 'the', 'toolbar'): 0.0004347070074769605,
#  ('the', 'toolbar', 'Phoenix'): 0.00017554638813306416,
#  ('toolbar', 'Phoenix', 'and'): 0.00017573148229505317,
#  ('Phoenix', 'and', 'Mozilla'): 0.0001757469244288225,
#  ('and', 'Mozilla', 'cannot'): 0.00017568517217146873,
#  ('Mozilla', 'cannot', 'comfortably'): 0.0001757469244288225,
#  ('cannot', 'comfortably', 'share'): 0.0001757469244288225,
#  ('comfortably', 'share', 'a'): 0.0001757469244288225,
#  ('share', 'a', 'source'): 0.0001757469244288225,
#  ('a', 'source', 'tree'): 0.0001757469244288225,
#  ('source', 'tree', 'Phoenix'): 0.0001757469244288225,
#  ('tree', 'Phoenix', 'forgets'): 0.0001757469244288225,
#  ('Phoenix', 'forgets', 'all'): 0.0001757469244288225,
#  ('forgets', 'all', 'cookies'): 0.0001757469244288225,
#  ('all', 'cookies', 'even'): 0.00017568517217146873,
#  ('cookies', 'even', 'though'): 0.00017573148229505317,
#  ('even', 'though', '"'): 0.00035115442015626374,
#  ('though', '"', 'Enable'): 0.00017571604287471446,
#  ('"', 'Enable', 'cookies'): 0.0002635972234425797,
#  ('Enable', 'cookies', 'for'): 0.00017573148229505317,
#  ('cookies', 'for', 'the'): 0.0002635972234425797,
#  ('for', 'the', 'current'): 0.00026223776223776224,
#  ('the', 'current', 'session'): 0.00035106196243637,
#  ('current', 'session', 'only'): 0.00035140121233418256,
#  ('session', 'only', '"'): 0.00035140121233418256,
#  ('only', '"', 'is'): 0.00017560804284836245,
#  ('"', 'is', 'NOT'): 0.00017513134851138354,
#  ('is', 'NOT', 'chosen'): 0.0001757469244288225,
#  ('NOT', 'chosen', 'Starting'): 0.0001757469244288225,
#  ('chosen', 'Starting', 'Customizing'): 0.0001757469244288225,
#  ('Starting', 'Customizing', 'Toolbar'): 0.0001757469244288225,
#  ('Customizing', 'Toolbar', 'makes'): 0.00017573148229505317,
#  ('Toolbar', 'makes', 'the'): 0.0001757469244288225,
#  ('makes', 'the', 'current'): 0.0001756543123133673,
#  ('the', 'current', 'page'): 0.0002632964718272775,
#  ('current', 'page', 'go'): 0.0001756697408871322,
#  ('page', 'go', 'blank'): 0.0001757469244288225,
#  ('go', 'blank', 'Check'): 0.00017573148229505317,
#  ('blank', 'Check', 'in'): 0.0001757469244288225,
#  ('Check', 'in', 'Satchel'): 0.00017573148229505317,
#  ('in', 'Satchel', '('): 0.0001757469244288225,
#  ('Satchel', '(', 'the'): 0.0001757469244288225,
#  ('(', 'the', 'successor'): 0.00017571604287471446,
#  ('the', 'successor', 'to'): 0.0001757469244288225,
#  ('successor', 'to', 'wallet'): 0.0001757469244288225,
#  ('to', 'wallet', ')'): 0.0001757469244288225,
#  ('wallet', ')', 'Mousing'): 0.0001757469244288225,
#  (')', 'Mousing', 'over'): 0.0001757469244288225,
#  ('Mousing', 'over', 'back'): 0.0001757469244288225,
#  ('over', 'back', 'menu'): 0.0001757469244288225,
#  ('back', 'menu', 'in'): 0.00017573148229505317,
#  ('menu', 'in', 'second'): 0.00017557721007813187,
#  ('in', 'second', 'window'): 0.0001757469244288225,
#  ('second', 'window', 'horks'): 0.00017568517217146873,
#  ('window', 'horks', 'things'): 0.0001757469244288225,
#  ('horks', 'things', 'Personal'): 0.00017573148229505317,
#  ('things', 'Personal', 'toolbar'): 0.0001757469244288225,
#  ('Personal', 'toolbar', 'needs'): 0.00017573148229505317,
#  ('toolbar', 'needs', 'a'): 0.0001757469244288225,
#  ('needs', 'a', 'min'): 0.00017570060616709128,
#  ('a', 'min', '-'): 0.0001757469244288225,
#  ('min', '-', 'height'): 0.0001757469244288225,
#  ('-', 'height', 'to'): 0.00017573148229505317,
#  ('height', 'to', 'avoid'): 0.00017573148229505317,
#  ('to', 'avoid', '"'): 0.00017570060616709128,
#  ('avoid', '"', 'popping'): 0.0001757469244288225,
#  ('"', 'popping', 'in'): 0.0001757469244288225,
#  ('popping', 'in', '"'): 0.0001757469244288225,
#  ('in', '"', 'New'): 0.00017517736708417273,
#  ('"', 'New', 'Folder'): 0.0003511852502194908,
#  ('New', 'Folder', '...'): 0.0002633889376646181,
#  ('Folder', '...', 'in'): 0.00017573148229505317,
#  ('...', 'in', 'ptoolbar'): 0.0001757469244288225,
#  ('in', 'ptoolbar', 'context'): 0.0001757469244288225,
#  ('ptoolbar', 'context', 'menu'): 0.0001757469244288225,
#  ('context', 'menu', 'is'): 0.0002617344268016053,
#  ('menu', 'is', 'broken'): 0.00017560804284836245,
#  ('is', 'broken', 'Implement'): 0.00017533093714385903,
#  ('broken', 'Implement', 'Mozilla'): 0.0001757469244288225,
#  ('Implement', 'Mozilla', 'Firebird'): 0.0001757469244288225,
#  ('Mozilla', 'Firebird', 'Help'): 0.00026182579856868566,
#  ('Firebird', 'Help', 'tabs'): 0.00017568517217146873,
#  ('Help', 'tabs', 'close'): 0.0001757469244288225,
#  ('tabs', 'close', 'in'): 0.0001757469244288225,
#  ('close', 'in', 'the'): 0.00017573148229505317,
#  ('in', 'the', 'wrong'): 0.0005978817902289033,
#  ('the', 'wrong', 'order'): 0.00017556179775280898,
#  ('wrong', 'order', '('): 0.00017571604287471446,
#  ('order', '(', 'right'): 0.00017573148229505317,
#  ('(', 'right', 'to'): 0.00017571604287471446,
#  ('right', 'to', 'left'): 0.00017568517217146873,
#  ('to', 'left', ')'): 0.00017568517217146873,
#  ('left', ')', 'back'): 0.00017573148229505317,
#  (')', 'back', 'buttons'): 0.0001757469244288225,
#  ('back', 'buttons', 'and'): 0.00017562346329469617,
#  ('buttons', 'and', 'context'): 0.00017570060616709128,
#  ('and', 'context', 'options'): 0.00017573148229505317,
#  ('context', 'options', 'always'): 0.0001757469244288225,
#  ('options', 'always', 'disabled'): 0.0001757469244288225,
#  ('always', 'disabled', '.'): 0.0001757469244288225,
#  ('disabled', '.', '</s>'): 0.0002635972234425797,
#  ('</s>', '<s>', 'Customising'): 0.00012211503236048357,
#  ('<s>', 'Customising', 'toolbar'): 0.0001757469244288225,
#  ('Customising', 'toolbar', 'breaks'): 0.0001757469244288225,
#  ('toolbar', 'breaks', 'the'): 0.00017573148229505317,
#  ('breaks', 'the', 'throbber'): 0.00017570060616709128,
#  ('the', 'throbber', '!'): 0.0001757469244288225,
#  ('throbber', '!', '</s>'): 0.0001757469244288225,
#  ('!', '</s>', '<s>'): 0.09142446502714788,
#  ('</s>', '<s>', 'manage'): 0.00012211503236048357,
#  ('<s>', 'manage', 'bookmarks'): 0.0001757469244288225,
#  ('manage', 'bookmarks', 'causes'): 0.0002634814684700509,
#  ('bookmarks', 'causes', 'hang'): 0.00017570060616709128,
#  ('causes', 'hang', 'land'): 0.00017573148229505317,
#  ('hang', 'land', 'pch'): 0.0001757469244288225,
#  ('land', 'pch', "'"): 0.0001757469244288225,
#  ('pch', "'", 's'): 0.0001757469244288225,
#  ("'", 's', 'bookmarks'): 0.00025092004014720643,
#  ('s', 'bookmarks', 'patch'): 0.00017573148229505317,
#  ('bookmarks', 'patch', 'from'): 0.0001757469244288225,
#  ('patch', 'from', 'bug'): 0.0001757469244288225,
#  ('from', 'bug', '160019'): 0.00017571604287471446,
#  ('bug', '160019', 'Preferences'): 0.0001757469244288225,
#  ('160019', 'Preferences', '>'): 0.0001757469244288225,
#  ('Preferences', '>', 'Privacy'): 0.00017568517217146873,
#  ('>', 'Privacy', '>'): 0.0001757469244288225,
#  ('Privacy', '>', 'Images'): 0.00017573148229505317,
#  ('>', 'Images', '=='): 0.0001757469244288225,
#  ('Images', '==', 'Wonky'): 0.0001757469244288225,
#  ('==', 'Wonky', 'Extremely'): 0.0001757469244288225,
#  ('Wonky', 'Extremely', 'high'): 0.0001757469244288225,
#  ('Extremely', 'high', 'memory'): 0.0001757469244288225,
#  ('high', 'memory', 'consumption'): 0.0001757469244288225,
#  ('memory', 'consumption', 'after'): 0.0001757469244288225,
#  ('consumption', 'after', 'closing'): 0.0001757469244288225,
#  ('after', 'closing', 'all'): 0.00035112359550561797,
#  ('closing', 'all', 'windows'): 0.0004392515154177282,
#  ('all', 'windows', 'with'): 0.00017554638813306416,
#  ('windows', 'with', 'Quick'): 0.00017573148229505317,
#  ('with', 'Quick', 'Launch'): 0.0001757469244288225,
#  ('Quick', 'Launch', '('): 0.0001756697408871322,
#  ('Launch', '(', 'Turbo'): 0.0001757469244288225,
#  ('(', 'Turbo', ')'): 0.0001757469244288225,
#  ('Turbo', ')', 'enabled'): 0.0001757469244288225,
#  (')', 'enabled', 'Go'): 0.0001757469244288225,
#  ('enabled', 'Go', 'menu'): 0.0001757469244288225,
#  ('Go', 'menu', 'needs'): 0.00017560804284836245,
#  ('menu', 'needs', 'to'): 0.0001757469244288225,
#  ('needs', 'to', 'have'): 0.00017548477669562167,
#  ('to', 'have', 'an'): 0.00035081564637782847,
#  ('have', 'an', 'id'): 0.00017568517217146873,
#  ('an', 'id', '='): 0.00017573148229505317,
#  ('id', '=', 'implement'): 0.00017573148229505317,
#  ('=', 'implement', 'progress'): 0.0001757469244288225,
#  ('implement', 'progress', 'meter'): 0.0001757469244288225,
#  ('progress', 'meter', 'in'): 0.0001757469244288225,
#  ('meter', 'in', 'URLbar'): 0.0001757469244288225,
#  ('in', 'URLbar', 'view'): 0.0001757469244288225,
#  ('URLbar', 'view', 'source'): 0.0001757469244288225,
#  ('view', 'source', 'tries'): 0.000175530981218185,
#  ('source', 'tries', 'to'): 0.0001757469244288225,
#  ('tries', 'to', 'download'): 0.00035103115401491884,
#  ('to', 'download', 'type'): 0.0001752694768206117,
#  ('download', 'type', 'application'): 0.0001757469244288225,
#  ('type', 'application', 'x'): 0.0001757469244288225,
#  ('application', 'x', '-'): 0.0001757469244288225,
#  ('x', '-', 'view'): 0.00017570060616709128,
#  ('-', 'view', '-'): 0.0001757469244288225,
#  ('view', '-', 'source'): 0.0005270555165144061,
#  ('-', 'source', 'from'): 0.0001756543123133673,
#  ('source', 'from', 'view'): 0.00017571604287471446,
#  ('from', 'view', '-'): 0.00017573148229505317,
#  ('-', 'source', ':<'): 0.0001756543123133673,
#  ('source', ':<', 'url'): 0.0001757469244288225,
#  (':<', 'url', '>'): 0.0001757469244288225,
#  ('url', '>', 'second'): 0.00017573148229505317,
#  ('>', 'second', 'window'): 0.0001757469244288225,
#  ('second', 'window', 'opens'): 0.00017568517217146873,
#  ('window', 'opens', 'mozilla'): 0.00017570060616709128,
#  ('opens', 'mozilla', 'fix'): 0.0001757469244288225,
#  ('mozilla', 'fix', 'branding'): 0.0001757469244288225,
#  ('fix', 'branding', 'auto'): 0.0001757469244288225,
#  ('branding', 'auto', 'close'): 0.0001757469244288225,
#  ('auto', 'close', 'for'): 0.00017573148229505317,
#  ('close', 'for', 'download'): 0.0001757469244288225,
#  ('for', 'download', 'manager'): 0.00035137034434293746,
#  ('download', 'manager', 'would'): 0.00017468774565464234,
#  ('manager', 'would', 'be'): 0.0001757469244288225,
#  ('would', 'be', 'nice'): 0.00043890449438202246,
#  ('be', 'nice', 'Components'): 0.0001756543123133673,
#  ('nice', 'Components', 'of'): 0.0001757469244288225,
#  ('Components', 'of', 'the'): 0.0001757469244288225,
#  ('of', 'the', 'Navigation'): 0.00017301038062283736,
#  ('the', 'Navigation', 'Toolbar'): 0.0001757469244288225,
#  ('Navigation', 'Toolbar', 'do'): 0.0001756697408871322,
#  ('Toolbar', 'do', 'not'): 0.0001757469244288225,
#  ('do', 'not', 'appear'): 0.00043557801202195314,
#  ('not', 'appear', 'with'): 0.0002630655910206945,
#  ('appear', 'with', 'the'): 0.00017573148229505317,
#  ('with', 'the', 'Modern'): 0.0001751006828926633,
#  ('the', 'Modern', 'theme'): 0.0002635972234425797,
#  ('Modern', 'theme', '.'): 0.00017570060616709128,
#  ('theme', '.', '</s>'): 0.0007903749890225696,
#  ('</s>', '<s>', 'Pop'): 0.00018317254854072538,
#  ('<s>', 'Pop', 'up'): 0.00017573148229505317,
#  ('Pop', 'up', 'window'): 0.0001757469244288225,
#  ('up', 'window', 'blocking'): 0.00017560804284836245,
#  ('window', 'blocking', 'Uabar'): 0.00017571604287471446,
#  ('blocking', 'Uabar', 'doesn'): 0.0001757469244288225,
#  ('Uabar', 'doesn', "'"): 0.0001757469244288225,
#  ('t', 'work', 'Theme'): 0.0001727563272004837,
#  ('work', 'Theme', 'changes'): 0.00017573148229505317,
#  ('Theme', 'changes', 'will'): 0.0001757469244288225,
#  ('changes', 'will', 'take'): 0.0001757469244288225,
#  ('will', 'take', 'effect'): 0.00017573148229505317,
#  ('take', 'effect', 'when'): 0.00017568517217146873,
#  ('effect', 'when', 'you'): 0.00017573148229505317,
#  ('when', 'you', 'restart'): 0.00017514668534897976,
#  ('you', 'restart', '_Mozilla_'): 0.00017573148229505317,
#  ('restart', '_Mozilla_', '.'): 0.0001757469244288225,
#  ('_Mozilla_', '.', '</s>'): 0.0001757469244288225,
#  ('</s>', '<s>', 'Need'): 0.00024423006472096715,
#  ('<s>', 'Need', 'large'): 0.00017571604287471446,
#  ('Need', 'large', 'icons'): 0.0001757469244288225,
#  ('large', 'icons', 'for'): 0.00017573148229505317,
#  ('icons', 'for', 'the'): 0.00017562346329469617,
#  ('for', 'the', 'Options'): 0.00017482517482517483,
#  ('the', 'Options', 'menu'): 0.0001756388864494599,
#  ('Options', 'menu', 'Enable'): 0.0001757469244288225,
#  ('menu', 'Enable', 'images'): 0.0001757469244288225,
#  ('Enable', 'images', 'cannot'): 0.00017573148229505317,
#  ('images', 'cannot', 'be'): 0.0001757469244288225,
#  ('cannot', 'be', 'used'): 0.000437598459653422,
#  ('be', 'used', 'to'): 0.0003513394817742644,
#  ('used', 'to', 'disable'): 0.00017539244058581075,
#  ('to', 'disable', 'the'): 0.00035093876118617303,
#  ('disable', 'the', 'display'): 0.00017568517217146873,
#  ('the', 'display', 'of'): 0.0002635740643120717,
#  ('display', 'of', 'images'): 0.0001755926251097454,
#  ('of', 'images', '.'): 0.00017571604287471446,
#  ('images', '.', '</s>'): 0.0003514320857494289,
#  ('</s>', '<s>', 'The'): 0.003113933325192331,
#  ('<s>', 'The', 'bookmark'): 0.00017499343774608452,
#  ('The', 'bookmark', 'tree'): 0.00017573148229505317,
#  ('bookmark', 'tree', 'jumps'): 0.0001757469244288225,
#  ('tree', 'jumps', 'unexpectedly'): 0.0001757469244288225,
#  ('jumps', 'unexpectedly', 'to'): 0.0001757469244288225,
#  ('unexpectedly', 'to', 'the'): 0.0001757469244288225,
#  ('to', 'the', 'bottom'): 0.00034725236565674104,
#  ('the', 'bottom', 'of'): 0.0004389815627743635,
#  ('bottom', 'of', 'its'): 0.0001756388864494599,
#  ('of', 'its', 'view'): 0.0001757469244288225,
#  ('its', 'view', 'when'): 0.0001757469244288225,
#  ('view', 'when', 'the'): 0.00017573148229505317,
#  ('when', 'the', 'the'): 0.00017517736708417273,
#  ('the', 'the', 'first'): 0.00017573148229505317,
#  ('the', 'first', 'visible'): 0.00017522340984755565,
#  ('first', 'visible', 'row'): 0.0001757469244288225,
#  ('visible', 'row', 'is'): 0.00017573148229505317,
#  ('row', 'is', 'not'): 0.0001757469244288225,
#  ('is', 'not', 'the'): 0.0003465003465003465,
#  ('not', 'the', 'first'): 0.0002633889376646181,
#  ('the', 'first', 'one'): 0.00017522340984755565,
#  ('first', 'one', 'Move'): 0.00017573148229505317,
#  ('one', 'Move', 'bookmarks'): 0.0001757469244288225,
#  ('Move', 'bookmarks', 'transactions'): 0.0001757469244288225,
#  ('bookmarks', 'transactions', 'into'): 0.0001757469244288225,
#  ('transactions', 'into', 'a'): 0.0001757469244288225,
#  ('into', 'a', 'JS'): 0.00017548477669562167,
#  ('a', 'JS', 'service'): 0.00017571604287471446,
#  ('JS', 'service', '('): 0.0001757469244288225,
#  ('service', '(', 'adding'): 0.0001757469244288225,
#  ('(', 'adding', 'a'): 0.0001757469244288225,
#  ('adding', 'a', 'bookmark'): 0.00026350461133069827,
#  ('a', 'bookmark', 'leaks'): 0.00017497812773403323,
#  ('bookmark', 'leaks', 'the'): 0.0001757469244288225,
#  ('leaks', 'the', 'Add'): 0.0001757469244288225,
#  ('the', 'Add', 'Bookmark'): 0.0001757469244288225,
#  ('Add', 'Bookmark', 'dialog'): 0.0011394513103690068,
#  ('Bookmark', 'dialog', ')'): 0.00017556179775280898,
#  ('dialog', ')', 'Shortcut'): 0.00017573148229505317,
#  (')', 'Shortcut', 'Ctrl'): 0.0001757469244288225,
#  ('Shortcut', 'Ctrl', '-'): 0.0001757469244288225,
#  ('Ctrl', '-', 'Y'): 0.00017539244058581075,
#  ('-', 'Y', '('): 0.0001757469244288225,
#  ('Y', '(', 'redo'): 0.0001757469244288225,
#  ('(', 'redo', ')'): 0.0001757469244288225,
#  ('redo', ')', 'does'): 0.0001757469244288225,
#  (')', 'does', 'not'): 0.0008780402142418123,
#  ('does', 'not', 'work'): 0.010484817983559805,
#  ('not', 'work', 'in'): 0.0013009540329575022,
#  ('work', 'in', 'Bookmarks'): 0.0002626740215392698,
#  ('in', 'Bookmarks', 'Manager'): 0.0010525392509428998,
#  ('Bookmarks', 'Manager', 'Eradicate'): 0.0001753155680224404,
#  ('Manager', 'Eradicate', 'AddBookmarkImmediately'): 0.0001757469244288225,
#  ('Eradicate', 'AddBookmarkImmediately', 'Deleting'): 0.0001757469244288225,
#  ('AddBookmarkImmediately', 'Deleting', 'a'): 0.0001757469244288225,
#  ('Deleting', 'a', 'selection'): 0.00017573148229505317,
#  ('a', 'selection', 'should'): 0.00017573148229505317,
#  ('selection', 'should', 'select'): 0.0001757469244288225,
#  ('should', 'select', 'the'): 0.0001757469244288225,
#  ('select', 'the', 'next'): 0.00017573148229505317,
#  ('the', 'next', 'item'): 0.00017557721007813187,
#  ('next', 'item', 'transaction'): 0.0001757469244288225,
#  ('item', 'transaction', 'manager'): 0.0001757469244288225,
#  ('transaction', 'manager', 'does'): 0.0001757469244288225,
#  ('manager', 'does', 'not'): 0.0009658442356659935,
#  ('does', 'not', 'handle'): 0.00033551417547391375,
#  ('not', 'handle', 'import'): 0.00017571604287471446,
#  ('handle', 'import', 'customize'): 0.0001757469244288225,
#  ('import', 'customize', 'toolbar'): 0.0001757469244288225,
#  ('customize', 'toolbar', 'clears'): 0.00017556179775280898,
#  ('toolbar', 'clears', 'URL'): 0.0001757469244288225,
#  ('clears', 'URL', '3'): 0.0001757469244288225,
#  ('URL', '3', '.'): 0.0001757469244288225,
#  ('3', '.', '2'): 0.0004388659703326604,
#  ('.', '2', '%'): 0.00017528483786152498,
#  ('2', '%', 'increase'): 0.0001757469244288225,
#  ('%', 'increase', 'in'): 0.0001757469244288225,
#  ('increase', 'in', 'Phoenix'): 0.00017573148229505317,
#  ('in', 'Phoenix', 'Ts'): 0.00017557721007813187,
#  ('Phoenix', 'Ts', 'after'): 0.0001757469244288225,
#  ('Ts', 'after', 'bookmark'): 0.0001757469244288225,
#  ('after', 'bookmark', 'landing'): 0.00017573148229505317,
#  ('bookmark', 'landing', 'cannot'): 0.0001757469244288225,
#  ('landing', 'cannot', 'close'): 0.0001757469244288225,
#  ('cannot', 'close', 'folder'): 0.00017573148229505317,
#  ('close', 'folder', 'with'): 0.0001757469244288225,
#  ('folder', 'with', 'single'): 0.00017573148229505317,
#  ('with', 'single', 'click'): 0.00017573148229505317,
#  ('single', 'click', 'on'): 0.00017573148229505317,
#  ('click', 'on', 'twistie'): 0.00017477934108188413,
#  ('on', 'twistie', 'Pref'): 0.0001757469244288225,
#  ('twistie', 'Pref', 'UI'): 0.0001757469244288225,
#  ('Pref', 'UI', 'to'): 0.0001757469244288225,
#  ('UI', 'to', 'specify'): 0.00017568517217146873,
#  ('to', 'specify', 'a'): 0.00026350461133069827,
#  ('specify', 'a', 'proxy'): 0.00017573148229505317,
#  ('a', 'proxy', 'server'): 0.0002635509092506369,
#  ('proxy', 'server', 'for'): 0.00017562346329469617,
#  ('server', 'for', 'web'): 0.0001757469244288225,
#  ('for', 'web', 'navigation'): 0.00017571604287471446,
#  ('web', 'navigation', 'Implement'): 0.0001757469244288225,
#  ('navigation', 'Implement', 'improved'): 0.0001757469244288225,
#  ('Implement', 'improved', 'Implement'): 0.0001757469244288225,
#  ('improved', 'Implement', 'global'): 0.0001757469244288225,
#  ('Implement', 'global', 'Go'): 0.0001757469244288225,
#  ('global', 'Go', 'menu'): 0.0001757469244288225,
#  ('Go', 'menu', 'Readd'): 0.00017560804284836245,
#  ('menu', 'Readd', 'Open'): 0.0001757469244288225,
#  ('Readd', 'Open', 'Location'): 0.0001757469244288225,
#  ('Open', 'Location', 'Need'): 0.00017568517217146873,
#  ('Location', 'Need', 'tab'): 0.0001757469244288225,
#  ('Need', 'tab', 'loading'): 0.0001757469244288225,
#  ('tab', 'loading', 'icon'): 0.0002635740643120717,
#  ('loading', 'icon', 'first'): 0.00017573148229505317,
#  ('icon', 'first', 'Mozilla'): 0.0001757469244288225,
#  ('first', 'Mozilla', 'Firefox'): 0.0001757469244288225,
#  ('Mozilla', 'Firefox', 'window'): 0.00017545398719185894,
#  ('Firefox', 'window', 'ignored'): 0.00017568517217146873,
#  ('window', 'ignored', 'by'): 0.0002635972234425797,
#  ('ignored', 'by', 'nsIWindowMediator'): 0.0002635740643120717,
#  ('by', 'nsIWindowMediator', 'first'): 0.00017573148229505317,
#  ('nsIWindowMediator', 'first', 'Phoenix'): 0.0001757469244288225,
#  ('first', 'Phoenix', 'window'): 0.0001757469244288225,
#  ('Phoenix', 'window', 'ignored'): 0.00017573148229505317,
#  ('by', 'nsIWindowMediator', 'preferences'): 0.00017573148229505317,
#  ('nsIWindowMediator', 'preferences', 'no'): 0.0001757469244288225,
#  ('preferences', 'no', 'longer'): 0.0002635972234425797,
#  ('no', 'longer', 'works'): 0.0010495932826029913,
#  ('longer', 'works', 'Open'): 0.0001755926251097454,
#  ('works', 'Open', 'Personal'): 0.0001757469244288225,
#  ('Open', 'Personal', 'Toolbar'): 0.0001757469244288225,
#  ('Personal', 'Toolbar', 'folder'): 0.0002633426966292135,
#  ('Toolbar', 'folder', 'in'): 0.00017571604287471446,
#  ('folder', 'in', 'toolbar'): 0.00017545398719185894,
#  ('in', 'toolbar', 'web'): 0.00017560804284836245,
#  ('toolbar', 'web', 'search'): 0.0001757469244288225,
#  ('web', 'search', 'for'): 0.0002635740643120717,
#  ('search', 'for', '""'): 0.00017556179775280898,
#  ('for', '""', 'in'): 0.0001757469244288225,
#  ('""', 'in', 'context'): 0.0001757469244288225,
#  ('in', 'context', 'menu'): 0.00035140121233418256,
#  ('context', 'menu', 'don'): 0.0002617344268016053,
#  ('menu', 'don', "'"): 0.0002635972234425797,
#  ('don', "'", 't'): 0.02057329775329259,
#  ('t', 'work', 'Fix'): 0.0001727563272004837,
#  ('work', 'Fix', 'full'): 0.0001757469244288225,
#  ('Fix', 'full', 'screen'): 0.0001757469244288225,
#  ('full', 'screen', 'to'): 0.00017546938059308652,
#  ('screen', 'to', 'have'): 0.00017573148229505317,
#  ('to', 'have', 'smaller'): 0.00017540782318891423,
#  ('have', 'smaller', 'icons'): 0.0001757469244288225,
#  ('smaller', 'icons', 'Port'): 0.0001757469244288225,
#  ('icons', 'Port', 'patch'): 0.0001757469244288225,
#  ('Port', 'patch', 'to'): 0.0001757469244288225,
#  ('patch', 'to', 'bug'): 0.00017573148229505317,
#  ('to', 'bug', '164006'): 0.00017570060616709128,
#  ('bug', '164006', '('): 0.00017573148229505317,
#  ('164006', '(', 'wyciwyg'): 0.0001757469244288225,
#  ('(', 'wyciwyg', ':'): 0.0001757469244288225,
#  ('wyciwyg', ':', 'in'): 0.0001757469244288225,
#  (':', 'in', 'tab'): 0.0001757469244288225,
#  ('in', 'tab', 'titles'): 0.00017556179775280898,
#  ('tab', 'titles', ')'): 0.0001757469244288225,
#  ('titles', ')', '['): 0.0001757469244288225,
#  (')', '[', 'cust'): 0.0001756543123133673,
#  ('cust', ']', 'Add'): 0.00017539244058581075,
#  (']', 'Add', 'more'): 0.00017571604287471446,
#  ('Add', 'more', 'off'): 0.00017573148229505317,
#  ('more', 'off', '-'): 0.0001757469244288225,
#  ('off', '-', 'by'): 0.00017568517217146873,
#  ('-', 'by', '-'): 0.0002635972234425797,
#  ('by', '-', 'default'): 0.00017573148229505317,
#  ('-', 'default', 'toolbar'): 0.00017573148229505317,
#  ('default', 'toolbar', 'buttons'): 0.00017573148229505317,
#  ('toolbar', 'buttons', 'textmode'): 0.0001755926251097454,
#  ('buttons', 'textmode', 'buttons'): 0.0001757469244288225,
#  ('textmode', 'buttons', 'need'): 0.0001757469244288225,
#  ('buttons', 'need', 'hover'): 0.0001757469244288225,
#  ('need', 'hover', 'state'): 0.0001757469244288225,
#  ('hover', 'state', 'enable'): 0.00017570060616709128,
#  ('state', 'enable', 'nsITheme'): 0.0001757469244288225,
#  ('enable', 'nsITheme', 'form'): 0.0001757469244288225,
#  ('nsITheme', 'form', 'control'): 0.0001757469244288225,
#  ('form', 'control', 'goodness'): 0.0001757469244288225,
#  ('control', 'goodness', 'for'): 0.0001757469244288225,
#  ('goodness', 'for', 'Phoenix'): 0.0001757469244288225,
#  ('for', 'Phoenix', 'rename'): 0.00017570060616709128,
#  ('Phoenix', 'rename', 'executable'): 0.0001757469244288225,
#  ('rename', 'executable', 'and'): 0.0001757469244288225,
#  ('executable', 'and', 'profile'): 0.00017573148229505317,
#  ('and', 'profile', 'dir'): 0.00017573148229505317,
#  ('profile', 'dir', 'Need'): 0.00017573148229505317,
#  ('dir', 'Need', 'to'): 0.0002635972234425797,
#  ('Need', 'to', 'enable'): 0.0001756543123133673,
#  ('to', 'enable', 'wallet'): 0.00017571604287471446,
#  ('enable', 'wallet', '('): 0.0001757469244288225,
#  ('wallet', '(', 'password'): 0.0001757469244288225,
#  ('(', 'password', 'manager'): 0.0001757469244288225,
#  ('password', 'manager', 'manager'): 0.00017537706068046299,
#  ('manager', 'manager', 'manager'): 0.00017573148229505317,
#  ('manager', 'manager', ')'): 0.00017573148229505317,
#  ('manager', ')', 'New'): 0.00017573148229505317,
#  (')', 'New', 'Extension'): 0.00017570060616709128,
#  ('New', 'Extension', 'Manager'): 0.0001757469244288225,
#  ('Extension', 'Manager', 'the'): 0.00017556179775280898,
#  ('Manager', 'the', 'changes'): 0.0001757469244288225,
#  ('the', 'changes', 'to'): 0.0001757469244288225,
#  ('changes', 'to', 'mozbrowser'): 0.00017562346329469617,
#  ('to', 'mozbrowser', 'too'): 0.0001757469244288225,
#  ('mozbrowser', 'too', 'confusing'): 0.0001757469244288225,
#  ('too', 'confusing', 'and'): 0.0001757469244288225,
#  ('confusing', 'and', 'too'): 0.0001757469244288225,
#  ('and', 'too', 'much'): 0.0001757469244288225,
#  ('too', 'much', 'Missing'): 0.00017568517217146873,
#  ('much', 'Missing', 'proxy'): 0.0001757469244288225,
#  ('Missing', 'proxy', 'image'): 0.0001757469244288225,
#  ('proxy', 'image', 'Cannot'): 0.0001757469244288225,
#  ('image', 'Cannot', 'File'): 0.0001757469244288225,
#  ('Cannot', 'File', '>'): 0.0001757469244288225,
#  ('File', '>', 'New'): 0.00017570060616709128,
#  ('>', 'New', 'Bookmark'): 0.0001757469244288225,
#  ('New', 'Bookmark', 'while'): 0.0001756697408871322,
#  ('Bookmark', 'while', 'managing'): 0.0001757469244288225,
#  ('while', 'managing', 'a'): 0.0001757469244288225,
#  ('managing', 'a', 'new'): 0.0001757469244288225,
#  ('a', 'new', 'folder'): 0.00034825004353125546,
#  ('new', 'folder', 'Bookmarks'): 0.00017562346329469617,
#  ('folder', 'Bookmarks', 'are'): 0.00017573148229505317,
#  ('Bookmarks', 'are', 'not'): 0.0004391743522178305,
#  ('are', 'not', 'loaded'): 0.00026189436927106065,
#  ('not', 'loaded', 'if'): 0.00017568517217146873,
#  ('loaded', 'if', 'the'): 0.0001757469244288225,
#  ('if', 'the', 'Personal'): 0.00017537706068046299,
#  ('the', 'Personal', 'Toolbar'): 0.0002635972234425797,
#  ('Personal', 'Toolbar', 'is'): 0.00017556179775280898,
#  ('Toolbar', 'is', 'switched'): 0.0001756697408871322,
#  ('is', 'switched', 'off'): 0.0001757469244288225,
#  ('switched', 'off', 'Pretty'): 0.0001757469244288225,
#  ('off', 'Pretty', 'up'): 0.0001757469244288225,
#  ('Pretty', 'up', 'dns'): 0.0001757469244288225,
#  ('up', 'dns', 'error'): 0.0001757469244288225,
#  ('dns', 'error', 'page'): 0.0002635972234425797,
#  ('error', 'page', 'a'): 0.00017568517217146873,
#  ('page', 'a', 'bit'): 0.00017571604287471446,
#  ('a', 'bit', 'middle'): 0.0001756388864494599,
#  ('bit', 'middle', 'click'): 0.0001757469244288225,
#  ('middle', 'click', '('): 0.000175530981218185,
#  ('click', '(', 'pt'): 0.00017570060616709128,
#  ('(', 'pt', '+'): 0.0001757469244288225,
#  ('pt', '+', 'bookmark'): 0.0001757469244288225,
#  ('+', 'bookmark', 'menu'): 0.0001757469244288225,
#  ('bookmark', 'menu', ')'): 0.00017557721007813187,
#  ('menu', ')', 'loads'): 0.0001756543123133673,
#  (')', 'loads', 'in'): 0.00017571604287471446,
#  ('loads', 'in', 'the'): 0.00026352775825720307,
#  ('in', 'the', 'current'): 0.00017082336863682952,
#  ('the', 'current', 'tab'): 0.0004388274530454625,
#  ('current', 'tab', '+'): 0.00017560804284836245,
#  ('tab', '+', 'new'): 0.0001757469244288225,
#  ('+', 'new', 'tab'): 0.0001757469244288225,
#  ('new', 'tab', 'Nightly'): 0.0001737921445950643,
#  ('tab', 'Nightly', 'for'): 0.0001757469244288225,
#  ('Nightly', 'for', '22'): 0.0001757469244288225,
#  ('for', '22', 'Sept'): 0.0001757469244288225,
#  ('22', 'Sept', 'displays'): 0.0001757469244288225,
#  ('Sept', 'displays', 'page'): 0.0001757469244288225,
#  ('displays', 'page', 'details'): 0.0001757469244288225,
#  ('page', 'details', 'above'): 0.0001757469244288225,
#  ('details', 'above', 'window'): 0.0001757469244288225,
#  ('above', 'window', 'Ctrl'): 0.0001757469244288225,
#  ('window', 'Ctrl', '-'): 0.0002635740643120717,
#  ('Ctrl', '-', 'W'): 0.00017539244058581075,
#  ('-', 'W', 'does'): 0.00017571604287471446,
#  ('W', 'does', 'not'): 0.0002635972234425797,
#  ('does', 'not', 'close'): 0.0014259352457641336,
#  ('not', 'close', 'the'): 0.0005262696254714499,
#  ('close', 'the', 'current'): 0.0002633426966292135,
#  ('current', 'tab', 'listboxes'): 0.00017560804284836245,
#  ('tab', 'listboxes', 'and'): 0.0001757469244288225,
#  ('listboxes', 'and', 'tree'): 0.0001757469244288225,
#  ('and', 'tree', 'views'): 0.0001757469244288225,
#  ('tree', 'views', 'don'): 0.0001757469244288225,
#  ('views', 'don', "'"): 0.0001757469244288225,
#  ("'", 't', 'support'): 0.00047374654559810504,
#  ('t', 'support', 'themes'): 0.00017568517217146873,
#  ('support', 'themes', 'on'): 0.0001757469244288225,
#  ('themes', 'on', 'winxp'): 0.0001757469244288225,
#  ('on', 'winxp', 'Ctrl'): 0.0001757469244288225,
#  ('winxp', 'Ctrl', '+'): 0.0001757469244288225,
#  ('Ctrl', '+', 'Mousewheel'): 0.0002621461027612723,
#  ('+', 'Mousewheel', 'should'): 0.0002635972234425797,
#  ('Mousewheel', 'should', 'resize'): 0.00017573148229505317,
#  ('should', 'resize', 'text'): 0.0001757469244288225,
#  ('resize', 'text', 'bookmarks'): 0.0001757469244288225,
#  ('text', 'bookmarks', 'should'): 0.0001757469244288225,
#  ('bookmarks', 'should', 'import'): 0.00017571604287471446,
#  ('should', 'import', 'Mozilla'): 0.0001757469244288225,
#  ('import', 'Mozilla', "'"): 0.00017571604287471446,
#  ('Mozilla', "'", 's'): 0.0005270555165144061,
#  ('s', 'bookmarks', 'Please'): 0.00017573148229505317,
#  ('bookmarks', 'Please', 'tell'): 0.0001757469244288225,
#  ('Please', 'tell', 'people'): 0.0001757469244288225,
#  ('tell', 'people', 'to'): 0.0001757469244288225,
#  ('people', 'to', 'use'): 0.0001757469244288225,
#  ('to', 'use', 'a'): 0.0001751927119831815,
#  ('use', 'a', 'new'): 0.00017568517217146873,
#  ('a', 'new', 'profile'): 0.0004353125544140693,
#  ('new', 'profile', '.'): 0.00017554638813306416,
#  ('profile', '.', '</s>'): 0.0002635972234425797,
#  ('</s>', '<s>', 'combine'): 0.00012211503236048357,
#  ('<s>', 'combine', 'links'): 0.0001757469244288225,
#  ('combine', 'links', '+'): 0.0001757469244288225,
#  ('links', '+', 'toolbar'): 0.0001757469244288225,
#  ('+', 'toolbar', 'File'): 0.0001757469244288225,
#  ('toolbar', 'File', '|'): 0.0001757469244288225,
#  ('File', '|', 'Import'): 0.0002635509092506369,
#  ('|', 'Import', '...'): 0.00017573148229505317,
#  ('Import', '...', 'does'): 0.00017573148229505317,
#  ('...', 'does', 'not'): 0.0003514320857494289,
#  ('not', 'work', 'cannot'): 0.00017346053772766696,
#  ('work', 'cannot', 'import'): 0.0001757469244288225,
#  ('cannot', 'import', '4'): 0.00017573148229505317,
#  ('import', '4', '.'): 0.0001757469244288225,
#  ('4', '.', 'x'): 0.00017551557700745942,
#  ('.', 'x', 'About'): 0.0001756697408871322,
#  ('x', 'About', 'dialog'): 0.0001757469244288225,
#  ('About', 'dialog', 'weirdness'): 0.00017568517217146873,
#  ('dialog', 'weirdness', 'Context'): 0.00017573148229505317,
#  ('weirdness', 'Context', 'menu'): 0.0001757469244288225,
#  ('Context', 'menu', 'doesn'): 0.00017556179775280898,
#  ('menu', 'doesn', "'"): 0.0010535557506584723,
#  ("'", 't', 'appear'): 0.0011843663639952626,
#  ('t', 'appear', 'when'): 0.00026331958219959624,
#  ('appear', 'when', 'right'): 0.00017570060616709128,
#  ('when', 'right', 'clicking'): 0.00026343519494204424,
#  ('right', 'clicking', 'on'): 0.0003513086246267346,
#  ('clicking', 'on', 'disabled'): 0.00017470300489168413,
#  ('on', 'disabled', 'forward'): 0.00017573148229505317,
#  ('disabled', 'forward', 'or'): 0.0001757469244288225,
#  ('forward', 'or', 'back'): 0.0001757469244288225,
#  ('or', 'back', 'can'): 0.0001757469244288225,
#  ('back', 'can', "'"): 0.0001757469244288225,
#  ('can', "'", 't'): 0.011982287053920291,
#  ("'", 't', 'specify'): 0.00023687327279905252,
#  ('t', 'specify', 'cookie'): 0.00017573148229505317,
#  ('specify', 'cookie', 'details'): 0.0001757469244288225,
#  ('cookie', 'details', 'Proxy'): 0.0001757469244288225,
#  ('details', 'Proxy', 'settings'): 0.0001757469244288225,
#  ('Proxy', 'settings', 'in'): 0.0001757469244288225,
#  ('settings', 'in', 'prefs'): 0.00017573148229505317,
#  ('in', 'prefs', '.'): 0.00017571604287471446,
#  ('prefs', '.', 'js'): 0.0001757469244288225,
#  ('.', 'js', 'seem'): 0.0001752541184717841,
#  ('js', 'seem', 'to'): 0.0001757469244288225,
#  ('seem', 'to', 'be'): 0.00035115442015626374,
#  ('to', 'be', 'ignored'): 0.0003487662394280234,
#  ('be', 'ignored', '...'): 0.00017570060616709128,
#  ('ignored', '...', '</s>'): 0.0001757469244288225,
#  ('...', '</s>', '<s>'): 0.0024548483254427495,
#  ('</s>', '<s>', 'Incorrectly'): 0.00012211503236048357,
#  ('<s>', 'Incorrectly', 'renders'): 0.0001757469244288225,
#  ('Incorrectly', 'renders', 'various'): 0.0001757469244288225,
#  ('renders', 'various', 'web'): 0.0001757469244288225,
#  ('various', 'web', 'pages'): 0.00017573148229505317,
#  ('web', 'pages', 'Window'): 0.00017556179775280898,
#  ('pages', 'Window', 'won'): 0.0001757469244288225,
#  ('Window', 'won', "'"): 0.0001757469244288225,
#  ('won', "'", 't'): 0.0076748648177219604,
#  ("'", 't', 'show'): 0.002289774970390841,
#  ('t', 'show', 'completely'): 0.00017533093714385903,
#  ('show', 'completely', 'Can'): 0.0001757469244288225,
#  ('completely', 'Can', "'"): 0.0001757469244288225,
#  ("'", 't', 'change'): 0.0011843663639952626,
#  ('t', 'change', 'privacy'): 0.00017554638813306416,
#  ('change', 'privacy', 'settings'): 0.0001757469244288225,
#  ('privacy', 'settings', '['): 0.0001757469244288225,
#  ('settings', '[', 'Moz'): 0.0001757469244288225,
#  ('[', 'Moz', ']'): 0.0005270555165144061,
#  ('Moz', ']', 'Cannot'): 0.00017568517217146873,
#  (']', 'Cannot', 'set'): 0.00017573148229505317,
#  ('Cannot', 'set', '"'): 0.00017573148229505317,
#  ('set', '"', 'Imported'): 0.00017573148229505317,
#  ('"', 'Imported', 'IE'): 0.0002635972234425797,
#  ('Imported', 'IE', 'Favorites'): 0.0002635740643120717,
#  ('IE', 'Favorites', '"'): 0.00017573148229505317,
#  ('Favorites', '"', 'to'): 0.0001757469244288225,
#  ('"', 'to', 'default'): 0.0001753155680224404,
#  ('to', 'default', 'personal'): 0.0001755926251097454,
#  ('default', 'personal', 'toolbar'): 0.0001757469244288225,
#  ('personal', 'toolbar', 'folder'): 0.00035075412136092597,
#  ('toolbar', 'folder', 'pheonix'): 0.00017545398719185894,
#  ('folder', 'pheonix', 'Need'): 0.0001757469244288225,
#  ('pheonix', 'Need', 'smaller'): 0.0001757469244288225,
#  ('Need', 'smaller', 'throbber'): 0.0001757469244288225,
#  ('smaller', 'throbber', 'to'): 0.0001757469244288225,
#  ('throbber', 'to', 'use'): 0.0001757469244288225,
#  ('to', 'use', 'with'): 0.0001751927119831815,
#  ('use', 'with', 'small'): 0.0001757469244288225,
#  ('with', 'small', 'icons'): 0.0001757469244288225,
#  ('small', 'icons', 'Blank'): 0.00017560804284836245,
#  ('icons', 'Blank', 'URL'): 0.0001757469244288225,
#  ('Blank', 'URL', 'bar'): 0.0001757469244288225,
#  ('URL', 'bar', 'after'): 0.00017528483786152498,
#  ('bar', 'after', 'using'): 0.0001756697408871322,
#  ('after', 'using', 'Customize'): 0.00017554638813306416,
#  ('using', 'Customize', 'Toolbar'): 0.0001757469244288225,
#  ('Customize', 'Toolbar', 'Mousewheel'): 0.0001756388864494599,
#  ('Toolbar', 'Mousewheel', 'does'): 0.0001757469244288225,
#  ('Mousewheel', 'does', 'not'): 0.0001757469244288225,
#  ('does', 'not', 'scroll'): 0.000754906894816306,
#  ('not', 'scroll', 'web'): 0.00017554638813306416,
#  ('scroll', 'web', 'page'): 0.0001757469244288225,
#  ('web', 'page', 'ctrl'): 0.00017514668534897976,
#  ('page', 'ctrl', '+'): 0.0001757469244288225,
#  ('ctrl', '+', 'tab'): 0.00017543859649122806,
#  ('+', 'tab', 'should'): 0.0002635972234425797,
#  ('tab', 'should', 'switch'): 0.00026350461133069827,
#  ('should', 'switch', 'tabs'): 0.0002635509092506369,
#  ('switch', 'tabs', 'in'): 0.0001756697408871322,
#  ('tabs', 'in', 'browser'): 0.00017568517217146873,
#  ('in', 'browser', 'favicon'): 0.00017543859649122806,
#  ('browser', 'favicon', '.'): 0.0001757469244288225,
#  ('favicon', '.', 'ico'): 0.0008780402142418123,
#  ('.', 'ico', 'colors'): 0.0001755926251097454,
#  ('ico', 'colors', 'render'): 0.0001757469244288225,
#  ('colors', 'render', 'improperly'): 0.0001757469244288225,
#  ('render', 'improperly', 'in'): 0.0001757469244288225,
#  ('improperly', 'in', 'tabs'): 0.0001757469244288225,
#  ('in', 'tabs', 'and'): 0.00017514668534897976,
#  ('tabs', 'and', 'URL'): 0.00017562346329469617,
#  ('and', 'URL', 'bar'): 0.00017573148229505317,
#  ('URL', 'bar', '-'): 0.00017528483786152498,
#  ('bar', '-', 'remote'): 0.00017571604287471446,
#  ('-', 'remote', 'openurl'): 0.00026313481273572496,
#  ('remote', 'openurl', '()'): 0.00017573148229505317,
#  ('openurl', '()', 'opens'): 0.0001757469244288225,
#  ('()', 'opens', 'Mozilla'): 0.0001757469244288225,
#  ('opens', 'Mozilla', 'window'): 0.00017573148229505317,
#  ('Mozilla', 'window', 'if'): 0.0001757469244288225,
#  ('window', 'if', 'Mozilla'): 0.00017571604287471446,
#  ('if', 'Mozilla', 'is'): 0.0002635740643120717,
#  ('is', 'running', 'make'): 0.000175530981218185,
#  ('running', 'make', 'preferences'): 0.0001757469244288225,
#  ('make', 'preferences', 'resizable'): 0.0001757469244288225,
#  ('preferences', 'resizable', 'Scroll'): 0.0001757469244288225,
#  ('resizable', 'Scroll', 'bar'): 0.0001757469244288225,
#  ('Scroll', 'bar', 'becomes'): 0.0001756697408871322,
#  ('bar', 'becomes', 'blank'): 0.00017573148229505317,
#  ('becomes', 'blank', 'fix'): 0.00017573148229505317,
#  ('blank', 'fix', 'addressbar'): 0.0001757469244288225,
#  ('fix', 'addressbar', 'dropdown'): 0.0001757469244288225,
#  ('addressbar', 'dropdown', 'icon'): 0.0001757469244288225,
#  ('dropdown', 'icon', 'for'): 0.0001757469244288225,
#  ('icon', 'for', 'linux'): 0.0001755001755001755,
#  ('for', 'linux', '.'): 0.00017570060616709128,
#  ('linux', '.', '</s>'): 0.0001757469244288225,
#  ('</s>', '<s>', '"'): 0.001404322872145561,
#  ('<s>', '"', 'Find'): 0.00026313481273572496,
#  ('"', 'Find', 'Next'): 0.00026322716504343247,
#  ('Find', 'Next', '"'): 0.0002635972234425797,
#  ('Next', '"', 'button'): 0.00017573148229505317,
#  ('"', 'button', 'doesn'): 0.000437598459653422,
#  ('button', 'doesn', "'"): 0.001754693805930865,
#  ("'", 't', 'always'): 0.0006316620607974733,
#  ('t', 'always', 'respond'): 0.0001756543123133673,
#  ('always', 'respond', 'to'): 0.0001757469244288225,
#  ('respond', 'to', 'Enter'): 0.0001755926251097454,
#  ('to', 'Enter', 'Ctrl'): 0.0001757469244288225,
#  ('Enter', 'Ctrl', '+'): 0.0001757469244288225,
#  ('Mousewheel', 'should', 'cycle'): 0.00017573148229505317,
#  ('should', 'cycle', 'tabs'): 0.0001757469244288225,
#  ('cycle', 'tabs', 'A'): 0.0001757469244288225,
#  ('tabs', 'A', 'new'): 0.0001757469244288225,
#  ('A', 'new', 'icon'): 0.00017573148229505317,
#  ('new', 'icon', 'for'): 0.0001757469244288225,
#  ('icon', 'for', 'Firebird'): 0.00026325026325026325,
#  ('for', 'Firebird', '2nd'): 0.0001756388864494599,
#  ('Firebird', '2nd', 'Copy'): 0.0001757469244288225,
#  ('2nd', 'Copy', 'won'): 0.0001757469244288225,
#  ('Copy', 'won', "'"): 0.0001757469244288225,
#  ("'", 't', 'load'): 0.0015001973943939992,
#  ('t', 'load', 'with'): 0.00026322716504343247,
#  ('load', 'with', 'same'): 0.00017573148229505317,
#  ('with', 'same', 'profile'): 0.0001756697408871322,
#  ('same', 'profile', 'width'): 0.0001757469244288225,
#  ('profile', 'width', 'of'): 0.0001757469244288225,
#  ('width', 'of', 'table'): 0.00017573148229505317,
#  ('of', 'table', 'containing'): 0.0001757469244288225,
#  ('table', 'containing', 'text'): 0.00017573148229505317,
#  ('containing', 'text', 'being'): 0.0001757469244288225,
#  ('text', 'being', 'handled'): 0.0001757469244288225,
#  ('being', 'handled', 'incorrectly'): 0.0001757469244288225,
#  ('handled', 'incorrectly', '('): 0.0001757469244288225,
#  ('incorrectly', '(', 'multiple'): 0.0001757469244288225,
#  ('(', 'multiple', 'screenwidths'): 0.0001757469244288225,
#  ('multiple', 'screenwidths', 'wide'): 0.0001757469244288225,
#  ('screenwidths', 'wide', ')'): 0.0001757469244288225,
#  ('wide', ')', 'accessing'): 0.0001757469244288225,
#  (')', 'accessing', '"'): 0.0001757469244288225,
#  ('accessing', '"', 'navigator'): 0.0001757469244288225,
#  ('"', 'navigator', '.'): 0.0003514320857494289,
#  ('navigator', '.', 'cookieEnabled'): 0.0002634814684700509,
#  ('.', 'cookieEnabled', '"'): 0.0002635972234425797,
#  ('cookieEnabled', '"', 'produces'): 0.00017573148229505317,
#  ('"', 'produces', '"'): 0.0001757469244288225,
#  ('produces', '"', 'uncaught'): 0.0001757469244288225,
#  ('"', 'uncaught', 'exception'): 0.0002635972234425797,
#  ('uncaught', 'exception', '"'): 0.00017571604287471446,
#  ('exception', '"', 'Need'): 0.00017573148229505317,
#  ('"', 'Need', 'Mozilla'): 0.00017570060616709128,
#  ('Need', 'Mozilla', 'Firebird'): 0.0001757469244288225,
#  ('Mozilla', 'Firebird', 'newsgroup'): 0.00017455053237912376,
#  ('Firebird', 'newsgroup', 'Revive'): 0.0001757469244288225,
#  ('newsgroup', 'Revive', 'XUL'): 0.0001757469244288225,
#  ('Revive', 'XUL', 'preprocessor'): 0.0001757469244288225,
#  ('XUL', 'preprocessor', 'Phoenix'): 0.00017573148229505317,
#  ('preprocessor', 'Phoenix', 'needs'): 0.0001757469244288225,
#  ('Phoenix', 'needs', 'talkback'): 0.00017571604287471446,
#  ('needs', 'talkback', 'Navigation'): 0.0001757469244288225,
#  ('talkback', 'Navigation', 'toolbar'): 0.0001757469244288225,
#  ('Navigation', 'toolbar', 'is'): 0.00017571604287471446,
#  ('toolbar', 'is', 'completely'): 0.00017554638813306416,
#  ('is', 'completely', 'blank'): 0.00017568517217146873,
#  ('completely', 'blank', 'Phoenix'): 0.00017573148229505317,
#  ('blank', 'Phoenix', 'refuses'): 0.00017573148229505317,
#  ('Phoenix', 'refuses', 'to'): 0.0001757469244288225,
#  ('refuses', 'to', 'start'): 0.0005266391643991925,
#  ('to', 'start', 'due'): 0.000263042525208242,
#  ('start', 'due', 'missing'): 0.00017570060616709128,
#  ('due', 'missing', 'libstdc'): 0.00017570060616709128,
#  ('missing', 'libstdc', '++-'): 0.00017573148229505317,
#  ('libstdc', '++-', 'libc6'): 0.0001757469244288225,
#  ('++-', 'libc6', '.'): 0.0001757469244288225,
#  ('libc6', '.', '2'): 0.0001757469244288225,
#  ('.', '2', '-'): 0.00026292725679228745,
#  ('2', '-', '2'): 0.00017570060616709128,
#  ('-', '2', '.'): 0.0002635740643120717,
#  ('2', '.', 'so'): 0.00017545398719185894,
#  ('.', 'so', '.'): 0.0002633658151171978,
#  ('so', '.', '3'): 0.00017562346329469617,
#  ('.', '3', 'restore'): 0.00017537706068046299,
#  ('3', 'restore', 'image'): 0.0001757469244288225,
#  ('restore', 'image', 'blocking'): 0.0001757469244288225,
#  ('image', 'blocking', 'in'): 0.00017570060616709128,
#  ('blocking', 'in', 'Phoenix'): 0.0001757469244288225,
#  ...}

# %% [markdown]
# ### Predict next words (TRIGRAMS)

# %%
def predict_next_word_trigrams(word, trigrams, cp_t):
  max_prob = 0
  next_word = ""

  for i in trigrams:
    if i[0] == word:
      if cp_t[i] > max_prob:
        max_prob = cp_t[i]
        next_word = i[1]

  return next_word

# %%
predict_next_word_trigrams("took", trigrams_brown, cp_t_brown)
# Out:
# 'place'

# %%
predict_next_word_trigrams("took", trigrams_webtext, cp_t_webtext)
# Out:
# 'to'

# %% [markdown]
# ### Predict sentences (TRIGRAMS):

# %%
def predict_sentence_trigrams(initial_sentence, trigrams, limit, cp_t):
  sentence = initial_sentence.split()
  while len(sentence) < limit:
    next_word = predict_next_word_trigrams(sentence[-1], trigrams, cp_t)
    sentence.append(next_word)

  return " ".join(sentence)

# %%
sent_t_brown = predict_sentence_trigrams("<s> Fools are ", trigrams_brown, 9, cp_t_brown)
print(sent_t_brown)
# Out:
# <s> Fools are expected to attend the United Nations

# %%
sent_t_webtext = predict_sentence_trigrams("<s> Fools are ", trigrams_webtext, 9, cp_t_webtext)
print(sent_t_webtext)
# Out:
# <s> Fools are . </s> <s> ARTHUR : Oh

# %% [markdown]
# ### Calculate Perplexity using BIGRAM models

# %%
import math
def perplexity_bigrams(sentence, ct, bgrams_wc, corpus_wc, V):
    bgrams_s = create_bigrams(sentence.split())

    log_prob_sum = 0  # Using log sum of probabilities instead of multiplying (multiplication was giving division by zero error)
    for i in bgrams_s:
        if i in ct:
            prob = ct[i]
        else:
            prob = conditional_probability(i[0], i[1], bgrams_wc, corpus_wc, V)

        log_prob_sum += math.log2(prob)

    perplexity = 2 ** (-log_prob_sum / len(bgrams_s))
    return perplexity

# %%
perplexity_bigrams(sent_b_brown, cp_brown, bgrams_brown_wc, brown_wc, V_brown)
# Out:
# 756.9730396235207

# %%
perplexity_bigrams(sent_b_webtext, cp_webtext, bgrams_webtext_wc, webtext_wc, V_webtext)
# Out:
# 452.73677982528073

# %% [markdown]
# ### Calculate perplexity using TRIGRAM models

# %%
def perplexity_trigrams(sentence, cp_t, trigrams_wc, bgrams_wc, V):
    trigrams_s = create_trigrams(sentence.split())

    log_prob_sum = 0
    for i in trigrams_s:
        if i in cp_t:
            prob = cp_t[i]
        else:
            prob = conditional_probability_trigrams(i[0], i[1], i[2], trigrams_wc, bgrams_wc, V)

        log_prob_sum += math.log2(prob)

    perplexity = 2 ** (-log_prob_sum / len(trigrams_s))
    return perplexity

# %%
perplexity_trigrams(sent_t_brown, cp_t_brown, trigrams_brown_wc, bgrams_brown_wc, V_brown)
# Out:
# 5858.908232448942

# %%
perplexity_trigrams(sent_t_webtext, cp_t_webtext, trigrams_webtext_wc, bgrams_webtext_wc, V_webtext)
# Out:
# 530.2337982680406

# %% [markdown]
# ### bigrams_brown

# %%
bgrams_brown
# Out:
# [('<s>', 'The'),
#  ('The', 'Fulton'),
#  ('Fulton', 'County'),
#  ('County', 'Grand'),
#  ('Grand', 'Jury'),
#  ('Jury', 'said'),
#  ('said', 'Friday'),
#  ('Friday', 'an'),
#  ('an', 'investigation'),
#  ('investigation', 'of'),
#  ('of', "Atlanta's"),
#  ("Atlanta's", 'recent'),
#  ('recent', 'primary'),
#  ('primary', 'election'),
#  ('election', 'produced'),
#  ('produced', '``'),
#  ('``', 'no'),
#  ('no', 'evidence'),
#  ('evidence', "''"),
#  ("''", 'that'),
#  ('that', 'any'),
#  ('any', 'irregularities'),
#  ('irregularities', 'took'),
#  ('took', 'place'),
#  ('place', '.'),
#  ('.', '</s>'),
#  ('</s>', '<s>'),
#  ('<s>', 'The'),
#  ('The', 'jury'),
#  ('jury', 'further'),
#  ('further', 'said'),
#  ('said', 'in'),
#  ('in', 'term-end'),
#  ('term-end', 'presentments'),
#  ('presentments', 'that'),
#  ('that', 'the'),
#  ('the', 'City'),
#  ('City', 'Executive'),
#  ('Executive', 'Committee'),
#  ('Committee', ','),
#  (',', 'which'),
#  ('which', 'had'),
#  ('had', 'over-all'),
#  ('over-all', 'charge'),
#  ('charge', 'of'),
#  ('of', 'the'),
#  ('the', 'election'),
#  ('election', ','),
#  (',', '``'),
#  ('``', 'deserves'),
#  ('deserves', 'the'),
#  ('the', 'praise'),
#  ('praise', 'and'),
#  ('and', 'thanks'),
#  ('thanks', 'of'),
#  ('of', 'the'),
#  ('the', 'City'),
#  ('City', 'of'),
#  ('of', 'Atlanta'),
#  ('Atlanta', "''"),
#  ("''", 'for'),
#  ('for', 'the'),
#  ('the', 'manner'),
#  ('manner', 'in'),
#  ('in', 'which'),
#  ('which', 'the'),
#  ('the', 'election'),
#  ('election', 'was'),
#  ('was', 'conducted'),
#  ('conducted', '.'),
#  ('.', '</s>'),
#  ('</s>', '<s>'),
#  ('<s>', 'The'),
#  ('The', 'September-October'),
#  ('September-October', 'term'),
#  ('term', 'jury'),
#  ('jury', 'had'),
#  ('had', 'been'),
#  ('been', 'charged'),
#  ('charged', 'by'),
#  ('by', 'Fulton'),
#  ('Fulton', 'Superior'),
#  ('Superior', 'Court'),
#  ('Court', 'Judge'),
#  ('Judge', 'Durwood'),
#  ('Durwood', 'Pye'),
#  ('Pye', 'to'),
#  ('to', 'investigate'),
#  ('investigate', 'reports'),
#  ('reports', 'of'),
#  ('of', 'possible'),
#  ('possible', '``'),
#  ('``', 'irregularities'),
#  ('irregularities', "''"),
#  ("''", 'in'),
#  ('in', 'the'),
#  ('the', 'hard-fought'),
#  ('hard-fought', 'primary'),
#  ('primary', 'which'),
#  ('which', 'was'),
#  ('was', 'won'),
#  ('won', 'by'),
#  ('by', 'Mayor-nominate'),
#  ('Mayor-nominate', 'Ivan'),
#  ('Ivan', 'Allen'),
#  ('Allen', 'Jr.'),
#  ('Jr.', '.'),
#  ('.', '</s>'),
#  ('</s>', '<s>'),
#  ('<s>', '``'),
#  ('``', 'Only'),
#  ('Only', 'a'),
#  ('a', 'relative'),
#  ('relative', 'handful'),
#  ('handful', 'of'),
#  ('of', 'such'),
#  ('such', 'reports'),
#  ('reports', 'was'),
#  ('was', 'received'),
#  ('received', "''"),
#  ("''", ','),
#  (',', 'the'),
#  ('the', 'jury'),
#  ('jury', 'said'),
#  ('said', ','),
#  (',', '``'),
#  ('``', 'considering'),
#  ('considering', 'the'),
#  ('the', 'widespread'),
#  ('widespread', 'interest'),
#  ('interest', 'in'),
#  ('in', 'the'),
#  ('the', 'election'),
#  ('election', ','),
#  (',', 'the'),
#  ('the', 'number'),
#  ('number', 'of'),
#  ('of', 'voters'),
#  ('voters', 'and'),
#  ('and', 'the'),
#  ('the', 'size'),
#  ('size', 'of'),
#  ('of', 'this'),
#  ('this', 'city'),
#  ('city', "''"),
#  ("''", '.'),
#  ('.', '</s>'),
#  ('</s>', '<s>'),
#  ('<s>', 'The'),
#  ('The', 'jury'),
#  ('jury', 'said'),
#  ('said', 'it'),
#  ('it', 'did'),
#  ('did', 'find'),
#  ('find', 'that'),
#  ('that', 'many'),
#  ('many', 'of'),
#  ('of', "Georgia's"),
#  ("Georgia's", 'registration'),
#  ('registration', 'and'),
#  ('and', 'election'),
#  ('election', 'laws'),
#  ('laws', '``'),
#  ('``', 'are'),
#  ('are', 'outmoded'),
#  ('outmoded', 'or'),
#  ('or', 'inadequate'),
#  ('inadequate', 'and'),
#  ('and', 'often'),
#  ('often', 'ambiguous'),
#  ('ambiguous', "''"),
#  ("''", '.'),
#  ('.', '</s>'),
#  ('</s>', '<s>'),
#  ('<s>', 'It'),
#  ('It', 'recommended'),
#  ('recommended', 'that'),
#  ('that', 'Fulton'),
#  ('Fulton', 'legislators'),
#  ('legislators', 'act'),
#  ('act', '``'),
#  ('``', 'to'),
#  ('to', 'have'),
#  ('have', 'these'),
#  ('these', 'laws'),
#  ('laws', 'studied'),
#  ('studied', 'and'),
#  ('and', 'revised'),
#  ('revised', 'to'),
#  ('to', 'the'),
#  ('the', 'end'),
#  ('end', 'of'),
#  ('of', 'modernizing'),
#  ('modernizing', 'and'),
#  ('and', 'improving'),
#  ('improving', 'them'),
#  ('them', "''"),
#  ("''", '.'),
#  ('.', '</s>'),
#  ('</s>', '<s>'),
#  ('<s>', 'The'),
#  ('The', 'grand'),
#  ('grand', 'jury'),
#  ('jury', 'commented'),
#  ('commented', 'on'),
#  ('on', 'a'),
#  ('a', 'number'),
#  ('number', 'of'),
#  ('of', 'other'),
#  ('other', 'topics'),
#  ('topics', ','),
#  (',', 'among'),
#  ('among', 'them'),
#  ('them', 'the'),
#  ('the', 'Atlanta'),
#  ('Atlanta', 'and'),
#  ('and', 'Fulton'),
#  ('Fulton', 'County'),
#  ('County', 'purchasing'),
#  ('purchasing', 'departments'),
#  ('departments', 'which'),
#  ('which', 'it'),
#  ('it', 'said'),
#  ('said', '``'),
#  ('``', 'are'),
#  ('are', 'well'),
#  ('well', 'operated'),
#  ('operated', 'and'),
#  ('and', 'follow'),
#  ('follow', 'generally'),
#  ('generally', 'accepted'),
#  ('accepted', 'practices'),
#  ('practices', 'which'),
#  ('which', 'inure'),
#  ('inure', 'to'),
#  ('to', 'the'),
#  ('the', 'best'),
#  ('best', 'interest'),
#  ('interest', 'of'),
#  ('of', 'both'),
#  ('both', 'governments'),
#  ('governments', "''"),
#  ("''", '.'),
#  ('.', '</s>'),
#  ('</s>', '<s>'),
#  ('<s>', 'Merger'),
#  ('Merger', 'proposed'),
#  ('proposed', '</s>'),
#  ('</s>', '<s>'),
#  ('<s>', 'However'),
#  ('However', ','),
#  (',', 'the'),
#  ('the', 'jury'),
#  ('jury', 'said'),
#  ('said', 'it'),
#  ('it', 'believes'),
#  ('believes', '``'),
#  ('``', 'these'),
#  ('these', 'two'),
#  ('two', 'offices'),
#  ('offices', 'should'),
#  ('should', 'be'),
#  ('be', 'combined'),
#  ('combined', 'to'),
#  ('to', 'achieve'),
#  ('achieve', 'greater'),
#  ('greater', 'efficiency'),
#  ('efficiency', 'and'),
#  ('and', 'reduce'),
#  ('reduce', 'the'),
#  ('the', 'cost'),
#  ('cost', 'of'),
#  ('of', 'administration'),
#  ('administration', "''"),
#  ("''", '.'),
#  ('.', '</s>'),
#  ('</s>', '<s>'),
#  ('<s>', 'The'),
#  ('The', 'City'),
#  ('City', 'Purchasing'),
#  ('Purchasing', 'Department'),
#  ('Department', ','),
#  (',', 'the'),
#  ('the', 'jury'),
#  ('jury', 'said'),
#  ('said', ','),
#  (',', '``'),
#  ('``', 'is'),
#  ('is', 'lacking'),
#  ('lacking', 'in'),
#  ('in', 'experienced'),
#  ('experienced', 'clerical'),
#  ('clerical', 'personnel'),
#  ('personnel', 'as'),
#  ('as', 'a'),
#  ('a', 'result'),
#  ('result', 'of'),
#  ('of', 'city'),
#  ('city', 'personnel'),
#  ('personnel', 'policies'),
#  ('policies', "''"),
#  ("''", '.'),
#  ('.', '</s>'),
#  ('</s>', '<s>'),
#  ('<s>', 'It'),
#  ('It', 'urged'),
#  ('urged', 'that'),
#  ('that', 'the'),
#  ('the', 'city'),
#  ('city', '``'),
#  ('``', 'take'),
#  ('take', 'steps'),
#  ('steps', 'to'),
#  ('to', 'remedy'),
#  ('remedy', "''"),
#  ("''", 'this'),
#  ('this', 'problem'),
#  ('problem', '.'),
#  ('.', '</s>'),
#  ('</s>', '<s>'),
#  ('<s>', 'Implementation'),
#  ('Implementation', 'of'),
#  ('of', "Georgia's"),
#  ("Georgia's", 'automobile'),
#  ('automobile', 'title'),
#  ('title', 'law'),
#  ('law', 'was'),
#  ('was', 'also'),
#  ('also', 'recommended'),
#  ('recommended', 'by'),
#  ('by', 'the'),
#  ('the', 'outgoing'),
#  ('outgoing', 'jury'),
#  ('jury', '.'),
#  ('.', '</s>'),
#  ('</s>', '<s>'),
#  ('<s>', 'It'),
#  ('It', 'urged'),
#  ('urged', 'that'),
#  ('that', 'the'),
#  ('the', 'next'),
#  ('next', 'Legislature'),
#  ('Legislature', '``'),
#  ('``', 'provide'),
#  ('provide', 'enabling'),
#  ('enabling', 'funds'),
#  ('funds', 'and'),
#  ('and', 're-set'),
#  ('re-set', 'the'),
#  ('the', 'effective'),
#  ('effective', 'date'),
#  ('date', 'so'),
#  ('so', 'that'),
#  ('that', 'an'),
#  ('an', 'orderly'),
#  ('orderly', 'implementation'),
#  ('implementation', 'of'),
#  ('of', 'the'),
#  ('the', 'law'),
#  ('law', 'may'),
#  ('may', 'be'),
#  ('be', 'effected'),
#  ('effected', "''"),
#  ("''", '.'),
#  ('.', '</s>'),
#  ('</s>', '<s>'),
#  ('<s>', 'The'),
#  ('The', 'grand'),
#  ('grand', 'jury'),
#  ('jury', 'took'),
#  ('took', 'a'),
#  ('a', 'swipe'),
#  ('swipe', 'at'),
#  ('at', 'the'),
#  ('the', 'State'),
#  ('State', 'Welfare'),
#  ('Welfare', "Department's"),
#  ("Department's", 'handling'),
#  ('handling', 'of'),
#  ('of', 'federal'),
#  ('federal', 'funds'),
#  ('funds', 'granted'),
#  ('granted', 'for'),
#  ('for', 'child'),
#  ('child', 'welfare'),
#  ('welfare', 'services'),
#  ('services', 'in'),
#  ('in', 'foster'),
#  ('foster', 'homes'),
#  ('homes', '.'),
#  ('.', '</s>'),
#  ('</s>', '<s>'),
#  ('<s>', '``'),
#  ('``', 'This'),
#  ('This', 'is'),
#  ('is', 'one'),
#  ('one', 'of'),
#  ('of', 'the'),
#  ('the', 'major'),
#  ('major', 'items'),
#  ('items', 'in'),
#  ('in', 'the'),
#  ('the', 'Fulton'),
#  ('Fulton', 'County'),
#  ('County', 'general'),
#  ('general', 'assistance'),
#  ('assistance', 'program'),
#  ('program', "''"),
#  ("''", ','),
#  (',', 'the'),
#  ('the', 'jury'),
#  ('jury', 'said'),
#  ('said', ','),
#  (',', 'but'),
#  ('but', 'the'),
#  ('the', 'State'),
#  ('State', 'Welfare'),
#  ('Welfare', 'Department'),
#  ('Department', '``'),
#  ('``', 'has'),
#  ('has', 'seen'),
#  ('seen', 'fit'),
#  ('fit', 'to'),
#  ('to', 'distribute'),
#  ('distribute', 'these'),
#  ('these', 'funds'),
#  ('funds', 'through'),
#  ('through', 'the'),
#  ('the', 'welfare'),
#  ('welfare', 'departments'),
#  ('departments', 'of'),
#  ('of', 'all'),
#  ('all', 'the'),
#  ('the', 'counties'),
#  ('counties', 'in'),
#  ('in', 'the'),
#  ('the', 'state'),
#  ('state', 'with'),
#  ('with', 'the'),
#  ('the', 'exception'),
#  ('exception', 'of'),
#  ('of', 'Fulton'),
#  ('Fulton', 'County'),
#  ('County', ','),
#  (',', 'which'),
#  ('which', 'receives'),
#  ('receives', 'none'),
#  ('none', 'of'),
#  ('of', 'this'),
#  ('this', 'money'),
#  ('money', '.'),
#  ('.', '</s>'),
#  ('</s>', '<s>'),
#  ('<s>', 'The'),
#  ('The', 'jurors'),
#  ('jurors', 'said'),
#  ('said', 'they'),
#  ('they', 'realize'),
#  ('realize', '``'),
#  ('``', 'a'),
#  ('a', 'proportionate'),
#  ('proportionate', 'distribution'),
#  ('distribution', 'of'),
#  ('of', 'these'),
#  ('these', 'funds'),
#  ('funds', 'might'),
#  ('might', 'disable'),
#  ('disable', 'this'),
#  ('this', 'program'),
#  ('program', 'in'),
#  ('in', 'our'),
#  ('our', 'less'),
#  ('less', 'populous'),
#  ('populous', 'counties'),
#  ('counties', "''"),
#  ("''", '.'),
#  ('.', '</s>'),
#  ('</s>', '<s>'),
#  ('<s>', 'Nevertheless'),
#  ('Nevertheless', ','),
#  (',', '``'),
#  ('``', 'we'),
#  ('we', 'feel'),
#  ('feel', 'that'),
#  ('that', 'in'),
#  ('in', 'the'),
#  ('the', 'future'),
#  ('future', 'Fulton'),
#  ('Fulton', 'County'),
#  ('County', 'should'),
#  ('should', 'receive'),
#  ('receive', 'some'),
#  ('some', 'portion'),
#  ('portion', 'of'),
#  ('of', 'these'),
#  ('these', 'available'),
#  ('available', 'funds'),
#  ('funds', "''"),
#  ("''", ','),
#  (',', 'the'),
#  ('the', 'jurors'),
#  ('jurors', 'said'),
#  ('said', '.'),
#  ('.', '</s>'),
#  ('</s>', '<s>'),
#  ('<s>', '``'),
#  ('``', 'Failure'),
#  ('Failure', 'to'),
#  ('to', 'do'),
#  ('do', 'this'),
#  ('this', 'will'),
#  ('will', 'continue'),
#  ('continue', 'to'),
#  ('to', 'place'),
#  ('place', 'a'),
#  ('a', 'disproportionate'),
#  ('disproportionate', 'burden'),
#  ('burden', "''"),
#  ("''", 'on'),
#  ('on', 'Fulton'),
#  ('Fulton', 'taxpayers'),
#  ('taxpayers', '.'),
#  ('.', '</s>'),
#  ('</s>', '<s>'),
#  ('<s>', 'The'),
#  ('The', 'jury'),
#  ('jury', 'also'),
#  ('also', 'commented'),
#  ('commented', 'on'),
#  ('on', 'the'),
#  ('the', 'Fulton'),
#  ('Fulton', "ordinary's"),
#  ("ordinary's", 'court'),
#  ('court', 'which'),
#  ('which', 'has'),
#  ('has', 'been'),
#  ('been', 'under'),
#  ('under', 'fire'),
#  ('fire', 'for'),
#  ('for', 'its'),
#  ('its', 'practices'),
#  ('practices', 'in'),
#  ('in', 'the'),
#  ('the', 'appointment'),
#  ('appointment', 'of'),
#  ('of', 'appraisers'),
#  ('appraisers', ','),
#  (',', 'guardians'),
#  ('guardians', 'and'),
#  ('and', 'administrators'),
#  ('administrators', 'and'),
#  ('and', 'the'),
#  ('the', 'awarding'),
#  ('awarding', 'of'),
#  ('of', 'fees'),
#  ('fees', 'and'),
#  ('and', 'compensation'),
#  ('compensation', '.'),
#  ('.', '</s>'),
#  ('</s>', '<s>'),
#  ('<s>', 'Wards'),
#  ('Wards', 'protected'),
#  ('protected', '</s>'),
#  ('</s>', '<s>'),
#  ('<s>', 'The'),
#  ('The', 'jury'),
#  ('jury', 'said'),
#  ('said', 'it'),
#  ('it', 'found'),
#  ('found', 'the'),
#  ('the', 'court'),
#  ('court', '``'),
#  ('``', 'has'),
#  ('has', 'incorporated'),
#  ('incorporated', 'into'),
#  ('into', 'its'),
#  ('its', 'operating'),
#  ('operating', 'procedures'),
#  ('procedures', 'the'),
#  ('the', 'recommendations'),
#  ('recommendations', "''"),
#  ("''", 'of'),
#  ('of', 'two'),
#  ('two', 'previous'),
#  ('previous', 'grand'),
#  ('grand', 'juries'),
#  ('juries', ','),
#  (',', 'the'),
#  ('the', 'Atlanta'),
#  ('Atlanta', 'Bar'),
#  ('Bar', 'Association'),
#  ('Association', 'and'),
#  ('and', 'an'),
#  ('an', 'interim'),
#  ('interim', 'citizens'),
#  ('citizens', 'committee'),
#  ('committee', '.'),
#  ('.', '</s>'),
#  ('</s>', '<s>'),
#  ('<s>', '``'),
#  ('``', 'These'),
#  ('These', 'actions'),
#  ('actions', 'should'),
#  ('should', 'serve'),
#  ('serve', 'to'),
#  ('to', 'protect'),
#  ('protect', 'in'),
#  ('in', 'fact'),
#  ('fact', 'and'),
#  ('and', 'in'),
#  ('in', 'effect'),
#  ('effect', 'the'),
#  ('the', "court's"),
#  ("court's", 'wards'),
#  ('wards', 'from'),
#  ('from', 'undue'),
#  ('undue', 'costs'),
#  ('costs', 'and'),
#  ('and', 'its'),
#  ('its', 'appointed'),
#  ('appointed', 'and'),
#  ('and', 'elected'),
#  ('elected', 'servants'),
#  ('servants', 'from'),
#  ('from', 'unmeritorious'),
#  ('unmeritorious', 'criticisms'),
#  ('criticisms', "''"),
#  ("''", ','),
#  (',', 'the'),
#  ('the', 'jury'),
#  ('jury', 'said'),
#  ('said', '.'),
#  ('.', '</s>'),
#  ('</s>', '<s>'),
#  ('<s>', 'Regarding'),
#  ('Regarding', "Atlanta's"),
#  ("Atlanta's", 'new'),
#  ('new', 'multi-million-dollar'),
#  ('multi-million-dollar', 'airport'),
#  ('airport', ','),
#  (',', 'the'),
#  ('the', 'jury'),
#  ('jury', 'recommended'),
#  ('recommended', '``'),
#  ('``', 'that'),
#  ('that', 'when'),
#  ('when', 'the'),
#  ('the', 'new'),
#  ('new', 'management'),
#  ('management', 'takes'),
#  ('takes', 'charge'),
#  ('charge', 'Jan.'),
#  ('Jan.', '1'),
#  ('1', 'the'),
#  ('the', 'airport'),
#  ('airport', 'be'),
#  ('be', 'operated'),
#  ('operated', 'in'),
#  ('in', 'a'),
#  ('a', 'manner'),
#  ('manner', 'that'),
#  ('that', 'will'),
#  ('will', 'eliminate'),
#  ('eliminate', 'political'),
#  ('political', 'influences'),
#  ('influences', "''"),
#  ("''", '.'),
#  ('.', '</s>'),
#  ('</s>', '<s>'),
#  ('<s>', 'The'),
#  ('The', 'jury'),
#  ('jury', 'did'),
#  ('did', 'not'),
#  ('not', 'elaborate'),
#  ('elaborate', ','),
#  (',', 'but'),
#  ('but', 'it'),
#  ('it', 'added'),
#  ('added', 'that'),
#  ('that', '``'),
#  ('``', 'there'),
#  ('there', 'should'),
#  ('should', 'be'),
#  ('be', 'periodic'),
#  ('periodic', 'surveillance'),
#  ('surveillance', 'of'),
#  ('of', 'the'),
#  ('the', 'pricing'),
#  ('pricing', 'practices'),
#  ('practices', 'of'),
#  ('of', 'the'),
#  ('the', 'concessionaires'),
#  ('concessionaires', 'for'),
#  ('for', 'the'),
#  ('the', 'purpose'),
#  ('purpose', 'of'),
#  ('of', 'keeping'),
#  ('keeping', 'the'),
#  ('the', 'prices'),
#  ('prices', 'reasonable'),
#  ('reasonable', "''"),
#  ("''", '.'),
#  ('.', '</s>'),
#  ('</s>', '<s>'),
#  ('<s>', 'Ask'),
#  ('Ask', 'jail'),
#  ('jail', 'deputies'),
#  ('deputies', '</s>'),
#  ('</s>', '<s>'),
#  ('<s>', 'On'),
#  ('On', 'other'),
#  ('other', 'matters'),
#  ('matters', ','),
#  (',', 'the'),
#  ('the', 'jury'),
#  ('jury', 'recommended'),
#  ('recommended', 'that'),
#  ('that', ':'),
#  (':', '('),
#  ('(', '1'),
#  ('1', ')'),
#  (')', '</s>'),
#  ('</s>', '<s>'),
#  ('<s>', 'Four'),
#  ('Four', 'additional'),
#  ('additional', 'deputies'),
#  ('deputies', 'be'),
#  ('be', 'employed'),
#  ('employed', 'at'),
#  ('at', 'the'),
#  ('the', 'Fulton'),
#  ('Fulton', 'County'),
#  ('County', 'Jail'),
#  ('Jail', 'and'),
#  ('and', '``'),
#  ('``', 'a'),
#  ('a', 'doctor'),
#  ('doctor', ','),
#  (',', 'medical'),
#  ('medical', 'intern'),
#  ('intern', 'or'),
#  ('or', 'extern'),
#  ('extern', 'be'),
#  ('be', 'employed'),
#  ('employed', 'for'),
#  ('for', 'night'),
#  ('night', 'and'),
#  ('and', 'weekend'),
#  ('weekend', 'duty'),
#  ('duty', 'at'),
#  ('at', 'the'),
#  ('the', 'jail'),
#  ('jail', "''"),
#  ("''", '.'),
#  ('.', '</s>'),
#  ('</s>', '<s>'),
#  ('<s>', '('),
#  ('(', '2'),
#  ('2', ')'),
#  (')', '</s>'),
#  ('</s>', '<s>'),
#  ('<s>', 'Fulton'),
#  ('Fulton', 'legislators'),
#  ('legislators', '``'),
#  ('``', 'work'),
#  ('work', 'with'),
#  ('with', 'city'),
#  ('city', 'officials'),
#  ('officials', 'to'),
#  ('to', 'pass'),
#  ('pass', 'enabling'),
#  ('enabling', 'legislation'),
#  ('legislation', 'that'),
#  ('that', 'will'),
#  ('will', 'permit'),
#  ('permit', 'the'),
#  ('the', 'establishment'),
#  ('establishment', 'of'),
#  ('of', 'a'),
#  ('a', 'fair'),
#  ('fair', 'and'),
#  ('and', 'equitable'),
#  ('equitable', "''"),
#  ("''", 'pension'),
#  ('pension', 'plan'),
#  ('plan', 'for'),
#  ('for', 'city'),
#  ('city', 'employes'),
#  ('employes', '.'),
#  ('.', '</s>'),
#  ('</s>', '<s>'),
#  ('<s>', 'The'),
#  ('The', 'jury'),
#  ('jury', 'praised'),
#  ('praised', 'the'),
#  ('the', 'administration'),
#  ('administration', 'and'),
#  ('and', 'operation'),
#  ('operation', 'of'),
#  ('of', 'the'),
#  ('the', 'Atlanta'),
#  ('Atlanta', 'Police'),
#  ('Police', 'Department'),
#  ('Department', ','),
#  (',', 'the'),
#  ('the', 'Fulton'),
#  ('Fulton', 'Tax'),
#  ('Tax', "Commissioner's"),
#  ("Commissioner's", 'Office'),
#  ('Office', ','),
#  (',', 'the'),
#  ('the', 'Bellwood'),
#  ('Bellwood', 'and'),
#  ('and', 'Alpharetta'),
#  ('Alpharetta', 'prison'),
#  ('prison', 'farms'),
#  ('farms', ','),
#  (',', 'Grady'),
#  ('Grady', 'Hospital'),
#  ('Hospital', 'and'),
#  ('and', 'the'),
#  ('the', 'Fulton'),
#  ('Fulton', 'Health'),
#  ('Health', 'Department'),
#  ('Department', '.'),
#  ('.', '</s>'),
#  ('</s>', '<s>'),
#  ('<s>', 'Mayor'),
#  ('Mayor', 'William'),
#  ('William', 'B.'),
#  ('B.', 'Hartsfield'),
#  ('Hartsfield', 'filed'),
#  ('filed', 'suit'),
#  ('suit', 'for'),
#  ('for', 'divorce'),
#  ('divorce', 'from'),
#  ('from', 'his'),
#  ('his', 'wife'),
#  ('wife', ','),
#  (',', 'Pearl'),
#  ('Pearl', 'Williams'),
#  ('Williams', 'Hartsfield'),
#  ('Hartsfield', ','),
#  (',', 'in'),
#  ('in', 'Fulton'),
#  ('Fulton', 'Superior'),
#  ('Superior', 'Court'),
#  ('Court', 'Friday'),
#  ('Friday', '.'),
#  ('.', '</s>'),
#  ('</s>', '<s>'),
#  ('<s>', 'His'),
#  ('His', 'petition'),
#  ('petition', 'charged'),
#  ('charged', 'mental'),
#  ('mental', 'cruelty'),
#  ('cruelty', '.'),
#  ('.', '</s>'),
#  ('</s>', '<s>'),
#  ('<s>', 'The'),
#  ('The', 'couple'),
#  ('couple', 'was'),
#  ('was', 'married'),
#  ('married', 'Aug.'),
#  ('Aug.', '2'),
#  ('2', ','),
#  (',', '1913'),
#  ('1913', '.'),
#  ('.', '</s>'),
#  ('</s>', '<s>'),
#  ('<s>', 'They'),
#  ('They', 'have'),
#  ('have', 'a'),
#  ('a', 'son'),
#  ('son', ','),
#  (',', 'William'),
#  ('William', 'Berry'),
#  ('Berry', 'Jr.'),
#  ('Jr.', ','),
#  (',', 'and'),
#  ('and', 'a'),
#  ('a', 'daughter'),
#  ('daughter', ','),
#  (',', 'Mrs.'),
#  ('Mrs.', 'J.'),
#  ('J.', 'M.'),
#  ('M.', 'Cheshire'),
#  ('Cheshire', 'of'),
#  ('of', 'Griffin'),
#  ('Griffin', '.'),
#  ('.', '</s>'),
#  ('</s>', '<s>'),
#  ('<s>', 'Attorneys'),
#  ('Attorneys', 'for'),
#  ('for', 'the'),
#  ('the', 'mayor'),
#  ('mayor', 'said'),
#  ('said', 'that'),
#  ('that', 'an'),
#  ('an', 'amicable'),
#  ('amicable', 'property'),
#  ('property', 'settlement'),
#  ('settlement', 'has'),
#  ('has', 'been'),
#  ('been', 'agreed'),
#  ('agreed', 'upon'),
#  ('upon', '.'),
#  ('.', '</s>'),
#  ('</s>', '<s>'),
#  ('<s>', 'The'),
#  ('The', 'petition'),
#  ('petition', 'listed'),
#  ('listed', 'the'),
#  ('the', "mayor's"),
#  ("mayor's", 'occupation'),
#  ('occupation', 'as'),
#  ('as', '``'),
#  ('``', 'attorney'),
#  ('attorney', "''"),
#  ("''", 'and'),
#  ('and', 'his'),
#  ('his', 'age'),
#  ('age', 'as'),
#  ('as', '71'),
#  ('71', '.'),
#  ('.', '</s>'),
#  ('</s>', '<s>'),
#  ('<s>', 'It'),
#  ('It', 'listed'),
#  ('listed', 'his'),
#  ('his', "wife's"),
#  ("wife's", 'age'),
#  ('age', 'as'),
#  ('as', '74'),
#  ('74', 'and'),
#  ('and', 'place'),
#  ('place', 'of'),
#  ('of', 'birth'),
#  ('birth', 'as'),
#  ('as', 'Opelika'),
#  ('Opelika', ','),
#  (',', 'Ala.'),
#  ('Ala.', '.'),
#  ('.', '</s>'),
#  ('</s>', '<s>'),
#  ('<s>', 'The'),
#  ('The', 'petition'),
#  ('petition', 'said'),
#  ('said', 'that'),
#  ('that', 'the'),
#  ('the', 'couple'),
#  ('couple', 'has'),
#  ('has', 'not'),
#  ('not', 'lived'),
#  ('lived', 'together'),
#  ('together', 'as'),
#  ('as', 'man'),
#  ('man', 'and'),
#  ('and', 'wife'),
#  ('wife', 'for'),
#  ('for', 'more'),
#  ('more', 'than'),
#  ('than', 'a'),
#  ('a', 'year'),
#  ('year', '.'),
#  ('.', '</s>'),
#  ('</s>', '<s>'),
#  ('<s>', 'The'),
#  ('The', 'Hartsfield'),
#  ('Hartsfield', 'home'),
#  ('home', 'is'),
#  ('is', 'at'),
#  ('at', '637'),
#  ('637', 'E.'),
#  ('E.', 'Pelham'),
#  ('Pelham', 'Rd.'),
#  ('Rd.', 'Aj'),
#  ('Aj', '.'),
#  ('.', '</s>'),
#  ('</s>', '<s>'),
#  ('<s>', 'Henry'),
#  ('Henry', 'L.'),
#  ('L.', 'Bowden'),
#  ('Bowden', 'was'),
#  ('was', 'listed'),
#  ('listed', 'on'),
#  ('on', 'the'),
#  ('the', 'petition'),
#  ('petition', 'as'),
#  ('as', 'the'),
#  ('the', "mayor's"),
#  ("mayor's", 'attorney'),
#  ('attorney', '.'),
#  ('.', '</s>'),
#  ('</s>', '<s>'),
#  ('<s>', 'Hartsfield'),
#  ('Hartsfield', 'has'),
#  ('has', 'been'),
#  ('been', 'mayor'),
#  ('mayor', 'of'),
#  ...]

# %% [markdown]
# ### trigrams_brown

# %%
trigrams_brown
# Out:
# [('<s>', 'The', 'Fulton'),
#  ('The', 'Fulton', 'County'),
#  ('Fulton', 'County', 'Grand'),
#  ('County', 'Grand', 'Jury'),
#  ('Grand', 'Jury', 'said'),
#  ('Jury', 'said', 'Friday'),
#  ('said', 'Friday', 'an'),
#  ('Friday', 'an', 'investigation'),
#  ('an', 'investigation', 'of'),
#  ('investigation', 'of', "Atlanta's"),
#  ('of', "Atlanta's", 'recent'),
#  ("Atlanta's", 'recent', 'primary'),
#  ('recent', 'primary', 'election'),
#  ('primary', 'election', 'produced'),
#  ('election', 'produced', '``'),
#  ('produced', '``', 'no'),
#  ('``', 'no', 'evidence'),
#  ('no', 'evidence', "''"),
#  ('evidence', "''", 'that'),
#  ("''", 'that', 'any'),
#  ('that', 'any', 'irregularities'),
#  ('any', 'irregularities', 'took'),
#  ('irregularities', 'took', 'place'),
#  ('took', 'place', '.'),
#  ('place', '.', '</s>'),
#  ('.', '</s>', '<s>'),
#  ('</s>', '<s>', 'The'),
#  ('<s>', 'The', 'jury'),
#  ('The', 'jury', 'further'),
#  ('jury', 'further', 'said'),
#  ('further', 'said', 'in'),
#  ('said', 'in', 'term-end'),
#  ('in', 'term-end', 'presentments'),
#  ('term-end', 'presentments', 'that'),
#  ('presentments', 'that', 'the'),
#  ('that', 'the', 'City'),
#  ('the', 'City', 'Executive'),
#  ('City', 'Executive', 'Committee'),
#  ('Executive', 'Committee', ','),
#  ('Committee', ',', 'which'),
#  (',', 'which', 'had'),
#  ('which', 'had', 'over-all'),
#  ('had', 'over-all', 'charge'),
#  ('over-all', 'charge', 'of'),
#  ('charge', 'of', 'the'),
#  ('of', 'the', 'election'),
#  ('the', 'election', ','),
#  ('election', ',', '``'),
#  (',', '``', 'deserves'),
#  ('``', 'deserves', 'the'),
#  ('deserves', 'the', 'praise'),
#  ('the', 'praise', 'and'),
#  ('praise', 'and', 'thanks'),
#  ('and', 'thanks', 'of'),
#  ('thanks', 'of', 'the'),
#  ('of', 'the', 'City'),
#  ('the', 'City', 'of'),
#  ('City', 'of', 'Atlanta'),
#  ('of', 'Atlanta', "''"),
#  ('Atlanta', "''", 'for'),
#  ("''", 'for', 'the'),
#  ('for', 'the', 'manner'),
#  ('the', 'manner', 'in'),
#  ('manner', 'in', 'which'),
#  ('in', 'which', 'the'),
#  ('which', 'the', 'election'),
#  ('the', 'election', 'was'),
#  ('election', 'was', 'conducted'),
#  ('was', 'conducted', '.'),
#  ('conducted', '.', '</s>'),
#  ('.', '</s>', '<s>'),
#  ('</s>', '<s>', 'The'),
#  ('<s>', 'The', 'September-October'),
#  ('The', 'September-October', 'term'),
#  ('September-October', 'term', 'jury'),
#  ('term', 'jury', 'had'),
#  ('jury', 'had', 'been'),
#  ('had', 'been', 'charged'),
#  ('been', 'charged', 'by'),
#  ('charged', 'by', 'Fulton'),
#  ('by', 'Fulton', 'Superior'),
#  ('Fulton', 'Superior', 'Court'),
#  ('Superior', 'Court', 'Judge'),
#  ('Court', 'Judge', 'Durwood'),
#  ('Judge', 'Durwood', 'Pye'),
#  ('Durwood', 'Pye', 'to'),
#  ('Pye', 'to', 'investigate'),
#  ('to', 'investigate', 'reports'),
#  ('investigate', 'reports', 'of'),
#  ('reports', 'of', 'possible'),
#  ('of', 'possible', '``'),
#  ('possible', '``', 'irregularities'),
#  ('``', 'irregularities', "''"),
#  ('irregularities', "''", 'in'),
#  ("''", 'in', 'the'),
#  ('in', 'the', 'hard-fought'),
#  ('the', 'hard-fought', 'primary'),
#  ('hard-fought', 'primary', 'which'),
#  ('primary', 'which', 'was'),
#  ('which', 'was', 'won'),
#  ('was', 'won', 'by'),
#  ('won', 'by', 'Mayor-nominate'),
#  ('by', 'Mayor-nominate', 'Ivan'),
#  ('Mayor-nominate', 'Ivan', 'Allen'),
#  ('Ivan', 'Allen', 'Jr.'),
#  ('Allen', 'Jr.', '.'),
#  ('Jr.', '.', '</s>'),
#  ('.', '</s>', '<s>'),
#  ('</s>', '<s>', '``'),
#  ('<s>', '``', 'Only'),
#  ('``', 'Only', 'a'),
#  ('Only', 'a', 'relative'),
#  ('a', 'relative', 'handful'),
#  ('relative', 'handful', 'of'),
#  ('handful', 'of', 'such'),
#  ('of', 'such', 'reports'),
#  ('such', 'reports', 'was'),
#  ('reports', 'was', 'received'),
#  ('was', 'received', "''"),
#  ('received', "''", ','),
#  ("''", ',', 'the'),
#  (',', 'the', 'jury'),
#  ('the', 'jury', 'said'),
#  ('jury', 'said', ','),
#  ('said', ',', '``'),
#  (',', '``', 'considering'),
#  ('``', 'considering', 'the'),
#  ('considering', 'the', 'widespread'),
#  ('the', 'widespread', 'interest'),
#  ('widespread', 'interest', 'in'),
#  ('interest', 'in', 'the'),
#  ('in', 'the', 'election'),
#  ('the', 'election', ','),
#  ('election', ',', 'the'),
#  (',', 'the', 'number'),
#  ('the', 'number', 'of'),
#  ('number', 'of', 'voters'),
#  ('of', 'voters', 'and'),
#  ('voters', 'and', 'the'),
#  ('and', 'the', 'size'),
#  ('the', 'size', 'of'),
#  ('size', 'of', 'this'),
#  ('of', 'this', 'city'),
#  ('this', 'city', "''"),
#  ('city', "''", '.'),
#  ("''", '.', '</s>'),
#  ('.', '</s>', '<s>'),
#  ('</s>', '<s>', 'The'),
#  ('<s>', 'The', 'jury'),
#  ('The', 'jury', 'said'),
#  ('jury', 'said', 'it'),
#  ('said', 'it', 'did'),
#  ('it', 'did', 'find'),
#  ('did', 'find', 'that'),
#  ('find', 'that', 'many'),
#  ('that', 'many', 'of'),
#  ('many', 'of', "Georgia's"),
#  ('of', "Georgia's", 'registration'),
#  ("Georgia's", 'registration', 'and'),
#  ('registration', 'and', 'election'),
#  ('and', 'election', 'laws'),
#  ('election', 'laws', '``'),
#  ('laws', '``', 'are'),
#  ('``', 'are', 'outmoded'),
#  ('are', 'outmoded', 'or'),
#  ('outmoded', 'or', 'inadequate'),
#  ('or', 'inadequate', 'and'),
#  ('inadequate', 'and', 'often'),
#  ('and', 'often', 'ambiguous'),
#  ('often', 'ambiguous', "''"),
#  ('ambiguous', "''", '.'),
#  ("''", '.', '</s>'),
#  ('.', '</s>', '<s>'),
#  ('</s>', '<s>', 'It'),
#  ('<s>', 'It', 'recommended'),
#  ('It', 'recommended', 'that'),
#  ('recommended', 'that', 'Fulton'),
#  ('that', 'Fulton', 'legislators'),
#  ('Fulton', 'legislators', 'act'),
#  ('legislators', 'act', '``'),
#  ('act', '``', 'to'),
#  ('``', 'to', 'have'),
#  ('to', 'have', 'these'),
#  ('have', 'these', 'laws'),
#  ('these', 'laws', 'studied'),
#  ('laws', 'studied', 'and'),
#  ('studied', 'and', 'revised'),
#  ('and', 'revised', 'to'),
#  ('revised', 'to', 'the'),
#  ('to', 'the', 'end'),
#  ('the', 'end', 'of'),
#  ('end', 'of', 'modernizing'),
#  ('of', 'modernizing', 'and'),
#  ('modernizing', 'and', 'improving'),
#  ('and', 'improving', 'them'),
#  ('improving', 'them', "''"),
#  ('them', "''", '.'),
#  ("''", '.', '</s>'),
#  ('.', '</s>', '<s>'),
#  ('</s>', '<s>', 'The'),
#  ('<s>', 'The', 'grand'),
#  ('The', 'grand', 'jury'),
#  ('grand', 'jury', 'commented'),
#  ('jury', 'commented', 'on'),
#  ('commented', 'on', 'a'),
#  ('on', 'a', 'number'),
#  ('a', 'number', 'of'),
#  ('number', 'of', 'other'),
#  ('of', 'other', 'topics'),
#  ('other', 'topics', ','),
#  ('topics', ',', 'among'),
#  (',', 'among', 'them'),
#  ('among', 'them', 'the'),
#  ('them', 'the', 'Atlanta'),
#  ('the', 'Atlanta', 'and'),
#  ('Atlanta', 'and', 'Fulton'),
#  ('and', 'Fulton', 'County'),
#  ('Fulton', 'County', 'purchasing'),
#  ('County', 'purchasing', 'departments'),
#  ('purchasing', 'departments', 'which'),
#  ('departments', 'which', 'it'),
#  ('which', 'it', 'said'),
#  ('it', 'said', '``'),
#  ('said', '``', 'are'),
#  ('``', 'are', 'well'),
#  ('are', 'well', 'operated'),
#  ('well', 'operated', 'and'),
#  ('operated', 'and', 'follow'),
#  ('and', 'follow', 'generally'),
#  ('follow', 'generally', 'accepted'),
#  ('generally', 'accepted', 'practices'),
#  ('accepted', 'practices', 'which'),
#  ('practices', 'which', 'inure'),
#  ('which', 'inure', 'to'),
#  ('inure', 'to', 'the'),
#  ('to', 'the', 'best'),
#  ('the', 'best', 'interest'),
#  ('best', 'interest', 'of'),
#  ('interest', 'of', 'both'),
#  ('of', 'both', 'governments'),
#  ('both', 'governments', "''"),
#  ('governments', "''", '.'),
#  ("''", '.', '</s>'),
#  ('.', '</s>', '<s>'),
#  ('</s>', '<s>', 'Merger'),
#  ('<s>', 'Merger', 'proposed'),
#  ('Merger', 'proposed', '</s>'),
#  ('proposed', '</s>', '<s>'),
#  ('</s>', '<s>', 'However'),
#  ('<s>', 'However', ','),
#  ('However', ',', 'the'),
#  (',', 'the', 'jury'),
#  ('the', 'jury', 'said'),
#  ('jury', 'said', 'it'),
#  ('said', 'it', 'believes'),
#  ('it', 'believes', '``'),
#  ('believes', '``', 'these'),
#  ('``', 'these', 'two'),
#  ('these', 'two', 'offices'),
#  ('two', 'offices', 'should'),
#  ('offices', 'should', 'be'),
#  ('should', 'be', 'combined'),
#  ('be', 'combined', 'to'),
#  ('combined', 'to', 'achieve'),
#  ('to', 'achieve', 'greater'),
#  ('achieve', 'greater', 'efficiency'),
#  ('greater', 'efficiency', 'and'),
#  ('efficiency', 'and', 'reduce'),
#  ('and', 'reduce', 'the'),
#  ('reduce', 'the', 'cost'),
#  ('the', 'cost', 'of'),
#  ('cost', 'of', 'administration'),
#  ('of', 'administration', "''"),
#  ('administration', "''", '.'),
#  ("''", '.', '</s>'),
#  ('.', '</s>', '<s>'),
#  ('</s>', '<s>', 'The'),
#  ('<s>', 'The', 'City'),
#  ('The', 'City', 'Purchasing'),
#  ('City', 'Purchasing', 'Department'),
#  ('Purchasing', 'Department', ','),
#  ('Department', ',', 'the'),
#  (',', 'the', 'jury'),
#  ('the', 'jury', 'said'),
#  ('jury', 'said', ','),
#  ('said', ',', '``'),
#  (',', '``', 'is'),
#  ('``', 'is', 'lacking'),
#  ('is', 'lacking', 'in'),
#  ('lacking', 'in', 'experienced'),
#  ('in', 'experienced', 'clerical'),
#  ('experienced', 'clerical', 'personnel'),
#  ('clerical', 'personnel', 'as'),
#  ('personnel', 'as', 'a'),
#  ('as', 'a', 'result'),
#  ('a', 'result', 'of'),
#  ('result', 'of', 'city'),
#  ('of', 'city', 'personnel'),
#  ('city', 'personnel', 'policies'),
#  ('personnel', 'policies', "''"),
#  ('policies', "''", '.'),
#  ("''", '.', '</s>'),
#  ('.', '</s>', '<s>'),
#  ('</s>', '<s>', 'It'),
#  ('<s>', 'It', 'urged'),
#  ('It', 'urged', 'that'),
#  ('urged', 'that', 'the'),
#  ('that', 'the', 'city'),
#  ('the', 'city', '``'),
#  ('city', '``', 'take'),
#  ('``', 'take', 'steps'),
#  ('take', 'steps', 'to'),
#  ('steps', 'to', 'remedy'),
#  ('to', 'remedy', "''"),
#  ('remedy', "''", 'this'),
#  ("''", 'this', 'problem'),
#  ('this', 'problem', '.'),
#  ('problem', '.', '</s>'),
#  ('.', '</s>', '<s>'),
#  ('</s>', '<s>', 'Implementation'),
#  ('<s>', 'Implementation', 'of'),
#  ('Implementation', 'of', "Georgia's"),
#  ('of', "Georgia's", 'automobile'),
#  ("Georgia's", 'automobile', 'title'),
#  ('automobile', 'title', 'law'),
#  ('title', 'law', 'was'),
#  ('law', 'was', 'also'),
#  ('was', 'also', 'recommended'),
#  ('also', 'recommended', 'by'),
#  ('recommended', 'by', 'the'),
#  ('by', 'the', 'outgoing'),
#  ('the', 'outgoing', 'jury'),
#  ('outgoing', 'jury', '.'),
#  ('jury', '.', '</s>'),
#  ('.', '</s>', '<s>'),
#  ('</s>', '<s>', 'It'),
#  ('<s>', 'It', 'urged'),
#  ('It', 'urged', 'that'),
#  ('urged', 'that', 'the'),
#  ('that', 'the', 'next'),
#  ('the', 'next', 'Legislature'),
#  ('next', 'Legislature', '``'),
#  ('Legislature', '``', 'provide'),
#  ('``', 'provide', 'enabling'),
#  ('provide', 'enabling', 'funds'),
#  ('enabling', 'funds', 'and'),
#  ('funds', 'and', 're-set'),
#  ('and', 're-set', 'the'),
#  ('re-set', 'the', 'effective'),
#  ('the', 'effective', 'date'),
#  ('effective', 'date', 'so'),
#  ('date', 'so', 'that'),
#  ('so', 'that', 'an'),
#  ('that', 'an', 'orderly'),
#  ('an', 'orderly', 'implementation'),
#  ('orderly', 'implementation', 'of'),
#  ('implementation', 'of', 'the'),
#  ('of', 'the', 'law'),
#  ('the', 'law', 'may'),
#  ('law', 'may', 'be'),
#  ('may', 'be', 'effected'),
#  ('be', 'effected', "''"),
#  ('effected', "''", '.'),
#  ("''", '.', '</s>'),
#  ('.', '</s>', '<s>'),
#  ('</s>', '<s>', 'The'),
#  ('<s>', 'The', 'grand'),
#  ('The', 'grand', 'jury'),
#  ('grand', 'jury', 'took'),
#  ('jury', 'took', 'a'),
#  ('took', 'a', 'swipe'),
#  ('a', 'swipe', 'at'),
#  ('swipe', 'at', 'the'),
#  ('at', 'the', 'State'),
#  ('the', 'State', 'Welfare'),
#  ('State', 'Welfare', "Department's"),
#  ('Welfare', "Department's", 'handling'),
#  ("Department's", 'handling', 'of'),
#  ('handling', 'of', 'federal'),
#  ('of', 'federal', 'funds'),
#  ('federal', 'funds', 'granted'),
#  ('funds', 'granted', 'for'),
#  ('granted', 'for', 'child'),
#  ('for', 'child', 'welfare'),
#  ('child', 'welfare', 'services'),
#  ('welfare', 'services', 'in'),
#  ('services', 'in', 'foster'),
#  ('in', 'foster', 'homes'),
#  ('foster', 'homes', '.'),
#  ('homes', '.', '</s>'),
#  ('.', '</s>', '<s>'),
#  ('</s>', '<s>', '``'),
#  ('<s>', '``', 'This'),
#  ('``', 'This', 'is'),
#  ('This', 'is', 'one'),
#  ('is', 'one', 'of'),
#  ('one', 'of', 'the'),
#  ('of', 'the', 'major'),
#  ('the', 'major', 'items'),
#  ('major', 'items', 'in'),
#  ('items', 'in', 'the'),
#  ('in', 'the', 'Fulton'),
#  ('the', 'Fulton', 'County'),
#  ('Fulton', 'County', 'general'),
#  ('County', 'general', 'assistance'),
#  ('general', 'assistance', 'program'),
#  ('assistance', 'program', "''"),
#  ('program', "''", ','),
#  ("''", ',', 'the'),
#  (',', 'the', 'jury'),
#  ('the', 'jury', 'said'),
#  ('jury', 'said', ','),
#  ('said', ',', 'but'),
#  (',', 'but', 'the'),
#  ('but', 'the', 'State'),
#  ('the', 'State', 'Welfare'),
#  ('State', 'Welfare', 'Department'),
#  ('Welfare', 'Department', '``'),
#  ('Department', '``', 'has'),
#  ('``', 'has', 'seen'),
#  ('has', 'seen', 'fit'),
#  ('seen', 'fit', 'to'),
#  ('fit', 'to', 'distribute'),
#  ('to', 'distribute', 'these'),
#  ('distribute', 'these', 'funds'),
#  ('these', 'funds', 'through'),
#  ('funds', 'through', 'the'),
#  ('through', 'the', 'welfare'),
#  ('the', 'welfare', 'departments'),
#  ('welfare', 'departments', 'of'),
#  ('departments', 'of', 'all'),
#  ('of', 'all', 'the'),
#  ('all', 'the', 'counties'),
#  ('the', 'counties', 'in'),
#  ('counties', 'in', 'the'),
#  ('in', 'the', 'state'),
#  ('the', 'state', 'with'),
#  ('state', 'with', 'the'),
#  ('with', 'the', 'exception'),
#  ('the', 'exception', 'of'),
#  ('exception', 'of', 'Fulton'),
#  ('of', 'Fulton', 'County'),
#  ('Fulton', 'County', ','),
#  ('County', ',', 'which'),
#  (',', 'which', 'receives'),
#  ('which', 'receives', 'none'),
#  ('receives', 'none', 'of'),
#  ('none', 'of', 'this'),
#  ('of', 'this', 'money'),
#  ('this', 'money', '.'),
#  ('money', '.', '</s>'),
#  ('.', '</s>', '<s>'),
#  ('</s>', '<s>', 'The'),
#  ('<s>', 'The', 'jurors'),
#  ('The', 'jurors', 'said'),
#  ('jurors', 'said', 'they'),
#  ('said', 'they', 'realize'),
#  ('they', 'realize', '``'),
#  ('realize', '``', 'a'),
#  ('``', 'a', 'proportionate'),
#  ('a', 'proportionate', 'distribution'),
#  ('proportionate', 'distribution', 'of'),
#  ('distribution', 'of', 'these'),
#  ('of', 'these', 'funds'),
#  ('these', 'funds', 'might'),
#  ('funds', 'might', 'disable'),
#  ('might', 'disable', 'this'),
#  ('disable', 'this', 'program'),
#  ('this', 'program', 'in'),
#  ('program', 'in', 'our'),
#  ('in', 'our', 'less'),
#  ('our', 'less', 'populous'),
#  ('less', 'populous', 'counties'),
#  ('populous', 'counties', "''"),
#  ('counties', "''", '.'),
#  ("''", '.', '</s>'),
#  ('.', '</s>', '<s>'),
#  ('</s>', '<s>', 'Nevertheless'),
#  ('<s>', 'Nevertheless', ','),
#  ('Nevertheless', ',', '``'),
#  (',', '``', 'we'),
#  ('``', 'we', 'feel'),
#  ('we', 'feel', 'that'),
#  ('feel', 'that', 'in'),
#  ('that', 'in', 'the'),
#  ('in', 'the', 'future'),
#  ('the', 'future', 'Fulton'),
#  ('future', 'Fulton', 'County'),
#  ('Fulton', 'County', 'should'),
#  ('County', 'should', 'receive'),
#  ('should', 'receive', 'some'),
#  ('receive', 'some', 'portion'),
#  ('some', 'portion', 'of'),
#  ('portion', 'of', 'these'),
#  ('of', 'these', 'available'),
#  ('these', 'available', 'funds'),
#  ('available', 'funds', "''"),
#  ('funds', "''", ','),
#  ("''", ',', 'the'),
#  (',', 'the', 'jurors'),
#  ('the', 'jurors', 'said'),
#  ('jurors', 'said', '.'),
#  ('said', '.', '</s>'),
#  ('.', '</s>', '<s>'),
#  ('</s>', '<s>', '``'),
#  ('<s>', '``', 'Failure'),
#  ('``', 'Failure', 'to'),
#  ('Failure', 'to', 'do'),
#  ('to', 'do', 'this'),
#  ('do', 'this', 'will'),
#  ('this', 'will', 'continue'),
#  ('will', 'continue', 'to'),
#  ('continue', 'to', 'place'),
#  ('to', 'place', 'a'),
#  ('place', 'a', 'disproportionate'),
#  ('a', 'disproportionate', 'burden'),
#  ('disproportionate', 'burden', "''"),
#  ('burden', "''", 'on'),
#  ("''", 'on', 'Fulton'),
#  ('on', 'Fulton', 'taxpayers'),
#  ('Fulton', 'taxpayers', '.'),
#  ('taxpayers', '.', '</s>'),
#  ('.', '</s>', '<s>'),
#  ('</s>', '<s>', 'The'),
#  ('<s>', 'The', 'jury'),
#  ('The', 'jury', 'also'),
#  ('jury', 'also', 'commented'),
#  ('also', 'commented', 'on'),
#  ('commented', 'on', 'the'),
#  ('on', 'the', 'Fulton'),
#  ('the', 'Fulton', "ordinary's"),
#  ('Fulton', "ordinary's", 'court'),
#  ("ordinary's", 'court', 'which'),
#  ('court', 'which', 'has'),
#  ('which', 'has', 'been'),
#  ('has', 'been', 'under'),
#  ('been', 'under', 'fire'),
#  ('under', 'fire', 'for'),
#  ('fire', 'for', 'its'),
#  ('for', 'its', 'practices'),
#  ('its', 'practices', 'in'),
#  ('practices', 'in', 'the'),
#  ('in', 'the', 'appointment'),
#  ('the', 'appointment', 'of'),
#  ('appointment', 'of', 'appraisers'),
#  ('of', 'appraisers', ','),
#  ('appraisers', ',', 'guardians'),
#  (',', 'guardians', 'and'),
#  ('guardians', 'and', 'administrators'),
#  ('and', 'administrators', 'and'),
#  ('administrators', 'and', 'the'),
#  ('and', 'the', 'awarding'),
#  ('the', 'awarding', 'of'),
#  ('awarding', 'of', 'fees'),
#  ('of', 'fees', 'and'),
#  ('fees', 'and', 'compensation'),
#  ('and', 'compensation', '.'),
#  ('compensation', '.', '</s>'),
#  ('.', '</s>', '<s>'),
#  ('</s>', '<s>', 'Wards'),
#  ('<s>', 'Wards', 'protected'),
#  ('Wards', 'protected', '</s>'),
#  ('protected', '</s>', '<s>'),
#  ('</s>', '<s>', 'The'),
#  ('<s>', 'The', 'jury'),
#  ('The', 'jury', 'said'),
#  ('jury', 'said', 'it'),
#  ('said', 'it', 'found'),
#  ('it', 'found', 'the'),
#  ('found', 'the', 'court'),
#  ('the', 'court', '``'),
#  ('court', '``', 'has'),
#  ('``', 'has', 'incorporated'),
#  ('has', 'incorporated', 'into'),
#  ('incorporated', 'into', 'its'),
#  ('into', 'its', 'operating'),
#  ('its', 'operating', 'procedures'),
#  ('operating', 'procedures', 'the'),
#  ('procedures', 'the', 'recommendations'),
#  ('the', 'recommendations', "''"),
#  ('recommendations', "''", 'of'),
#  ("''", 'of', 'two'),
#  ('of', 'two', 'previous'),
#  ('two', 'previous', 'grand'),
#  ('previous', 'grand', 'juries'),
#  ('grand', 'juries', ','),
#  ('juries', ',', 'the'),
#  (',', 'the', 'Atlanta'),
#  ('the', 'Atlanta', 'Bar'),
#  ('Atlanta', 'Bar', 'Association'),
#  ('Bar', 'Association', 'and'),
#  ('Association', 'and', 'an'),
#  ('and', 'an', 'interim'),
#  ('an', 'interim', 'citizens'),
#  ('interim', 'citizens', 'committee'),
#  ('citizens', 'committee', '.'),
#  ('committee', '.', '</s>'),
#  ('.', '</s>', '<s>'),
#  ('</s>', '<s>', '``'),
#  ('<s>', '``', 'These'),
#  ('``', 'These', 'actions'),
#  ('These', 'actions', 'should'),
#  ('actions', 'should', 'serve'),
#  ('should', 'serve', 'to'),
#  ('serve', 'to', 'protect'),
#  ('to', 'protect', 'in'),
#  ('protect', 'in', 'fact'),
#  ('in', 'fact', 'and'),
#  ('fact', 'and', 'in'),
#  ('and', 'in', 'effect'),
#  ('in', 'effect', 'the'),
#  ('effect', 'the', "court's"),
#  ('the', "court's", 'wards'),
#  ("court's", 'wards', 'from'),
#  ('wards', 'from', 'undue'),
#  ('from', 'undue', 'costs'),
#  ('undue', 'costs', 'and'),
#  ('costs', 'and', 'its'),
#  ('and', 'its', 'appointed'),
#  ('its', 'appointed', 'and'),
#  ('appointed', 'and', 'elected'),
#  ('and', 'elected', 'servants'),
#  ('elected', 'servants', 'from'),
#  ('servants', 'from', 'unmeritorious'),
#  ('from', 'unmeritorious', 'criticisms'),
#  ('unmeritorious', 'criticisms', "''"),
#  ('criticisms', "''", ','),
#  ("''", ',', 'the'),
#  (',', 'the', 'jury'),
#  ('the', 'jury', 'said'),
#  ('jury', 'said', '.'),
#  ('said', '.', '</s>'),
#  ('.', '</s>', '<s>'),
#  ('</s>', '<s>', 'Regarding'),
#  ('<s>', 'Regarding', "Atlanta's"),
#  ('Regarding', "Atlanta's", 'new'),
#  ("Atlanta's", 'new', 'multi-million-dollar'),
#  ('new', 'multi-million-dollar', 'airport'),
#  ('multi-million-dollar', 'airport', ','),
#  ('airport', ',', 'the'),
#  (',', 'the', 'jury'),
#  ('the', 'jury', 'recommended'),
#  ('jury', 'recommended', '``'),
#  ('recommended', '``', 'that'),
#  ('``', 'that', 'when'),
#  ('that', 'when', 'the'),
#  ('when', 'the', 'new'),
#  ('the', 'new', 'management'),
#  ('new', 'management', 'takes'),
#  ('management', 'takes', 'charge'),
#  ('takes', 'charge', 'Jan.'),
#  ('charge', 'Jan.', '1'),
#  ('Jan.', '1', 'the'),
#  ('1', 'the', 'airport'),
#  ('the', 'airport', 'be'),
#  ('airport', 'be', 'operated'),
#  ('be', 'operated', 'in'),
#  ('operated', 'in', 'a'),
#  ('in', 'a', 'manner'),
#  ('a', 'manner', 'that'),
#  ('manner', 'that', 'will'),
#  ('that', 'will', 'eliminate'),
#  ('will', 'eliminate', 'political'),
#  ('eliminate', 'political', 'influences'),
#  ('political', 'influences', "''"),
#  ('influences', "''", '.'),
#  ("''", '.', '</s>'),
#  ('.', '</s>', '<s>'),
#  ('</s>', '<s>', 'The'),
#  ('<s>', 'The', 'jury'),
#  ('The', 'jury', 'did'),
#  ('jury', 'did', 'not'),
#  ('did', 'not', 'elaborate'),
#  ('not', 'elaborate', ','),
#  ('elaborate', ',', 'but'),
#  (',', 'but', 'it'),
#  ('but', 'it', 'added'),
#  ('it', 'added', 'that'),
#  ('added', 'that', '``'),
#  ('that', '``', 'there'),
#  ('``', 'there', 'should'),
#  ('there', 'should', 'be'),
#  ('should', 'be', 'periodic'),
#  ('be', 'periodic', 'surveillance'),
#  ('periodic', 'surveillance', 'of'),
#  ('surveillance', 'of', 'the'),
#  ('of', 'the', 'pricing'),
#  ('the', 'pricing', 'practices'),
#  ('pricing', 'practices', 'of'),
#  ('practices', 'of', 'the'),
#  ('of', 'the', 'concessionaires'),
#  ('the', 'concessionaires', 'for'),
#  ('concessionaires', 'for', 'the'),
#  ('for', 'the', 'purpose'),
#  ('the', 'purpose', 'of'),
#  ('purpose', 'of', 'keeping'),
#  ('of', 'keeping', 'the'),
#  ('keeping', 'the', 'prices'),
#  ('the', 'prices', 'reasonable'),
#  ('prices', 'reasonable', "''"),
#  ('reasonable', "''", '.'),
#  ("''", '.', '</s>'),
#  ('.', '</s>', '<s>'),
#  ('</s>', '<s>', 'Ask'),
#  ('<s>', 'Ask', 'jail'),
#  ('Ask', 'jail', 'deputies'),
#  ('jail', 'deputies', '</s>'),
#  ('deputies', '</s>', '<s>'),
#  ('</s>', '<s>', 'On'),
#  ('<s>', 'On', 'other'),
#  ('On', 'other', 'matters'),
#  ('other', 'matters', ','),
#  ('matters', ',', 'the'),
#  (',', 'the', 'jury'),
#  ('the', 'jury', 'recommended'),
#  ('jury', 'recommended', 'that'),
#  ('recommended', 'that', ':'),
#  ('that', ':', '('),
#  (':', '(', '1'),
#  ('(', '1', ')'),
#  ('1', ')', '</s>'),
#  (')', '</s>', '<s>'),
#  ('</s>', '<s>', 'Four'),
#  ('<s>', 'Four', 'additional'),
#  ('Four', 'additional', 'deputies'),
#  ('additional', 'deputies', 'be'),
#  ('deputies', 'be', 'employed'),
#  ('be', 'employed', 'at'),
#  ('employed', 'at', 'the'),
#  ('at', 'the', 'Fulton'),
#  ('the', 'Fulton', 'County'),
#  ('Fulton', 'County', 'Jail'),
#  ('County', 'Jail', 'and'),
#  ('Jail', 'and', '``'),
#  ('and', '``', 'a'),
#  ('``', 'a', 'doctor'),
#  ('a', 'doctor', ','),
#  ('doctor', ',', 'medical'),
#  (',', 'medical', 'intern'),
#  ('medical', 'intern', 'or'),
#  ('intern', 'or', 'extern'),
#  ('or', 'extern', 'be'),
#  ('extern', 'be', 'employed'),
#  ('be', 'employed', 'for'),
#  ('employed', 'for', 'night'),
#  ('for', 'night', 'and'),
#  ('night', 'and', 'weekend'),
#  ('and', 'weekend', 'duty'),
#  ('weekend', 'duty', 'at'),
#  ('duty', 'at', 'the'),
#  ('at', 'the', 'jail'),
#  ('the', 'jail', "''"),
#  ('jail', "''", '.'),
#  ("''", '.', '</s>'),
#  ('.', '</s>', '<s>'),
#  ('</s>', '<s>', '('),
#  ('<s>', '(', '2'),
#  ('(', '2', ')'),
#  ('2', ')', '</s>'),
#  (')', '</s>', '<s>'),
#  ('</s>', '<s>', 'Fulton'),
#  ('<s>', 'Fulton', 'legislators'),
#  ('Fulton', 'legislators', '``'),
#  ('legislators', '``', 'work'),
#  ('``', 'work', 'with'),
#  ('work', 'with', 'city'),
#  ('with', 'city', 'officials'),
#  ('city', 'officials', 'to'),
#  ('officials', 'to', 'pass'),
#  ('to', 'pass', 'enabling'),
#  ('pass', 'enabling', 'legislation'),
#  ('enabling', 'legislation', 'that'),
#  ('legislation', 'that', 'will'),
#  ('that', 'will', 'permit'),
#  ('will', 'permit', 'the'),
#  ('permit', 'the', 'establishment'),
#  ('the', 'establishment', 'of'),
#  ('establishment', 'of', 'a'),
#  ('of', 'a', 'fair'),
#  ('a', 'fair', 'and'),
#  ('fair', 'and', 'equitable'),
#  ('and', 'equitable', "''"),
#  ('equitable', "''", 'pension'),
#  ("''", 'pension', 'plan'),
#  ('pension', 'plan', 'for'),
#  ('plan', 'for', 'city'),
#  ('for', 'city', 'employes'),
#  ('city', 'employes', '.'),
#  ('employes', '.', '</s>'),
#  ('.', '</s>', '<s>'),
#  ('</s>', '<s>', 'The'),
#  ('<s>', 'The', 'jury'),
#  ('The', 'jury', 'praised'),
#  ('jury', 'praised', 'the'),
#  ('praised', 'the', 'administration'),
#  ('the', 'administration', 'and'),
#  ('administration', 'and', 'operation'),
#  ('and', 'operation', 'of'),
#  ('operation', 'of', 'the'),
#  ('of', 'the', 'Atlanta'),
#  ('the', 'Atlanta', 'Police'),
#  ('Atlanta', 'Police', 'Department'),
#  ('Police', 'Department', ','),
#  ('Department', ',', 'the'),
#  (',', 'the', 'Fulton'),
#  ('the', 'Fulton', 'Tax'),
#  ('Fulton', 'Tax', "Commissioner's"),
#  ('Tax', "Commissioner's", 'Office'),
#  ("Commissioner's", 'Office', ','),
#  ('Office', ',', 'the'),
#  (',', 'the', 'Bellwood'),
#  ('the', 'Bellwood', 'and'),
#  ('Bellwood', 'and', 'Alpharetta'),
#  ('and', 'Alpharetta', 'prison'),
#  ('Alpharetta', 'prison', 'farms'),
#  ('prison', 'farms', ','),
#  ('farms', ',', 'Grady'),
#  (',', 'Grady', 'Hospital'),
#  ('Grady', 'Hospital', 'and'),
#  ('Hospital', 'and', 'the'),
#  ('and', 'the', 'Fulton'),
#  ('the', 'Fulton', 'Health'),
#  ('Fulton', 'Health', 'Department'),
#  ('Health', 'Department', '.'),
#  ('Department', '.', '</s>'),
#  ('.', '</s>', '<s>'),
#  ('</s>', '<s>', 'Mayor'),
#  ('<s>', 'Mayor', 'William'),
#  ('Mayor', 'William', 'B.'),
#  ('William', 'B.', 'Hartsfield'),
#  ('B.', 'Hartsfield', 'filed'),
#  ('Hartsfield', 'filed', 'suit'),
#  ('filed', 'suit', 'for'),
#  ('suit', 'for', 'divorce'),
#  ('for', 'divorce', 'from'),
#  ('divorce', 'from', 'his'),
#  ('from', 'his', 'wife'),
#  ('his', 'wife', ','),
#  ('wife', ',', 'Pearl'),
#  (',', 'Pearl', 'Williams'),
#  ('Pearl', 'Williams', 'Hartsfield'),
#  ('Williams', 'Hartsfield', ','),
#  ('Hartsfield', ',', 'in'),
#  (',', 'in', 'Fulton'),
#  ('in', 'Fulton', 'Superior'),
#  ('Fulton', 'Superior', 'Court'),
#  ('Superior', 'Court', 'Friday'),
#  ('Court', 'Friday', '.'),
#  ('Friday', '.', '</s>'),
#  ('.', '</s>', '<s>'),
#  ('</s>', '<s>', 'His'),
#  ('<s>', 'His', 'petition'),
#  ('His', 'petition', 'charged'),
#  ('petition', 'charged', 'mental'),
#  ('charged', 'mental', 'cruelty'),
#  ('mental', 'cruelty', '.'),
#  ('cruelty', '.', '</s>'),
#  ('.', '</s>', '<s>'),
#  ('</s>', '<s>', 'The'),
#  ('<s>', 'The', 'couple'),
#  ('The', 'couple', 'was'),
#  ('couple', 'was', 'married'),
#  ('was', 'married', 'Aug.'),
#  ('married', 'Aug.', '2'),
#  ('Aug.', '2', ','),
#  ('2', ',', '1913'),
#  (',', '1913', '.'),
#  ('1913', '.', '</s>'),
#  ('.', '</s>', '<s>'),
#  ('</s>', '<s>', 'They'),
#  ('<s>', 'They', 'have'),
#  ('They', 'have', 'a'),
#  ('have', 'a', 'son'),
#  ('a', 'son', ','),
#  ('son', ',', 'William'),
#  (',', 'William', 'Berry'),
#  ('William', 'Berry', 'Jr.'),
#  ('Berry', 'Jr.', ','),
#  ('Jr.', ',', 'and'),
#  (',', 'and', 'a'),
#  ('and', 'a', 'daughter'),
#  ('a', 'daughter', ','),
#  ('daughter', ',', 'Mrs.'),
#  (',', 'Mrs.', 'J.'),
#  ('Mrs.', 'J.', 'M.'),
#  ('J.', 'M.', 'Cheshire'),
#  ('M.', 'Cheshire', 'of'),
#  ('Cheshire', 'of', 'Griffin'),
#  ('of', 'Griffin', '.'),
#  ('Griffin', '.', '</s>'),
#  ('.', '</s>', '<s>'),
#  ('</s>', '<s>', 'Attorneys'),
#  ('<s>', 'Attorneys', 'for'),
#  ('Attorneys', 'for', 'the'),
#  ('for', 'the', 'mayor'),
#  ('the', 'mayor', 'said'),
#  ('mayor', 'said', 'that'),
#  ('said', 'that', 'an'),
#  ('that', 'an', 'amicable'),
#  ('an', 'amicable', 'property'),
#  ('amicable', 'property', 'settlement'),
#  ('property', 'settlement', 'has'),
#  ('settlement', 'has', 'been'),
#  ('has', 'been', 'agreed'),
#  ('been', 'agreed', 'upon'),
#  ('agreed', 'upon', '.'),
#  ('upon', '.', '</s>'),
#  ('.', '</s>', '<s>'),
#  ('</s>', '<s>', 'The'),
#  ('<s>', 'The', 'petition'),
#  ('The', 'petition', 'listed'),
#  ('petition', 'listed', 'the'),
#  ('listed', 'the', "mayor's"),
#  ('the', "mayor's", 'occupation'),
#  ("mayor's", 'occupation', 'as'),
#  ('occupation', 'as', '``'),
#  ('as', '``', 'attorney'),
#  ('``', 'attorney', "''"),
#  ('attorney', "''", 'and'),
#  ("''", 'and', 'his'),
#  ('and', 'his', 'age'),
#  ('his', 'age', 'as'),
#  ('age', 'as', '71'),
#  ('as', '71', '.'),
#  ('71', '.', '</s>'),
#  ('.', '</s>', '<s>'),
#  ('</s>', '<s>', 'It'),
#  ('<s>', 'It', 'listed'),
#  ('It', 'listed', 'his'),
#  ('listed', 'his', "wife's"),
#  ('his', "wife's", 'age'),
#  ("wife's", 'age', 'as'),
#  ('age', 'as', '74'),
#  ('as', '74', 'and'),
#  ('74', 'and', 'place'),
#  ('and', 'place', 'of'),
#  ('place', 'of', 'birth'),
#  ('of', 'birth', 'as'),
#  ('birth', 'as', 'Opelika'),
#  ('as', 'Opelika', ','),
#  ('Opelika', ',', 'Ala.'),
#  (',', 'Ala.', '.'),
#  ('Ala.', '.', '</s>'),
#  ('.', '</s>', '<s>'),
#  ('</s>', '<s>', 'The'),
#  ('<s>', 'The', 'petition'),
#  ('The', 'petition', 'said'),
#  ('petition', 'said', 'that'),
#  ('said', 'that', 'the'),
#  ('that', 'the', 'couple'),
#  ('the', 'couple', 'has'),
#  ('couple', 'has', 'not'),
#  ('has', 'not', 'lived'),
#  ('not', 'lived', 'together'),
#  ('lived', 'together', 'as'),
#  ('together', 'as', 'man'),
#  ('as', 'man', 'and'),
#  ('man', 'and', 'wife'),
#  ('and', 'wife', 'for'),
#  ('wife', 'for', 'more'),
#  ('for', 'more', 'than'),
#  ('more', 'than', 'a'),
#  ('than', 'a', 'year'),
#  ('a', 'year', '.'),
#  ('year', '.', '</s>'),
#  ('.', '</s>', '<s>'),
#  ('</s>', '<s>', 'The'),
#  ('<s>', 'The', 'Hartsfield'),
#  ('The', 'Hartsfield', 'home'),
#  ('Hartsfield', 'home', 'is'),
#  ('home', 'is', 'at'),
#  ('is', 'at', '637'),
#  ('at', '637', 'E.'),
#  ('637', 'E.', 'Pelham'),
#  ('E.', 'Pelham', 'Rd.'),
#  ('Pelham', 'Rd.', 'Aj'),
#  ('Rd.', 'Aj', '.'),
#  ('Aj', '.', '</s>'),
#  ('.', '</s>', '<s>'),
#  ('</s>', '<s>', 'Henry'),
#  ('<s>', 'Henry', 'L.'),
#  ('Henry', 'L.', 'Bowden'),
#  ('L.', 'Bowden', 'was'),
#  ('Bowden', 'was', 'listed'),
#  ('was', 'listed', 'on'),
#  ('listed', 'on', 'the'),
#  ('on', 'the', 'petition'),
#  ('the', 'petition', 'as'),
#  ('petition', 'as', 'the'),
#  ('as', 'the', "mayor's"),
#  ('the', "mayor's", 'attorney'),
#  ("mayor's", 'attorney', '.'),
#  ('attorney', '.', '</s>'),
#  ('.', '</s>', '<s>'),
#  ('</s>', '<s>', 'Hartsfield'),
#  ('<s>', 'Hartsfield', 'has'),
#  ('Hartsfield', 'has', 'been'),
#  ('has', 'been', 'mayor'),
#  ('been', 'mayor', 'of'),
#  ('mayor', 'of', 'Atlanta'),
#  ...]

# %% [markdown]
# ### bigrams_webtext

# %%
bgrams_webtext
# Out:
# [('<s>', 'Cookie'),
#  ('Cookie', 'Manager'),
#  ('Manager', ':'),
#  (':', '"'),
#  ('"', 'Don'),
#  ('Don', "'"),
#  ("'", 't'),
#  ('t', 'allow'),
#  ('allow', 'sites'),
#  ('sites', 'that'),
#  ('that', 'set'),
#  ('set', 'removed'),
#  ('removed', 'cookies'),
#  ('cookies', 'to'),
#  ('to', 'set'),
#  ('set', 'future'),
#  ('future', 'cookies'),
#  ('cookies', '"'),
#  ('"', 'should'),
#  ('should', 'stay'),
#  ('stay', 'checked'),
#  ('checked', 'When'),
#  ('When', 'in'),
#  ('in', 'full'),
#  ('full', 'screen'),
#  ('screen', 'mode'),
#  ('mode', 'Pressing'),
#  ('Pressing', 'Ctrl'),
#  ('Ctrl', '-'),
#  ('-', 'N'),
#  ('N', 'should'),
#  ('should', 'open'),
#  ('open', 'a'),
#  ('a', 'new'),
#  ('new', 'browser'),
#  ('browser', 'when'),
#  ('when', 'only'),
#  ('only', 'download'),
#  ('download', 'dialog'),
#  ('dialog', 'is'),
#  ('is', 'left'),
#  ('left', 'open'),
#  ('open', 'add'),
#  ('add', 'icons'),
#  ('icons', 'to'),
#  ('to', 'context'),
#  ('context', 'menu'),
#  ('menu', 'So'),
#  ('So', 'called'),
#  ('called', '"'),
#  ('"', 'tab'),
#  ('tab', 'bar'),
#  ('bar', '"'),
#  ('"', 'should'),
#  ('should', 'be'),
#  ('be', 'made'),
#  ('made', 'a'),
#  ('a', 'proper'),
#  ('proper', 'toolbar'),
#  ('toolbar', 'or'),
#  ('or', 'given'),
#  ('given', 'the'),
#  ('the', 'ability'),
#  ('ability', 'collapse'),
#  ('collapse', '/'),
#  ('/', 'expand'),
#  ('expand', '.'),
#  ('.', '</s>'),
#  ('</s>', '<s>'),
#  ('<s>', '['),
#  ('[', 'XUL'),
#  ('XUL', ']'),
#  (']', 'Implement'),
#  ('Implement', 'Cocoa'),
#  ('Cocoa', '-'),
#  ('-', 'style'),
#  ('style', 'toolbar'),
#  ('toolbar', 'customization'),
#  ('customization', '.'),
#  ('.', '</s>'),
#  ('</s>', '<s>'),
#  ('<s>', '#'),
#  ('#', 'ifdefs'),
#  ('ifdefs', 'for'),
#  ('for', 'MOZ_PHOENIX'),
#  ('MOZ_PHOENIX', 'customize'),
#  ('customize', 'dialog'),
#  ('dialog', "'"),
#  ("'", 's'),
#  ('s', 'toolbar'),
#  ('toolbar', 'has'),
#  ('has', 'small'),
#  ('small', 'icons'),
#  ('icons', 'when'),
#  ('when', 'small'),
#  ('small', 'icons'),
#  ('icons', 'is'),
#  ('is', 'not'),
#  ('not', 'checked'),
#  ('checked', 'nightly'),
#  ('nightly', 'builds'),
#  ('builds', 'and'),
#  ('and', 'tinderboxen'),
#  ('tinderboxen', 'for'),
#  ('for', 'Phoenix'),
#  ('Phoenix', 'finish'),
#  ('finish', 'tearing'),
#  ('tearing', 'prefs'),
#  ('prefs', 'UI'),
#  ('UI', 'to'),
#  ('to', 'pieces'),
#  ('pieces', 'and'),
#  ('and', 'then'),
#  ('then', 'make'),
#  ('make', 'it'),
#  ('it', 'not'),
#  ('not', 'suck'),
#  ('suck', '"'),
#  ('"', 'mozbrowser'),
#  ('mozbrowser', '"'),
#  ('"', 'script'),
#  ('script', 'doesn'),
#  ('doesn', "'"),
#  ("'", 't'),
#  ('t', 'start'),
#  ('start', 'correct'),
#  ('correct', 'binary'),
#  ('binary', 'Need'),
#  ('Need', 'bookmark'),
#  ('bookmark', 'groups'),
#  ('groups', 'icon'),
#  ('icon', 'Dropping'),
#  ('Dropping', 'at'),
#  ('at', 'top'),
#  ('top', 'of'),
#  ('of', 'palette'),
#  ('palette', 'box'),
#  ('box', 'horks'),
#  ('horks', 'things'),
#  ('things', 'keyboard'),
#  ('keyboard', 'shortcut'),
#  ('shortcut', 'for'),
#  ('for', 'Increase'),
#  ('Increase', 'Text'),
#  ('Text', 'Size'),
#  ('Size', 'is'),
#  ('is', 'broken'),
#  ('broken', 'default'),
#  ('default', 'phoenix'),
#  ('phoenix', 'bookmarks'),
#  ('bookmarks', '['),
#  ('[', 'cust'),
#  ('cust', ']'),
#  (']', 'need'),
#  ('need', 'a'),
#  ('a', 'toolbar'),
#  ('toolbar', 'spacer'),
#  ('spacer', 'and'),
#  ('and', 'spring'),
#  ('spring', 'spacer'),
#  ('spacer', 'for'),
#  ('for', 'customize'),
#  ('customize', 'Can'),
#  ('Can', "'"),
#  ("'", 't'),
#  ('t', 'launch'),
#  ('launch', 'phoenix'),
#  ('phoenix', 'while'),
#  ('while', 'Mozilla'),
#  ('Mozilla', 'is'),
#  ('is', 'running'),
#  ('running', '('),
#  ('(', 'or'),
#  ('or', 'vice'),
#  ('vice', 'versa'),
#  ('versa', ')'),
#  (')', 'separator'),
#  ('separator', 'not'),
#  ('not', 'available'),
#  ('available', 'when'),
#  ('when', 'all'),
#  ('all', 'toolbar'),
#  ('toolbar', 'items'),
#  ('items', 'are'),
#  ('are', 'in'),
#  ('in', 'toolbar'),
#  ('toolbar', 'layout'),
#  ('layout', 'history'),
#  ('history', 'menu'),
#  ('menu', 'for'),
#  ('for', 'the'),
#  ('the', 'back'),
#  ('back', 'buttons'),
#  ('buttons', 'doesn'),
#  ('doesn', "'"),
#  ("'", 't'),
#  ('t', 'work'),
#  ('work', 'attempting'),
#  ('attempting', 'to'),
#  ('to', 'open'),
#  ('open', '"'),
#  ('"', 'back'),
#  ('back', 'button'),
#  ('button', 'history'),
#  ('history', 'menu'),
#  ('menu', '"'),
#  ('"', 'in'),
#  ('in', 'the'),
#  ('the', 'second'),
#  ('second', 'window'),
#  ('window', 'generates'),
#  ('generates', 'another'),
#  ('another', 'back'),
#  ('back', 'button'),
#  ('button', 'on'),
#  ('on', 'the'),
#  ('the', 'toolbar'),
#  ('toolbar', 'Phoenix'),
#  ('Phoenix', 'and'),
#  ('and', 'Mozilla'),
#  ('Mozilla', 'cannot'),
#  ('cannot', 'comfortably'),
#  ('comfortably', 'share'),
#  ('share', 'a'),
#  ('a', 'source'),
#  ('source', 'tree'),
#  ('tree', 'Phoenix'),
#  ('Phoenix', 'forgets'),
#  ('forgets', 'all'),
#  ('all', 'cookies'),
#  ('cookies', 'even'),
#  ('even', 'though'),
#  ('though', '"'),
#  ('"', 'Enable'),
#  ('Enable', 'cookies'),
#  ('cookies', 'for'),
#  ('for', 'the'),
#  ('the', 'current'),
#  ('current', 'session'),
#  ('session', 'only'),
#  ('only', '"'),
#  ('"', 'is'),
#  ('is', 'NOT'),
#  ('NOT', 'chosen'),
#  ('chosen', 'Starting'),
#  ('Starting', 'Customizing'),
#  ('Customizing', 'Toolbar'),
#  ('Toolbar', 'makes'),
#  ('makes', 'the'),
#  ('the', 'current'),
#  ('current', 'page'),
#  ('page', 'go'),
#  ('go', 'blank'),
#  ('blank', 'Check'),
#  ('Check', 'in'),
#  ('in', 'Satchel'),
#  ('Satchel', '('),
#  ('(', 'the'),
#  ('the', 'successor'),
#  ('successor', 'to'),
#  ('to', 'wallet'),
#  ('wallet', ')'),
#  (')', 'Mousing'),
#  ('Mousing', 'over'),
#  ('over', 'back'),
#  ('back', 'menu'),
#  ('menu', 'in'),
#  ('in', 'second'),
#  ('second', 'window'),
#  ('window', 'horks'),
#  ('horks', 'things'),
#  ('things', 'Personal'),
#  ('Personal', 'toolbar'),
#  ('toolbar', 'needs'),
#  ('needs', 'a'),
#  ('a', 'min'),
#  ('min', '-'),
#  ('-', 'height'),
#  ('height', 'to'),
#  ('to', 'avoid'),
#  ('avoid', '"'),
#  ('"', 'popping'),
#  ('popping', 'in'),
#  ('in', '"'),
#  ('"', 'New'),
#  ('New', 'Folder'),
#  ('Folder', '...'),
#  ('...', 'in'),
#  ('in', 'ptoolbar'),
#  ('ptoolbar', 'context'),
#  ('context', 'menu'),
#  ('menu', 'is'),
#  ('is', 'broken'),
#  ('broken', 'Implement'),
#  ('Implement', 'Mozilla'),
#  ('Mozilla', 'Firebird'),
#  ('Firebird', 'Help'),
#  ('Help', 'tabs'),
#  ('tabs', 'close'),
#  ('close', 'in'),
#  ('in', 'the'),
#  ('the', 'wrong'),
#  ('wrong', 'order'),
#  ('order', '('),
#  ('(', 'right'),
#  ('right', 'to'),
#  ('to', 'left'),
#  ('left', ')'),
#  (')', 'back'),
#  ('back', 'buttons'),
#  ('buttons', 'and'),
#  ('and', 'context'),
#  ('context', 'options'),
#  ('options', 'always'),
#  ('always', 'disabled'),
#  ('disabled', '.'),
#  ('.', '</s>'),
#  ('</s>', '<s>'),
#  ('<s>', 'Customising'),
#  ('Customising', 'toolbar'),
#  ('toolbar', 'breaks'),
#  ('breaks', 'the'),
#  ('the', 'throbber'),
#  ('throbber', '!'),
#  ('!', '</s>'),
#  ('</s>', '<s>'),
#  ('<s>', 'manage'),
#  ('manage', 'bookmarks'),
#  ('bookmarks', 'causes'),
#  ('causes', 'hang'),
#  ('hang', 'land'),
#  ('land', 'pch'),
#  ('pch', "'"),
#  ("'", 's'),
#  ('s', 'bookmarks'),
#  ('bookmarks', 'patch'),
#  ('patch', 'from'),
#  ('from', 'bug'),
#  ('bug', '160019'),
#  ('160019', 'Preferences'),
#  ('Preferences', '>'),
#  ('>', 'Privacy'),
#  ('Privacy', '>'),
#  ('>', 'Images'),
#  ('Images', '=='),
#  ('==', 'Wonky'),
#  ('Wonky', 'Extremely'),
#  ('Extremely', 'high'),
#  ('high', 'memory'),
#  ('memory', 'consumption'),
#  ('consumption', 'after'),
#  ('after', 'closing'),
#  ('closing', 'all'),
#  ('all', 'windows'),
#  ('windows', 'with'),
#  ('with', 'Quick'),
#  ('Quick', 'Launch'),
#  ('Launch', '('),
#  ('(', 'Turbo'),
#  ('Turbo', ')'),
#  (')', 'enabled'),
#  ('enabled', 'Go'),
#  ('Go', 'menu'),
#  ('menu', 'needs'),
#  ('needs', 'to'),
#  ('to', 'have'),
#  ('have', 'an'),
#  ('an', 'id'),
#  ('id', '='),
#  ('=', 'implement'),
#  ('implement', 'progress'),
#  ('progress', 'meter'),
#  ('meter', 'in'),
#  ('in', 'URLbar'),
#  ('URLbar', 'view'),
#  ('view', 'source'),
#  ('source', 'tries'),
#  ('tries', 'to'),
#  ('to', 'download'),
#  ('download', 'type'),
#  ('type', 'application'),
#  ('application', 'x'),
#  ('x', '-'),
#  ('-', 'view'),
#  ('view', '-'),
#  ('-', 'source'),
#  ('source', 'from'),
#  ('from', 'view'),
#  ('view', '-'),
#  ('-', 'source'),
#  ('source', ':<'),
#  (':<', 'url'),
#  ('url', '>'),
#  ('>', 'second'),
#  ('second', 'window'),
#  ('window', 'opens'),
#  ('opens', 'mozilla'),
#  ('mozilla', 'fix'),
#  ('fix', 'branding'),
#  ('branding', 'auto'),
#  ('auto', 'close'),
#  ('close', 'for'),
#  ('for', 'download'),
#  ('download', 'manager'),
#  ('manager', 'would'),
#  ('would', 'be'),
#  ('be', 'nice'),
#  ('nice', 'Components'),
#  ('Components', 'of'),
#  ('of', 'the'),
#  ('the', 'Navigation'),
#  ('Navigation', 'Toolbar'),
#  ('Toolbar', 'do'),
#  ('do', 'not'),
#  ('not', 'appear'),
#  ('appear', 'with'),
#  ('with', 'the'),
#  ('the', 'Modern'),
#  ('Modern', 'theme'),
#  ('theme', '.'),
#  ('.', '</s>'),
#  ('</s>', '<s>'),
#  ('<s>', 'Pop'),
#  ('Pop', 'up'),
#  ('up', 'window'),
#  ('window', 'blocking'),
#  ('blocking', 'Uabar'),
#  ('Uabar', 'doesn'),
#  ('doesn', "'"),
#  ("'", 't'),
#  ('t', 'work'),
#  ('work', 'Theme'),
#  ('Theme', 'changes'),
#  ('changes', 'will'),
#  ('will', 'take'),
#  ('take', 'effect'),
#  ('effect', 'when'),
#  ('when', 'you'),
#  ('you', 'restart'),
#  ('restart', '_Mozilla_'),
#  ('_Mozilla_', '.'),
#  ('.', '</s>'),
#  ('</s>', '<s>'),
#  ('<s>', 'Need'),
#  ('Need', 'large'),
#  ('large', 'icons'),
#  ('icons', 'for'),
#  ('for', 'the'),
#  ('the', 'Options'),
#  ('Options', 'menu'),
#  ('menu', 'Enable'),
#  ('Enable', 'images'),
#  ('images', 'cannot'),
#  ('cannot', 'be'),
#  ('be', 'used'),
#  ('used', 'to'),
#  ('to', 'disable'),
#  ('disable', 'the'),
#  ('the', 'display'),
#  ('display', 'of'),
#  ('of', 'images'),
#  ('images', '.'),
#  ('.', '</s>'),
#  ('</s>', '<s>'),
#  ('<s>', 'The'),
#  ('The', 'bookmark'),
#  ('bookmark', 'tree'),
#  ('tree', 'jumps'),
#  ('jumps', 'unexpectedly'),
#  ('unexpectedly', 'to'),
#  ('to', 'the'),
#  ('the', 'bottom'),
#  ('bottom', 'of'),
#  ('of', 'its'),
#  ('its', 'view'),
#  ('view', 'when'),
#  ('when', 'the'),
#  ('the', 'the'),
#  ('the', 'first'),
#  ('first', 'visible'),
#  ('visible', 'row'),
#  ('row', 'is'),
#  ('is', 'not'),
#  ('not', 'the'),
#  ('the', 'first'),
#  ('first', 'one'),
#  ('one', 'Move'),
#  ('Move', 'bookmarks'),
#  ('bookmarks', 'transactions'),
#  ('transactions', 'into'),
#  ('into', 'a'),
#  ('a', 'JS'),
#  ('JS', 'service'),
#  ('service', '('),
#  ('(', 'adding'),
#  ('adding', 'a'),
#  ('a', 'bookmark'),
#  ('bookmark', 'leaks'),
#  ('leaks', 'the'),
#  ('the', 'Add'),
#  ('Add', 'Bookmark'),
#  ('Bookmark', 'dialog'),
#  ('dialog', ')'),
#  (')', 'Shortcut'),
#  ('Shortcut', 'Ctrl'),
#  ('Ctrl', '-'),
#  ('-', 'Y'),
#  ('Y', '('),
#  ('(', 'redo'),
#  ('redo', ')'),
#  (')', 'does'),
#  ('does', 'not'),
#  ('not', 'work'),
#  ('work', 'in'),
#  ('in', 'Bookmarks'),
#  ('Bookmarks', 'Manager'),
#  ('Manager', 'Eradicate'),
#  ('Eradicate', 'AddBookmarkImmediately'),
#  ('AddBookmarkImmediately', 'Deleting'),
#  ('Deleting', 'a'),
#  ('a', 'selection'),
#  ('selection', 'should'),
#  ('should', 'select'),
#  ('select', 'the'),
#  ('the', 'next'),
#  ('next', 'item'),
#  ('item', 'transaction'),
#  ('transaction', 'manager'),
#  ('manager', 'does'),
#  ('does', 'not'),
#  ('not', 'handle'),
#  ('handle', 'import'),
#  ('import', 'customize'),
#  ('customize', 'toolbar'),
#  ('toolbar', 'clears'),
#  ('clears', 'URL'),
#  ('URL', '3'),
#  ('3', '.'),
#  ('.', '2'),
#  ('2', '%'),
#  ('%', 'increase'),
#  ('increase', 'in'),
#  ('in', 'Phoenix'),
#  ('Phoenix', 'Ts'),
#  ('Ts', 'after'),
#  ('after', 'bookmark'),
#  ('bookmark', 'landing'),
#  ('landing', 'cannot'),
#  ('cannot', 'close'),
#  ('close', 'folder'),
#  ('folder', 'with'),
#  ('with', 'single'),
#  ('single', 'click'),
#  ('click', 'on'),
#  ('on', 'twistie'),
#  ('twistie', 'Pref'),
#  ('Pref', 'UI'),
#  ('UI', 'to'),
#  ('to', 'specify'),
#  ('specify', 'a'),
#  ('a', 'proxy'),
#  ('proxy', 'server'),
#  ('server', 'for'),
#  ('for', 'web'),
#  ('web', 'navigation'),
#  ('navigation', 'Implement'),
#  ('Implement', 'improved'),
#  ('improved', 'Implement'),
#  ('Implement', 'global'),
#  ('global', 'Go'),
#  ('Go', 'menu'),
#  ('menu', 'Readd'),
#  ('Readd', 'Open'),
#  ('Open', 'Location'),
#  ('Location', 'Need'),
#  ('Need', 'tab'),
#  ('tab', 'loading'),
#  ('loading', 'icon'),
#  ('icon', 'first'),
#  ('first', 'Mozilla'),
#  ('Mozilla', 'Firefox'),
#  ('Firefox', 'window'),
#  ('window', 'ignored'),
#  ('ignored', 'by'),
#  ('by', 'nsIWindowMediator'),
#  ('nsIWindowMediator', 'first'),
#  ('first', 'Phoenix'),
#  ('Phoenix', 'window'),
#  ('window', 'ignored'),
#  ('ignored', 'by'),
#  ('by', 'nsIWindowMediator'),
#  ('nsIWindowMediator', 'preferences'),
#  ('preferences', 'no'),
#  ('no', 'longer'),
#  ('longer', 'works'),
#  ('works', 'Open'),
#  ('Open', 'Personal'),
#  ('Personal', 'Toolbar'),
#  ('Toolbar', 'folder'),
#  ('folder', 'in'),
#  ('in', 'toolbar'),
#  ('toolbar', 'web'),
#  ('web', 'search'),
#  ('search', 'for'),
#  ('for', '""'),
#  ('""', 'in'),
#  ('in', 'context'),
#  ('context', 'menu'),
#  ('menu', 'don'),
#  ('don', "'"),
#  ("'", 't'),
#  ('t', 'work'),
#  ('work', 'Fix'),
#  ('Fix', 'full'),
#  ('full', 'screen'),
#  ('screen', 'to'),
#  ('to', 'have'),
#  ('have', 'smaller'),
#  ('smaller', 'icons'),
#  ('icons', 'Port'),
#  ('Port', 'patch'),
#  ('patch', 'to'),
#  ('to', 'bug'),
#  ('bug', '164006'),
#  ('164006', '('),
#  ('(', 'wyciwyg'),
#  ('wyciwyg', ':'),
#  (':', 'in'),
#  ('in', 'tab'),
#  ('tab', 'titles'),
#  ('titles', ')'),
#  (')', '['),
#  ('[', 'cust'),
#  ('cust', ']'),
#  (']', 'Add'),
#  ('Add', 'more'),
#  ('more', 'off'),
#  ('off', '-'),
#  ('-', 'by'),
#  ('by', '-'),
#  ('-', 'default'),
#  ('default', 'toolbar'),
#  ('toolbar', 'buttons'),
#  ('buttons', 'textmode'),
#  ('textmode', 'buttons'),
#  ('buttons', 'need'),
#  ('need', 'hover'),
#  ('hover', 'state'),
#  ('state', 'enable'),
#  ('enable', 'nsITheme'),
#  ('nsITheme', 'form'),
#  ('form', 'control'),
#  ('control', 'goodness'),
#  ('goodness', 'for'),
#  ('for', 'Phoenix'),
#  ('Phoenix', 'rename'),
#  ('rename', 'executable'),
#  ('executable', 'and'),
#  ('and', 'profile'),
#  ('profile', 'dir'),
#  ('dir', 'Need'),
#  ('Need', 'to'),
#  ('to', 'enable'),
#  ('enable', 'wallet'),
#  ('wallet', '('),
#  ('(', 'password'),
#  ('password', 'manager'),
#  ('manager', 'manager'),
#  ('manager', 'manager'),
#  ('manager', ')'),
#  (')', 'New'),
#  ('New', 'Extension'),
#  ('Extension', 'Manager'),
#  ('Manager', 'the'),
#  ('the', 'changes'),
#  ('changes', 'to'),
#  ('to', 'mozbrowser'),
#  ('mozbrowser', 'too'),
#  ('too', 'confusing'),
#  ('confusing', 'and'),
#  ('and', 'too'),
#  ('too', 'much'),
#  ('much', 'Missing'),
#  ('Missing', 'proxy'),
#  ('proxy', 'image'),
#  ('image', 'Cannot'),
#  ('Cannot', 'File'),
#  ('File', '>'),
#  ('>', 'New'),
#  ('New', 'Bookmark'),
#  ('Bookmark', 'while'),
#  ('while', 'managing'),
#  ('managing', 'a'),
#  ('a', 'new'),
#  ('new', 'folder'),
#  ('folder', 'Bookmarks'),
#  ('Bookmarks', 'are'),
#  ('are', 'not'),
#  ('not', 'loaded'),
#  ('loaded', 'if'),
#  ('if', 'the'),
#  ('the', 'Personal'),
#  ('Personal', 'Toolbar'),
#  ('Toolbar', 'is'),
#  ('is', 'switched'),
#  ('switched', 'off'),
#  ('off', 'Pretty'),
#  ('Pretty', 'up'),
#  ('up', 'dns'),
#  ('dns', 'error'),
#  ('error', 'page'),
#  ('page', 'a'),
#  ('a', 'bit'),
#  ('bit', 'middle'),
#  ('middle', 'click'),
#  ('click', '('),
#  ('(', 'pt'),
#  ('pt', '+'),
#  ('+', 'bookmark'),
#  ('bookmark', 'menu'),
#  ('menu', ')'),
#  (')', 'loads'),
#  ('loads', 'in'),
#  ('in', 'the'),
#  ('the', 'current'),
#  ('current', 'tab'),
#  ('tab', '+'),
#  ('+', 'new'),
#  ('new', 'tab'),
#  ('tab', 'Nightly'),
#  ('Nightly', 'for'),
#  ('for', '22'),
#  ('22', 'Sept'),
#  ('Sept', 'displays'),
#  ('displays', 'page'),
#  ('page', 'details'),
#  ('details', 'above'),
#  ('above', 'window'),
#  ('window', 'Ctrl'),
#  ('Ctrl', '-'),
#  ('-', 'W'),
#  ('W', 'does'),
#  ('does', 'not'),
#  ('not', 'close'),
#  ('close', 'the'),
#  ('the', 'current'),
#  ('current', 'tab'),
#  ('tab', 'listboxes'),
#  ('listboxes', 'and'),
#  ('and', 'tree'),
#  ('tree', 'views'),
#  ('views', 'don'),
#  ('don', "'"),
#  ("'", 't'),
#  ('t', 'support'),
#  ('support', 'themes'),
#  ('themes', 'on'),
#  ('on', 'winxp'),
#  ('winxp', 'Ctrl'),
#  ('Ctrl', '+'),
#  ('+', 'Mousewheel'),
#  ('Mousewheel', 'should'),
#  ('should', 'resize'),
#  ('resize', 'text'),
#  ('text', 'bookmarks'),
#  ('bookmarks', 'should'),
#  ('should', 'import'),
#  ('import', 'Mozilla'),
#  ('Mozilla', "'"),
#  ("'", 's'),
#  ('s', 'bookmarks'),
#  ('bookmarks', 'Please'),
#  ('Please', 'tell'),
#  ('tell', 'people'),
#  ('people', 'to'),
#  ('to', 'use'),
#  ('use', 'a'),
#  ('a', 'new'),
#  ('new', 'profile'),
#  ('profile', '.'),
#  ('.', '</s>'),
#  ('</s>', '<s>'),
#  ('<s>', 'combine'),
#  ('combine', 'links'),
#  ('links', '+'),
#  ('+', 'toolbar'),
#  ('toolbar', 'File'),
#  ('File', '|'),
#  ('|', 'Import'),
#  ('Import', '...'),
#  ('...', 'does'),
#  ('does', 'not'),
#  ('not', 'work'),
#  ('work', 'cannot'),
#  ('cannot', 'import'),
#  ('import', '4'),
#  ('4', '.'),
#  ('.', 'x'),
#  ('x', 'About'),
#  ('About', 'dialog'),
#  ('dialog', 'weirdness'),
#  ('weirdness', 'Context'),
#  ('Context', 'menu'),
#  ('menu', 'doesn'),
#  ('doesn', "'"),
#  ("'", 't'),
#  ('t', 'appear'),
#  ('appear', 'when'),
#  ('when', 'right'),
#  ('right', 'clicking'),
#  ('clicking', 'on'),
#  ('on', 'disabled'),
#  ('disabled', 'forward'),
#  ('forward', 'or'),
#  ('or', 'back'),
#  ('back', 'can'),
#  ('can', "'"),
#  ("'", 't'),
#  ('t', 'specify'),
#  ('specify', 'cookie'),
#  ('cookie', 'details'),
#  ('details', 'Proxy'),
#  ('Proxy', 'settings'),
#  ('settings', 'in'),
#  ('in', 'prefs'),
#  ('prefs', '.'),
#  ('.', 'js'),
#  ('js', 'seem'),
#  ('seem', 'to'),
#  ('to', 'be'),
#  ('be', 'ignored'),
#  ('ignored', '...'),
#  ('...', '</s>'),
#  ('</s>', '<s>'),
#  ('<s>', 'Incorrectly'),
#  ('Incorrectly', 'renders'),
#  ('renders', 'various'),
#  ('various', 'web'),
#  ('web', 'pages'),
#  ('pages', 'Window'),
#  ('Window', 'won'),
#  ('won', "'"),
#  ("'", 't'),
#  ('t', 'show'),
#  ('show', 'completely'),
#  ('completely', 'Can'),
#  ('Can', "'"),
#  ("'", 't'),
#  ('t', 'change'),
#  ('change', 'privacy'),
#  ('privacy', 'settings'),
#  ('settings', '['),
#  ('[', 'Moz'),
#  ('Moz', ']'),
#  (']', 'Cannot'),
#  ('Cannot', 'set'),
#  ('set', '"'),
#  ('"', 'Imported'),
#  ('Imported', 'IE'),
#  ('IE', 'Favorites'),
#  ('Favorites', '"'),
#  ('"', 'to'),
#  ('to', 'default'),
#  ('default', 'personal'),
#  ('personal', 'toolbar'),
#  ('toolbar', 'folder'),
#  ('folder', 'pheonix'),
#  ('pheonix', 'Need'),
#  ('Need', 'smaller'),
#  ('smaller', 'throbber'),
#  ('throbber', 'to'),
#  ('to', 'use'),
#  ('use', 'with'),
#  ('with', 'small'),
#  ('small', 'icons'),
#  ('icons', 'Blank'),
#  ('Blank', 'URL'),
#  ('URL', 'bar'),
#  ('bar', 'after'),
#  ('after', 'using'),
#  ('using', 'Customize'),
#  ('Customize', 'Toolbar'),
#  ('Toolbar', 'Mousewheel'),
#  ('Mousewheel', 'does'),
#  ('does', 'not'),
#  ('not', 'scroll'),
#  ('scroll', 'web'),
#  ('web', 'page'),
#  ('page', 'ctrl'),
#  ('ctrl', '+'),
#  ('+', 'tab'),
#  ('tab', 'should'),
#  ('should', 'switch'),
#  ('switch', 'tabs'),
#  ('tabs', 'in'),
#  ('in', 'browser'),
#  ('browser', 'favicon'),
#  ('favicon', '.'),
#  ('.', 'ico'),
#  ('ico', 'colors'),
#  ('colors', 'render'),
#  ('render', 'improperly'),
#  ('improperly', 'in'),
#  ('in', 'tabs'),
#  ('tabs', 'and'),
#  ('and', 'URL'),
#  ('URL', 'bar'),
#  ('bar', '-'),
#  ('-', 'remote'),
#  ('remote', 'openurl'),
#  ('openurl', '()'),
#  ('()', 'opens'),
#  ('opens', 'Mozilla'),
#  ('Mozilla', 'window'),
#  ('window', 'if'),
#  ('if', 'Mozilla'),
#  ('Mozilla', 'is'),
#  ('is', 'running'),
#  ('running', 'make'),
#  ('make', 'preferences'),
#  ('preferences', 'resizable'),
#  ('resizable', 'Scroll'),
#  ('Scroll', 'bar'),
#  ('bar', 'becomes'),
#  ('becomes', 'blank'),
#  ('blank', 'fix'),
#  ('fix', 'addressbar'),
#  ('addressbar', 'dropdown'),
#  ('dropdown', 'icon'),
#  ('icon', 'for'),
#  ('for', 'linux'),
#  ('linux', '.'),
#  ('.', '</s>'),
#  ('</s>', '<s>'),
#  ('<s>', '"'),
#  ('"', 'Find'),
#  ('Find', 'Next'),
#  ('Next', '"'),
#  ('"', 'button'),
#  ('button', 'doesn'),
#  ('doesn', "'"),
#  ("'", 't'),
#  ('t', 'always'),
#  ('always', 'respond'),
#  ('respond', 'to'),
#  ('to', 'Enter'),
#  ('Enter', 'Ctrl'),
#  ('Ctrl', '+'),
#  ('+', 'Mousewheel'),
#  ('Mousewheel', 'should'),
#  ('should', 'cycle'),
#  ('cycle', 'tabs'),
#  ('tabs', 'A'),
#  ('A', 'new'),
#  ('new', 'icon'),
#  ('icon', 'for'),
#  ('for', 'Firebird'),
#  ('Firebird', '2nd'),
#  ('2nd', 'Copy'),
#  ('Copy', 'won'),
#  ('won', "'"),
#  ("'", 't'),
#  ('t', 'load'),
#  ('load', 'with'),
#  ('with', 'same'),
#  ('same', 'profile'),
#  ('profile', 'width'),
#  ('width', 'of'),
#  ('of', 'table'),
#  ('table', 'containing'),
#  ('containing', 'text'),
#  ('text', 'being'),
#  ('being', 'handled'),
#  ('handled', 'incorrectly'),
#  ('incorrectly', '('),
#  ('(', 'multiple'),
#  ('multiple', 'screenwidths'),
#  ('screenwidths', 'wide'),
#  ('wide', ')'),
#  (')', 'accessing'),
#  ('accessing', '"'),
#  ('"', 'navigator'),
#  ('navigator', '.'),
#  ('.', 'cookieEnabled'),
#  ('cookieEnabled', '"'),
#  ('"', 'produces'),
#  ('produces', '"'),
#  ('"', 'uncaught'),
#  ('uncaught', 'exception'),
#  ('exception', '"'),
#  ('"', 'Need'),
#  ('Need', 'Mozilla'),
#  ('Mozilla', 'Firebird'),
#  ('Firebird', 'newsgroup'),
#  ('newsgroup', 'Revive'),
#  ('Revive', 'XUL'),
#  ('XUL', 'preprocessor'),
#  ('preprocessor', 'Phoenix'),
#  ('Phoenix', 'needs'),
#  ('needs', 'talkback'),
#  ...]

# %% [markdown]
# ### trigrams_webtext

# %%
trigrams_webtext
# Out:
# [('<s>', 'Cookie', 'Manager'),
#  ('Cookie', 'Manager', ':'),
#  ('Manager', ':', '"'),
#  (':', '"', 'Don'),
#  ('"', 'Don', "'"),
#  ('Don', "'", 't'),
#  ("'", 't', 'allow'),
#  ('t', 'allow', 'sites'),
#  ('allow', 'sites', 'that'),
#  ('sites', 'that', 'set'),
#  ('that', 'set', 'removed'),
#  ('set', 'removed', 'cookies'),
#  ('removed', 'cookies', 'to'),
#  ('cookies', 'to', 'set'),
#  ('to', 'set', 'future'),
#  ('set', 'future', 'cookies'),
#  ('future', 'cookies', '"'),
#  ('cookies', '"', 'should'),
#  ('"', 'should', 'stay'),
#  ('should', 'stay', 'checked'),
#  ('stay', 'checked', 'When'),
#  ('checked', 'When', 'in'),
#  ('When', 'in', 'full'),
#  ('in', 'full', 'screen'),
#  ('full', 'screen', 'mode'),
#  ('screen', 'mode', 'Pressing'),
#  ('mode', 'Pressing', 'Ctrl'),
#  ('Pressing', 'Ctrl', '-'),
#  ('Ctrl', '-', 'N'),
#  ('-', 'N', 'should'),
#  ('N', 'should', 'open'),
#  ('should', 'open', 'a'),
#  ('open', 'a', 'new'),
#  ('a', 'new', 'browser'),
#  ('new', 'browser', 'when'),
#  ('browser', 'when', 'only'),
#  ('when', 'only', 'download'),
#  ('only', 'download', 'dialog'),
#  ('download', 'dialog', 'is'),
#  ('dialog', 'is', 'left'),
#  ('is', 'left', 'open'),
#  ('left', 'open', 'add'),
#  ('open', 'add', 'icons'),
#  ('add', 'icons', 'to'),
#  ('icons', 'to', 'context'),
#  ('to', 'context', 'menu'),
#  ('context', 'menu', 'So'),
#  ('menu', 'So', 'called'),
#  ('So', 'called', '"'),
#  ('called', '"', 'tab'),
#  ('"', 'tab', 'bar'),
#  ('tab', 'bar', '"'),
#  ('bar', '"', 'should'),
#  ('"', 'should', 'be'),
#  ('should', 'be', 'made'),
#  ('be', 'made', 'a'),
#  ('made', 'a', 'proper'),
#  ('a', 'proper', 'toolbar'),
#  ('proper', 'toolbar', 'or'),
#  ('toolbar', 'or', 'given'),
#  ('or', 'given', 'the'),
#  ('given', 'the', 'ability'),
#  ('the', 'ability', 'collapse'),
#  ('ability', 'collapse', '/'),
#  ('collapse', '/', 'expand'),
#  ('/', 'expand', '.'),
#  ('expand', '.', '</s>'),
#  ('.', '</s>', '<s>'),
#  ('</s>', '<s>', '['),
#  ('<s>', '[', 'XUL'),
#  ('[', 'XUL', ']'),
#  ('XUL', ']', 'Implement'),
#  (']', 'Implement', 'Cocoa'),
#  ('Implement', 'Cocoa', '-'),
#  ('Cocoa', '-', 'style'),
#  ('-', 'style', 'toolbar'),
#  ('style', 'toolbar', 'customization'),
#  ('toolbar', 'customization', '.'),
#  ('customization', '.', '</s>'),
#  ('.', '</s>', '<s>'),
#  ('</s>', '<s>', '#'),
#  ('<s>', '#', 'ifdefs'),
#  ('#', 'ifdefs', 'for'),
#  ('ifdefs', 'for', 'MOZ_PHOENIX'),
#  ('for', 'MOZ_PHOENIX', 'customize'),
#  ('MOZ_PHOENIX', 'customize', 'dialog'),
#  ('customize', 'dialog', "'"),
#  ('dialog', "'", 's'),
#  ("'", 's', 'toolbar'),
#  ('s', 'toolbar', 'has'),
#  ('toolbar', 'has', 'small'),
#  ('has', 'small', 'icons'),
#  ('small', 'icons', 'when'),
#  ('icons', 'when', 'small'),
#  ('when', 'small', 'icons'),
#  ('small', 'icons', 'is'),
#  ('icons', 'is', 'not'),
#  ('is', 'not', 'checked'),
#  ('not', 'checked', 'nightly'),
#  ('checked', 'nightly', 'builds'),
#  ('nightly', 'builds', 'and'),
#  ('builds', 'and', 'tinderboxen'),
#  ('and', 'tinderboxen', 'for'),
#  ('tinderboxen', 'for', 'Phoenix'),
#  ('for', 'Phoenix', 'finish'),
#  ('Phoenix', 'finish', 'tearing'),
#  ('finish', 'tearing', 'prefs'),
#  ('tearing', 'prefs', 'UI'),
#  ('prefs', 'UI', 'to'),
#  ('UI', 'to', 'pieces'),
#  ('to', 'pieces', 'and'),
#  ('pieces', 'and', 'then'),
#  ('and', 'then', 'make'),
#  ('then', 'make', 'it'),
#  ('make', 'it', 'not'),
#  ('it', 'not', 'suck'),
#  ('not', 'suck', '"'),
#  ('suck', '"', 'mozbrowser'),
#  ('"', 'mozbrowser', '"'),
#  ('mozbrowser', '"', 'script'),
#  ('"', 'script', 'doesn'),
#  ('script', 'doesn', "'"),
#  ('doesn', "'", 't'),
#  ("'", 't', 'start'),
#  ('t', 'start', 'correct'),
#  ('start', 'correct', 'binary'),
#  ('correct', 'binary', 'Need'),
#  ('binary', 'Need', 'bookmark'),
#  ('Need', 'bookmark', 'groups'),
#  ('bookmark', 'groups', 'icon'),
#  ('groups', 'icon', 'Dropping'),
#  ('icon', 'Dropping', 'at'),
#  ('Dropping', 'at', 'top'),
#  ('at', 'top', 'of'),
#  ('top', 'of', 'palette'),
#  ('of', 'palette', 'box'),
#  ('palette', 'box', 'horks'),
#  ('box', 'horks', 'things'),
#  ('horks', 'things', 'keyboard'),
#  ('things', 'keyboard', 'shortcut'),
#  ('keyboard', 'shortcut', 'for'),
#  ('shortcut', 'for', 'Increase'),
#  ('for', 'Increase', 'Text'),
#  ('Increase', 'Text', 'Size'),
#  ('Text', 'Size', 'is'),
#  ('Size', 'is', 'broken'),
#  ('is', 'broken', 'default'),
#  ('broken', 'default', 'phoenix'),
#  ('default', 'phoenix', 'bookmarks'),
#  ('phoenix', 'bookmarks', '['),
#  ('bookmarks', '[', 'cust'),
#  ('[', 'cust', ']'),
#  ('cust', ']', 'need'),
#  (']', 'need', 'a'),
#  ('need', 'a', 'toolbar'),
#  ('a', 'toolbar', 'spacer'),
#  ('toolbar', 'spacer', 'and'),
#  ('spacer', 'and', 'spring'),
#  ('and', 'spring', 'spacer'),
#  ('spring', 'spacer', 'for'),
#  ('spacer', 'for', 'customize'),
#  ('for', 'customize', 'Can'),
#  ('customize', 'Can', "'"),
#  ('Can', "'", 't'),
#  ("'", 't', 'launch'),
#  ('t', 'launch', 'phoenix'),
#  ('launch', 'phoenix', 'while'),
#  ('phoenix', 'while', 'Mozilla'),
#  ('while', 'Mozilla', 'is'),
#  ('Mozilla', 'is', 'running'),
#  ('is', 'running', '('),
#  ('running', '(', 'or'),
#  ('(', 'or', 'vice'),
#  ('or', 'vice', 'versa'),
#  ('vice', 'versa', ')'),
#  ('versa', ')', 'separator'),
#  (')', 'separator', 'not'),
#  ('separator', 'not', 'available'),
#  ('not', 'available', 'when'),
#  ('available', 'when', 'all'),
#  ('when', 'all', 'toolbar'),
#  ('all', 'toolbar', 'items'),
#  ('toolbar', 'items', 'are'),
#  ('items', 'are', 'in'),
#  ('are', 'in', 'toolbar'),
#  ('in', 'toolbar', 'layout'),
#  ('toolbar', 'layout', 'history'),
#  ('layout', 'history', 'menu'),
#  ('history', 'menu', 'for'),
#  ('menu', 'for', 'the'),
#  ('for', 'the', 'back'),
#  ('the', 'back', 'buttons'),
#  ('back', 'buttons', 'doesn'),
#  ('buttons', 'doesn', "'"),
#  ('doesn', "'", 't'),
#  ("'", 't', 'work'),
#  ('t', 'work', 'attempting'),
#  ('work', 'attempting', 'to'),
#  ('attempting', 'to', 'open'),
#  ('to', 'open', '"'),
#  ('open', '"', 'back'),
#  ('"', 'back', 'button'),
#  ('back', 'button', 'history'),
#  ('button', 'history', 'menu'),
#  ('history', 'menu', '"'),
#  ('menu', '"', 'in'),
#  ('"', 'in', 'the'),
#  ('in', 'the', 'second'),
#  ('the', 'second', 'window'),
#  ('second', 'window', 'generates'),
#  ('window', 'generates', 'another'),
#  ('generates', 'another', 'back'),
#  ('another', 'back', 'button'),
#  ('back', 'button', 'on'),
#  ('button', 'on', 'the'),
#  ('on', 'the', 'toolbar'),
#  ('the', 'toolbar', 'Phoenix'),
#  ('toolbar', 'Phoenix', 'and'),
#  ('Phoenix', 'and', 'Mozilla'),
#  ('and', 'Mozilla', 'cannot'),
#  ('Mozilla', 'cannot', 'comfortably'),
#  ('cannot', 'comfortably', 'share'),
#  ('comfortably', 'share', 'a'),
#  ('share', 'a', 'source'),
#  ('a', 'source', 'tree'),
#  ('source', 'tree', 'Phoenix'),
#  ('tree', 'Phoenix', 'forgets'),
#  ('Phoenix', 'forgets', 'all'),
#  ('forgets', 'all', 'cookies'),
#  ('all', 'cookies', 'even'),
#  ('cookies', 'even', 'though'),
#  ('even', 'though', '"'),
#  ('though', '"', 'Enable'),
#  ('"', 'Enable', 'cookies'),
#  ('Enable', 'cookies', 'for'),
#  ('cookies', 'for', 'the'),
#  ('for', 'the', 'current'),
#  ('the', 'current', 'session'),
#  ('current', 'session', 'only'),
#  ('session', 'only', '"'),
#  ('only', '"', 'is'),
#  ('"', 'is', 'NOT'),
#  ('is', 'NOT', 'chosen'),
#  ('NOT', 'chosen', 'Starting'),
#  ('chosen', 'Starting', 'Customizing'),
#  ('Starting', 'Customizing', 'Toolbar'),
#  ('Customizing', 'Toolbar', 'makes'),
#  ('Toolbar', 'makes', 'the'),
#  ('makes', 'the', 'current'),
#  ('the', 'current', 'page'),
#  ('current', 'page', 'go'),
#  ('page', 'go', 'blank'),
#  ('go', 'blank', 'Check'),
#  ('blank', 'Check', 'in'),
#  ('Check', 'in', 'Satchel'),
#  ('in', 'Satchel', '('),
#  ('Satchel', '(', 'the'),
#  ('(', 'the', 'successor'),
#  ('the', 'successor', 'to'),
#  ('successor', 'to', 'wallet'),
#  ('to', 'wallet', ')'),
#  ('wallet', ')', 'Mousing'),
#  (')', 'Mousing', 'over'),
#  ('Mousing', 'over', 'back'),
#  ('over', 'back', 'menu'),
#  ('back', 'menu', 'in'),
#  ('menu', 'in', 'second'),
#  ('in', 'second', 'window'),
#  ('second', 'window', 'horks'),
#  ('window', 'horks', 'things'),
#  ('horks', 'things', 'Personal'),
#  ('things', 'Personal', 'toolbar'),
#  ('Personal', 'toolbar', 'needs'),
#  ('toolbar', 'needs', 'a'),
#  ('needs', 'a', 'min'),
#  ('a', 'min', '-'),
#  ('min', '-', 'height'),
#  ('-', 'height', 'to'),
#  ('height', 'to', 'avoid'),
#  ('to', 'avoid', '"'),
#  ('avoid', '"', 'popping'),
#  ('"', 'popping', 'in'),
#  ('popping', 'in', '"'),
#  ('in', '"', 'New'),
#  ('"', 'New', 'Folder'),
#  ('New', 'Folder', '...'),
#  ('Folder', '...', 'in'),
#  ('...', 'in', 'ptoolbar'),
#  ('in', 'ptoolbar', 'context'),
#  ('ptoolbar', 'context', 'menu'),
#  ('context', 'menu', 'is'),
#  ('menu', 'is', 'broken'),
#  ('is', 'broken', 'Implement'),
#  ('broken', 'Implement', 'Mozilla'),
#  ('Implement', 'Mozilla', 'Firebird'),
#  ('Mozilla', 'Firebird', 'Help'),
#  ('Firebird', 'Help', 'tabs'),
#  ('Help', 'tabs', 'close'),
#  ('tabs', 'close', 'in'),
#  ('close', 'in', 'the'),
#  ('in', 'the', 'wrong'),
#  ('the', 'wrong', 'order'),
#  ('wrong', 'order', '('),
#  ('order', '(', 'right'),
#  ('(', 'right', 'to'),
#  ('right', 'to', 'left'),
#  ('to', 'left', ')'),
#  ('left', ')', 'back'),
#  (')', 'back', 'buttons'),
#  ('back', 'buttons', 'and'),
#  ('buttons', 'and', 'context'),
#  ('and', 'context', 'options'),
#  ('context', 'options', 'always'),
#  ('options', 'always', 'disabled'),
#  ('always', 'disabled', '.'),
#  ('disabled', '.', '</s>'),
#  ('.', '</s>', '<s>'),
#  ('</s>', '<s>', 'Customising'),
#  ('<s>', 'Customising', 'toolbar'),
#  ('Customising', 'toolbar', 'breaks'),
#  ('toolbar', 'breaks', 'the'),
#  ('breaks', 'the', 'throbber'),
#  ('the', 'throbber', '!'),
#  ('throbber', '!', '</s>'),
#  ('!', '</s>', '<s>'),
#  ('</s>', '<s>', 'manage'),
#  ('<s>', 'manage', 'bookmarks'),
#  ('manage', 'bookmarks', 'causes'),
#  ('bookmarks', 'causes', 'hang'),
#  ('causes', 'hang', 'land'),
#  ('hang', 'land', 'pch'),
#  ('land', 'pch', "'"),
#  ('pch', "'", 's'),
#  ("'", 's', 'bookmarks'),
#  ('s', 'bookmarks', 'patch'),
#  ('bookmarks', 'patch', 'from'),
#  ('patch', 'from', 'bug'),
#  ('from', 'bug', '160019'),
#  ('bug', '160019', 'Preferences'),
#  ('160019', 'Preferences', '>'),
#  ('Preferences', '>', 'Privacy'),
#  ('>', 'Privacy', '>'),
#  ('Privacy', '>', 'Images'),
#  ('>', 'Images', '=='),
#  ('Images', '==', 'Wonky'),
#  ('==', 'Wonky', 'Extremely'),
#  ('Wonky', 'Extremely', 'high'),
#  ('Extremely', 'high', 'memory'),
#  ('high', 'memory', 'consumption'),
#  ('memory', 'consumption', 'after'),
#  ('consumption', 'after', 'closing'),
#  ('after', 'closing', 'all'),
#  ('closing', 'all', 'windows'),
#  ('all', 'windows', 'with'),
#  ('windows', 'with', 'Quick'),
#  ('with', 'Quick', 'Launch'),
#  ('Quick', 'Launch', '('),
#  ('Launch', '(', 'Turbo'),
#  ('(', 'Turbo', ')'),
#  ('Turbo', ')', 'enabled'),
#  (')', 'enabled', 'Go'),
#  ('enabled', 'Go', 'menu'),
#  ('Go', 'menu', 'needs'),
#  ('menu', 'needs', 'to'),
#  ('needs', 'to', 'have'),
#  ('to', 'have', 'an'),
#  ('have', 'an', 'id'),
#  ('an', 'id', '='),
#  ('id', '=', 'implement'),
#  ('=', 'implement', 'progress'),
#  ('implement', 'progress', 'meter'),
#  ('progress', 'meter', 'in'),
#  ('meter', 'in', 'URLbar'),
#  ('in', 'URLbar', 'view'),
#  ('URLbar', 'view', 'source'),
#  ('view', 'source', 'tries'),
#  ('source', 'tries', 'to'),
#  ('tries', 'to', 'download'),
#  ('to', 'download', 'type'),
#  ('download', 'type', 'application'),
#  ('type', 'application', 'x'),
#  ('application', 'x', '-'),
#  ('x', '-', 'view'),
#  ('-', 'view', '-'),
#  ('view', '-', 'source'),
#  ('-', 'source', 'from'),
#  ('source', 'from', 'view'),
#  ('from', 'view', '-'),
#  ('view', '-', 'source'),
#  ('-', 'source', ':<'),
#  ('source', ':<', 'url'),
#  (':<', 'url', '>'),
#  ('url', '>', 'second'),
#  ('>', 'second', 'window'),
#  ('second', 'window', 'opens'),
#  ('window', 'opens', 'mozilla'),
#  ('opens', 'mozilla', 'fix'),
#  ('mozilla', 'fix', 'branding'),
#  ('fix', 'branding', 'auto'),
#  ('branding', 'auto', 'close'),
#  ('auto', 'close', 'for'),
#  ('close', 'for', 'download'),
#  ('for', 'download', 'manager'),
#  ('download', 'manager', 'would'),
#  ('manager', 'would', 'be'),
#  ('would', 'be', 'nice'),
#  ('be', 'nice', 'Components'),
#  ('nice', 'Components', 'of'),
#  ('Components', 'of', 'the'),
#  ('of', 'the', 'Navigation'),
#  ('the', 'Navigation', 'Toolbar'),
#  ('Navigation', 'Toolbar', 'do'),
#  ('Toolbar', 'do', 'not'),
#  ('do', 'not', 'appear'),
#  ('not', 'appear', 'with'),
#  ('appear', 'with', 'the'),
#  ('with', 'the', 'Modern'),
#  ('the', 'Modern', 'theme'),
#  ('Modern', 'theme', '.'),
#  ('theme', '.', '</s>'),
#  ('.', '</s>', '<s>'),
#  ('</s>', '<s>', 'Pop'),
#  ('<s>', 'Pop', 'up'),
#  ('Pop', 'up', 'window'),
#  ('up', 'window', 'blocking'),
#  ('window', 'blocking', 'Uabar'),
#  ('blocking', 'Uabar', 'doesn'),
#  ('Uabar', 'doesn', "'"),
#  ('doesn', "'", 't'),
#  ("'", 't', 'work'),
#  ('t', 'work', 'Theme'),
#  ('work', 'Theme', 'changes'),
#  ('Theme', 'changes', 'will'),
#  ('changes', 'will', 'take'),
#  ('will', 'take', 'effect'),
#  ('take', 'effect', 'when'),
#  ('effect', 'when', 'you'),
#  ('when', 'you', 'restart'),
#  ('you', 'restart', '_Mozilla_'),
#  ('restart', '_Mozilla_', '.'),
#  ('_Mozilla_', '.', '</s>'),
#  ('.', '</s>', '<s>'),
#  ('</s>', '<s>', 'Need'),
#  ('<s>', 'Need', 'large'),
#  ('Need', 'large', 'icons'),
#  ('large', 'icons', 'for'),
#  ('icons', 'for', 'the'),
#  ('for', 'the', 'Options'),
#  ('the', 'Options', 'menu'),
#  ('Options', 'menu', 'Enable'),
#  ('menu', 'Enable', 'images'),
#  ('Enable', 'images', 'cannot'),
#  ('images', 'cannot', 'be'),
#  ('cannot', 'be', 'used'),
#  ('be', 'used', 'to'),
#  ('used', 'to', 'disable'),
#  ('to', 'disable', 'the'),
#  ('disable', 'the', 'display'),
#  ('the', 'display', 'of'),
#  ('display', 'of', 'images'),
#  ('of', 'images', '.'),
#  ('images', '.', '</s>'),
#  ('.', '</s>', '<s>'),
#  ('</s>', '<s>', 'The'),
#  ('<s>', 'The', 'bookmark'),
#  ('The', 'bookmark', 'tree'),
#  ('bookmark', 'tree', 'jumps'),
#  ('tree', 'jumps', 'unexpectedly'),
#  ('jumps', 'unexpectedly', 'to'),
#  ('unexpectedly', 'to', 'the'),
#  ('to', 'the', 'bottom'),
#  ('the', 'bottom', 'of'),
#  ('bottom', 'of', 'its'),
#  ('of', 'its', 'view'),
#  ('its', 'view', 'when'),
#  ('view', 'when', 'the'),
#  ('when', 'the', 'the'),
#  ('the', 'the', 'first'),
#  ('the', 'first', 'visible'),
#  ('first', 'visible', 'row'),
#  ('visible', 'row', 'is'),
#  ('row', 'is', 'not'),
#  ('is', 'not', 'the'),
#  ('not', 'the', 'first'),
#  ('the', 'first', 'one'),
#  ('first', 'one', 'Move'),
#  ('one', 'Move', 'bookmarks'),
#  ('Move', 'bookmarks', 'transactions'),
#  ('bookmarks', 'transactions', 'into'),
#  ('transactions', 'into', 'a'),
#  ('into', 'a', 'JS'),
#  ('a', 'JS', 'service'),
#  ('JS', 'service', '('),
#  ('service', '(', 'adding'),
#  ('(', 'adding', 'a'),
#  ('adding', 'a', 'bookmark'),
#  ('a', 'bookmark', 'leaks'),
#  ('bookmark', 'leaks', 'the'),
#  ('leaks', 'the', 'Add'),
#  ('the', 'Add', 'Bookmark'),
#  ('Add', 'Bookmark', 'dialog'),
#  ('Bookmark', 'dialog', ')'),
#  ('dialog', ')', 'Shortcut'),
#  (')', 'Shortcut', 'Ctrl'),
#  ('Shortcut', 'Ctrl', '-'),
#  ('Ctrl', '-', 'Y'),
#  ('-', 'Y', '('),
#  ('Y', '(', 'redo'),
#  ('(', 'redo', ')'),
#  ('redo', ')', 'does'),
#  (')', 'does', 'not'),
#  ('does', 'not', 'work'),
#  ('not', 'work', 'in'),
#  ('work', 'in', 'Bookmarks'),
#  ('in', 'Bookmarks', 'Manager'),
#  ('Bookmarks', 'Manager', 'Eradicate'),
#  ('Manager', 'Eradicate', 'AddBookmarkImmediately'),
#  ('Eradicate', 'AddBookmarkImmediately', 'Deleting'),
#  ('AddBookmarkImmediately', 'Deleting', 'a'),
#  ('Deleting', 'a', 'selection'),
#  ('a', 'selection', 'should'),
#  ('selection', 'should', 'select'),
#  ('should', 'select', 'the'),
#  ('select', 'the', 'next'),
#  ('the', 'next', 'item'),
#  ('next', 'item', 'transaction'),
#  ('item', 'transaction', 'manager'),
#  ('transaction', 'manager', 'does'),
#  ('manager', 'does', 'not'),
#  ('does', 'not', 'handle'),
#  ('not', 'handle', 'import'),
#  ('handle', 'import', 'customize'),
#  ('import', 'customize', 'toolbar'),
#  ('customize', 'toolbar', 'clears'),
#  ('toolbar', 'clears', 'URL'),
#  ('clears', 'URL', '3'),
#  ('URL', '3', '.'),
#  ('3', '.', '2'),
#  ('.', '2', '%'),
#  ('2', '%', 'increase'),
#  ('%', 'increase', 'in'),
#  ('increase', 'in', 'Phoenix'),
#  ('in', 'Phoenix', 'Ts'),
#  ('Phoenix', 'Ts', 'after'),
#  ('Ts', 'after', 'bookmark'),
#  ('after', 'bookmark', 'landing'),
#  ('bookmark', 'landing', 'cannot'),
#  ('landing', 'cannot', 'close'),
#  ('cannot', 'close', 'folder'),
#  ('close', 'folder', 'with'),
#  ('folder', 'with', 'single'),
#  ('with', 'single', 'click'),
#  ('single', 'click', 'on'),
#  ('click', 'on', 'twistie'),
#  ('on', 'twistie', 'Pref'),
#  ('twistie', 'Pref', 'UI'),
#  ('Pref', 'UI', 'to'),
#  ('UI', 'to', 'specify'),
#  ('to', 'specify', 'a'),
#  ('specify', 'a', 'proxy'),
#  ('a', 'proxy', 'server'),
#  ('proxy', 'server', 'for'),
#  ('server', 'for', 'web'),
#  ('for', 'web', 'navigation'),
#  ('web', 'navigation', 'Implement'),
#  ('navigation', 'Implement', 'improved'),
#  ('Implement', 'improved', 'Implement'),
#  ('improved', 'Implement', 'global'),
#  ('Implement', 'global', 'Go'),
#  ('global', 'Go', 'menu'),
#  ('Go', 'menu', 'Readd'),
#  ('menu', 'Readd', 'Open'),
#  ('Readd', 'Open', 'Location'),
#  ('Open', 'Location', 'Need'),
#  ('Location', 'Need', 'tab'),
#  ('Need', 'tab', 'loading'),
#  ('tab', 'loading', 'icon'),
#  ('loading', 'icon', 'first'),
#  ('icon', 'first', 'Mozilla'),
#  ('first', 'Mozilla', 'Firefox'),
#  ('Mozilla', 'Firefox', 'window'),
#  ('Firefox', 'window', 'ignored'),
#  ('window', 'ignored', 'by'),
#  ('ignored', 'by', 'nsIWindowMediator'),
#  ('by', 'nsIWindowMediator', 'first'),
#  ('nsIWindowMediator', 'first', 'Phoenix'),
#  ('first', 'Phoenix', 'window'),
#  ('Phoenix', 'window', 'ignored'),
#  ('window', 'ignored', 'by'),
#  ('ignored', 'by', 'nsIWindowMediator'),
#  ('by', 'nsIWindowMediator', 'preferences'),
#  ('nsIWindowMediator', 'preferences', 'no'),
#  ('preferences', 'no', 'longer'),
#  ('no', 'longer', 'works'),
#  ('longer', 'works', 'Open'),
#  ('works', 'Open', 'Personal'),
#  ('Open', 'Personal', 'Toolbar'),
#  ('Personal', 'Toolbar', 'folder'),
#  ('Toolbar', 'folder', 'in'),
#  ('folder', 'in', 'toolbar'),
#  ('in', 'toolbar', 'web'),
#  ('toolbar', 'web', 'search'),
#  ('web', 'search', 'for'),
#  ('search', 'for', '""'),
#  ('for', '""', 'in'),
#  ('""', 'in', 'context'),
#  ('in', 'context', 'menu'),
#  ('context', 'menu', 'don'),
#  ('menu', 'don', "'"),
#  ('don', "'", 't'),
#  ("'", 't', 'work'),
#  ('t', 'work', 'Fix'),
#  ('work', 'Fix', 'full'),
#  ('Fix', 'full', 'screen'),
#  ('full', 'screen', 'to'),
#  ('screen', 'to', 'have'),
#  ('to', 'have', 'smaller'),
#  ('have', 'smaller', 'icons'),
#  ('smaller', 'icons', 'Port'),
#  ('icons', 'Port', 'patch'),
#  ('Port', 'patch', 'to'),
#  ('patch', 'to', 'bug'),
#  ('to', 'bug', '164006'),
#  ('bug', '164006', '('),
#  ('164006', '(', 'wyciwyg'),
#  ('(', 'wyciwyg', ':'),
#  ('wyciwyg', ':', 'in'),
#  (':', 'in', 'tab'),
#  ('in', 'tab', 'titles'),
#  ('tab', 'titles', ')'),
#  ('titles', ')', '['),
#  (')', '[', 'cust'),
#  ('[', 'cust', ']'),
#  ('cust', ']', 'Add'),
#  (']', 'Add', 'more'),
#  ('Add', 'more', 'off'),
#  ('more', 'off', '-'),
#  ('off', '-', 'by'),
#  ('-', 'by', '-'),
#  ('by', '-', 'default'),
#  ('-', 'default', 'toolbar'),
#  ('default', 'toolbar', 'buttons'),
#  ('toolbar', 'buttons', 'textmode'),
#  ('buttons', 'textmode', 'buttons'),
#  ('textmode', 'buttons', 'need'),
#  ('buttons', 'need', 'hover'),
#  ('need', 'hover', 'state'),
#  ('hover', 'state', 'enable'),
#  ('state', 'enable', 'nsITheme'),
#  ('enable', 'nsITheme', 'form'),
#  ('nsITheme', 'form', 'control'),
#  ('form', 'control', 'goodness'),
#  ('control', 'goodness', 'for'),
#  ('goodness', 'for', 'Phoenix'),
#  ('for', 'Phoenix', 'rename'),
#  ('Phoenix', 'rename', 'executable'),
#  ('rename', 'executable', 'and'),
#  ('executable', 'and', 'profile'),
#  ('and', 'profile', 'dir'),
#  ('profile', 'dir', 'Need'),
#  ('dir', 'Need', 'to'),
#  ('Need', 'to', 'enable'),
#  ('to', 'enable', 'wallet'),
#  ('enable', 'wallet', '('),
#  ('wallet', '(', 'password'),
#  ('(', 'password', 'manager'),
#  ('password', 'manager', 'manager'),
#  ('manager', 'manager', 'manager'),
#  ('manager', 'manager', ')'),
#  ('manager', ')', 'New'),
#  (')', 'New', 'Extension'),
#  ('New', 'Extension', 'Manager'),
#  ('Extension', 'Manager', 'the'),
#  ('Manager', 'the', 'changes'),
#  ('the', 'changes', 'to'),
#  ('changes', 'to', 'mozbrowser'),
#  ('to', 'mozbrowser', 'too'),
#  ('mozbrowser', 'too', 'confusing'),
#  ('too', 'confusing', 'and'),
#  ('confusing', 'and', 'too'),
#  ('and', 'too', 'much'),
#  ('too', 'much', 'Missing'),
#  ('much', 'Missing', 'proxy'),
#  ('Missing', 'proxy', 'image'),
#  ('proxy', 'image', 'Cannot'),
#  ('image', 'Cannot', 'File'),
#  ('Cannot', 'File', '>'),
#  ('File', '>', 'New'),
#  ('>', 'New', 'Bookmark'),
#  ('New', 'Bookmark', 'while'),
#  ('Bookmark', 'while', 'managing'),
#  ('while', 'managing', 'a'),
#  ('managing', 'a', 'new'),
#  ('a', 'new', 'folder'),
#  ('new', 'folder', 'Bookmarks'),
#  ('folder', 'Bookmarks', 'are'),
#  ('Bookmarks', 'are', 'not'),
#  ('are', 'not', 'loaded'),
#  ('not', 'loaded', 'if'),
#  ('loaded', 'if', 'the'),
#  ('if', 'the', 'Personal'),
#  ('the', 'Personal', 'Toolbar'),
#  ('Personal', 'Toolbar', 'is'),
#  ('Toolbar', 'is', 'switched'),
#  ('is', 'switched', 'off'),
#  ('switched', 'off', 'Pretty'),
#  ('off', 'Pretty', 'up'),
#  ('Pretty', 'up', 'dns'),
#  ('up', 'dns', 'error'),
#  ('dns', 'error', 'page'),
#  ('error', 'page', 'a'),
#  ('page', 'a', 'bit'),
#  ('a', 'bit', 'middle'),
#  ('bit', 'middle', 'click'),
#  ('middle', 'click', '('),
#  ('click', '(', 'pt'),
#  ('(', 'pt', '+'),
#  ('pt', '+', 'bookmark'),
#  ('+', 'bookmark', 'menu'),
#  ('bookmark', 'menu', ')'),
#  ('menu', ')', 'loads'),
#  (')', 'loads', 'in'),
#  ('loads', 'in', 'the'),
#  ('in', 'the', 'current'),
#  ('the', 'current', 'tab'),
#  ('current', 'tab', '+'),
#  ('tab', '+', 'new'),
#  ('+', 'new', 'tab'),
#  ('new', 'tab', 'Nightly'),
#  ('tab', 'Nightly', 'for'),
#  ('Nightly', 'for', '22'),
#  ('for', '22', 'Sept'),
#  ('22', 'Sept', 'displays'),
#  ('Sept', 'displays', 'page'),
#  ('displays', 'page', 'details'),
#  ('page', 'details', 'above'),
#  ('details', 'above', 'window'),
#  ('above', 'window', 'Ctrl'),
#  ('window', 'Ctrl', '-'),
#  ('Ctrl', '-', 'W'),
#  ('-', 'W', 'does'),
#  ('W', 'does', 'not'),
#  ('does', 'not', 'close'),
#  ('not', 'close', 'the'),
#  ('close', 'the', 'current'),
#  ('the', 'current', 'tab'),
#  ('current', 'tab', 'listboxes'),
#  ('tab', 'listboxes', 'and'),
#  ('listboxes', 'and', 'tree'),
#  ('and', 'tree', 'views'),
#  ('tree', 'views', 'don'),
#  ('views', 'don', "'"),
#  ('don', "'", 't'),
#  ("'", 't', 'support'),
#  ('t', 'support', 'themes'),
#  ('support', 'themes', 'on'),
#  ('themes', 'on', 'winxp'),
#  ('on', 'winxp', 'Ctrl'),
#  ('winxp', 'Ctrl', '+'),
#  ('Ctrl', '+', 'Mousewheel'),
#  ('+', 'Mousewheel', 'should'),
#  ('Mousewheel', 'should', 'resize'),
#  ('should', 'resize', 'text'),
#  ('resize', 'text', 'bookmarks'),
#  ('text', 'bookmarks', 'should'),
#  ('bookmarks', 'should', 'import'),
#  ('should', 'import', 'Mozilla'),
#  ('import', 'Mozilla', "'"),
#  ('Mozilla', "'", 's'),
#  ("'", 's', 'bookmarks'),
#  ('s', 'bookmarks', 'Please'),
#  ('bookmarks', 'Please', 'tell'),
#  ('Please', 'tell', 'people'),
#  ('tell', 'people', 'to'),
#  ('people', 'to', 'use'),
#  ('to', 'use', 'a'),
#  ('use', 'a', 'new'),
#  ('a', 'new', 'profile'),
#  ('new', 'profile', '.'),
#  ('profile', '.', '</s>'),
#  ('.', '</s>', '<s>'),
#  ('</s>', '<s>', 'combine'),
#  ('<s>', 'combine', 'links'),
#  ('combine', 'links', '+'),
#  ('links', '+', 'toolbar'),
#  ('+', 'toolbar', 'File'),
#  ('toolbar', 'File', '|'),
#  ('File', '|', 'Import'),
#  ('|', 'Import', '...'),
#  ('Import', '...', 'does'),
#  ('...', 'does', 'not'),
#  ('does', 'not', 'work'),
#  ('not', 'work', 'cannot'),
#  ('work', 'cannot', 'import'),
#  ('cannot', 'import', '4'),
#  ('import', '4', '.'),
#  ('4', '.', 'x'),
#  ('.', 'x', 'About'),
#  ('x', 'About', 'dialog'),
#  ('About', 'dialog', 'weirdness'),
#  ('dialog', 'weirdness', 'Context'),
#  ('weirdness', 'Context', 'menu'),
#  ('Context', 'menu', 'doesn'),
#  ('menu', 'doesn', "'"),
#  ('doesn', "'", 't'),
#  ("'", 't', 'appear'),
#  ('t', 'appear', 'when'),
#  ('appear', 'when', 'right'),
#  ('when', 'right', 'clicking'),
#  ('right', 'clicking', 'on'),
#  ('clicking', 'on', 'disabled'),
#  ('on', 'disabled', 'forward'),
#  ('disabled', 'forward', 'or'),
#  ('forward', 'or', 'back'),
#  ('or', 'back', 'can'),
#  ('back', 'can', "'"),
#  ('can', "'", 't'),
#  ("'", 't', 'specify'),
#  ('t', 'specify', 'cookie'),
#  ('specify', 'cookie', 'details'),
#  ('cookie', 'details', 'Proxy'),
#  ('details', 'Proxy', 'settings'),
#  ('Proxy', 'settings', 'in'),
#  ('settings', 'in', 'prefs'),
#  ('in', 'prefs', '.'),
#  ('prefs', '.', 'js'),
#  ('.', 'js', 'seem'),
#  ('js', 'seem', 'to'),
#  ('seem', 'to', 'be'),
#  ('to', 'be', 'ignored'),
#  ('be', 'ignored', '...'),
#  ('ignored', '...', '</s>'),
#  ('...', '</s>', '<s>'),
#  ('</s>', '<s>', 'Incorrectly'),
#  ('<s>', 'Incorrectly', 'renders'),
#  ('Incorrectly', 'renders', 'various'),
#  ('renders', 'various', 'web'),
#  ('various', 'web', 'pages'),
#  ('web', 'pages', 'Window'),
#  ('pages', 'Window', 'won'),
#  ('Window', 'won', "'"),
#  ('won', "'", 't'),
#  ("'", 't', 'show'),
#  ('t', 'show', 'completely'),
#  ('show', 'completely', 'Can'),
#  ('completely', 'Can', "'"),
#  ('Can', "'", 't'),
#  ("'", 't', 'change'),
#  ('t', 'change', 'privacy'),
#  ('change', 'privacy', 'settings'),
#  ('privacy', 'settings', '['),
#  ('settings', '[', 'Moz'),
#  ('[', 'Moz', ']'),
#  ('Moz', ']', 'Cannot'),
#  (']', 'Cannot', 'set'),
#  ('Cannot', 'set', '"'),
#  ('set', '"', 'Imported'),
#  ('"', 'Imported', 'IE'),
#  ('Imported', 'IE', 'Favorites'),
#  ('IE', 'Favorites', '"'),
#  ('Favorites', '"', 'to'),
#  ('"', 'to', 'default'),
#  ('to', 'default', 'personal'),
#  ('default', 'personal', 'toolbar'),
#  ('personal', 'toolbar', 'folder'),
#  ('toolbar', 'folder', 'pheonix'),
#  ('folder', 'pheonix', 'Need'),
#  ('pheonix', 'Need', 'smaller'),
#  ('Need', 'smaller', 'throbber'),
#  ('smaller', 'throbber', 'to'),
#  ('throbber', 'to', 'use'),
#  ('to', 'use', 'with'),
#  ('use', 'with', 'small'),
#  ('with', 'small', 'icons'),
#  ('small', 'icons', 'Blank'),
#  ('icons', 'Blank', 'URL'),
#  ('Blank', 'URL', 'bar'),
#  ('URL', 'bar', 'after'),
#  ('bar', 'after', 'using'),
#  ('after', 'using', 'Customize'),
#  ('using', 'Customize', 'Toolbar'),
#  ('Customize', 'Toolbar', 'Mousewheel'),
#  ('Toolbar', 'Mousewheel', 'does'),
#  ('Mousewheel', 'does', 'not'),
#  ('does', 'not', 'scroll'),
#  ('not', 'scroll', 'web'),
#  ('scroll', 'web', 'page'),
#  ('web', 'page', 'ctrl'),
#  ('page', 'ctrl', '+'),
#  ('ctrl', '+', 'tab'),
#  ('+', 'tab', 'should'),
#  ('tab', 'should', 'switch'),
#  ('should', 'switch', 'tabs'),
#  ('switch', 'tabs', 'in'),
#  ('tabs', 'in', 'browser'),
#  ('in', 'browser', 'favicon'),
#  ('browser', 'favicon', '.'),
#  ('favicon', '.', 'ico'),
#  ('.', 'ico', 'colors'),
#  ('ico', 'colors', 'render'),
#  ('colors', 'render', 'improperly'),
#  ('render', 'improperly', 'in'),
#  ('improperly', 'in', 'tabs'),
#  ('in', 'tabs', 'and'),
#  ('tabs', 'and', 'URL'),
#  ('and', 'URL', 'bar'),
#  ('URL', 'bar', '-'),
#  ('bar', '-', 'remote'),
#  ('-', 'remote', 'openurl'),
#  ('remote', 'openurl', '()'),
#  ('openurl', '()', 'opens'),
#  ('()', 'opens', 'Mozilla'),
#  ('opens', 'Mozilla', 'window'),
#  ('Mozilla', 'window', 'if'),
#  ('window', 'if', 'Mozilla'),
#  ('if', 'Mozilla', 'is'),
#  ('Mozilla', 'is', 'running'),
#  ('is', 'running', 'make'),
#  ('running', 'make', 'preferences'),
#  ('make', 'preferences', 'resizable'),
#  ('preferences', 'resizable', 'Scroll'),
#  ('resizable', 'Scroll', 'bar'),
#  ('Scroll', 'bar', 'becomes'),
#  ('bar', 'becomes', 'blank'),
#  ('becomes', 'blank', 'fix'),
#  ('blank', 'fix', 'addressbar'),
#  ('fix', 'addressbar', 'dropdown'),
#  ('addressbar', 'dropdown', 'icon'),
#  ('dropdown', 'icon', 'for'),
#  ('icon', 'for', 'linux'),
#  ('for', 'linux', '.'),
#  ('linux', '.', '</s>'),
#  ('.', '</s>', '<s>'),
#  ('</s>', '<s>', '"'),
#  ('<s>', '"', 'Find'),
#  ('"', 'Find', 'Next'),
#  ('Find', 'Next', '"'),
#  ('Next', '"', 'button'),
#  ('"', 'button', 'doesn'),
#  ('button', 'doesn', "'"),
#  ('doesn', "'", 't'),
#  ("'", 't', 'always'),
#  ('t', 'always', 'respond'),
#  ('always', 'respond', 'to'),
#  ('respond', 'to', 'Enter'),
#  ('to', 'Enter', 'Ctrl'),
#  ('Enter', 'Ctrl', '+'),
#  ('Ctrl', '+', 'Mousewheel'),
#  ('+', 'Mousewheel', 'should'),
#  ('Mousewheel', 'should', 'cycle'),
#  ('should', 'cycle', 'tabs'),
#  ('cycle', 'tabs', 'A'),
#  ('tabs', 'A', 'new'),
#  ('A', 'new', 'icon'),
#  ('new', 'icon', 'for'),
#  ('icon', 'for', 'Firebird'),
#  ('for', 'Firebird', '2nd'),
#  ('Firebird', '2nd', 'Copy'),
#  ('2nd', 'Copy', 'won'),
#  ('Copy', 'won', "'"),
#  ('won', "'", 't'),
#  ("'", 't', 'load'),
#  ('t', 'load', 'with'),
#  ('load', 'with', 'same'),
#  ('with', 'same', 'profile'),
#  ('same', 'profile', 'width'),
#  ('profile', 'width', 'of'),
#  ('width', 'of', 'table'),
#  ('of', 'table', 'containing'),
#  ('table', 'containing', 'text'),
#  ('containing', 'text', 'being'),
#  ('text', 'being', 'handled'),
#  ('being', 'handled', 'incorrectly'),
#  ('handled', 'incorrectly', '('),
#  ('incorrectly', '(', 'multiple'),
#  ('(', 'multiple', 'screenwidths'),
#  ('multiple', 'screenwidths', 'wide'),
#  ('screenwidths', 'wide', ')'),
#  ('wide', ')', 'accessing'),
#  (')', 'accessing', '"'),
#  ('accessing', '"', 'navigator'),
#  ('"', 'navigator', '.'),
#  ('navigator', '.', 'cookieEnabled'),
#  ('.', 'cookieEnabled', '"'),
#  ('cookieEnabled', '"', 'produces'),
#  ('"', 'produces', '"'),
#  ('produces', '"', 'uncaught'),
#  ('"', 'uncaught', 'exception'),
#  ('uncaught', 'exception', '"'),
#  ('exception', '"', 'Need'),
#  ('"', 'Need', 'Mozilla'),
#  ('Need', 'Mozilla', 'Firebird'),
#  ('Mozilla', 'Firebird', 'newsgroup'),
#  ('Firebird', 'newsgroup', 'Revive'),
#  ('newsgroup', 'Revive', 'XUL'),
#  ('Revive', 'XUL', 'preprocessor'),
#  ('XUL', 'preprocessor', 'Phoenix'),
#  ('preprocessor', 'Phoenix', 'needs'),
#  ('Phoenix', 'needs', 'talkback'),
#  ('needs', 'talkback', 'Navigation'),
#  ...]

# %% [markdown]
# ### Testing trained data using Brown, Webtext and Reuters corpus

# %%
from random import sample

# %%
#Brown corpus

sentence_brown = ""

# for i in range(3):
#   sentence_brown += brown_corpus[i]

sentence_brown = sample(brown_corpus, 5)

# %%
#Webtext corpus

sentence_webtext = ""

sentence_webtext = sample(webtext_corpus, 5)

# %%
perplexity_bigrams(sentence_brown[0], cp_brown, bgrams_brown_wc, brown_wc, V_brown)
# Out:
# 2027.6832677329162

# %%
perplexity_bigrams(sentence_webtext[0], cp_webtext, bgrams_webtext_wc, webtext_wc, V_webtext)
# Out:
# 324.2753109594715

# %%
perplexity_trigrams(sentence_brown[0], cp_t_brown, trigrams_brown_wc, bgrams_brown_wc, V_brown)
# Out:
# 5907.899592583485

# %%
perplexity_trigrams(sentence_webtext[0], cp_t_webtext, trigrams_webtext, bgrams_webtext, V_webtext)
# Out:
# 1703.6000234506382

# %%
#Reuters corpus

sentence_reuters = ""

sentence_reuters = sample(webtext_corpus, 25)

# %%
#Bigrams

perplexity_reuters_brown = []
perplexity_reuters_webtext = []

for sent in sentence_reuters:
  perplexity_reuters_brown.append(perplexity_bigrams(sent, cp_brown, bgrams_brown_wc, brown_wc, V_brown))
  perplexity_reuters_webtext.append(perplexity_bigrams(sent, cp_webtext, bgrams_webtext_wc, webtext_wc, V_webtext))

print("BIGRAMS")
print("For brown corpus - ", sum(perplexity_reuters_brown)/len(perplexity_reuters_brown))
print("For webtext corpus - ", sum(perplexity_reuters_webtext)/len(perplexity_reuters_webtext))
# Out:
# BIGRAMS
# For brown corpus -  7184.086475265947
# For webtext corpus -  874.4615084977543

# %%
#Trigrams

perplexity_reuters_brown = []
perplexity_reuters_webtext = []

for sent in sentence_reuters:
  perplexity_reuters_brown.append(perplexity_trigrams(sent, cp_t_brown, trigrams_brown_wc, bgrams_brown_wc, V_brown))
  perplexity_reuters_webtext.append(perplexity_trigrams(sent, cp_t_webtext, trigrams_webtext_wc, bgrams_webtext_wc, V_webtext))

print("TRIGRAMS")
print("For brown corpus - ", sum(perplexity_reuters_brown)/len(perplexity_reuters_brown))
print("For webtext corpus - ", sum(perplexity_reuters_webtext)/len(perplexity_reuters_webtext))
# Out:
# TRIGRAMS
# For brown corpus -  14132.009282947682
# For webtext corpus -  2793.3643862436434
